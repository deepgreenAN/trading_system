# %% [markdown]
# # CSV・APIを用いて休日データを取得

# %% [markdown]
# [内閣府のサイト](https://www8.cao.go.jp/chosei/shukujitsu/gaiyou.html)と
# [日本の祝日API](https://holidays-jp.github.io/)を利用して振替休日を含んだデータをCSVファイルとして取得する．あるいはデータをひとまとめにしてCSVとして保存する．二つのフォーマットが少し異なるのと，振替休日の表記が異なることに注意
#
# 結果として，適切なフォーマットにして保存するプログラムにする．

# %%
import requests
from pathlib import Path
import pandas as pd
import datetime
import time
import io
import jpholiday
import numpy as np

# %% [markdown]
# ## 内閣府のサイトから休日データを取得する

# %% [markdown]
# ### データを取得してみる

# %% [markdown]
# requestによってcsvをメモリ上に保存し，pandas.Dataframeで取得している．このcsvを実際に開いてみれば分かるが，日付フォーマットが特殊(ex. 2020/1/1)なのでパースする必要がある．

# %%
url = "https://www8.cao.go.jp/chosei/shukujitsu/syukujitsu.csv"
req = requests.get(url)

csv_bin = io.BytesIO(req.content)

# %%
my_parser = lambda date: datetime.datetime.strptime(date, "%Y/%m/%d")

# %%
holiday_df_csv = pd.read_csv(csv_bin,
                             names=["date", "holiday_name"],
                             index_col="date",
                             parse_dates=True,
                             date_parser=my_parser,
                             header=0,
                             encoding="shift-jis"
                            )
holiday_df_csv
# Out:
#            holiday_name
# date
# 1955-01-01           元日
# 1955-01-15         成人の日
# 1955-03-21         春分の日
# 1955-04-29        天皇誕生日
# 1955-05-03        憲法記念日
# ...                 ...
# 2022-09-19         敬老の日
# 2022-09-23         秋分の日
# 2022-10-10       スポーツの日
# 2022-11-03         文化の日
# 2022-11-23       勤労感謝の日
#
# [975 rows x 1 columns]

# %%
holiday_df_csv.index.date
# Out:
# array([datetime.date(1955, 1, 1), datetime.date(1955, 1, 15),
#        datetime.date(1955, 3, 21), datetime.date(1955, 4, 29),
#        datetime.date(1955, 5, 3), datetime.date(1955, 5, 5),
#        datetime.date(1955, 9, 24), datetime.date(1955, 11, 3),
#        datetime.date(1955, 11, 23), datetime.date(1956, 1, 1),
#        datetime.date(1956, 1, 15), datetime.date(1956, 3, 21),
#        datetime.date(1956, 4, 29), datetime.date(1956, 5, 3),
#        datetime.date(1956, 5, 5), datetime.date(1956, 9, 23),
#        datetime.date(1956, 11, 3), datetime.date(1956, 11, 23),
#        datetime.date(1957, 1, 1), datetime.date(1957, 1, 15),
#        datetime.date(1957, 3, 21), datetime.date(1957, 4, 29),
#        datetime.date(1957, 5, 3), datetime.date(1957, 5, 5),
#        datetime.date(1957, 9, 23), datetime.date(1957, 11, 3),
#        datetime.date(1957, 11, 23), datetime.date(1958, 1, 1),
#        datetime.date(1958, 1, 15), datetime.date(1958, 3, 21),
#        datetime.date(1958, 4, 29), datetime.date(1958, 5, 3),
#        datetime.date(1958, 5, 5), datetime.date(1958, 9, 23),
#        datetime.date(1958, 11, 3), datetime.date(1958, 11, 23),
#        datetime.date(1959, 1, 1), datetime.date(1959, 1, 15),
#        datetime.date(1959, 3, 21), datetime.date(1959, 4, 10),
#        datetime.date(1959, 4, 29), datetime.date(1959, 5, 3),
#        datetime.date(1959, 5, 5), datetime.date(1959, 9, 24),
#        datetime.date(1959, 11, 3), datetime.date(1959, 11, 23),
#        datetime.date(1960, 1, 1), datetime.date(1960, 1, 15),
#        datetime.date(1960, 3, 20), datetime.date(1960, 4, 29),
#        datetime.date(1960, 5, 3), datetime.date(1960, 5, 5),
#        datetime.date(1960, 9, 23), datetime.date(1960, 11, 3),
#        datetime.date(1960, 11, 23), datetime.date(1961, 1, 1),
#        datetime.date(1961, 1, 15), datetime.date(1961, 3, 21),
#        datetime.date(1961, 4, 29), datetime.date(1961, 5, 3),
#        datetime.date(1961, 5, 5), datetime.date(1961, 9, 23),
#        datetime.date(1961, 11, 3), datetime.date(1961, 11, 23),
#        datetime.date(1962, 1, 1), datetime.date(1962, 1, 15),
#        datetime.date(1962, 3, 21), datetime.date(1962, 4, 29),
#        datetime.date(1962, 5, 3), datetime.date(1962, 5, 5),
#        datetime.date(1962, 9, 23), datetime.date(1962, 11, 3),
#        datetime.date(1962, 11, 23), datetime.date(1963, 1, 1),
#        datetime.date(1963, 1, 15), datetime.date(1963, 3, 21),
#        datetime.date(1963, 4, 29), datetime.date(1963, 5, 3),
#        datetime.date(1963, 5, 5), datetime.date(1963, 9, 24),
#        datetime.date(1963, 11, 3), datetime.date(1963, 11, 23),
#        datetime.date(1964, 1, 1), datetime.date(1964, 1, 15),
#        datetime.date(1964, 3, 20), datetime.date(1964, 4, 29),
#        datetime.date(1964, 5, 3), datetime.date(1964, 5, 5),
#        datetime.date(1964, 9, 23), datetime.date(1964, 11, 3),
#        datetime.date(1964, 11, 23), datetime.date(1965, 1, 1),
#        datetime.date(1965, 1, 15), datetime.date(1965, 3, 21),
#        datetime.date(1965, 4, 29), datetime.date(1965, 5, 3),
#        datetime.date(1965, 5, 5), datetime.date(1965, 9, 23),
#        datetime.date(1965, 11, 3), datetime.date(1965, 11, 23),
#        datetime.date(1966, 1, 1), datetime.date(1966, 1, 15),
#        datetime.date(1966, 3, 21), datetime.date(1966, 4, 29),
#        datetime.date(1966, 5, 3), datetime.date(1966, 5, 5),
#        datetime.date(1966, 9, 15), datetime.date(1966, 9, 23),
#        datetime.date(1966, 10, 10), datetime.date(1966, 11, 3),
#        datetime.date(1966, 11, 23), datetime.date(1967, 1, 1),
#        datetime.date(1967, 1, 15), datetime.date(1967, 2, 11),
#        datetime.date(1967, 3, 21), datetime.date(1967, 4, 29),
#        datetime.date(1967, 5, 3), datetime.date(1967, 5, 5),
#        datetime.date(1967, 9, 15), datetime.date(1967, 9, 24),
#        datetime.date(1967, 10, 10), datetime.date(1967, 11, 3),
#        datetime.date(1967, 11, 23), datetime.date(1968, 1, 1),
#        datetime.date(1968, 1, 15), datetime.date(1968, 2, 11),
#        datetime.date(1968, 3, 20), datetime.date(1968, 4, 29),
#        datetime.date(1968, 5, 3), datetime.date(1968, 5, 5),
#        datetime.date(1968, 9, 15), datetime.date(1968, 9, 23),
#        datetime.date(1968, 10, 10), datetime.date(1968, 11, 3),
#        datetime.date(1968, 11, 23), datetime.date(1969, 1, 1),
#        datetime.date(1969, 1, 15), datetime.date(1969, 2, 11),
#        datetime.date(1969, 3, 21), datetime.date(1969, 4, 29),
#        datetime.date(1969, 5, 3), datetime.date(1969, 5, 5),
#        datetime.date(1969, 9, 15), datetime.date(1969, 9, 23),
#        datetime.date(1969, 10, 10), datetime.date(1969, 11, 3),
#        datetime.date(1969, 11, 23), datetime.date(1970, 1, 1),
#        datetime.date(1970, 1, 15), datetime.date(1970, 2, 11),
#        datetime.date(1970, 3, 21), datetime.date(1970, 4, 29),
#        datetime.date(1970, 5, 3), datetime.date(1970, 5, 5),
#        datetime.date(1970, 9, 15), datetime.date(1970, 9, 23),
#        datetime.date(1970, 10, 10), datetime.date(1970, 11, 3),
#        datetime.date(1970, 11, 23), datetime.date(1971, 1, 1),
#        datetime.date(1971, 1, 15), datetime.date(1971, 2, 11),
#        datetime.date(1971, 3, 21), datetime.date(1971, 4, 29),
#        datetime.date(1971, 5, 3), datetime.date(1971, 5, 5),
#        datetime.date(1971, 9, 15), datetime.date(1971, 9, 24),
#        datetime.date(1971, 10, 10), datetime.date(1971, 11, 3),
#        datetime.date(1971, 11, 23), datetime.date(1972, 1, 1),
#        datetime.date(1972, 1, 15), datetime.date(1972, 2, 11),
#        datetime.date(1972, 3, 20), datetime.date(1972, 4, 29),
#        datetime.date(1972, 5, 3), datetime.date(1972, 5, 5),
#        datetime.date(1972, 9, 15), datetime.date(1972, 9, 23),
#        datetime.date(1972, 10, 10), datetime.date(1972, 11, 3),
#        datetime.date(1972, 11, 23), datetime.date(1973, 1, 1),
#        datetime.date(1973, 1, 15), datetime.date(1973, 2, 11),
#        datetime.date(1973, 3, 21), datetime.date(1973, 4, 29),
#        datetime.date(1973, 4, 30), datetime.date(1973, 5, 3),
#        datetime.date(1973, 5, 5), datetime.date(1973, 9, 15),
#        datetime.date(1973, 9, 23), datetime.date(1973, 9, 24),
#        datetime.date(1973, 10, 10), datetime.date(1973, 11, 3),
#        datetime.date(1973, 11, 23), datetime.date(1974, 1, 1),
#        datetime.date(1974, 1, 15), datetime.date(1974, 2, 11),
#        datetime.date(1974, 3, 21), datetime.date(1974, 4, 29),
#        datetime.date(1974, 5, 3), datetime.date(1974, 5, 5),
#        datetime.date(1974, 5, 6), datetime.date(1974, 9, 15),
#        datetime.date(1974, 9, 16), datetime.date(1974, 9, 23),
#        datetime.date(1974, 10, 10), datetime.date(1974, 11, 3),
#        datetime.date(1974, 11, 4), datetime.date(1974, 11, 23),
#        datetime.date(1975, 1, 1), datetime.date(1975, 1, 15),
#        datetime.date(1975, 2, 11), datetime.date(1975, 3, 21),
#        datetime.date(1975, 4, 29), datetime.date(1975, 5, 3),
#        datetime.date(1975, 5, 5), datetime.date(1975, 9, 15),
#        datetime.date(1975, 9, 24), datetime.date(1975, 10, 10),
#        datetime.date(1975, 11, 3), datetime.date(1975, 11, 23),
#        datetime.date(1975, 11, 24), datetime.date(1976, 1, 1),
#        datetime.date(1976, 1, 15), datetime.date(1976, 2, 11),
#        datetime.date(1976, 3, 20), datetime.date(1976, 4, 29),
#        datetime.date(1976, 5, 3), datetime.date(1976, 5, 5),
#        datetime.date(1976, 9, 15), datetime.date(1976, 9, 23),
#        datetime.date(1976, 10, 10), datetime.date(1976, 10, 11),
#        datetime.date(1976, 11, 3), datetime.date(1976, 11, 23),
#        datetime.date(1977, 1, 1), datetime.date(1977, 1, 15),
#        datetime.date(1977, 2, 11), datetime.date(1977, 3, 21),
#        datetime.date(1977, 4, 29), datetime.date(1977, 5, 3),
#        datetime.date(1977, 5, 5), datetime.date(1977, 9, 15),
#        datetime.date(1977, 9, 23), datetime.date(1977, 10, 10),
#        datetime.date(1977, 11, 3), datetime.date(1977, 11, 23),
#        datetime.date(1978, 1, 1), datetime.date(1978, 1, 2),
#        datetime.date(1978, 1, 15), datetime.date(1978, 1, 16),
#        datetime.date(1978, 2, 11), datetime.date(1978, 3, 21),
#        datetime.date(1978, 4, 29), datetime.date(1978, 5, 3),
#        datetime.date(1978, 5, 5), datetime.date(1978, 9, 15),
#        datetime.date(1978, 9, 23), datetime.date(1978, 10, 10),
#        datetime.date(1978, 11, 3), datetime.date(1978, 11, 23),
#        datetime.date(1979, 1, 1), datetime.date(1979, 1, 15),
#        datetime.date(1979, 2, 11), datetime.date(1979, 2, 12),
#        datetime.date(1979, 3, 21), datetime.date(1979, 4, 29),
#        datetime.date(1979, 4, 30), datetime.date(1979, 5, 3),
#        datetime.date(1979, 5, 5), datetime.date(1979, 9, 15),
#        datetime.date(1979, 9, 24), datetime.date(1979, 10, 10),
#        datetime.date(1979, 11, 3), datetime.date(1979, 11, 23),
#        datetime.date(1980, 1, 1), datetime.date(1980, 1, 15),
#        datetime.date(1980, 2, 11), datetime.date(1980, 3, 20),
#        datetime.date(1980, 4, 29), datetime.date(1980, 5, 3),
#        datetime.date(1980, 5, 5), datetime.date(1980, 9, 15),
#        datetime.date(1980, 9, 23), datetime.date(1980, 10, 10),
#        datetime.date(1980, 11, 3), datetime.date(1980, 11, 23),
#        datetime.date(1980, 11, 24), datetime.date(1981, 1, 1),
#        datetime.date(1981, 1, 15), datetime.date(1981, 2, 11),
#        datetime.date(1981, 3, 21), datetime.date(1981, 4, 29),
#        datetime.date(1981, 5, 3), datetime.date(1981, 5, 4),
#        datetime.date(1981, 5, 5), datetime.date(1981, 9, 15),
#        datetime.date(1981, 9, 23), datetime.date(1981, 10, 10),
#        datetime.date(1981, 11, 3), datetime.date(1981, 11, 23),
#        datetime.date(1982, 1, 1), datetime.date(1982, 1, 15),
#        datetime.date(1982, 2, 11), datetime.date(1982, 3, 21),
#        datetime.date(1982, 3, 22), datetime.date(1982, 4, 29),
#        datetime.date(1982, 5, 3), datetime.date(1982, 5, 5),
#        datetime.date(1982, 9, 15), datetime.date(1982, 9, 23),
#        datetime.date(1982, 10, 10), datetime.date(1982, 10, 11),
#        datetime.date(1982, 11, 3), datetime.date(1982, 11, 23),
#        datetime.date(1983, 1, 1), datetime.date(1983, 1, 15),
#        datetime.date(1983, 2, 11), datetime.date(1983, 3, 21),
#        datetime.date(1983, 4, 29), datetime.date(1983, 5, 3),
#        datetime.date(1983, 5, 5), datetime.date(1983, 9, 15),
#        datetime.date(1983, 9, 23), datetime.date(1983, 10, 10),
#        datetime.date(1983, 11, 3), datetime.date(1983, 11, 23),
#        datetime.date(1984, 1, 1), datetime.date(1984, 1, 2),
#        datetime.date(1984, 1, 15), datetime.date(1984, 1, 16),
#        datetime.date(1984, 2, 11), datetime.date(1984, 3, 20),
#        datetime.date(1984, 4, 29), datetime.date(1984, 4, 30),
#        datetime.date(1984, 5, 3), datetime.date(1984, 5, 5),
#        datetime.date(1984, 9, 15), datetime.date(1984, 9, 23),
#        datetime.date(1984, 9, 24), datetime.date(1984, 10, 10),
#        datetime.date(1984, 11, 3), datetime.date(1984, 11, 23),
#        datetime.date(1985, 1, 1), datetime.date(1985, 1, 15),
#        datetime.date(1985, 2, 11), datetime.date(1985, 3, 21),
#        datetime.date(1985, 4, 29), datetime.date(1985, 5, 3),
#        datetime.date(1985, 5, 5), datetime.date(1985, 5, 6),
#        datetime.date(1985, 9, 15), datetime.date(1985, 9, 16),
#        datetime.date(1985, 9, 23), datetime.date(1985, 10, 10),
#        datetime.date(1985, 11, 3), datetime.date(1985, 11, 4),
#        datetime.date(1985, 11, 23), datetime.date(1986, 1, 1),
#        datetime.date(1986, 1, 15), datetime.date(1986, 2, 11),
#        datetime.date(1986, 3, 21), datetime.date(1986, 4, 29),
#        datetime.date(1986, 5, 3), datetime.date(1986, 5, 5),
#        datetime.date(1986, 9, 15), datetime.date(1986, 9, 23),
#        datetime.date(1986, 10, 10), datetime.date(1986, 11, 3),
#        datetime.date(1986, 11, 23), datetime.date(1986, 11, 24),
#        datetime.date(1987, 1, 1), datetime.date(1987, 1, 15),
#        datetime.date(1987, 2, 11), datetime.date(1987, 3, 21),
#        datetime.date(1987, 4, 29), datetime.date(1987, 5, 3),
#        datetime.date(1987, 5, 4), datetime.date(1987, 5, 5),
#        datetime.date(1987, 9, 15), datetime.date(1987, 9, 23),
#        datetime.date(1987, 10, 10), datetime.date(1987, 11, 3),
#        datetime.date(1987, 11, 23), datetime.date(1988, 1, 1),
#        datetime.date(1988, 1, 15), datetime.date(1988, 2, 11),
#        datetime.date(1988, 3, 20), datetime.date(1988, 3, 21),
#        datetime.date(1988, 4, 29), datetime.date(1988, 5, 3),
#        datetime.date(1988, 5, 4), datetime.date(1988, 5, 5),
#        datetime.date(1988, 9, 15), datetime.date(1988, 9, 23),
#        datetime.date(1988, 10, 10), datetime.date(1988, 11, 3),
#        datetime.date(1988, 11, 23), datetime.date(1989, 1, 1),
#        datetime.date(1989, 1, 2), datetime.date(1989, 1, 15),
#        datetime.date(1989, 1, 16), datetime.date(1989, 2, 11),
#        datetime.date(1989, 2, 24), datetime.date(1989, 3, 21),
#        datetime.date(1989, 4, 29), datetime.date(1989, 5, 3),
#        datetime.date(1989, 5, 4), datetime.date(1989, 5, 5),
#        datetime.date(1989, 9, 15), datetime.date(1989, 9, 23),
#        datetime.date(1989, 10, 10), datetime.date(1989, 11, 3),
#        datetime.date(1989, 11, 23), datetime.date(1989, 12, 23),
#        datetime.date(1990, 1, 1), datetime.date(1990, 1, 15),
#        datetime.date(1990, 2, 11), datetime.date(1990, 2, 12),
#        datetime.date(1990, 3, 21), datetime.date(1990, 4, 29),
#        datetime.date(1990, 4, 30), datetime.date(1990, 5, 3),
#        datetime.date(1990, 5, 4), datetime.date(1990, 5, 5),
#        datetime.date(1990, 9, 15), datetime.date(1990, 9, 23),
#        datetime.date(1990, 9, 24), datetime.date(1990, 10, 10),
#        datetime.date(1990, 11, 3), datetime.date(1990, 11, 12),
#        datetime.date(1990, 11, 23), datetime.date(1990, 12, 23),
#        datetime.date(1990, 12, 24), datetime.date(1991, 1, 1),
#        datetime.date(1991, 1, 15), datetime.date(1991, 2, 11),
#        datetime.date(1991, 3, 21), datetime.date(1991, 4, 29),
#        datetime.date(1991, 5, 3), datetime.date(1991, 5, 4),
#        datetime.date(1991, 5, 5), datetime.date(1991, 5, 6),
#        datetime.date(1991, 9, 15), datetime.date(1991, 9, 16),
#        datetime.date(1991, 9, 23), datetime.date(1991, 10, 10),
#        datetime.date(1991, 11, 3), datetime.date(1991, 11, 4),
#        datetime.date(1991, 11, 23), datetime.date(1991, 12, 23),
#        datetime.date(1992, 1, 1), datetime.date(1992, 1, 15),
#        datetime.date(1992, 2, 11), datetime.date(1992, 3, 20),
#        datetime.date(1992, 4, 29), datetime.date(1992, 5, 3),
#        datetime.date(1992, 5, 4), datetime.date(1992, 5, 5),
#        datetime.date(1992, 9, 15), datetime.date(1992, 9, 23),
#        datetime.date(1992, 10, 10), datetime.date(1992, 11, 3),
#        datetime.date(1992, 11, 23), datetime.date(1992, 12, 23),
#        datetime.date(1993, 1, 1), datetime.date(1993, 1, 15),
#        datetime.date(1993, 2, 11), datetime.date(1993, 3, 20),
#        datetime.date(1993, 4, 29), datetime.date(1993, 5, 3),
#        datetime.date(1993, 5, 4), datetime.date(1993, 5, 5),
#        datetime.date(1993, 6, 9), datetime.date(1993, 9, 15),
#        datetime.date(1993, 9, 23), datetime.date(1993, 10, 10),
#        datetime.date(1993, 10, 11), datetime.date(1993, 11, 3),
#        datetime.date(1993, 11, 23), datetime.date(1993, 12, 23),
#        datetime.date(1994, 1, 1), datetime.date(1994, 1, 15),
#        datetime.date(1994, 2, 11), datetime.date(1994, 3, 21),
#        datetime.date(1994, 4, 29), datetime.date(1994, 5, 3),
#        datetime.date(1994, 5, 4), datetime.date(1994, 5, 5),
#        datetime.date(1994, 9, 15), datetime.date(1994, 9, 23),
#        datetime.date(1994, 10, 10), datetime.date(1994, 11, 3),
#        datetime.date(1994, 11, 23), datetime.date(1994, 12, 23),
#        datetime.date(1995, 1, 1), datetime.date(1995, 1, 2),
#        datetime.date(1995, 1, 15), datetime.date(1995, 1, 16),
#        datetime.date(1995, 2, 11), datetime.date(1995, 3, 21),
#        datetime.date(1995, 4, 29), datetime.date(1995, 5, 3),
#        datetime.date(1995, 5, 4), datetime.date(1995, 5, 5),
#        datetime.date(1995, 9, 15), datetime.date(1995, 9, 23),
#        datetime.date(1995, 10, 10), datetime.date(1995, 11, 3),
#        datetime.date(1995, 11, 23), datetime.date(1995, 12, 23),
#        datetime.date(1996, 1, 1), datetime.date(1996, 1, 15),
#        datetime.date(1996, 2, 11), datetime.date(1996, 2, 12),
#        datetime.date(1996, 3, 20), datetime.date(1996, 4, 29),
#        datetime.date(1996, 5, 3), datetime.date(1996, 5, 4),
#        datetime.date(1996, 5, 5), datetime.date(1996, 5, 6),
#        datetime.date(1996, 7, 20), datetime.date(1996, 9, 15),
#        datetime.date(1996, 9, 16), datetime.date(1996, 9, 23),
#        datetime.date(1996, 10, 10), datetime.date(1996, 11, 3),
#        datetime.date(1996, 11, 4), datetime.date(1996, 11, 23),
#        datetime.date(1996, 12, 23), datetime.date(1997, 1, 1),
#        datetime.date(1997, 1, 15), datetime.date(1997, 2, 11),
#        datetime.date(1997, 3, 20), datetime.date(1997, 4, 29),
#        datetime.date(1997, 5, 3), datetime.date(1997, 5, 5),
#        datetime.date(1997, 7, 20), datetime.date(1997, 7, 21),
#        datetime.date(1997, 9, 15), datetime.date(1997, 9, 23),
#        datetime.date(1997, 10, 10), datetime.date(1997, 11, 3),
#        datetime.date(1997, 11, 23), datetime.date(1997, 11, 24),
#        datetime.date(1997, 12, 23), datetime.date(1998, 1, 1),
#        datetime.date(1998, 1, 15), datetime.date(1998, 2, 11),
#        datetime.date(1998, 3, 21), datetime.date(1998, 4, 29),
#        datetime.date(1998, 5, 3), datetime.date(1998, 5, 4),
#        datetime.date(1998, 5, 5), datetime.date(1998, 7, 20),
#        datetime.date(1998, 9, 15), datetime.date(1998, 9, 23),
#        datetime.date(1998, 10, 10), datetime.date(1998, 11, 3),
#        datetime.date(1998, 11, 23), datetime.date(1998, 12, 23),
#        datetime.date(1999, 1, 1), datetime.date(1999, 1, 15),
#        datetime.date(1999, 2, 11), datetime.date(1999, 3, 21),
#        datetime.date(1999, 3, 22), datetime.date(1999, 4, 29),
#        datetime.date(1999, 5, 3), datetime.date(1999, 5, 4),
#        datetime.date(1999, 5, 5), datetime.date(1999, 7, 20),
#        datetime.date(1999, 9, 15), datetime.date(1999, 9, 23),
#        datetime.date(1999, 10, 10), datetime.date(1999, 10, 11),
#        datetime.date(1999, 11, 3), datetime.date(1999, 11, 23),
#        datetime.date(1999, 12, 23), datetime.date(2000, 1, 1),
#        datetime.date(2000, 1, 10), datetime.date(2000, 2, 11),
#        datetime.date(2000, 3, 20), datetime.date(2000, 4, 29),
#        datetime.date(2000, 5, 3), datetime.date(2000, 5, 4),
#        datetime.date(2000, 5, 5), datetime.date(2000, 7, 20),
#        datetime.date(2000, 9, 15), datetime.date(2000, 9, 23),
#        datetime.date(2000, 10, 9), datetime.date(2000, 11, 3),
#        datetime.date(2000, 11, 23), datetime.date(2000, 12, 23),
#        datetime.date(2001, 1, 1), datetime.date(2001, 1, 8),
#        datetime.date(2001, 2, 11), datetime.date(2001, 2, 12),
#        datetime.date(2001, 3, 20), datetime.date(2001, 4, 29),
#        datetime.date(2001, 4, 30), datetime.date(2001, 5, 3),
#        datetime.date(2001, 5, 4), datetime.date(2001, 5, 5),
#        datetime.date(2001, 7, 20), datetime.date(2001, 9, 15),
#        datetime.date(2001, 9, 23), datetime.date(2001, 9, 24),
#        datetime.date(2001, 10, 8), datetime.date(2001, 11, 3),
#        datetime.date(2001, 11, 23), datetime.date(2001, 12, 23),
#        datetime.date(2001, 12, 24), datetime.date(2002, 1, 1),
#        datetime.date(2002, 1, 14), datetime.date(2002, 2, 11),
#        datetime.date(2002, 3, 21), datetime.date(2002, 4, 29),
#        datetime.date(2002, 5, 3), datetime.date(2002, 5, 4),
#        datetime.date(2002, 5, 5), datetime.date(2002, 5, 6),
#        datetime.date(2002, 7, 20), datetime.date(2002, 9, 15),
#        datetime.date(2002, 9, 16), datetime.date(2002, 9, 23),
#        datetime.date(2002, 10, 14), datetime.date(2002, 11, 3),
#        datetime.date(2002, 11, 4), datetime.date(2002, 11, 23),
#        datetime.date(2002, 12, 23), datetime.date(2003, 1, 1),
#        datetime.date(2003, 1, 13), datetime.date(2003, 2, 11),
#        datetime.date(2003, 3, 21), datetime.date(2003, 4, 29),
#        datetime.date(2003, 5, 3), datetime.date(2003, 5, 5),
#        datetime.date(2003, 7, 21), datetime.date(2003, 9, 15),
#        datetime.date(2003, 9, 23), datetime.date(2003, 10, 13),
#        datetime.date(2003, 11, 3), datetime.date(2003, 11, 23),
#        datetime.date(2003, 11, 24), datetime.date(2003, 12, 23),
#        datetime.date(2004, 1, 1), datetime.date(2004, 1, 12),
#        datetime.date(2004, 2, 11), datetime.date(2004, 3, 20),
#        datetime.date(2004, 4, 29), datetime.date(2004, 5, 3),
#        datetime.date(2004, 5, 4), datetime.date(2004, 5, 5),
#        datetime.date(2004, 7, 19), datetime.date(2004, 9, 20),
#        datetime.date(2004, 9, 23), datetime.date(2004, 10, 11),
#        datetime.date(2004, 11, 3), datetime.date(2004, 11, 23),
#        datetime.date(2004, 12, 23), datetime.date(2005, 1, 1),
#        datetime.date(2005, 1, 10), datetime.date(2005, 2, 11),
#        datetime.date(2005, 3, 20), datetime.date(2005, 3, 21),
#        datetime.date(2005, 4, 29), datetime.date(2005, 5, 3),
#        datetime.date(2005, 5, 4), datetime.date(2005, 5, 5),
#        datetime.date(2005, 7, 18), datetime.date(2005, 9, 19),
#        datetime.date(2005, 9, 23), datetime.date(2005, 10, 10),
#        datetime.date(2005, 11, 3), datetime.date(2005, 11, 23),
#        datetime.date(2005, 12, 23), datetime.date(2006, 1, 1),
#        datetime.date(2006, 1, 2), datetime.date(2006, 1, 9),
#        datetime.date(2006, 2, 11), datetime.date(2006, 3, 21),
#        datetime.date(2006, 4, 29), datetime.date(2006, 5, 3),
#        datetime.date(2006, 5, 4), datetime.date(2006, 5, 5),
#        datetime.date(2006, 7, 17), datetime.date(2006, 9, 18),
#        datetime.date(2006, 9, 23), datetime.date(2006, 10, 9),
#        datetime.date(2006, 11, 3), datetime.date(2006, 11, 23),
#        datetime.date(2006, 12, 23), datetime.date(2007, 1, 1),
#        datetime.date(2007, 1, 8), datetime.date(2007, 2, 11),
#        datetime.date(2007, 2, 12), datetime.date(2007, 3, 21),
#        datetime.date(2007, 4, 29), datetime.date(2007, 4, 30),
#        datetime.date(2007, 5, 3), datetime.date(2007, 5, 4),
#        datetime.date(2007, 5, 5), datetime.date(2007, 7, 16),
#        datetime.date(2007, 9, 17), datetime.date(2007, 9, 23),
#        datetime.date(2007, 9, 24), datetime.date(2007, 10, 8),
#        datetime.date(2007, 11, 3), datetime.date(2007, 11, 23),
#        datetime.date(2007, 12, 23), datetime.date(2007, 12, 24),
#        datetime.date(2008, 1, 1), datetime.date(2008, 1, 14),
#        datetime.date(2008, 2, 11), datetime.date(2008, 3, 20),
#        datetime.date(2008, 4, 29), datetime.date(2008, 5, 3),
#        datetime.date(2008, 5, 4), datetime.date(2008, 5, 5),
#        datetime.date(2008, 5, 6), datetime.date(2008, 7, 21),
#        datetime.date(2008, 9, 15), datetime.date(2008, 9, 23),
#        datetime.date(2008, 10, 13), datetime.date(2008, 11, 3),
#        datetime.date(2008, 11, 23), datetime.date(2008, 11, 24),
#        datetime.date(2008, 12, 23), datetime.date(2009, 1, 1),
#        datetime.date(2009, 1, 12), datetime.date(2009, 2, 11),
#        datetime.date(2009, 3, 20), datetime.date(2009, 4, 29),
#        datetime.date(2009, 5, 3), datetime.date(2009, 5, 4),
#        datetime.date(2009, 5, 5), datetime.date(2009, 5, 6),
#        datetime.date(2009, 7, 20), datetime.date(2009, 9, 21),
#        datetime.date(2009, 9, 22), datetime.date(2009, 9, 23),
#        datetime.date(2009, 10, 12), datetime.date(2009, 11, 3),
#        datetime.date(2009, 11, 23), datetime.date(2009, 12, 23),
#        datetime.date(2010, 1, 1), datetime.date(2010, 1, 11),
#        datetime.date(2010, 2, 11), datetime.date(2010, 3, 21),
#        datetime.date(2010, 3, 22), datetime.date(2010, 4, 29),
#        datetime.date(2010, 5, 3), datetime.date(2010, 5, 4),
#        datetime.date(2010, 5, 5), datetime.date(2010, 7, 19),
#        datetime.date(2010, 9, 20), datetime.date(2010, 9, 23),
#        datetime.date(2010, 10, 11), datetime.date(2010, 11, 3),
#        datetime.date(2010, 11, 23), datetime.date(2010, 12, 23),
#        datetime.date(2011, 1, 1), datetime.date(2011, 1, 10),
#        datetime.date(2011, 2, 11), datetime.date(2011, 3, 21),
#        datetime.date(2011, 4, 29), datetime.date(2011, 5, 3),
#        datetime.date(2011, 5, 4), datetime.date(2011, 5, 5),
#        datetime.date(2011, 7, 18), datetime.date(2011, 9, 19),
#        datetime.date(2011, 9, 23), datetime.date(2011, 10, 10),
#        datetime.date(2011, 11, 3), datetime.date(2011, 11, 23),
#        datetime.date(2011, 12, 23), datetime.date(2012, 1, 1),
#        datetime.date(2012, 1, 2), datetime.date(2012, 1, 9),
#        datetime.date(2012, 2, 11), datetime.date(2012, 3, 20),
#        datetime.date(2012, 4, 29), datetime.date(2012, 4, 30),
#        datetime.date(2012, 5, 3), datetime.date(2012, 5, 4),
#        datetime.date(2012, 5, 5), datetime.date(2012, 7, 16),
#        datetime.date(2012, 9, 17), datetime.date(2012, 9, 22),
#        datetime.date(2012, 10, 8), datetime.date(2012, 11, 3),
#        datetime.date(2012, 11, 23), datetime.date(2012, 12, 23),
#        datetime.date(2012, 12, 24), datetime.date(2013, 1, 1),
#        datetime.date(2013, 1, 14), datetime.date(2013, 2, 11),
#        datetime.date(2013, 3, 20), datetime.date(2013, 4, 29),
#        datetime.date(2013, 5, 3), datetime.date(2013, 5, 4),
#        datetime.date(2013, 5, 5), datetime.date(2013, 5, 6),
#        datetime.date(2013, 7, 15), datetime.date(2013, 9, 16),
#        datetime.date(2013, 9, 23), datetime.date(2013, 10, 14),
#        datetime.date(2013, 11, 3), datetime.date(2013, 11, 4),
#        datetime.date(2013, 11, 23), datetime.date(2013, 12, 23),
#        datetime.date(2014, 1, 1), datetime.date(2014, 1, 13),
#        datetime.date(2014, 2, 11), datetime.date(2014, 3, 21),
#        datetime.date(2014, 4, 29), datetime.date(2014, 5, 3),
#        datetime.date(2014, 5, 4), datetime.date(2014, 5, 5),
#        datetime.date(2014, 5, 6), datetime.date(2014, 7, 21),
#        datetime.date(2014, 9, 15), datetime.date(2014, 9, 23),
#        datetime.date(2014, 10, 13), datetime.date(2014, 11, 3),
#        datetime.date(2014, 11, 23), datetime.date(2014, 11, 24),
#        datetime.date(2014, 12, 23), datetime.date(2015, 1, 1),
#        datetime.date(2015, 1, 12), datetime.date(2015, 2, 11),
#        datetime.date(2015, 3, 21), datetime.date(2015, 4, 29),
#        datetime.date(2015, 5, 3), datetime.date(2015, 5, 4),
#        datetime.date(2015, 5, 5), datetime.date(2015, 5, 6),
#        datetime.date(2015, 7, 20), datetime.date(2015, 9, 21),
#        datetime.date(2015, 9, 22), datetime.date(2015, 9, 23),
#        datetime.date(2015, 10, 12), datetime.date(2015, 11, 3),
#        datetime.date(2015, 11, 23), datetime.date(2015, 12, 23),
#        datetime.date(2016, 1, 1), datetime.date(2016, 1, 11),
#        datetime.date(2016, 2, 11), datetime.date(2016, 3, 20),
#        datetime.date(2016, 3, 21), datetime.date(2016, 4, 29),
#        datetime.date(2016, 5, 3), datetime.date(2016, 5, 4),
#        datetime.date(2016, 5, 5), datetime.date(2016, 7, 18),
#        datetime.date(2016, 8, 11), datetime.date(2016, 9, 19),
#        datetime.date(2016, 9, 22), datetime.date(2016, 10, 10),
#        datetime.date(2016, 11, 3), datetime.date(2016, 11, 23),
#        datetime.date(2016, 12, 23), datetime.date(2017, 1, 1),
#        datetime.date(2017, 1, 2), datetime.date(2017, 1, 9),
#        datetime.date(2017, 2, 11), datetime.date(2017, 3, 20),
#        datetime.date(2017, 4, 29), datetime.date(2017, 5, 3),
#        datetime.date(2017, 5, 4), datetime.date(2017, 5, 5),
#        datetime.date(2017, 7, 17), datetime.date(2017, 8, 11),
#        datetime.date(2017, 9, 18), datetime.date(2017, 9, 23),
#        datetime.date(2017, 10, 9), datetime.date(2017, 11, 3),
#        datetime.date(2017, 11, 23), datetime.date(2017, 12, 23),
#        datetime.date(2018, 1, 1), datetime.date(2018, 1, 8),
#        datetime.date(2018, 2, 11), datetime.date(2018, 2, 12),
#        datetime.date(2018, 3, 21), datetime.date(2018, 4, 29),
#        datetime.date(2018, 4, 30), datetime.date(2018, 5, 3),
#        datetime.date(2018, 5, 4), datetime.date(2018, 5, 5),
#        datetime.date(2018, 7, 16), datetime.date(2018, 8, 11),
#        datetime.date(2018, 9, 17), datetime.date(2018, 9, 23),
#        datetime.date(2018, 9, 24), datetime.date(2018, 10, 8),
#        datetime.date(2018, 11, 3), datetime.date(2018, 11, 23),
#        datetime.date(2018, 12, 23), datetime.date(2018, 12, 24),
#        datetime.date(2019, 1, 1), datetime.date(2019, 1, 14),
#        datetime.date(2019, 2, 11), datetime.date(2019, 3, 21),
#        datetime.date(2019, 4, 29), datetime.date(2019, 4, 30),
#        datetime.date(2019, 5, 1), datetime.date(2019, 5, 2),
#        datetime.date(2019, 5, 3), datetime.date(2019, 5, 4),
#        datetime.date(2019, 5, 5), datetime.date(2019, 5, 6),
#        datetime.date(2019, 7, 15), datetime.date(2019, 8, 11),
#        datetime.date(2019, 8, 12), datetime.date(2019, 9, 16),
#        datetime.date(2019, 9, 23), datetime.date(2019, 10, 14),
#        datetime.date(2019, 10, 22), datetime.date(2019, 11, 3),
#        datetime.date(2019, 11, 4), datetime.date(2019, 11, 23),
#        datetime.date(2020, 1, 1), datetime.date(2020, 1, 13),
#        datetime.date(2020, 2, 11), datetime.date(2020, 2, 23),
#        datetime.date(2020, 2, 24), datetime.date(2020, 3, 20),
#        datetime.date(2020, 4, 29), datetime.date(2020, 5, 3),
#        datetime.date(2020, 5, 4), datetime.date(2020, 5, 5),
#        datetime.date(2020, 5, 6), datetime.date(2020, 7, 23),
#        datetime.date(2020, 7, 24), datetime.date(2020, 8, 10),
#        datetime.date(2020, 9, 21), datetime.date(2020, 9, 22),
#        datetime.date(2020, 11, 3), datetime.date(2020, 11, 23),
#        datetime.date(2021, 1, 1), datetime.date(2021, 1, 11),
#        datetime.date(2021, 2, 11), datetime.date(2021, 2, 23),
#        datetime.date(2021, 3, 20), datetime.date(2021, 4, 29),
#        datetime.date(2021, 5, 3), datetime.date(2021, 5, 4),
#        datetime.date(2021, 5, 5), datetime.date(2021, 7, 22),
#        datetime.date(2021, 7, 23), datetime.date(2021, 8, 8),
#        datetime.date(2021, 8, 9), datetime.date(2021, 9, 20),
#        datetime.date(2021, 9, 23), datetime.date(2021, 11, 3),
#        datetime.date(2021, 11, 23), datetime.date(2022, 1, 1),
#        datetime.date(2022, 1, 10), datetime.date(2022, 2, 11),
#        datetime.date(2022, 2, 23), datetime.date(2022, 3, 21),
#        datetime.date(2022, 4, 29), datetime.date(2022, 5, 3),
#        datetime.date(2022, 5, 4), datetime.date(2022, 5, 5),
#        datetime.date(2022, 7, 18), datetime.date(2022, 8, 11),
#        datetime.date(2022, 9, 19), datetime.date(2022, 9, 23),
#        datetime.date(2022, 10, 10), datetime.date(2022, 11, 3),
#        datetime.date(2022, 11, 23)], dtype=object)

# %% [markdown]
# ### データを取得して適切な場所に適切なフォーマットで保存する関数

# %%
def make_source_with_naikaku(source_path):
    """
    内閣府のサイトから得られるデータ(https://www8.cao.go.jp/chosei/shukujitsu/syukujitsu.csv)
    を適切なフォーマット(header, indexの無い日にち，祝日名)に変換して引数のソースディレクトリに保存する関数．
    振替休日は休日と表記される．1955年からのデータであることに注意
    """
    url = "https://www8.cao.go.jp/chosei/shukujitsu/syukujitsu.csv"
    req = requests.get(url)
    csv_bin = io.BytesIO(req.content)
    my_parser = lambda date: datetime.datetime.strptime(date, "%Y/%m/%d")
    holiday_df_csv = pd.read_csv(csv_bin,
                             names=["date", "holiday_name"],
                             index_col="date",
                             parse_dates=True,
                             date_parser=my_parser,
                             header=0,
                             encoding="shift-jis"
                            )
    
    holiday_df_csv.to_csv(source_path, header=False)

# %%
source_path = Path("../source/holiday_naikaku.csv")
make_source_with_naikaku(source_path)

# %% [markdown]
# ## APIを試す

# %% [markdown]
# ### jsonデータを取得

# %%
url = "https://holidays-jp.github.io/api/v1/date.json"
req = requests.get(url)

# %%
req.json()
# Out:
# {'2020-01-01': '元日',
#  '2020-01-13': '成人の日',
#  '2020-02-11': '建国記念の日',
#  '2020-02-23': '天皇誕生日',
#  '2020-02-24': '天皇誕生日 振替休日',
#  '2020-03-20': '春分の日',
#  '2020-04-29': '昭和の日',
#  '2020-05-03': '憲法記念日',
#  '2020-05-04': 'みどりの日',
#  '2020-05-05': 'こどもの日',
#  '2020-05-06': '憲法記念日 振替休日',
#  '2020-07-23': '海の日',
#  '2020-07-24': '体育の日',
#  '2020-08-10': '山の日',
#  '2020-09-21': '敬老の日',
#  '2020-09-22': '秋分の日',
#  '2020-11-03': '文化の日',
#  '2020-11-23': '勤労感謝の日',
#  '2021-01-01': '元日',
#  '2021-01-11': '成人の日',
#  '2021-02-11': '建国記念の日',
#  '2021-02-23': '天皇誕生日',
#  '2021-03-20': '春分の日',
#  '2021-04-29': '昭和の日',
#  '2021-05-03': '憲法記念日',
#  '2021-05-04': 'みどりの日',
#  '2021-05-05': 'こどもの日',
#  '2021-07-22': '海の日',
#  '2021-07-23': '体育の日',
#  '2021-08-08': '山の日',
#  '2021-08-09': '休日 山の日',
#  '2021-09-20': '敬老の日',
#  '2021-09-23': '秋分の日',
#  '2021-11-03': '文化の日',
#  '2021-11-23': '勤労感謝の日',
#  '2022-01-01': '元日',
#  '2022-01-10': '成人の日',
#  '2022-02-11': '建国記念の日',
#  '2022-02-23': '天皇誕生日',
#  '2022-03-21': '春分の日',
#  '2022-04-29': '昭和の日',
#  '2022-05-03': '憲法記念日',
#  '2022-05-04': 'みどりの日',
#  '2022-05-05': 'こどもの日',
#  '2022-07-18': '海の日',
#  '2022-08-11': '山の日',
#  '2022-09-19': '敬老の日',
#  '2022-09-23': '秋分の日',
#  '2022-10-10': '体育の日',
#  '2022-11-03': '文化の日',
#  '2022-11-23': '勤労感謝の日'}

# %% [markdown]
# 振替休日も取得できている．また，内閣府のデータと違い振替休日の振替元を表示している．さらにフォーマットはすでに読み込める形になっている．

# %% [markdown]
# ### CSVデータとして保存

# %%
url = "https://holidays-jp.github.io/api/v1/date.csv"
csv_name = Path(url).name

req = requests.get(url)
csv_binary = req.content

with open(Path(csv_name), "wb") as f:
    f.write(csv_binary)

# %% [markdown]
# ### 2015年から現在年までの休日を取得しCSVファイルに保存

# %% [markdown]
# 実は，2015年からしか祝日を取得できない．

# %%
date_holidayname = {"date":[], "holiday_name":[]}

for year in range(2015, datetime.datetime.now().year+1):
    url = "https://holidays-jp.github.io/api/v1/{}/date.json".format(year)
    req = requests.get(url)
    date_dict = req.json()
    
    date_holidayname["date"].extend(list(date_dict.keys()))
    date_holidayname["holiday_name"].extend(list(date_dict.values()))
    time.sleep(0.1)  # スクレイピングでサーバーの負荷を軽減するため
    
holiday_df_api = pd.DataFrame(date_holidayname)

# %%
holiday_df
# Out:
#            date holiday_name
# 0    2015-01-01           元日
# 1    2015-01-12         成人の日
# 2    2015-02-11       建国記念の日
# 3    2015-03-21         春分の日
# 4    2015-04-29         昭和の日
# ..          ...          ...
# 123  2021-08-09       休日 山の日
# 124  2021-09-20         敬老の日
# 125  2021-09-23         秋分の日
# 126  2021-11-03         文化の日
# 127  2021-11-23       勤労感謝の日
#
# [128 rows x 2 columns]

# %%
file_name = "japanese_holiday_withapi.csv"

holiday_df.to_csv(file_name, index=False, header=False)

# %% [markdown]
# 開いてみる

# %%
holiday_df_api = pd.read_csv(Path(file_name),
                             names=["date", "holiday_name"],
                             index_col="date",
                             parse_dates=True,
                            )

holiday_df_api
# Out:
#            holiday_name
# date
# 2015-01-01           元日
# 2015-01-12         成人の日
# 2015-02-11       建国記念の日
# 2015-03-21         春分の日
# 2015-04-29         昭和の日
# ...                 ...
# 2021-08-09       休日 山の日
# 2021-09-20         敬老の日
# 2021-09-23         秋分の日
# 2021-11-03         文化の日
# 2021-11-23       勤労感謝の日
#
# [128 rows x 1 columns]

# %%
holiday_df_api.index.date
# Out:
# array([datetime.date(2015, 1, 1), datetime.date(2015, 1, 12),
#        datetime.date(2015, 2, 11), datetime.date(2015, 3, 21),
#        datetime.date(2015, 4, 29), datetime.date(2015, 5, 3),
#        datetime.date(2015, 5, 4), datetime.date(2015, 5, 5),
#        datetime.date(2015, 5, 6), datetime.date(2015, 7, 20),
#        datetime.date(2015, 9, 21), datetime.date(2015, 9, 22),
#        datetime.date(2015, 9, 23), datetime.date(2015, 10, 12),
#        datetime.date(2015, 11, 3), datetime.date(2015, 11, 23),
#        datetime.date(2015, 12, 23), datetime.date(2016, 1, 1),
#        datetime.date(2016, 1, 11), datetime.date(2016, 2, 11),
#        datetime.date(2016, 3, 20), datetime.date(2016, 3, 21),
#        datetime.date(2016, 4, 29), datetime.date(2016, 5, 3),
#        datetime.date(2016, 5, 4), datetime.date(2016, 5, 5),
#        datetime.date(2016, 7, 18), datetime.date(2016, 8, 11),
#        datetime.date(2016, 9, 19), datetime.date(2016, 9, 22),
#        datetime.date(2016, 10, 10), datetime.date(2016, 11, 3),
#        datetime.date(2016, 11, 23), datetime.date(2016, 12, 23),
#        datetime.date(2017, 1, 1), datetime.date(2017, 1, 2),
#        datetime.date(2017, 1, 9), datetime.date(2017, 2, 11),
#        datetime.date(2017, 3, 20), datetime.date(2017, 4, 29),
#        datetime.date(2017, 5, 3), datetime.date(2017, 5, 4),
#        datetime.date(2017, 5, 5), datetime.date(2017, 7, 17),
#        datetime.date(2017, 8, 11), datetime.date(2017, 9, 18),
#        datetime.date(2017, 9, 23), datetime.date(2017, 10, 9),
#        datetime.date(2017, 11, 3), datetime.date(2017, 11, 23),
#        datetime.date(2017, 12, 23), datetime.date(2018, 1, 1),
#        datetime.date(2018, 1, 8), datetime.date(2018, 2, 11),
#        datetime.date(2018, 2, 12), datetime.date(2018, 3, 21),
#        datetime.date(2018, 4, 29), datetime.date(2018, 4, 30),
#        datetime.date(2018, 5, 3), datetime.date(2018, 5, 4),
#        datetime.date(2018, 5, 5), datetime.date(2018, 7, 16),
#        datetime.date(2018, 8, 11), datetime.date(2018, 9, 17),
#        datetime.date(2018, 9, 23), datetime.date(2018, 9, 24),
#        datetime.date(2018, 10, 8), datetime.date(2018, 11, 3),
#        datetime.date(2018, 11, 23), datetime.date(2018, 12, 23),
#        datetime.date(2018, 12, 24), datetime.date(2019, 1, 1),
#        datetime.date(2019, 1, 14), datetime.date(2019, 2, 11),
#        datetime.date(2019, 3, 21), datetime.date(2019, 4, 29),
#        datetime.date(2019, 4, 30), datetime.date(2019, 5, 1),
#        datetime.date(2019, 5, 2), datetime.date(2019, 5, 3),
#        datetime.date(2019, 5, 4), datetime.date(2019, 5, 5),
#        datetime.date(2019, 5, 6), datetime.date(2019, 7, 15),
#        datetime.date(2019, 8, 11), datetime.date(2019, 8, 12),
#        datetime.date(2019, 9, 16), datetime.date(2019, 9, 23),
#        datetime.date(2019, 10, 14), datetime.date(2019, 10, 22),
#        datetime.date(2019, 11, 3), datetime.date(2019, 11, 4),
#        datetime.date(2019, 11, 23), datetime.date(2020, 1, 1),
#        datetime.date(2020, 1, 13), datetime.date(2020, 2, 11),
#        datetime.date(2020, 2, 23), datetime.date(2020, 2, 24),
#        datetime.date(2020, 3, 20), datetime.date(2020, 4, 29),
#        datetime.date(2020, 5, 3), datetime.date(2020, 5, 4),
#        datetime.date(2020, 5, 5), datetime.date(2020, 5, 6),
#        datetime.date(2020, 7, 23), datetime.date(2020, 7, 24),
#        datetime.date(2020, 8, 10), datetime.date(2020, 9, 21),
#        datetime.date(2020, 9, 22), datetime.date(2020, 11, 3),
#        datetime.date(2020, 11, 23), datetime.date(2021, 1, 1),
#        datetime.date(2021, 1, 11), datetime.date(2021, 2, 11),
#        datetime.date(2021, 2, 23), datetime.date(2021, 3, 20),
#        datetime.date(2021, 4, 29), datetime.date(2021, 5, 3),
#        datetime.date(2021, 5, 4), datetime.date(2021, 5, 5),
#        datetime.date(2021, 7, 22), datetime.date(2021, 7, 23),
#        datetime.date(2021, 8, 8), datetime.date(2021, 8, 9),
#        datetime.date(2021, 9, 20), datetime.date(2021, 9, 23),
#        datetime.date(2021, 11, 3), datetime.date(2021, 11, 23)],
#       dtype=object)

# %% [markdown]
# ### データを取得して適切な場所に適切なフォーマットで保存する関数

# %%
def make_source_with_api(source_path):
    """
    日本の祝日API(https://holidays-jp.github.io/)を用いて取得したデータを
    適切なフォーマット(header, indexの無い日にち，祝日名)に変換して引数のソースディレクトリに保存する関数．
    振替休日は振替元も同時に表示される．2015年からの祝日であることに注意
    """
    date_holidayname = {"date":[], "holiday_name":[]}

    for year in range(2015, datetime.datetime.now().year+1):
        url = "https://holidays-jp.github.io/api/v1/{}/date.json".format(year)
        req = requests.get(url)
        date_dict = req.json()

        date_holidayname["date"].extend(list(date_dict.keys()))
        date_holidayname["holiday_name"].extend(list(date_dict.values()))
        time.sleep(0.1)  # スクレイピングでサーバーの負荷を軽減するため

    holiday_df_api = pd.DataFrame(date_holidayname)
    holiday_df_api.to_csv(source_path, index=False, header=False)

# %%
source_path = Path("../source/holiday_api.csv")
make_source_with_api(source_path)

# %% [markdown]
# ## JPholidayを利用する

# %% [markdown]
# jpholidayはデータの取得に時間がかかるので，csvに保存するだけでも速度上の効果がある．

# %%
start_date = datetime.date(1955,1,1)
end_date = datetime.date(datetime.datetime.now().year+1,12,31)
holidays_array = np.array(jpholiday.between(start_date, end_date))
holidays_array
# Out:
# array([[datetime.date(1955, 1, 1), '元日'],
#        [datetime.date(1955, 1, 15), '成人の日'],
#        [datetime.date(1955, 3, 21), '春分の日'],
#        ...,
#        [datetime.date(2022, 10, 10), 'スポーツの日'],
#        [datetime.date(2022, 11, 3), '文化の日'],
#        [datetime.date(2022, 11, 23), '勤労感謝の日']], dtype=object)

# %%
holiday_df_jpholiday = pd.DataFrame(holidays_array[:,1,None], 
                          columns=["holiday_name"],
                          index=pd.DatetimeIndex(holidays_array[:,0])
                         )
holiday_df_jpholiday.index.name = "date"
holiday_df_jpholiday
# Out:
#            holiday_name
# date
# 1955-01-01           元日
# 1955-01-15         成人の日
# 1955-03-21         春分の日
# 1955-04-29        天皇誕生日
# 1955-05-03        憲法記念日
# ...                 ...
# 2022-09-19         敬老の日
# 2022-09-23         秋分の日
# 2022-10-10       スポーツの日
# 2022-11-03         文化の日
# 2022-11-23       勤労感謝の日
#
# [1003 rows x 1 columns]

# %%
def make_source_with_jpholiday(source_path):
    """
    jpholiday(https://pypi.org/project/jpholiday/)を用いて取得したデータを
    適切なフォーマット(header, indexの無い日にち，祝日名)に変換して引数のソースディレクトリに保存する関数．
    振替休日は振替元も同時に表示される．1955年からの祝日であることに注意
    """ 
    start_date = datetime.date(1955,1,1)
    end_date = datetime.date(datetime.datetime.now().year+1,12,31)
    holidays_array = np.array(jpholiday.between(start_date, end_date))
    
    holiday_df_jpholiday = pd.DataFrame(holidays_array[:,1,None], 
                          columns=["holiday_name"],
                          index=pd.DatetimeIndex(holidays_array[:,0])
                         )
    holiday_df_jpholiday.index.name = "date"
    holiday_df_jpholiday.to_csv(source_path, header=False)

# %%
source_path = Path("../source/holiday_jpholiday.csv")
make_source_with_jpholiday(source_path)
