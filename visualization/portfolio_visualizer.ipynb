# %%
# %cd ..
# Out:
# E:\システムトレード入門\trade_system_git_workspace

# %%
from pathlib import Path
import pandas as pd
from pathlib import Path
from pytz import timezone
import datetime
import numpy as np
from scipy.special import softmax

# %%
import bokeh.plotting
from bokeh.models import Range1d, LinearAxis, Div, HoverTool
from bokeh.io import show
from bokeh.io import output_notebook, reset_output, output_file
from bokeh.palettes import d3
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
import matplotlib.pyplot as plt

# %%
from get_stock_price import StockDatabase

# %%
from utils import get_naive_datetime_from_datetime

# %%
from portfolio.trade_transformer import PortfolioTransformer, PortfolioRestrictorIdentity, FeeCalculatorPerNumber
from portfolio.price_supply import StockDBPriceSupplier

# %% [markdown]
# ## データベース

# %%
db_path = Path("E:/システムトレード入門/trade_system_git_workspace/db/sub_stock_db") / Path("sub_stock.db")
stock_db = StockDatabase(db_path)

# %% [markdown]
# ## ポートフォリオの遷移

# %%
jst_timezone = timezone("Asia/Tokyo")
start_datetime = jst_timezone.localize(datetime.datetime(2020,11,10,9,0,0))
stock_list = ["4755","9984","6701","7203","7267", "6502"]
episode_length = 500

price_supplier = StockDBPriceSupplier(stock_db=stock_db,
                                     ticker_names=stock_list,
                                     episode_length=episode_length,
                                     freq_str="5T",
                                     interpolate=True
                                    )

transformer = PortfolioTransformer(price_supplier=price_supplier,
                                   portfolio_restrictor=PortfolioRestrictorIdentity(),
                                   use_ohlc="Close",
                                   initial_portfolio_vector=None,
                                   initial_all_assets=1e6,
                                   fee_calculator=FeeCalculatorPerNumber(0)
                                  )


portfolio_state_list = []
initial_state, _ = transformer.reset(start_datetime, window=[-1,0,1])
portfolio_state_list.append(initial_state.partial("names", "now_price_array", "mean_cost_price_array", "portfolio_vector", "all_assets", "datetime"))

while True:
    action = softmax(np.abs(np.random.randn(1+len(stock_list))))
    portfolio_state, done = transformer.step(action)
    portfolio_state_list.append(portfolio_state.partial("names", "now_price_array", "mean_cost_price_array", "portfolio_vector", "all_assets", "datetime"))
    if done:
        break

# %%
portfolio_state_list
# Out:
# [PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 0, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1280e+03, 7.0720e+03, 5.6800e+03, 7.3420e+03,
#         2.9595e+03, 2.7800e+03]), portfolio_vector=array([1., 0., 0., 0., 0., 0., 0.]), mean_cost_price_array=array([1.0000e+00, 1.1280e+03, 7.0720e+03, 5.6800e+03, 7.3420e+03,
#         2.9595e+03, 2.7800e+03]), all_assets=1000000.0),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 5, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1070e+03, 7.0190e+03, 5.7200e+03, 7.3360e+03,
#         2.9415e+03, 2.8040e+03]), portfolio_vector=array([0.06153869, 0.43947999, 0.07834547, 0.09209479, 0.1298696 ,
#         0.06993181, 0.12873965]), mean_cost_price_array=array([1.0000e+00, 1.1070e+03, 7.0190e+03, 5.7200e+03, 7.3360e+03,
#         2.9415e+03, 2.8040e+03]), all_assets=992459.5556854538),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 10, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1050e+03, 7.0040e+03, 5.7100e+03, 7.3530e+03,
#         2.9705e+03, 2.7950e+03]), portfolio_vector=array([0.10858049, 0.08048412, 0.06423277, 0.17703843, 0.09467354,
#         0.29931276, 0.1756779 ]), mean_cost_price_array=array([1.00000000e+00, 1.11587927e+03, 7.02221988e+03, 5.71518243e+03,
#         7.32967299e+03, 2.96367136e+03, 2.80156096e+03]), all_assets=994458.5977375048),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 15, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.062e+03, 6.988e+03, 5.690e+03, 7.328e+03, 2.931e+03,
#         2.777e+03]), portfolio_vector=array([0.09256155, 0.04015797, 0.07618343, 0.25154456, 0.1893381 ,
#         0.072897  , 0.2773174 ]), mean_cost_price_array=array([1.00000000e+00, 1.14532784e+03, 7.00154079e+03, 5.70411171e+03,
#         7.34053350e+03, 3.09199780e+03, 2.78839797e+03]), all_assets=988475.0996684307),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 20, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.076e+03, 6.957e+03, 5.670e+03, 7.317e+03, 2.917e+03,
#         2.780e+03]), portfolio_vector=array([0.24448671, 0.03307649, 0.14210892, 0.21548998, 0.09047696,
#         0.05608843, 0.21827252]), mean_cost_price_array=array([1.00000000e+00, 1.05875931e+03, 6.97356367e+03, 5.69329031e+03,
#         7.34001054e+03, 2.93512891e+03, 2.77618008e+03]), all_assets=987368.2650962482),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 25, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0850e+03, 6.9680e+03, 5.7100e+03, 7.3020e+03,
#         2.9095e+03, 2.7830e+03]), portfolio_vector=array([0.14265871, 0.08093807, 0.26536303, 0.09743576, 0.11970256,
#         0.11150716, 0.18239471]), mean_cost_price_array=array([1.00000000e+00, 1.08129662e+03, 6.96210843e+03, 5.62104036e+03,
#         7.31329811e+03, 2.91325738e+03, 2.77941121e+03]), all_assets=988798.647207424),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 30, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0810e+03, 6.9170e+03, 5.6900e+03, 7.2730e+03,
#         2.9015e+03, 2.7720e+03]), portfolio_vector=array([0.08596543, 0.12058711, 0.05840242, 0.05846807, 0.29898858,
#         0.05201904, 0.32556934]), mean_cost_price_array=array([1.00000000e+00, 1.08368482e+03, 7.14788551e+03, 5.72333597e+03,
#         7.28460716e+03, 2.91866492e+03, 2.77816097e+03]), all_assets=985145.9110930957),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 35, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0890e+03, 6.8840e+03, 5.7100e+03, 7.2980e+03,
#         2.9155e+03, 2.7790e+03]), portfolio_vector=array([0.16264132, 0.06964044, 0.10110543, 0.11086731, 0.0705377 ,
#         0.0894049 , 0.3958029 ]), mean_cost_price_array=array([1.00000000e+00, 1.07507413e+03, 6.90293146e+03, 5.69943767e+03,
#         7.19189051e+03, 2.90733210e+03, 2.77323965e+03]), all_assets=987210.839648205),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 40, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0890e+03, 6.8570e+03, 5.6900e+03, 7.2850e+03,
#         2.9055e+03, 2.7780e+03]), portfolio_vector=array([0.17133009, 0.23867311, 0.13220108, 0.1353363 , 0.15247964,
#         0.05784452, 0.11213525]), mean_cost_price_array=array([1.00000000e+00, 1.08900000e+03, 6.87759917e+03, 5.70635116e+03,
#         7.29101218e+03, 2.92092624e+03, 2.78153373e+03]), all_assets=985727.1492621487),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 45, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.097e+03, 6.874e+03, 5.680e+03, 7.297e+03, 2.908e+03,
#         2.775e+03]), portfolio_vector=array([0.17667999, 0.17393404, 0.06379429, 0.05652726, 0.40242428,
#         0.0816414 , 0.04499874]), mean_cost_price_array=array([1.00000000e+00, 1.08596402e+03, 6.83875475e+03, 5.70385149e+03,
#         7.29245486e+03, 2.90623075e+03, 2.78245276e+03]), all_assets=987719.4038104428),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 50, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0980e+03, 6.8680e+03, 5.6800e+03, 7.3120e+03,
#         2.9155e+03, 2.7840e+03]), portfolio_vector=array([0.07164956, 0.148565  , 0.04942166, 0.08464431, 0.45440387,
#         0.09164087, 0.09967473]), mean_cost_price_array=array([1.00000000e+00, 1.09683003e+03, 6.87572589e+03, 5.68000000e+03,
#         7.29870963e+03, 2.90881174e+03, 2.77993017e+03]), all_assets=989285.927411113),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 55, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1040e+03, 6.8890e+03, 5.6900e+03, 7.2940e+03,
#         2.9185e+03, 2.7890e+03]), portfolio_vector=array([0.28060444, 0.18090401, 0.07770597, 0.09771893, 0.08559448,
#         0.10477912, 0.17269306]), mean_cost_price_array=array([1.00000000e+00, 1.09905360e+03, 6.87562446e+03, 5.68133664e+03,
#         7.38917035e+03, 2.91587768e+03, 2.78611356e+03]), all_assets=990874.1719430244),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 10, 0, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.111e+03, 6.888e+03, 5.710e+03, 7.303e+03, 2.918e+03,
#         2.784e+03]), portfolio_vector=array([0.25597611, 0.086306  , 0.12620539, 0.12762113, 0.13101119,
#         0.11724492, 0.15563526]), mean_cost_price_array=array([1.00000000e+00, 1.09624682e+03, 6.88861510e+03, 5.69464516e+03,
#         7.29711765e+03, 2.91844639e+03, 2.78953341e+03]), all_assets=991706.5472780934),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 10, 5, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1140e+03, 6.8890e+03, 5.7100e+03, 7.2980e+03,
#         2.9215e+03, 2.7800e+03]), portfolio_vector=array([0.07823672, 0.09778087, 0.10468648, 0.10587295, 0.29151279,
#         0.1447485 , 0.1771617 ]), mean_cost_price_array=array([1.00000000e+00, 1.11134491e+03, 6.88779427e+03, 5.71000000e+03,
#         7.30024556e+03, 2.91866163e+03, 2.78350893e+03]), all_assets=991705.2828620395),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 10, 10, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.112e+03, 6.864e+03, 5.740e+03, 7.300e+03, 2.923e+03,
#         2.781e+03]), portfolio_vector=array([0.11957587, 0.08037555, 0.07012521, 0.10938529, 0.2481743 ,
#         0.13062148, 0.24174228]), mean_cost_price_array=array([1.00000000e+00, 1.11442777e+03, 6.90117104e+03, 5.71082235e+03,
#         7.29765103e+03, 2.92133758e+03, 2.78026717e+03]), all_assets=992099.9372501515),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 10, 15, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.108e+03, 6.837e+03, 5.720e+03, 7.300e+03, 2.922e+03,
#         2.781e+03]), portfolio_vector=array([0.08912132, 0.12630431, 0.0932872 , 0.21743186, 0.17280638,
#         0.18841099, 0.11263794]), mean_cost_price_array=array([1.00000000e+00, 1.11054048e+03, 6.85724969e+03, 5.73004302e+03,
#         7.30000000e+03, 2.92269418e+03, 2.78100000e+03]), all_assets=990469.5759474179),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 10, 20, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1080e+03, 6.8540e+03, 5.7100e+03, 7.3000e+03,
#         2.9235e+03, 2.7790e+03]), portfolio_vector=array([0.42722108, 0.10320663, 0.12309382, 0.06894609, 0.09258866,
#         0.08901303, 0.0959307 ]), mean_cost_price_array=array([1.00000000e+00, 1.10800000e+03, 6.84108653e+03, 5.74147626e+03,
#         7.30000000e+03, 2.92032388e+03, 2.78134625e+03]), all_assets=990630.2682823126),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 10, 25, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1110e+03, 6.8520e+03, 5.7300e+03, 7.3030e+03,
#         2.9245e+03, 2.7800e+03]), portfolio_vector=array([0.10215091, 0.1236975 , 0.19397467, 0.147059  , 0.17757919,
#         0.08838472, 0.16715401]), mean_cost_price_array=array([1.00000000e+00, 1.10849258e+03, 6.85326759e+03, 5.72059949e+03,
#         7.30143667e+03, 2.92349351e+03, 2.77942644e+03]), all_assets=991578.0747754322),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 10, 30, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.103e+03, 6.864e+03, 5.730e+03, 7.300e+03, 2.926e+03,
#         2.787e+03]), portfolio_vector=array([0.09786964, 0.13044911, 0.11272293, 0.10886195, 0.11278049,
#         0.36795096, 0.06936493]), mean_cost_price_array=array([1.00000000e+00, 1.11053452e+03, 6.84330533e+03, 5.73000000e+03,
#         7.30472373e+03, 2.92563935e+03, 2.77008190e+03]), all_assets=991156.7943931621),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 10, 35, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0980e+03, 6.8450e+03, 5.7200e+03, 7.2920e+03,
#         2.9165e+03, 2.7790e+03]), portfolio_vector=array([0.1035021 , 0.08305733, 0.48203705, 0.11834106, 0.06964317,
#         0.04174241, 0.10167688]), mean_cost_price_array=array([1.00000000e+00, 1.10583633e+03, 6.84944155e+03, 5.72920523e+03,
#         7.30497245e+03, 3.00017127e+03, 2.78445522e+03]), all_assets=988757.1498546943),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 10, 40, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.095e+03, 6.849e+03, 5.720e+03, 7.301e+03, 2.932e+03,
#         2.781e+03]), portfolio_vector=array([0.10304995, 0.13063913, 0.0550579 , 0.08977191, 0.39926735,
#         0.13283052, 0.08938325]), mean_cost_price_array=array([1.00000000e+00, 1.09690034e+03, 6.81399201e+03, 5.72000000e+03,
#         7.29942969e+03, 2.92710778e+03, 2.77872542e+03]), all_assets=989684.8921126219),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 10, 45, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.095e+03, 6.855e+03, 5.730e+03, 7.301e+03, 2.934e+03,
#         2.779e+03]), portfolio_vector=array([0.12676978, 0.04418569, 0.04194245, 0.46648898, 0.07203565,
#         0.15555824, 0.09301922]), mean_cost_price_array=array([1.00000000e+00, 1.09500000e+03, 6.84712391e+03, 5.72807394e+03,
#         7.30100000e+03, 2.93229257e+03, 2.78091873e+03]), all_assets=990567.194093739),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 10, 50, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.092e+03, 6.851e+03, 5.740e+03, 7.301e+03, 2.932e+03,
#         2.783e+03]), portfolio_vector=array([0.23031086, 0.15053649, 0.27066445, 0.12294999, 0.0545687 ,
#         0.11477159, 0.05619791]), mean_cost_price_array=array([1.00000000e+00, 1.09287846e+03, 6.85161970e+03, 5.70197900e+03,
#         7.30100000e+03, 2.93470985e+03, 2.77636730e+03]), all_assets=990217.3857378676),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 10, 55, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0900e+03, 6.8550e+03, 5.7300e+03, 7.2950e+03,
#         2.9305e+03, 2.7770e+03]), portfolio_vector=array([0.05980185, 0.29770366, 0.06614188, 0.18122253, 0.11662289,
#         0.23138052, 0.04712668]), mean_cost_price_array=array([1.00000000e+00, 1.09101062e+03, 6.83860306e+03, 5.73678037e+03,
#         7.29780833e+03, 2.93124451e+03, 2.78414763e+03]), all_assets=989090.3565191774),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 11, 0, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.094e+03, 6.883e+03, 5.740e+03, 7.299e+03, 2.940e+03,
#         2.781e+03]), portfolio_vector=array([0.17176198, 0.09859618, 0.28318006, 0.06461856, 0.05830283,
#         0.24691555, 0.07662484]), mean_cost_price_array=array([1.00000000e+00, 1.08190911e+03, 6.87645023e+03, 5.71197822e+03,
#         7.29101498e+03, 2.93109178e+03, 2.77854266e+03]), all_assets=991636.3298930107),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 11, 5, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.099e+03, 6.873e+03, 5.750e+03, 7.302e+03, 2.943e+03,
#         2.782e+03]), portfolio_vector=array([0.10445627, 0.14105643, 0.06820574, 0.14189524, 0.24350923,
#         0.11217041, 0.18870668]), mean_cost_price_array=array([1.00000000e+00, 1.09549288e+03, 6.91441366e+03, 5.74544300e+03,
#         7.30128219e+03, 2.93639660e+03, 2.78159424e+03]), all_assets=992702.531881505),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 11, 10, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.096e+03, 6.859e+03, 5.740e+03, 7.298e+03, 2.939e+03,
#         2.781e+03]), portfolio_vector=array([0.16245577, 0.17393166, 0.11293249, 0.18577541, 0.16656508,
#         0.11623199, 0.0821076 ]), mean_cost_price_array=array([1.00000000e+00, 1.09842950e+03, 6.86744914e+03, 5.74763469e+03,
#         7.30385223e+03, 2.94286002e+03, 2.78330046e+03]), all_assets=991405.4152540006),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 11, 15, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.097e+03, 6.854e+03, 5.750e+03, 7.297e+03, 2.941e+03,
#         2.780e+03]), portfolio_vector=array([0.11967245, 0.21721132, 0.18645079, 0.09959052, 0.15352786,
#         0.10351245, 0.12003461]), mean_cost_price_array=array([1.00000000e+00, 1.09619871e+03, 6.85702554e+03, 5.73131810e+03,
#         7.29808451e+03, 2.93875326e+03, 2.78068362e+03]), all_assets=991645.3477517263),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 11, 20, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.096e+03, 6.858e+03, 5.740e+03, 7.301e+03, 2.940e+03,
#         2.777e+03]), portfolio_vector=array([0.07472882, 0.07788194, 0.14407923, 0.04947747, 0.06515097,
#         0.52124871, 0.06743286]), mean_cost_price_array=array([1.00000000e+00, 1.09878724e+03, 6.85281915e+03, 5.76009922e+03,
#         7.29156615e+03, 2.94019858e+03, 2.78233595e+03]), all_assets=991360.4985853205),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 11, 25, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.095e+03, 6.855e+03, 5.730e+03, 7.295e+03, 2.929e+03,
#         2.773e+03]), portfolio_vector=array([0.19910694, 0.11519827, 0.12632162, 0.08456461, 0.09624799,
#         0.17866966, 0.19989092]), mean_cost_price_array=array([1.00000000e+00, 1.09567636e+03, 6.85842483e+03, 5.73584851e+03,
#         7.29906356e+03, 2.96101420e+03, 2.77434926e+03]), all_assets=990028.8988244929),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 12, 30, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.094e+03, 6.847e+03, 5.740e+03, 7.282e+03, 2.929e+03,
#         2.751e+03]), portfolio_vector=array([0.11071241, 0.06511578, 0.03557008, 0.13055988, 0.32631229,
#         0.17708026, 0.15464931]), mean_cost_price_array=array([1.00000000e+00, 1.09577049e+03, 6.87542540e+03, 5.73350069e+03,
#         7.28583405e+03, 2.92900000e+03, 2.77925787e+03]), all_assets=988364.1059501306),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 12, 35, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0880e+03, 6.8300e+03, 5.7200e+03, 7.2420e+03,
#         2.9035e+03, 2.7330e+03]), portfolio_vector=array([0.10870546, 0.12312394, 0.29994833, 0.05112052, 0.11630882,
#         0.16827178, 0.13252115]), mean_cost_price_array=array([1.00000000e+00, 1.09117026e+03, 6.83202021e+03, 5.77113490e+03,
#         7.35411855e+03, 2.93022332e+03, 2.75396395e+03]), all_assets=983848.1978756455),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 12, 40, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.087e+03, 6.825e+03, 5.710e+03, 7.240e+03, 2.903e+03,
#         2.731e+03]), portfolio_vector=array([0.26782407, 0.07328383, 0.06720092, 0.39515214, 0.06012846,
#         0.05978175, 0.07662883]), mean_cost_price_array=array([1.00000000e+00, 1.08868005e+03, 6.84732081e+03, 5.71129258e+03,
#         7.24387106e+03, 2.90440840e+03, 2.73445933e+03]), all_assets=982972.2244445033),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 12, 45, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.087e+03, 6.830e+03, 5.710e+03, 7.250e+03, 2.912e+03,
#         2.729e+03]), portfolio_vector=array([0.41662807, 0.09977609, 0.22747193, 0.08681466, 0.05481247,
#         0.05308467, 0.06141211]), mean_cost_price_array=array([1.00000000e+00, 1.08700000e+03, 6.82852233e+03, 5.71000000e+03,
#         7.23901897e+03, 2.90183683e+03, 2.73149283e+03]), all_assets=983328.0162802453),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 12, 50, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0870e+03, 6.8350e+03, 5.6900e+03, 7.2510e+03,
#         2.9165e+03, 2.7290e+03]), portfolio_vector=array([0.1365557 , 0.12781448, 0.07457677, 0.12113867, 0.11516909,
#         0.1586039 , 0.26614139]), mean_cost_price_array=array([1.00000000e+00, 1.08700000e+03, 6.81973632e+03, 5.70428445e+03,
#         7.25052395e+03, 2.91499136e+03, 2.72900000e+03]), all_assets=983221.1011161277),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 12, 55, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0890e+03, 6.8310e+03, 5.7000e+03, 7.2520e+03,
#         2.9145e+03, 2.7240e+03]), portfolio_vector=array([0.09204486, 0.24024771, 0.10309697, 0.07719256, 0.09199249,
#         0.24239151, 0.1530339 ]), mean_cost_price_array=array([1.00000000e+00, 1.08793411e+03, 6.83389153e+03, 5.68428068e+03,
#         7.25074799e+03, 2.91580765e+03, 2.73267885e+03]), all_assets=983303.1493645603),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 13, 0, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.089e+03, 6.822e+03, 5.710e+03, 7.253e+03, 2.921e+03,
#         2.731e+03]), portfolio_vector=array([0.10100572, 0.10210366, 0.17706293, 0.21405001, 0.08463755,
#         0.18797425, 0.13316587]), mean_cost_price_array=array([1.00000000e+00, 1.08900000e+03, 6.82722867e+03, 5.70639069e+03,
#         7.25191395e+03, 2.91260728e+03, 2.72294232e+03]), all_assets=984203.2073224983),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 13, 5, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.086e+03, 6.804e+03, 5.700e+03, 7.254e+03, 2.926e+03,
#         2.733e+03]), portfolio_vector=array([0.18002466, 0.06086118, 0.08141462, 0.29413278, 0.11427372,
#         0.06829548, 0.20099756]), mean_cost_price_array=array([1.00000000e+00, 1.09102218e+03, 6.84306778e+03, 5.70726907e+03,
#         7.25325878e+03, 2.91220609e+03, 2.73167316e+03]), all_assets=983595.2276279732),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 13, 10, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.086e+03, 6.805e+03, 5.690e+03, 7.246e+03, 2.928e+03,
#         2.732e+03]), portfolio_vector=array([0.25424407, 0.07213199, 0.16063881, 0.11037419, 0.08102543,
#         0.05923891, 0.2623466 ]), mean_cost_price_array=array([1.00000000e+00, 1.08600000e+03, 6.80449295e+03, 5.71661032e+03,
#         7.25727386e+03, 2.92569193e+03, 2.73276611e+03]), all_assets=983285.5049901255),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 13, 15, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0840e+03, 6.8070e+03, 5.6800e+03, 7.2410e+03,
#         2.9225e+03, 2.7270e+03]), portfolio_vector=array([0.17463011, 0.08079426, 0.06944507, 0.06049407, 0.12784309,
#         0.1360069 , 0.3507865 ]), mean_cost_price_array=array([1.00000000e+00, 1.08578446e+03, 6.80236663e+03, 5.69823565e+03,
#         7.24417062e+03, 2.92489399e+03, 2.73073712e+03]), all_assets=982085.5147779578),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 13, 20, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.083e+03, 6.802e+03, 5.690e+03, 7.241e+03, 2.923e+03,
#         2.733e+03]), portfolio_vector=array([0.10205601, 0.15062431, 0.1416016 , 0.170067  , 0.15634037,
#         0.15552104, 0.12378967]), mean_cost_price_array=array([1.00000000e+00, 1.08353571e+03, 6.80444946e+03, 5.68643793e+03,
#         7.24100000e+03, 2.92256282e+03, 2.71596627e+03]), all_assets=982434.5692936222),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 13, 25, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.083e+03, 6.801e+03, 5.690e+03, 7.240e+03, 2.924e+03,
#         2.731e+03]), portfolio_vector=array([0.15342696, 0.12834685, 0.08636961, 0.17131361, 0.15641428,
#         0.09580641, 0.20832227]), mean_cost_price_array=array([1.00000000e+00, 1.08300000e+03, 6.80263950e+03, 5.69000000e+03,
#         7.24099954e+03, 2.92237591e+03, 2.73218776e+03]), all_assets=982283.3022127608),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 13, 30, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.083e+03, 6.799e+03, 5.700e+03, 7.241e+03, 2.924e+03,
#         2.729e+03]), portfolio_vector=array([0.11176205, 0.19173775, 0.1268593 , 0.0735809 , 0.10740043,
#         0.07286592, 0.31579365]), mean_cost_price_array=array([1.00000000e+00, 1.08300000e+03, 6.80036143e+03, 5.67667383e+03,
#         7.23954325e+03, 2.92400000e+03, 2.73031855e+03]), all_assets=982161.0850270347),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 13, 35, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0850e+03, 6.7970e+03, 5.7000e+03, 7.2430e+03,
#         2.9265e+03, 2.7320e+03]), portfolio_vector=array([0.04264794, 0.05848869, 0.52406974, 0.04643831, 0.09693493,
#         0.0450531 , 0.18636729]), mean_cost_price_array=array([1.00000000e+00, 1.07843296e+03, 6.79748388e+03, 5.70000000e+03,
#         7.24078396e+03, 2.92245411e+03, 2.72691214e+03]), all_assets=982381.1085442645),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 13, 40, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.082e+03, 6.795e+03, 5.680e+03, 7.225e+03, 2.915e+03,
#         2.733e+03]), portfolio_vector=array([0.39147624, 0.08884904, 0.23301524, 0.08697605, 0.05216024,
#         0.07412022, 0.07340298]), mean_cost_price_array=array([1.00000000e+00, 1.08397142e+03, 6.79950140e+03, 5.69065174e+03,
#         7.25840204e+03, 2.92196973e+03, 2.73045753e+03]), all_assets=981385.5332270591),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 13, 45, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0820e+03, 6.7870e+03, 5.6900e+03, 7.2190e+03,
#         2.9115e+03, 2.7260e+03]), portfolio_vector=array([0.04453019, 0.09192401, 0.05654414, 0.08851223, 0.34795357,
#         0.32394853, 0.04658733]), mean_cost_price_array=array([1.00000000e+00, 1.08200000e+03, 6.81995207e+03, 5.68014928e+03,
#         7.21989932e+03, 2.91230041e+03, 2.73700874e+03]), all_assets=980690.729803254),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 13, 50, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.081e+03, 6.794e+03, 5.680e+03, 7.216e+03, 2.909e+03,
#         2.727e+03]), portfolio_vector=array([0.0926709 , 0.12255838, 0.13968967, 0.13187754, 0.07863843,
#         0.12462307, 0.30994201]), mean_cost_price_array=array([1.00000000e+00, 1.08174952e+03, 6.79116295e+03, 5.68670142e+03,
#         7.22927168e+03, 2.91549446e+03, 2.72684960e+03]), all_assets=980468.1542244928),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 13, 55, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.081e+03, 6.785e+03, 5.680e+03, 7.217e+03, 2.904e+03,
#         2.724e+03]), portfolio_vector=array([0.11180595, 0.09561581, 0.10331513, 0.11890538, 0.25503904,
#         0.09066395, 0.22465474]), mean_cost_price_array=array([1.00000000e+00, 1.08100000e+03, 6.79715868e+03, 5.68000000e+03,
#         7.21669146e+03, 2.91086445e+03, 2.72813644e+03]), all_assets=979973.5116713131),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 14, 0, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.086e+03, 6.796e+03, 5.700e+03, 7.230e+03, 2.917e+03,
#         2.731e+03]), portfolio_vector=array([0.179564  , 0.19594573, 0.13771349, 0.05713272, 0.08258365,
#         0.05559099, 0.29146941]), mean_cost_price_array=array([1.00000000e+00, 1.08355492e+03, 6.78775465e+03, 5.65833240e+03,
#         7.18987981e+03, 2.89575588e+03, 2.72560414e+03]), all_assets=982401.2709465403),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 14, 5, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0860e+03, 6.8030e+03, 5.7100e+03, 7.2540e+03,
#         2.9225e+03, 2.7350e+03]), portfolio_vector=array([0.06901471, 0.19024413, 0.10866031, 0.30574697, 0.05898499,
#         0.19213201, 0.07521688]), mean_cost_price_array=array([1.00000000e+00, 1.08600000e+03, 6.79413091e+03, 5.70813056e+03,
#         7.22033088e+03, 2.92090774e+03, 2.71949750e+03]), all_assets=983694.6545049914),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 14, 10, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0880e+03, 6.8050e+03, 5.7300e+03, 7.2550e+03,
#         2.9255e+03, 2.7390e+03]), portfolio_vector=array([0.09181134, 0.10153755, 0.14303141, 0.10124015, 0.23854364,
#         0.19806574, 0.12577018]), mean_cost_price_array=array([1.00000000e+00, 1.08424960e+03, 6.80348169e+03, 5.66944888e+03,
#         7.25475294e+03, 2.92258981e+03, 2.73660670e+03]), all_assets=984682.0812386791),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 14, 15, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.089e+03, 6.799e+03, 5.740e+03, 7.261e+03, 2.926e+03,
#         2.741e+03]), portfolio_vector=array([0.06840398, 0.0624404 , 0.09741145, 0.2778565 , 0.38165986,
#         0.07412489, 0.03810293]), mean_cost_price_array=array([1.00000000e+00, 1.08737368e+03, 6.80779502e+03, 5.73635299e+03,
#         7.25724985e+03, 2.92466483e+03, 2.73439894e+03]), all_assets=985482.1820154733),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 14, 20, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0900e+03, 6.8060e+03, 5.7500e+03, 7.2660e+03,
#         2.9255e+03, 2.7390e+03]), portfolio_vector=array([0.14207966, 0.08064157, 0.12663942, 0.14067107, 0.22905081,
#         0.17124138, 0.10967609]), mean_cost_price_array=array([1.00000000e+00, 1.08922538e+03, 6.80061272e+03, 5.73022322e+03,
#         7.25766708e+03, 2.92571629e+03, 2.73969397e+03]), all_assets=985972.8972164915),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 14, 25, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0890e+03, 6.8010e+03, 5.7500e+03, 7.2770e+03,
#         2.9275e+03, 2.7400e+03]), portfolio_vector=array([0.10909563, 0.14620171, 0.16482986, 0.14417099, 0.11882399,
#         0.19932611, 0.11755171]), mean_cost_price_array=array([1.00000000e+00, 1.08955101e+03, 6.80483830e+03, 5.75000000e+03,
#         7.25576598e+03, 2.92578080e+03, 2.73906675e+03]), all_assets=986075.2923768683),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 14, 30, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0900e+03, 6.7990e+03, 5.7500e+03, 7.2800e+03,
#         2.9295e+03, 2.7450e+03]), portfolio_vector=array([0.07434356, 0.27058571, 0.13569776, 0.2139738 , 0.12371186,
#         0.08846221, 0.0932251 ]), mean_cost_price_array=array([1.00000000e+00, 1.08945945e+03, 6.80142746e+03, 5.75000000e+03,
#         7.27711875e+03, 2.92499266e+03, 2.73868687e+03]), all_assets=986558.5893732962),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 14, 35, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.091e+03, 6.803e+03, 5.760e+03, 7.263e+03, 2.924e+03,
#         2.738e+03]), portfolio_vector=array([0.08330627, 0.16704537, 0.05721228, 0.07321268, 0.10207837,
#         0.22103704, 0.29610799]), mean_cost_price_array=array([1.00000000e+00, 1.08937690e+03, 6.79349670e+03, 5.73069077e+03,
#         7.28357722e+03, 2.92619945e+03, 2.74020063e+03]), all_assets=985479.0765919792),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 14, 40, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0890e+03, 6.7890e+03, 5.7500e+03, 7.2640e+03,
#         2.9265e+03, 2.7390e+03]), portfolio_vector=array([0.09599202, 0.1382171 , 0.13011966, 0.08498151, 0.05314339,
#         0.17386055, 0.32368578]), mean_cost_price_array=array([1.00000000e+00, 1.09141367e+03, 6.79514541e+03, 5.75860357e+03,
#         7.26207817e+03, 2.92331766e+03, 2.73808450e+03]), all_assets=985090.3020022039),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 14, 45, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0910e+03, 6.7800e+03, 5.7400e+03, 7.2580e+03,
#         2.9245e+03, 2.7390e+03]), portfolio_vector=array([0.1722245 , 0.11191927, 0.08440752, 0.14372316, 0.08763436,
#         0.19644829, 0.20364289]), mean_cost_price_array=array([1.00000000e+00, 1.08852462e+03, 6.79386072e+03, 5.74590472e+03,
#         7.26163685e+03, 2.92626947e+03, 2.73900000e+03]), all_assets=984732.768286128),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 14, 50, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0890e+03, 6.7620e+03, 5.7300e+03, 7.2500e+03,
#         2.9235e+03, 2.7380e+03]), portfolio_vector=array([0.26190941, 0.26458279, 0.13751961, 0.05730759, 0.05095341,
#         0.07213403, 0.15559316]), mean_cost_price_array=array([1.00000000e+00, 1.08984537e+03, 6.77303080e+03, 5.75506282e+03,
#         7.26375893e+03, 2.92622541e+03, 2.73930976e+03]), all_assets=983661.775096007),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 14, 55, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0890e+03, 6.7470e+03, 5.7400e+03, 7.2700e+03,
#         2.9265e+03, 2.7300e+03]), portfolio_vector=array([0.15334022, 0.1930838 , 0.10489564, 0.14859198, 0.0893073 ,
#         0.07542046, 0.23536059]), mean_cost_price_array=array([1.00000000e+00, 1.08900000e+03, 6.76662820e+03, 5.73613526e+03,
#         7.25855386e+03, 2.92362681e+03, 2.73527500e+03]), all_assets=983329.993748533),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 11, 9, 0, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0910e+03, 6.5390e+03, 5.5400e+03, 7.3930e+03,
#         2.9865e+03, 2.7780e+03]), portfolio_vector=array([0.11079503, 0.16884107, 0.17951577, 0.13464524, 0.23083634,
#         0.05973848, 0.11562807]), mean_cost_price_array=array([1.00000000e+00, 1.08870231e+03, 6.65711792e+03, 5.75361375e+03,
#         7.34447437e+03, 2.90898296e+03, 2.67830388e+03]), all_assets=980623.5644629555),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 11, 9, 5, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0910e+03, 6.5450e+03, 5.5900e+03, 7.4280e+03,
#         2.9625e+03, 2.7850e+03]), portfolio_vector=array([0.08008368, 0.10813821, 0.14345421, 0.12498904, 0.07878618,
#         0.20295457, 0.26159411]), mean_cost_price_array=array([1.00000000e+00, 1.09100000e+03, 6.53748979e+03, 5.53568695e+03,
#         7.32503575e+03, 2.96950286e+03, 2.78190016e+03]), all_assets=981271.6272722267),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 11, 9, 10, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.093e+03, 6.595e+03, 5.580e+03, 7.426e+03, 2.961e+03,
#         2.775e+03]), portfolio_vector=array([0.17764258, 0.29217106, 0.0739003 , 0.0815389 , 0.05253648,
#         0.09124174, 0.23096893]), mean_cost_price_array=array([1.00000000e+00, 1.09225845e+03, 6.49720556e+03, 5.59530035e+03,
#         7.42899829e+03, 2.96433464e+03, 2.78628455e+03]), all_assets=981335.033396959),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 11, 9, 15, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0990e+03, 6.6090e+03, 5.5500e+03, 7.4260e+03,
#         2.9635e+03, 2.7660e+03]), portfolio_vector=array([0.3099183 , 0.06541861, 0.06920826, 0.0963452 , 0.27303415,
#         0.05309298, 0.1329825 ]), mean_cost_price_array=array([1.00000000e+00, 1.07204510e+03, 6.59401315e+03, 5.57526317e+03,
#         7.42600000e+03, 2.95919834e+03, 2.78158705e+03]), all_assets=980944.0480747814),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 11, 9, 20, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0970e+03, 6.6420e+03, 5.5600e+03, 7.4250e+03,
#         2.9595e+03, 2.7700e+03]), portfolio_vector=array([0.18163116, 0.1108778 , 0.04292176, 0.22284327, 0.05123114,
#         0.25188987, 0.13860499]), mean_cost_price_array=array([1.00000000e+00, 1.09817755e+03, 6.58853849e+03, 5.55566992e+03,
#         7.43032731e+03, 2.96034175e+03, 2.76615774e+03]), all_assets=981206.55751471),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 11, 9, 25, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0940e+03, 6.6450e+03, 5.5800e+03, 7.4320e+03,
#         2.9625e+03, 2.7670e+03]), portfolio_vector=array([0.1309112 , 0.20148077, 0.19004372, 0.24897733, 0.04235603,
#         0.14759769, 0.03863325]), mean_cost_price_array=array([1.00000000e+00, 1.09564548e+03, 6.64432253e+03, 5.56204530e+03,
#         7.42353016e+03, 2.95737798e+03, 2.77774527e+03]), all_assets=981773.8436020508),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 11, 9, 30, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.094e+03, 6.663e+03, 5.580e+03, 7.428e+03, 2.957e+03,
#         2.770e+03]), portfolio_vector=array([0.22464631, 0.06587527, 0.08936263, 0.07955938, 0.14045333,
#         0.19713436, 0.20296873]), mean_cost_price_array=array([1.00000000e+00, 1.09400000e+03, 6.62461726e+03, 5.58000000e+03,
#         7.42920559e+03, 2.96111021e+03, 2.76942837e+03]), all_assets=981794.0133608668),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 11, 9, 35, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0950e+03, 6.6450e+03, 5.5800e+03, 7.4290e+03,
#         2.9625e+03, 2.7630e+03]), portfolio_vector=array([0.1303932 , 0.09480836, 0.18162715, 0.08558955, 0.0607663 ,
#         0.37269952, 0.07411592]), mean_cost_price_array=array([1.00000000e+00, 1.09430462e+03, 6.65383131e+03, 5.58000000e+03,
#         7.42668857e+03, 2.95958576e+03, 2.78211917e+03]), all_assets=981902.1105430698),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 11, 9, 40, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0980e+03, 6.6490e+03, 5.6100e+03, 7.4380e+03,
#         2.9695e+03, 2.7720e+03]), portfolio_vector=array([0.10973688, 0.1681067 , 0.03998177, 0.12889164, 0.13716637,
#         0.04967336, 0.36644328]), mean_cost_price_array=array([1.00000000e+00, 1.09630792e+03, 6.63086620e+03, 5.59002465e+03,
#         7.43401863e+03, 2.91699425e+03, 2.77017859e+03]), all_assets=984508.8349053904),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 11, 9, 45, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.098e+03, 6.658e+03, 5.600e+03, 7.436e+03, 2.964e+03,
#         2.794e+03]), portfolio_vector=array([0.05516104, 0.09150223, 0.37750529, 0.07562693, 0.17344512,
#         0.12676819, 0.09999121]), mean_cost_price_array=array([1.00000000e+00, 1.09800000e+03, 6.65704636e+03, 5.61699761e+03,
#         7.43757984e+03, 2.96614924e+03, 2.71280764e+03]), all_assets=985383.4006066584),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 11, 9, 50, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0970e+03, 6.6760e+03, 5.5900e+03, 7.4310e+03,
#         2.9615e+03, 2.7980e+03]), portfolio_vector=array([0.11845134, 0.36427506, 0.09407751, 0.08574099, 0.08827029,
#         0.07716624, 0.17201858]), mean_cost_price_array=array([1.00000000e+00, 1.09725099e+03, 6.60356817e+03, 5.59880560e+03,
#         7.44081912e+03, 2.96560397e+03, 2.79567129e+03]), all_assets=985276.2871068763),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 11, 9, 55, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.0980e+03, 6.6890e+03, 5.5800e+03, 7.4270e+03,
#         2.9595e+03, 2.7870e+03]), portfolio_vector=array([0.3416485 , 0.13749487, 0.1136941 , 0.09917912, 0.08280397,
#         0.07295399, 0.15222544]), mean_cost_price_array=array([1.00000000e+00, 1.09534683e+03, 6.67821641e+03, 5.58863411e+03,
#         7.43126400e+03, 2.96161515e+03, 2.79938789e+03]), all_assets=984760.9992943007),
# ...
#         2.9865e+03, 2.7910e+03]), portfolio_vector=array([0.10060303, 0.07735009, 0.0619693 , 0.48835894, 0.07748326,
#         0.09724195, 0.09699343]), mean_cost_price_array=array([1.00000000e+00, 1.12829179e+03, 6.60645369e+03, 5.71828681e+03,
#         7.49092436e+03, 2.98484462e+03, 2.72987945e+03]), all_assets=997813.5633472563),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 9, 35, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1300e+03, 6.7080e+03, 5.7300e+03, 7.4970e+03,
#         2.9885e+03, 2.7820e+03]), portfolio_vector=array([0.09718228, 0.11522874, 0.09216059, 0.28548242, 0.1618181 ,
#         0.10152794, 0.14659994]), mean_cost_price_array=array([1.00000000e+00, 1.12932843e+03, 6.69451774e+03, 5.71287136e+03,
#         7.49747855e+03, 2.98658401e+03, 2.78793271e+03]), all_assets=998263.0123113412),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 9, 40, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1280e+03, 6.7060e+03, 5.7200e+03, 7.4830e+03,
#         2.9805e+03, 2.7790e+03]), portfolio_vector=array([0.06845107, 0.10917351, 0.19704301, 0.08471857, 0.14114562,
#         0.29790233, 0.10156587]), mean_cost_price_array=array([1.00000000e+00, 1.13011051e+03, 6.70693663e+03, 5.75369184e+03,
#         7.49904569e+03, 2.98322345e+03, 2.78333233e+03]), all_assets=996695.347935949),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 9, 45, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.132e+03, 6.721e+03, 5.740e+03, 7.474e+03, 2.973e+03,
#         2.775e+03]), portfolio_vector=array([0.13904869, 0.08059464, 0.13352455, 0.0807915 , 0.37316612,
#         0.08974378, 0.10313071]), mean_cost_price_array=array([1.00000000e+00, 1.12656262e+03, 6.69881587e+03, 5.71895544e+03,
#         7.47739990e+03, 2.99783233e+03, 2.77893346e+03]), all_assets=996739.0685443454),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 9, 50, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.130e+03, 6.707e+03, 5.720e+03, 7.470e+03, 2.973e+03,
#         2.776e+03]), portfolio_vector=array([0.07028473, 0.14015825, 0.22421385, 0.06152144, 0.19153533,
#         0.10270476, 0.20958163]), mean_cost_price_array=array([1.00000000e+00, 1.13114912e+03, 6.71532792e+03, 5.74619803e+03,
#         7.47779644e+03, 2.97300000e+03, 2.77550727e+03]), all_assets=995786.17087438),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 9, 55, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.131e+03, 6.715e+03, 5.710e+03, 7.457e+03, 2.966e+03,
#         2.773e+03]), portfolio_vector=array([0.27187314, 0.13619031, 0.2579553 , 0.11246054, 0.06616727,
#         0.09857534, 0.0567781 ]), mean_cost_price_array=array([1.00000000e+00, 1.12996977e+03, 6.70803690e+03, 5.71546189e+03,
#         7.49457245e+03, 2.97327735e+03, 2.78406371e+03]), all_assets=995609.9065291967),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 10, 0, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1310e+03, 6.6910e+03, 5.7000e+03, 7.4370e+03,
#         2.9515e+03, 2.7700e+03]), portfolio_vector=array([0.0968715 , 0.34219418, 0.10608852, 0.06507852, 0.20157059,
#         0.0799944 , 0.1082023 ]), mean_cost_price_array=array([1.00000000e+00, 1.13100000e+03, 6.74923747e+03, 5.71727712e+03,
#         7.44355767e+03, 2.96930814e+03, 2.77157495e+03]), all_assets=994074.7803382056),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 10, 5, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1360e+03, 6.7180e+03, 5.7100e+03, 7.4360e+03,
#         2.9505e+03, 2.7680e+03]), portfolio_vector=array([0.05493108, 0.05154347, 0.05349068, 0.58465343, 0.14487724,
#         0.06062799, 0.0498761 ]), mean_cost_price_array=array([1.00000000e+00, 1.10270493e+03, 6.66430940e+03, 5.70888649e+03,
#         7.43738920e+03, 2.95181715e+03, 2.77232968e+03]), all_assets=995459.9145269075),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 10, 10, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.134e+03, 6.715e+03, 5.710e+03, 7.445e+03, 2.951e+03,
#         2.770e+03]), portfolio_vector=array([0.36446619, 0.11363935, 0.11462392, 0.11043363, 0.14019733,
#         0.0812736 , 0.07536598]), mean_cost_price_array=array([1.00000000e+00, 1.13490556e+03, 6.71639938e+03, 5.71000000e+03,
#         7.43568819e+03, 2.95062694e+03, 2.76867546e+03]), all_assets=995446.6320060226),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 10, 15, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.131e+03, 6.724e+03, 5.700e+03, 7.451e+03, 2.961e+03,
#         2.774e+03]), portfolio_vector=array([0.07740418, 0.18764613, 0.21343635, 0.17301657, 0.19424448,
#         0.06093938, 0.09331291]), mean_cost_price_array=array([1.00000000e+00, 1.13281204e+03, 6.71916008e+03, 5.70637176e+03,
#         7.44666590e+03, 2.94761780e+03, 2.77076461e+03]), all_assets=995431.1389927916),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 10, 20, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1310e+03, 6.7230e+03, 5.7000e+03, 7.4500e+03,
#         2.9555e+03, 2.7810e+03]), portfolio_vector=array([0.04933988, 0.05447009, 0.05794867, 0.05874419, 0.15071316,
#         0.10881934, 0.51996467]), mean_cost_price_array=array([1.00000000e+00, 1.13100000e+03, 6.72667867e+03, 5.70000000e+03,
#         7.45128727e+03, 2.95857099e+03, 2.77974197e+03]), all_assets=996507.3196920386),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 10, 25, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1320e+03, 6.7110e+03, 5.6900e+03, 7.4460e+03,
#         2.9495e+03, 2.7820e+03]), portfolio_vector=array([0.07636918, 0.1450093 , 0.07825724, 0.17583781, 0.09279868,
#         0.30959213, 0.12213567]), mean_cost_price_array=array([1.00000000e+00, 1.13162368e+03, 6.71987849e+03, 5.69333814e+03,
#         7.45249906e+03, 2.95160668e+03, 2.77773713e+03]), all_assets=995556.2822501784),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 10, 30, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1310e+03, 6.7010e+03, 5.7000e+03, 7.4370e+03,
#         2.9465e+03, 2.7990e+03]), portfolio_vector=array([0.09998077, 0.20151226, 0.19299236, 0.15128252, 0.12606488,
#         0.13810006, 0.09006715]), mean_cost_price_array=array([1.00000000e+00, 1.13171893e+03, 6.70504866e+03, 5.68835710e+03,
#         7.44361667e+03, 2.95321816e+03, 2.77580760e+03]), all_assets=995613.8440316011),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 10, 35, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1310e+03, 6.6840e+03, 5.7000e+03, 7.4320e+03,
#         2.9425e+03, 2.8000e+03]), portfolio_vector=array([0.24469165, 0.29543585, 0.06782737, 0.10537946, 0.08557337,
#         0.10101663, 0.10007566]), mean_cost_price_array=array([1.00000000e+00, 1.13100000e+03, 6.73226415e+03, 5.70000000e+03,
#         7.43936338e+03, 2.94796279e+03, 2.79909939e+03]), all_assets=995284.3096409707),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 10, 40, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1320e+03, 6.6810e+03, 5.7200e+03, 7.4320e+03,
#         2.9385e+03, 2.7980e+03]), portfolio_vector=array([0.09263731, 0.15886505, 0.08280212, 0.30470906, 0.08892996,
#         0.09387214, 0.17818436]), mean_cost_price_array=array([1.00000000e+00, 1.13014040e+03, 6.68345410e+03, 5.71306537e+03,
#         7.43200000e+03, 2.94279464e+03, 2.79912145e+03]), all_assets=996197.5539468975),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 10, 45, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.130e+03, 6.677e+03, 5.710e+03, 7.438e+03, 2.942e+03,
#         2.786e+03]), portfolio_vector=array([0.08266222, 0.13177387, 0.39244941, 0.06602334, 0.05961129,
#         0.09382527, 0.1736546 ]), mean_cost_price_array=array([1.00000000e+00, 1.13240973e+03, 6.67784443e+03, 5.75612491e+03,
#         7.42903131e+03, 2.93848998e+03, 2.79827455e+03]), all_assets=995033.9027913056),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 10, 50, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.129e+03, 6.675e+03, 5.710e+03, 7.434e+03, 2.937e+03,
#         2.792e+03]), portfolio_vector=array([0.20460909, 0.14195837, 0.14045484, 0.22783174, 0.12999035,
#         0.06383581, 0.09131981]), mean_cost_price_array=array([1.00000000e+00, 1.12992757e+03, 6.68058743e+03, 5.71000000e+03,
#         7.43583362e+03, 2.94433756e+03, 2.78056406e+03]), all_assets=994885.2188142479),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 10, 55, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1290e+03, 6.6780e+03, 5.7100e+03, 7.4310e+03,
#         2.9395e+03, 2.7930e+03]), portfolio_vector=array([0.13035337, 0.15806428, 0.20136853, 0.20138386, 0.21058294,
#         0.05679386, 0.04145317]), mean_cost_price_array=array([1.00000000e+00, 1.12900000e+03, 6.67590670e+03, 5.71000000e+03,
#         7.43285099e+03, 2.93668782e+03, 2.79079640e+03]), all_assets=994953.5796161465),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 11, 0, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1280e+03, 6.6830e+03, 5.7200e+03, 7.4330e+03,
#         2.9495e+03, 2.8030e+03]), portfolio_vector=array([0.18169254, 0.16470547, 0.08539696, 0.10981525, 0.13327134,
#         0.10184411, 0.22327433]), mean_cost_price_array=array([1.00000000e+00, 1.12895759e+03, 6.67121625e+03, 5.70165317e+03,
#         7.42984302e+03, 2.94391170e+03, 2.80113915e+03]), all_assets=996239.1761470074),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 11, 5, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1280e+03, 6.6650e+03, 5.7200e+03, 7.4280e+03,
#         2.9455e+03, 2.7870e+03]), portfolio_vector=array([0.08771451, 0.13175978, 0.10489671, 0.17805318, 0.06851454,
#         0.33497602, 0.09408526]), mean_cost_price_array=array([1.00000000e+00, 1.12800000e+03, 6.67963374e+03, 5.72000000e+03,
#         7.43773207e+03, 2.94671609e+03, 2.82480286e+03]), all_assets=994924.1868764206),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 11, 10, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1290e+03, 6.6690e+03, 5.7100e+03, 7.4210e+03,
#         2.9435e+03, 2.7860e+03]), portfolio_vector=array([0.13012712, 0.28640109, 0.08248603, 0.15131868, 0.17741126,
#         0.04852146, 0.12373435]), mean_cost_price_array=array([1.00000000e+00, 1.12853944e+03, 6.66390914e+03, 5.72174861e+03,
#         7.42370134e+03, 2.95730080e+03, 2.78676026e+03]), all_assets=994719.5613505633),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 11, 15, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1270e+03, 6.6700e+03, 5.7100e+03, 7.4120e+03,
#         2.9405e+03, 2.7740e+03]), portfolio_vector=array([0.08512394, 0.09550842, 0.06267875, 0.08219958, 0.04872515,
#         0.05073129, 0.57503286]), mean_cost_price_array=array([1.00000000e+00, 1.13300327e+03, 6.66868016e+03, 5.71000000e+03,
#         7.44481998e+03, 2.94337429e+03, 2.77657810e+03]), all_assets=991986.6678993918),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 11, 20, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.124e+03, 6.670e+03, 5.700e+03, 7.420e+03, 2.946e+03,
#         2.772e+03]), portfolio_vector=array([0.41794051, 0.14215453, 0.11403566, 0.05956873, 0.08715547,
#         0.1055257 , 0.07361939]), mean_cost_price_array=array([1.00000000e+00, 1.12601072e+03, 6.67000000e+03, 5.71377832e+03,
#         7.41552160e+03, 2.94335029e+03, 2.78761433e+03]), all_assets=991744.2663642202),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 11, 25, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.126e+03, 6.681e+03, 5.700e+03, 7.417e+03, 2.942e+03,
#         2.772e+03]), portfolio_vector=array([0.10832551, 0.06963555, 0.0806537 , 0.13409171, 0.40060629,
#         0.14324915, 0.06343809]), mean_cost_price_array=array([1.00000000e+00, 1.12190951e+03, 6.66541998e+03, 5.70000000e+03,
#         7.41765248e+03, 2.94494293e+03, 2.77200000e+03]), all_assets=991645.536928729),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 12, 12, 30, tzinfo=<DstTzInfo 'Asia/Tokyo'
# <b>limit_output extension: Maximum message size of 100000 exceeded with 332532 characters</b>

# %% [markdown]
# ## ポートフォリオ遷移の可視化

# %%
def make_y_limit(y_array, upper_ratio=0.1, lowwer_ratio=0.1):
    min_value = np.amin(y_array)
    max_value = np.amax(y_array)
    diff = max_value - min_value
    return min_value-lowwer_ratio*diff, max_value+upper_ratio*diff

# %%
def make_y_limit_multi(y_arrays, upper_ratio=0.1, lowwer_ratio=0.1):
    min_values = []
    max_values = []
    for y_array in y_arrays:
        min_values.append(np.amin(y_array))
        max_values.append(np.amax(y_array))
        
    min_value = min(min_values)
    max_value = max(max_values)
    diff = max_value - min_value
    
    return min_value-lowwer_ratio*diff, max_value+upper_ratio*diff

# %%
def make_ticker_text(ticker_value_array, ticker_names):
    div_text = ""
    text_sum_line = 150
    text_sum_count = 0

    for i, ticker_name in enumerate(ticker_names):
        div_text += ticker_name + "="
        text_sum_count += len(ticker_name)
        ticke_value_str = str(ticker_value_array[i])
        div_text += ticke_value_str
        text_sum_count += len(ticke_value_str)

        div_text += ", "
        text_sum_count += 2

        if text_sum_count > text_sum_line:
            div_text += "\n"
            text_sum_count = 0
            
    return div_text

# %%
def visualize_portfolio_transform_bokeh(portfolio_state_list, save_path=None, is_save=False, is_show=True, is_jupyter=True):
    # テータの取り出し
    ticker_names = portfolio_state_list[0].names
    colors = d3["Category20"][len(ticker_names)]

    all_price_array = np.stack([one_state.now_price_array for one_state in portfolio_state_list], axis=1)
    all_portfolio_vector = np.stack([one_state.portfolio_vector for one_state in portfolio_state_list], axis=1)
    all_mean_cost_price_array = np.stack([one_state.mean_cost_price_array for one_state in portfolio_state_list], axis=1)
    all_assets_array = np.array([one_state.all_assets for one_state in portfolio_state_list])
    all_datetime_array = np.array([get_naive_datetime_from_datetime(one_state.datetime) for one_state in portfolio_state_list])
    x = np.arange(0, len(portfolio_state_list))


    # sorceの作成
    portfolio_vector_source = {"x":x, "datetime":all_datetime_array}
    price_source_x = []
    price_source_y = []

    mean_cost_price_source_x = []
    mean_cost_price_source_y = []

    for i, ticker_name in enumerate(ticker_names):
        portfolio_vector_source[ticker_name] = all_portfolio_vector[i,:]

        price_source_x.append(x)
        price_source_y.append(all_price_array[i,:]/all_price_array[i,0])

        mean_cost_price_source_x.append(x)
        mean_cost_price_source_y.append(all_mean_cost_price_array[i,:]/all_mean_cost_price_array[i,0])

    # ホバーツールの設定
    #tool_tips = [("x", "@x")]
    tool_tips = [("datetime", "@datetime{%F %H:%M:%S}")]
    tool_tips.extend([(ticker_name, "@"+ticker_name+"{0.000}") for ticker_name in ticker_names])

    hover_tool = HoverTool(
        tooltips=tool_tips,
        formatters={'@datetime' : 'datetime'}
    )

    # 描画

    p1_text = Div(text=make_ticker_text(all_price_array[:,0], ticker_names))

    p1 = bokeh.plotting.figure(plot_width=1200,plot_height=500,title="正規化価格・ポートフォリオ")
    p1.add_tools(hover_tool)

    p1.extra_y_ranges = {"portfolio_vector": Range1d(start=0, end=3)}
    p1.add_layout(LinearAxis(y_range_name="portfolio_vector"), 'right')
    p1.vbar_stack(ticker_names, x='x', width=1, color=colors,y_range_name="portfolio_vector", source=portfolio_vector_source, legend_label=ticker_names, alpha=0.8)

    p1.multi_line(xs=price_source_x, ys=price_source_y, line_color=colors, line_width=2)
    y_min, y_max = make_y_limit_multi(price_source_y, lowwer_ratio=0.1, upper_ratio=0.1)
    y_min -= (y_max - y_min) * 0.66  #  ポートフォリオ割合のためのオフセット
    p1.y_range = Range1d(start=y_min, end=y_max)

    p1.yaxis[0].axis_label = "正規化価格"
    p1.yaxis[1].axis_label = "保有割合"

    p1.xaxis.major_label_overrides = {str(one_x) : str(all_datetime_array[i]) for i, one_x in enumerate(x)}

    p2_text = Div(text=make_ticker_text(all_mean_cost_price_array[:,0], ticker_names))

    p2 = bokeh.plotting.figure(plot_width=1200,plot_height=300,title="正規化平均取得価格・全資産")
    p2.multi_line(xs=mean_cost_price_source_x, ys=mean_cost_price_source_y, line_color=colors, line_width=2)
    y_min, y_max = make_y_limit_multi(mean_cost_price_source_y, lowwer_ratio=0.1, upper_ratio=0.1)
    p2.y_range = Range1d(start=y_min, end=y_max)

    y_max, y_min = make_y_limit(all_assets_array, upper_ratio=0.1, lowwer_ratio=0.1)
    p2.extra_y_ranges = {"all_assets": Range1d(start=y_max, end=y_min)}
    p2.add_layout(LinearAxis(y_range_name="all_assets"), 'right')
    p2.line(x, all_assets_array, color="red", legend_label="all_assets", line_width=4, y_range_name="all_assets")

    # 疑似的なレジェンドをつける
    for ticker_name, color in zip(ticker_names, colors):
        p2.line([], [], legend_label=ticker_name, color=color, line_width=2)

    p2.yaxis[0].axis_label = "正規化平均取得価格"
    p2.yaxis[1].axis_label = "全資産 [円]"

    p2.xaxis.major_label_overrides = {str(one_x) : str(all_datetime_array[i]) for i, one_x in enumerate(x)}

    layout_list = [p1_text, p1, p2_text, p2]
    created_figure = bokeh.layouts.column(*layout_list)

    if is_save:
            if save_path.suffix == ".png":
                bokeh.io.export_png(created_figure, filename=save_path)
            elif save_path.suffix == ".html":
                output_file(save_path)
                bokeh.io.save(created_figure, filename=save_path, title="trading process")    
            else:
                raise Exception("The suffix of save_path is must be '.png' or '.html'.")
            
            return None
    if is_show:
        try:
            reset_output()
            if is_jupyter:
                output_notebook()
            show(created_figure)
        except:
            if is_jupyter:
                output_notebook()
            show(created_figure)
            
        return None
        
    if not is_save and not is_show:
        return layout_list

# %%
visualize_portfolio_transform_bokeh(portfolio_state_list, save_path=Path("visualization/trade_transform.png"), is_save=False, is_show=True)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1466">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="00da744e-202c-4c90-9e24-3471fe721910" data-root-id="1465"></div>

# %%
visualize_portfolio_transform_bokeh(portfolio_state_list, save_path=Path("visualization/trade_transform.png"), is_save=False, is_show=False)
# Out:
# [Div(id='1768', ...),
#  Figure(id='1769', ...),
#  Div(id='1987', ...),
#  Figure(id='1988', ...)]

# %%
def visualize_portfolio_transform_matplotlib(portfolio_state_list, save_path=None, is_save=False, is_show=True, is_jupyter=True):
    # テータの取り出し
    ticker_names = portfolio_state_list[0].names
    colors = d3["Category20"][len(ticker_names)]

    all_price_array = np.stack([one_state.now_price_array for one_state in portfolio_state_list], axis=1)
    all_portfolio_vector = np.stack([one_state.portfolio_vector for one_state in portfolio_state_list], axis=1)
    all_mean_cost_price_array = np.stack([one_state.mean_cost_price_array for one_state in portfolio_state_list], axis=1)
    all_assets_array = np.array([one_state.all_assets for one_state in portfolio_state_list])
    all_datetime_array = np.array([get_naive_datetime_from_datetime(one_state.datetime) for one_state in portfolio_state_list])
    x = np.arange(0, len(portfolio_state_list))

    # sorceの作成
    portfolio_vector_source = {"x":x, "datetime":all_datetime_array}
    price_source_x = []
    price_source_y = []

    mean_cost_price_source_x = []
    mean_cost_price_source_y = []

    for i, ticker_name in enumerate(ticker_names):
        portfolio_vector_source[ticker_name] = all_portfolio_vector[i,:]

        price_source_x.append(x)
        price_source_y.append(all_price_array[i,:]/all_price_array[i,0])

        mean_cost_price_source_x.append(x)
        mean_cost_price_source_y.append(all_mean_cost_price_array[i,:]/all_mean_cost_price_array[i,0])

    fig = plt.figure(figsize=(20,15))
    ax1 = fig.add_subplot(311)

    for one_price_x, one_price_y, ticker_name in zip(price_source_x, price_source_y, ticker_names):
        ax1.plot(one_price_x, one_price_y, label=ticker_name)

    ax1.legend(loc="upper right")
    ax1.set_title("normalized price")

    ax2 = fig.add_subplot(312)

    for i, ticker_name in enumerate(ticker_names):
        if i==0:
            ax2.bar(x, portfolio_vector_source[ticker_name], width=1, label=ticker_name)
            offset = portfolio_vector_source[ticker_name].copy()
        else:
            ax2.bar(x, portfolio_vector_source[ticker_name], width=1, label=ticker_name, bottom=offset)
            offset += portfolio_vector_source[ticker_name]

    ax2.legend(loc="upper right")
    ax2.set_title("portfolio vector")

    ax3 = fig.add_subplot(313)

    for one_mean_cost_price_x, one_mean_cost_price_y, ticker_name in zip(mean_cost_price_source_x, mean_cost_price_source_y, ticker_names):
        ax3.plot(one_mean_cost_price_x, one_mean_cost_price_y, label=ticker_name)

    ax3.legend(loc="upper right")
    ax3.set_title("mean_cost_price and all assets")
    y_min, y_max = make_y_limit_multi(mean_cost_price_source_y, lowwer_ratio=0.1, upper_ratio=0.1)
    ax3.set_ylim(y_min, y_max)

    ax4 = ax3.twinx()
    ax4.plot(x, all_assets_array, color="red", linewidth=3, label="all assets")

    ax4.legend(loc="upper left")
    y_min, y_max = make_y_limit(all_assets_array, upper_ratio=0.1, lowwer_ratio=0.1)
    ax4.set_ylim(y_min, y_max)
    
    if is_save:
            if save_path.suffix == ".png":
                  fig.savefig(save_path)
            else:
                raise Exception("The suffix of save_path is must be '.png' or '.html'.")
            
    if is_show:
        plt.show()
    else:
        plt.close(fig)

# %%
visualize_portfolio_transform_matplotlib(portfolio_state_list, save_path=Path("visualization/trade_transform_matplotlib.png"), is_save=True, is_show=False)
