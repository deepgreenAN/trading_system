# %% [markdown]
# ルートディレクトリに移動

# %%
# %cd ../..
# Out:
# E:\システムトレード入門\trade_system_git_workspace

# %%
from collections import namedtuple
import pandas as pd
from pathlib import Path
from pytz import timezone
import datetime
import numpy as np
from scipy.special import softmax
from abc import ABCMeta, abstractmethod

# %%
import bokeh.plotting
from bokeh.models import Range1d, LinearAxis, Div, HoverTool
from bokeh.io import show
from bokeh.io import output_notebook, reset_output, output_file
from bokeh.palettes import d3
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
from get_stock_price import StockDatabase

# %%
from utils import get_previous_workday_intraday_datetime, get_next_workday_intraday_datetime, get_naive_datetime_from_datetime

# %%
from utils import py_restart
from utils import py_workdays

# %% [markdown]
# ## データベース

# %%
db_path = Path("E:/システムトレード入門/trade_system_git_workspace/db/sub_stock_db") / Path("sub_stock.db")
stock_db = StockDatabase(db_path)

# %%
jst_timezone = timezone("Asia/Tokyo")
all_start_datetime = jst_timezone.localize(datetime.datetime(2020,11,1,0,0,0))
all_end_datetime = jst_timezone.localize(datetime.datetime(2020,12,1,0,0,0))
py_workdays.get_workdays_jp(all_start_datetime.date(), all_end_datetime.date())
# Out:
# array([datetime.date(2020, 11, 2), datetime.date(2020, 11, 4),
#        datetime.date(2020, 11, 5), datetime.date(2020, 11, 6),
#        datetime.date(2020, 11, 9), datetime.date(2020, 11, 10),
#        datetime.date(2020, 11, 11), datetime.date(2020, 11, 12),
#        datetime.date(2020, 11, 13), datetime.date(2020, 11, 16),
#        datetime.date(2020, 11, 17), datetime.date(2020, 11, 18),
#        datetime.date(2020, 11, 19), datetime.date(2020, 11, 20),
#        datetime.date(2020, 11, 24), datetime.date(2020, 11, 25),
#        datetime.date(2020, 11, 26), datetime.date(2020, 11, 27),
#        datetime.date(2020, 11, 30)], dtype=object)

# %%
#start_datetime = jst_timezone.localize(datetime.datetime(2020,11,10,9,0,0))
#end_datetime = jst_timezone.localize(datetime.datetime(2020,11,20,15,0,0))
#stock_list = ["4755","9984","6701","7203","7267"]

#stock_df = stock_db.search_span(stock_names=stock_list, 
#                                start_datetime=start_datetime,
#                                end_datetime=end_datetime,
#                                freq_str="5T",
#                                to_tokyo=True
#                               )

#stock_df

# %% [markdown]
# ## 供給データ単位クラス

# %% [markdown]
# 供給されるデータの単位

# %%
field_list = ["names",  # 銘柄名
              "key_currency_index",  # 基軸通貨のインデックス
              "datetime",  # データの日時
              "window",  # データのウィンドウ
              "open_array",  # [銘柄名, ウィンドウ(時間)]に対応する始値
              "close_array",  # [銘柄名, ウィンドウ(時間)]に対応する終値
              "high_array",  # [銘柄名, ウィンドウ(時間)]に対応する高値
              "low_array",  # [銘柄名, ウィンドウ(時間)]に対応する低値
              "volume_array"  # [銘柄名, ウィンドウ(時間)]に対応する取引量
             ]

DataSupplyUnitBase = namedtuple("DataSupplyUnitBase", field_list)

# %%
class DataSupplyUnit(DataSupplyUnitBase):
    """
    DataSupplierによって提供されるデータクラス
    """
    def __str__(self):
        return_str = "DataSupplyUnit( \n"
        for field_str in self._fields:
            return_str += field_str + "="
            return_str += str(getattr(self, field_str)) + "\n"
        return_str += ")"
        return return_str

# %% [markdown]
# ## ポートフォリオ状態クラス

# %% [markdown]
# ポートフォリオの状態を表すクラス

# %%
field_list = ["names",  # 銘柄名
              "key_currency_index",  # 基軸通貨のインデックス
              "window",  # データのウィンドウ
              "datetime",  # データの日時
              "price_array",  # [銘柄名, ウィンドウ(時間)]に対応する現在価格
              "volume_array",  # [銘柄名, ウィンドウ(時間)]に対応する取引量
              "now_price_array",  # 銘柄名に対応する現在価格
              "portfolio_vector",  # ポートフォリオベクトル
              "mean_cost_price_array",  # 銘柄名に対応する平均取得価格
              "all_assets"  # 基軸通貨で換算した全資産
             ]

PortfolioStateBase = namedtuple("PortfolioStateBase", field_list)

# %%
class PortfolioState(PortfolioStateBase):
    """
    バックテスト・強化学習で利用するTransformerが提供するデータクラス．強化学習における状態を内包する．
    """
    
    @property
    def numbers(self):
        """
        保有量のプロパティ
        """
        return self.all_assets*self.portfolio_vector/self.now_price_array
    
    def __str__(self):
        return_str = "PortfolioState( \n"
        for field_str in self._fields:
            return_str += field_str + "="
            return_str += str(getattr(self, field_str)) + "\n"
        return_str += ")"
        return return_str
    
    def copy(self):
        """
        自身のコビーを返す．ndarrayのプロパティの場合はそのコビーを保持する．
        """
        arg_dict = {}
        for field_str in self._fields:
            field_value = getattr(self, field_str)
            if isinstance(field_value, np.ndarray):
                field_value = field_value.copy()
            
            arg_dict[field_str] = field_value
        
        return PortfolioState(**arg_dict)
    
    def partial(self, *args):
        """
        メモリ等の状況によって，自身の部分的なコビーを返す．
        引数にを耐えられなかったプロパティはNoneとなる．
        """
        arg_dict = {}
        for field_str in self._fields:
            if field_str in args:
                field_value = getattr(self, field_str)
                if isinstance(field_value, np.ndarray):
                    field_value = field_value.copy()
            else:
                field_value = None
            
            arg_dict[field_str] = field_value
            
        return PortfolioState(**arg_dict)

# %% [markdown]
# ## データの供給クラス

# %%
class PriceSuppliier(metaclass=ABCMeta):
    @abstractmethod
    def reset(self, start_datetime, window):
        pass
    
    @abstractmethod
    def step(self):
        pass

# %% [markdown]
# 今回は株価データベースを用いて価格を供給する．

# %% [markdown]
# ### ナイーブな実装

# %%
class StockDBPriceSupplier(PriceSuppliier):
    """
    StockDatabaseに対応するPriceSupplier
    """
    def __init__(self, stock_db, ticker_names, episode_length, freq_str, interpolate=True):
        self.stock_db = stock_db
        self.ticker_names = ticker_names
        self.episode_length = episode_length
        self.freq_str = freq_str        
        self.interpolate = interpolate
        # column_namesを分かりやすくまとめる
        self.column_names_list_dict = {}
        for column_type in ["Open", "High", "Low", "Close", "Volume"]:
            self.column_names_list_dict[column_type] = [column_type+"_"+ticker_name for ticker_name in self.ticker_names]
        
    def reset(self, start_datetime, window=np.array([0])):
        """
        start_datetime: datetime.datetime 
            データ供給の開始時刻
        window: ndarray
            データ供給のウィンドウ
        """
        # 終了時刻を求める
        # 全datetimeデータを保持
        assert 0 in window
        if not isinstance(window, np.ndarray):
            self.window = np.array(window)
        else:
            self.window = window
        
        min_window = min(self.window)
        max_window = max(self.window)
        
        if min_window <= 0:
            episode_start_datetime = get_previous_workday_intraday_datetime(start_datetime, self.freq_str, abs(min_window))
        else:
            episode_start_datetime = get_next_workday_intraday_datetime(start_datetime, self.freq_str, min_window)
            
        if self.episode_length+max_window <= 0:  # 基本的にあり得ない
            episode_end_datetime = get_previous_workday_intraday_datetime(start_datetime, self.freq_str, abs(self.episode_length+max_window))
        else:
            episode_end_datetime = get_next_workday_intraday_datetime(start_datetime, self.freq_str, self.episode_length+max_window)
        
        episode_df = self.stock_db.search_span(stock_names=self.ticker_names,
                                               start_datetime=episode_start_datetime,
                                               end_datetime=episode_end_datetime,
                                               freq_str=self.freq_str,
                                               is_end_include=True,  # 最後の値も含める
                                               to_tokyo=True,  #必ずTrueに
                                              )
        
        self.episode_df = py_workdays.extract_workdays_intraday_jp(episode_df)
        
        all_datetime_index = pd.date_range(start=episode_start_datetime,
                                           end=episode_end_datetime,
                                           freq=self.freq_str,
                                           closed="left"
                                          )
        self.all_datetime_index = py_workdays.extract_workdays_intraday_jp_index(all_datetime_index)
        
        # episode_dfの補間
        if self.interpolate:
            add_datetime_bool = ~self.all_datetime_index.isin(self.episode_df.index)
            add_datetime_index = self.all_datetime_index[add_datetime_bool]
            # Noneのdfを作成
            nan_df = pd.DataFrame(None, index=add_datetime_index)
            for one_column in self.episode_df.columns:
                  nan_df[one_column] = np.nan
                    
            # Noneのdfを追加
            self.episode_df = self.episode_df.append(nan_df)
            self.episode_df.sort_index(inplace=True)
            
            # np.nanの補間
            self.episode_df.interpolate(limit_direction="both",inplace=True)
        
        # データの取得
        self.now_index = np.argwhere(self.window==0).item()
        now_datetime = self.all_datetime_index[self.now_index].to_pydatetime()
        
        add_window = [self.now_index+one_value for one_value in self.window]
        window_index_array = self.all_datetime_index[add_window]
        window_data_df = self.episode_df.loc[window_index_array,:]
        
        open_array = window_data_df.loc[:,self.column_names_list_dict["Open"]].values.T
        high_array = window_data_df.loc[:,self.column_names_list_dict["High"]].values.T
        low_array = window_data_df.loc[:,self.column_names_list_dict["Low"]].values.T
        close_array = window_data_df.loc[:,self.column_names_list_dict["Close"]].values.T
        volume_array = window_data_df.loc[:,self.column_names_list_dict["Volume"]].values.T
        
        open_array = np.concatenate([np.ones((1, open_array.shape[1])), open_array], axis=0)
        high_array = np.concatenate([np.ones((1, high_array.shape[1])), high_array], axis=0)
        low_array = np.concatenate([np.ones((1, low_array.shape[1])), low_array], axis=0)
        close_array = np.concatenate([np.ones((1, close_array.shape[1])), close_array], axis=0)
        volume_array = np.concatenate([np.ones((1, volume_array.shape[1])), volume_array], axis=0)
        
        
        out_ticker_names = ["yen"]
        out_ticker_names.extend(self.ticker_names)
        
        out_unit = DataSupplyUnit(names=out_ticker_names,
                                  key_currency_index=0,
                                  datetime=now_datetime,
                                  window=self.window,
                                  open_array=open_array,
                                  close_array=close_array,
                                  high_array=high_array,
                                  low_array=low_array,
                                  volume_array=volume_array
                                 )
        done = False
        return out_unit, done
    
    def step(self):
        # indexの更新
        self.now_index += 1
        now_datetime = self.all_datetime_index[self.now_index].to_pydatetime()
        
        add_window = [self.now_index+one_value for one_value in self.window]
        window_index_array = self.all_datetime_index[add_window]
        window_data_df = self.episode_df.loc[window_index_array,:]
        
        open_array = window_data_df.loc[:,self.column_names_list_dict["Open"]].values.T
        high_array = window_data_df.loc[:,self.column_names_list_dict["High"]].values.T
        low_array = window_data_df.loc[:,self.column_names_list_dict["Low"]].values.T
        close_array = window_data_df.loc[:,self.column_names_list_dict["Close"]].values.T
        volume_array = window_data_df.loc[:,self.column_names_list_dict["Volume"]].values.T
        
        
        open_array = np.concatenate([np.ones((1, open_array.shape[1])), open_array], axis=0)
        high_array = np.concatenate([np.ones((1, high_array.shape[1])), high_array], axis=0)
        low_array = np.concatenate([np.ones((1, low_array.shape[1])), low_array], axis=0)
        close_array = np.concatenate([np.ones((1, close_array.shape[1])), close_array], axis=0)
        volume_array = np.concatenate([np.ones((1, volume_array.shape[1])), volume_array], axis=0)
        
        out_ticker_names = ["yen"]
        out_ticker_names.extend(self.ticker_names)
        
        out_unit = DataSupplyUnit(names=out_ticker_names,
                                  key_currency_index=0,
                                  datetime=now_datetime,
                                  window=self.window,
                                  open_array=open_array,
                                  close_array=close_array,
                                  high_array=high_array,
                                  low_array=low_array,
                                  volume_array=volume_array
                                 )
        done = self.now_index >= self.episode_length
        
        return out_unit, done

# %%
start_datetime = jst_timezone.localize(datetime.datetime(2020,11,10,9,0,0))
stock_list = ["4755","9984","6701","7203","7267"]
episode_length = 50

price_supplier = StockDBPriceSupplier(stock_db=stock_db,
                                     ticker_names=stock_list,
                                     episode_length=episode_length,
                                     freq_str="5T",
                                     interpolate=True
                                    )

# %%
data_unit, _ = price_supplier.reset(start_datetime, window=[-3,-2,-1,0,1,2,3])
print(data_unit)
# Out:
# DataSupplyUnit(
# names=['yen', '4755', '9984', '6701', '7203', '7267']
# key_currency_index=0
# datetime=2020-11-10 09:00:00+09:00
# window=[-3 -2 -1  0  1  2  3]
# open_array=[[1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00
#   1.0000e+00]
#  [1.1200e+03 1.1190e+03 1.1190e+03 1.1250e+03 1.1270e+03 1.1080e+03
#   1.1050e+03]
#  [7.0770e+03 7.0680e+03 7.0730e+03 7.0040e+03 7.0720e+03 7.0190e+03
#   7.0040e+03]
#  [5.7600e+03 5.7600e+03 5.7600e+03 5.7300e+03 5.7000e+03 5.7300e+03
#   5.7100e+03]
#  [7.1810e+03 7.1750e+03 7.1770e+03 7.3200e+03 7.3430e+03 7.3380e+03
#   7.3550e+03]
#  [2.8435e+03 2.8400e+03 2.8395e+03 2.9200e+03 2.9595e+03 2.9420e+03
#   2.9710e+03]]
# close_array=[[1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00
#   1.0000e+00]
#  [1.
array=[[1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00
#   1.0000e+00]
#  [1.1190e+03 1.1170e+03 1.1280e+03 1.1070e+03 1.1050e+03 1.0620e+03
#   1.0760e+03]
#  [7.0740e+03 7.0960e+03 7.0720e+03 7.0190e+03 7.0040e+03 6.9880e+03
#   6.9570e+03]
#  [5.7600e+03 5.7600e+03 5.6800e+03 5.7200e+03 5.7100e+03 5.6900e+03
#   5.6700e+03]
#  [7.1770e+03 7.1770e+03 7.3420e+03 7.3360e+03 7.3530e+03 7.3280e+03
#   7.3170e+03]
#  [2.8395e+03 2.8340e+03 2.9595e+03 2.9415e+03 2.9705e+03 2.9310e+03
#   2.9170e+03]]
# high_array=[[1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00
#   1.0000e+00]
#  [1.1190e+03 1.1190e+03 1.1320e+03 1.1290e+03 1.1100e+03 1.1050e+03
#   1.0830e+03]
#  [7.0740e+03 7.0960e+03 7.0770e+03 7.0770e+03 7.0270e+03 7.0070e+03
#   6.9970e+03]
#  [5.7600e+03 5.7600e+03 5.7300e+03 5.7300e+03 5.7400e+03 5.7200e+03
#   5.6900e+03]
#  [7.1770e+03 7.1850e+03 7.3440e+03 7.3550e+03 7.3600e+03 7.3560e+03
#   7.3420e+03]
#  [2.8420e+03 2.8415e+03 2.9635e+03 2.9690e+03 2.9720e+03 2.9725e+03
#   2.9510e+03]]
# low_array=[[1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00
#   1.0000e+00]
#  [1.1180e+03 1.1170e+03 1.1240e+03 1.1050e+03 1.0990e+03 1.0550e+03
#   1.0630e+03]
#  [7.0530e+03 7.0730e+03 6.9350e+03 6.9900e+03 6.9640e+03 6.9770e+03
#   6.9570e+03]
#  [5.7500e+03 5.7500e+03 5.6700e+03 5.6800e+03 5.7000e+03 5.6800e+03
#   5.6700e+03]
#  [7.1720e+03 7.1720e+03 7.3020e+03 7.3150e+03 7.3210e+03 7.3230e+03
#   7.3150e+03]
#  [2.8350e+03 2.8340e+03 2.8840e+03 2.9340e+03 2.9235e+03 2.9255e+03
#   2.9105e+03]]
# volume_array=[[1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00
#   1.0000e+00]
#  [9.3300e+04 4.1190e+05 8.7840e+05 5.8380e+05 2.5710e+05 7.9410e+05
#   4.6700e+05]
#  [3.0980e+05 3.7840e+05 2.5031e+06 8.4220e+05 7.3700e+05 4.2530e+05
#   4.1350e+05]
#  [1.5600e+04 4.2800e+04 2.6540e+05 7.0900e+04 5.5200e+04 7.5200e+04
#   7.9000e+04]
#  [1.6710e+05 1.7530e+05 1.3002e+06 4.5750e+05 3.2870e+05 1.7930e+05
#   1.9250e+05]
#  [1.9780e+05 2.6770e+05 1.0599e+06 4.1260e+05 2.6840e+05 2.4110e+05
#   1.7630e+05]]
# )

# %% [markdown]
# ### プロファイリング

# %%
def temp_func():
    price_supplier = StockDBPriceSupplier(stock_db=stock_db,
                                         ticker_names=stock_list,
                                         episode_length=episode_length,
                                         freq_str="5T",
                                         interpolate=True
                                        )
    data_unit, _ = price_supplier.reset(start_datetime, window=[-3,-2,-1,0,1,2,3])
    for i in range(30):
        data_unit, _ = price_supplier.step()
    
from line_profiler import LineProfiler
prf = LineProfiler()                                                                                         
prf.add_module(StockDBPriceSupplier)                                                                                          
#prf.add_function()                                                                                      
prf.runcall(temp_func)                         
prf.print_stats()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.0002287 s
# File: <ipython-input-15-94ef1fcb0f78>
# Function: __init__ at line 5
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      5                                               def __init__(self, stock_db, ticker_names, episode_length, freq_str, interpolate=True):
#      6         1        221.0    221.0      9.7          self.stock_db = stock_db
#      7         1         78.0     78.0      3.4          self.ticker_names = ticker_names
#      8         1         68.0     68.0      3.0          self.episode_length = episode_length
#      9         1         62.0     62.0      2.7          self.freq_str = freq_str
#     10         1         62.0     62.0      2.7          self.interpolate = interpolate
#     11                                                   # column_namesを分かりやすくまとめる
#     12         1         67.0     67.0      2.9          self.column_names_list_dict = {}
#     13         6        373.0     62.2     16.3          for column_type in ["Open", "High", "Low", "Close", "Volume"]:
#     14         5       1356.0    271.2     59.3              self.column_names_list_dict[column_type] = [column_type+"_"+ticker_name for ticker_name in self.ticker_names]
#
# Total time: 1.05886 s
# File: <ipython-input-15-94ef1fcb0f78>
# Function: reset at line 16
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     16                                               def reset(self, start_datetime, window=np.array([0])):
#     17                                                   """
#     18                                                   start_datetime: datetime.datetime
#     19                                                       データ供給の開始時刻
#     20                                                   window: ndarray
#     21                                                       データ供給のウィンドウ
#     22                                                   """
#     23                                                   # 終了時刻を求める
#     24                                                   # 全datetimeデータを保持
#     25         1        146.0    146.0      0.0          assert 0 in window
#     26         1        189.0    189.0      0.0          if not isinstance(window, np.ndarray):
#     27         1        462.0    462.0      0.0              self.window = np.array(window)
#     28                                                   else:
#     29                                                       self.window = window
#     30
#     31         1        774.0    774.0      0.0          min_window = min(self.window)
#     32         1        319.0    319.0      0.0          max_window = max(self.window)
#     33
#     34         1        191.0    191.0      0.0          if min_window <= 0:
#     35         1      35794.0  35794.0      0.3              episode_start_datetime = get_previous_workday_intraday_datetime(start_datetime, self.freq_str, abs(min_window))
#     36                                                   else:
#     37                                                       episode_start_datetime = get_next_workday_intraday_datetime(start_datetime, self.freq_str, min_window)
#     38
#     39         1        254.0    254.0      0.0          if self.episode_length+max_window <= 0:  # 基本的にあり得ない
#     40                                                       episode_end_datetime = get_previous_workday_intraday_datetime(start_datetime, self.freq_str, abs(self.episode_length+max_window))
#     41                                                   else:
#     42         1      23752.0  23752.0      0.2              episode_end_datetime = get_next_workday_intraday_datetime(start_datetime, self.freq_str, self.episode_length+max_window)
#     43
#     44         1        190.0    190.0      0.0          episode_df = self.stock_db.search_span(stock_names=self.ticker_names,
#     45         1        139.0    139.0      0.0                                                 start_datetime=episode_start_datetime,
#     46         1        133.0    133.0      0.0                                                 end_datetime=episode_end_datetime,
#     47         1        146.0    146.0      0.0                                                 freq_str=self.freq_str,
#     48         1        135.0    135.0      0.0                                                 is_end_include=True,  # 最後の値も含める
#     49         1    7383642.0 7383642.0     69.7                                                 to_tokyo=True,  #必ずTrueに
#     50                                                                                         )
#     51
#     52         1     156220.0 156220.0      1.5          self.episode_df = py_workdays.extract_workdays_intraday_jp(episode_df)
#     53
#     54         1        194.0    194.0      0.0          all_datetime_index = pd.date_range(start=episode_start_datetime,
#     55         1        136.0    136.0      0.0                                             end=episode_end_datetime,
#     56         1        147.0    147.0      0.0                                             freq=self.freq_str,
#     57         1      25062.0  25062.0      0.2                                             closed="left"
#     58                                                                                     )
#     59         1     133410.0 133410.0      1.3          self.all_datetime_index = py_workdays.extract_workdays_intraday_jp_index(all_datetime_index)
#     60
#     61                                                   # episode_dfの補間
#     62         1        163.0    163.0      0.0          if self.interpolate:
#     63         1      10136.0  10136.0      0.1              add_datetime_bool = ~self.all_datetime_index.isin(self.episode_df.index)
#     64         1      13678.0  13678.0      0.1              add_datetime_index = self.all_datetime_index[add_datetime_bool]
#     65                                                       # Noneのdfを作成
#     66         1      30552.0  30552.0      0.3              nan_df = pd.DataFrame(None, index=add_datetime_index)
#     67        26       5558.0    213.8      0.1              for one_column in self.episode_df.columns:
#     68        25    2011335.0  80453.4     19.0                    nan_df[one_column] = np.nan
#     69
#     70                                                       # Noneのdfを追加
#     71         1     120870.0 120870.0      1.1              self.episode_df = self.episode_df.append(nan_df)
#     72         1       3356.0   3356.0      0.0              self.episode_df.sort_index(inplace=True)
#     73
#     74                                                       # np.nanの補間
#     75         1     162049.0 162049.0      1.5              self.episode_df.interpolate(limit_direction="both",inplace=True)
#     76
#     77                                                   # データの取得
#     78         1       1816.0   1816.0      0.0          self.now_index = np.argwhere(self.window==0).item()
#     79         1       3399.0   3399.0      0.0          now_datetime = self.all_datetime_index[self.now_index].to_pydatetime()
#     80
#     81         1        703.0    703.0      0.0          add_window = [self.now_index+one_value for one_value in self.window]
#     82         1      27141.0  27141.0      0.3          window_index_array = self.all_datetime_index[add_window]
#     83         1      32968.0  32968.0      0.3          window_data_df = self.episode_df.loc[window_index_array,:]
#     84
#     85         1      87815.0  87815.0      0.8          open_array = window_data_df.loc[:,self.column_names_list_dict["Open"]].values.T
#     86         1      78841.0  78841.0      0.7          high_array = window_data_df.loc[:,self.column_names_list_dict["High"]].values.T
#     87         1      86484.0  86484.0      0.8          low_array = window_data_df.loc[:,self.column_names_list_dict["Low"]].values.T
#     88         1      58992.0  58992.0      0.6          close_array = window_data_df.loc[:,self.column_names_list_dict["Close"]].values.T
#     89         1      86086.0  86086.0      0.8          volume_array = window_data_df.loc[:,self.column_names_list_dict["Volume"]].values.T
#     90
#     91         1        944.0    944.0      0.0          open_array = np.concatenate([np.ones((1, open_array.shape[1])), open_array], axis=0)
#     92         1        618.0    618.0      0.0          high_array = np.concatenate([np.ones((1, high_array.shape[1])), high_array], axis=0)
#     93         1        572.0    572.0      0.0          low_array = np.concatenate([np.ones((1, low_array.shape[1])), low_array], axis=0)
#     94         1        589.0    589.0      0.0          close_array = np.concatenate([np.ones((1, close_array.shape[1])), close_array], axis=0)
#     95         1        562.0    562.0      0.0          volume_array = np.concatenate([np.ones((1, volume_array.shape[1])), volume_array], axis=0)
#     96
#     97
#     98         1        138.0    138.0      0.0          out_ticker_names = ["yen"]
#     99         1        199.0    199.0      0.0          out_ticker_names.extend(self.ticker_names)
#    100
#    101         1        135.0    135.0      0.0          out_unit = DataSupplyUnit(names=out_ticker_names,
#    102         1        128.0    128.0      0.0                                    key_currency_index=0,
#    103         1        128.0    128.0      0.0                                    datetime=now_datetime,
#    104         1        148.0    148.0      0.0                                    window=self.window,
#    105         1        126.0    126.0      0.0                                    open_array=open_array,
#    106         1        124.0    124.0      0.0                                    close_array=close_array,
#    107         1        121.0    121.0      0.0                                    high_array=high_array,
#    108         1        126.0    126.0      0.0                                    low_array=low_array,
#    109         1        346.0    346.0      0.0                                    volume_array=volume_array
#    110                                                                            )
#    111         1        131.0    131.0      0.0          done = False
#    112         1        125.0    125.0      0.0          return out_unit, done
#
# Total time: 1.07252 s
# File: <ipython-input-15-94ef1fcb0f78>
# Function: step at line 114
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    114                                               def step(self):
#    115                                                   # indexの更新
#    116        30       2932.0     97.7      0.0          self.now_index += 1
#    117        30      74345.0   2478.2      0.7          now_datetime = self.all_datetime_index[self.now_index].to_pydatetime()
#    118
#    119        30      15251.0    508.4      0.1          add_window = [self.now_index+one_value for one_value in self.window]
#    120        30     658908.0  21963.6      6.1          window_index_array = self.all_datetime_index[add_window]
#    121        30     786189.0  26206.3      7.3          window_data_df = self.episode_df.loc[window_index_array,:]
#    122
#    123        30    1953741.0  65124.7     18.2          open_array = window_data_df.loc[:,self.column_names_list_dict["Open"]].values.T
#    124        30    1791146.0  59704.9     16.7          high_array = window_data_df.loc[:,self.column_names_list_dict["High"]].values.T
#    125        30    1772080.0  59069.3     16.5          low_array = window_data_df.loc[:,self.column_names_list_dict["Low"]].values.T
#    126        30    1860031.0  62001.0     17.3          close_array = window_data_df.loc[:,self.column_names_list_dict["Close"]].values.T
#    127        30    1717813.0  57260.4     16.0          volume_array = window_data_df.loc[:,self.column_names_list_dict["Volume"]].values.T
#    128
#    129
#    130        30      20370.0    679.0      0.2          open_array = np.concatenate([np.ones((1, open_array.shape[1])), open_array], axis=0)
#    131        30      13110.0    437.0      0.1          high_array = np.concatenate([np.ones((1, high_array.shape[1])), high_array], axis=0)
#    132        30       9733.0    324.4      0.1          low_array = np.concatenate([np.ones((1, low_array.shape[1])), low_array], axis=0)
#    133        30       9302.0    310.1      0.1          close_array = np.concatenate([np.ones((1, close_array.shape[1])), close_array], axis=0)
#    134        30      13302.0    443.4      0.1          volume_array = np.concatenate([np.ones((1, volume_array.shape[1])), volume_array], axis=0)
#    135
#    136        30       1749.0     58.3      0.0          out_ticker_names = ["yen"]
#    137        30       2805.0     93.5      0.0          out_ticker_names.extend(self.ticker_names)
#    138
#    139        30       1573.0     52.4      0.0          out_unit = DataSupplyUnit(names=out_ticker_names,
#    140        30       1867.0     62.2      0.0                                    key_currency_index=0,
#    141        30       1676.0     55.9      0.0                                    datetime=now_datetime,
#    142        30       1750.0     58.3      0.0                                    window=self.window,
#    143        30       1536.0     51.2      0.0                                    open_array=open_array,
#    144        30       1388.0     46.3      0.0                                    close_array=close_array,
#    145        30       1419.0     47.3      0.0                                    high_array=high_array,
#    146        30       1376.0     45.9      0.0                                    low_array=low_array,
#    147        30       6288.0    209.6      0.1                                    volume_array=volume_array
#    148                                                                            )
#    149        30       2087.0     69.6      0.0          done = self.now_index >= self.episode_length
#    150
#    151        30       1441.0     48.0      0.0          return out_unit, done

# %% [markdown]
# 以下の部分の処理が2msもかかるのはおかしい

# %%
window_index_array = price_supplier.all_datetime_index[[1,2,3,4,5]]
window_data_df = price_supplier.episode_df.loc[window_index_array,:]
# %timeit open_array = window_data_df.loc[:,price_supplier.column_names_list_dict["Open"]]
# Out:
# 2.35 ms ± 613 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit window_data_df.loc[:,["Open_4755", "High_4755"]]
# Out:
# 2.28 ms ± 516 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit window_data_df[["Open_4755", "High_4755"]]
# Out:
# 2.38 ms ± 600 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ちなみにカラムが一つだけなら100倍近く高速である

# %%
# %timeit window_data_df["Open_4755"].values
# Out:
# 16.2 µs ± 5.54 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit window_data_df.loc[:,"Open_4755"].values
# Out:
# 99.6 µs ± 4.12 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit window_data_df.loc[:,["Open_4755", "High_4755"]].values
# Out:
# 2.52 ms ± 511 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
bool_list = [False for _ in window_data_df.columns]
bool_list[0] = True
bool_list[1] = True
# %timeit window_data_df.loc[:,bool_list]
# Out:
# 2.04 ms ± 506 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ndarrayを直接扱う方がずっと高速である．しかし，一つの時はpandasの方が高速なのはなぜ？

# %%
# %timeit window_data_df.values[:,0]
# Out:
# 25.5 µs ± 4.09 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit window_data_df.values[:,[0,1]]
# Out:
# 42.9 µs ± 2.89 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit 
bool_list = [False for _ in window_data_df.columns]
bool_list[0] = True
bool_list[1] = True

window_data_df.values[:,bool_list]
# Out:
# 69.9 µs ± 2.91 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# locが遅いので，自分で簡単なクエリを実装する

# %%
# %%timeit
bool_list = window_data_df.columns.str.startswith("Open")
window_data_df.values[:,bool_list]
# Out:
# 520 µs ± 80.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
bool_array = np.char.startswith(window_data_df.columns.values.astype(str), "Open")
window_data_df.values[:,bool_list]
# Out:
# 221 µs ± 55.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# reset時にbool_arrayを求めてしまえば

# %%
bool_array = np.char.startswith(window_data_df.columns.values.astype(str), "Open")

# %%
# %%timeit
window_data_df.values[:,bool_list]
# Out:
# 43.7 µs ± 1.43 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# ### 速度面で修正

# %% [markdown]
# dfの保持を止め, ndarrayを直接クエリする

# %%
class StockDBPriceSupplier(PriceSuppliier):
    """
    StockDatabaseに対応するPriceSupplier
    """
    def __init__(self, stock_db, ticker_names, episode_length, freq_str, interpolate=True):
        """
        stock_db: get_stock_price.StockDatabase
            利用するStockDatabaseクラス
        ticker_names: list of str
            利用する銘柄名のリスト
        episode_length: int
            エピソードの長さ
        freq_str: str
            利用する周期を表す文字列
        interpolate: bool
            補間するかどうか
        """
        self.stock_db = stock_db
        self.ticker_names = ticker_names
        self.episode_length = episode_length
        self.freq_str = freq_str        
        self.interpolate = interpolate
        
    def reset(self, start_datetime, window=np.array([0])):
        """
        Parameters
        ----------
        start_datetime: datetime.datetime 
            データ供給の開始時刻
        window: ndarray
            データ供給のウィンドウ
        
        Returns
        -------
        DatasupplyUnit
            提供する価格データ
        bool
            エピソードが終了したかどうか
        """
        # 終了時刻を求める
        # 全datetimeデータを保持
        assert 0 in window
        if not isinstance(window, np.ndarray):
            self.window = np.array(window)
        else:
            self.window = window
        
        min_window = min(self.window)
        max_window = max(self.window)
        
        if min_window <= 0:
            episode_start_datetime = get_previous_workday_intraday_datetime(start_datetime, self.freq_str, abs(min_window))
        else:
            episode_start_datetime = get_next_workday_intraday_datetime(start_datetime, self.freq_str, min_window)
            
        if self.episode_length+max_window <= 0:  # 基本的にあり得ない
            episode_end_datetime = get_previous_workday_intraday_datetime(start_datetime, self.freq_str, abs(self.episode_length+max_window))
        else:
            episode_end_datetime = get_next_workday_intraday_datetime(start_datetime, self.freq_str, self.episode_length+max_window)
        
        episode_df = self.stock_db.search_span(stock_names=self.ticker_names,
                                               start_datetime=episode_start_datetime,
                                               end_datetime=episode_end_datetime,
                                               freq_str=self.freq_str,
                                               is_end_include=True,  # 最後の値も含める
                                               to_tokyo=True,  #必ずTrueに
                                              )
        
        self.episode_df = py_workdays.extract_workdays_intraday_jp(episode_df)
        
        # 各OHLCVに対応するboolを求めておく
        column_names_array = self.episode_df.columns.values.astype(str)
        self.open_bool_array = np.char.startswith(column_names_array, "Open")
        self.high_bool_array = np.char.startswith(column_names_array, "High")
        self.low_bool_array = np.char.startswith(column_names_array, "Low")
        self.close_bool_array = np.char.startswith(column_names_array, "Close")
        self.volume_bool_array = np.char.startswith(column_names_array, "Volume")
        
        
        all_datetime_index = pd.date_range(start=episode_start_datetime,
                                           end=episode_end_datetime,
                                           freq=self.freq_str,
                                           closed="left"
                                          )
        self.all_datetime_index = py_workdays.extract_workdays_intraday_jp_index(all_datetime_index)
        
        # episode_dfの補間
        if self.interpolate:
            add_datetime_bool = ~self.all_datetime_index.isin(self.episode_df.index)
            add_datetime_index = self.all_datetime_index[add_datetime_bool]
            # Noneのdfを作成
            nan_df = pd.DataFrame(index=add_datetime_index, columns=self.episode_df.columns)

            # Noneのdfを追加
            self.episode_df = self.episode_df.append(nan_df)
            self.episode_df.sort_index(inplace=True)
            
            # np.nanの補間
            self.episode_df.interpolate(limit_direction="both",inplace=True)
        else:
            share_index_bool = self.all_datetime_index.isin(self.episode_df.index)
            self.all_datetime_index = self.all_datetime_index[share_index_bool]
        
        # dfをndarrayに変更
        self.episode_df_values = self.episode_df.values
        del self.episode_df
        
        self.all_datetime_index_values = self.all_datetime_index.to_pydatetime()
        del self.all_datetime_index
        
        # データの取得
        self.now_index = np.argwhere(self.window==0).item()
        now_datetime = self.all_datetime_index_values[self.now_index]
        
        add_window = self.now_index + self.window
        window_data_value = self.episode_df_values[add_window,:]
        
        open_array = window_data_value[:,self.open_bool_array].T
        high_array = window_data_value[:,self.high_bool_array].T
        low_array = window_data_value[:,self.low_bool_array].T
        close_array = window_data_value[:,self.close_bool_array].T
        volume_array = window_data_value[:,self.volume_bool_array].T
        
        open_array = np.concatenate([np.ones((1, open_array.shape[1])), open_array], axis=0)
        high_array = np.concatenate([np.ones((1, high_array.shape[1])), high_array], axis=0)
        low_array = np.concatenate([np.ones((1, low_array.shape[1])), low_array], axis=0)
        close_array = np.concatenate([np.ones((1, close_array.shape[1])), close_array], axis=0)
        volume_array = np.concatenate([np.ones((1, volume_array.shape[1])), volume_array], axis=0)
        
        
        out_ticker_names = ["yen"]
        out_ticker_names.extend(self.ticker_names)
        
        out_unit = DataSupplyUnit(names=out_ticker_names,
                                  key_currency_index=0,
                                  datetime=now_datetime,
                                  window=self.window,
                                  open_array=open_array,
                                  close_array=close_array,
                                  high_array=high_array,
                                  low_array=low_array,
                                  volume_array=volume_array
                                 )
        done = False
        return out_unit, done
    
    def step(self):
        """
        Returns
        -------
        DatasupplyUnit
            提供する価格データ
        bool
            エピソードが終了したかどうか
        """
        # indexの更新
        self.now_index += 1
        now_datetime = self.all_datetime_index_values[self.now_index]
        
        add_window = self.now_index + self.window
        window_data_value = self.episode_df_values[add_window,:]
        
        open_array = window_data_value[:,self.open_bool_array].T
        high_array = window_data_value[:,self.high_bool_array].T
        low_array = window_data_value[:,self.low_bool_array].T
        close_array = window_data_value[:,self.close_bool_array].T
        volume_array = window_data_value[:,self.volume_bool_array].T
         
        open_array = np.concatenate([np.ones((1, open_array.shape[1])), open_array], axis=0)
        high_array = np.concatenate([np.ones((1, high_array.shape[1])), high_array], axis=0)
        low_array = np.concatenate([np.ones((1, low_array.shape[1])), low_array], axis=0)
        close_array = np.concatenate([np.ones((1, close_array.shape[1])), close_array], axis=0)
        volume_array = np.concatenate([np.ones((1, volume_array.shape[1])), volume_array], axis=0)
        
        out_ticker_names = ["yen"]
        out_ticker_names.extend(self.ticker_names)
        
        out_unit = DataSupplyUnit(names=out_ticker_names,
                                  key_currency_index=0,
                                  datetime=now_datetime,
                                  window=self.window,
                                  open_array=open_array,
                                  close_array=close_array,
                                  high_array=high_array,
                                  low_array=low_array,
                                  volume_array=volume_array
                                 )
        done = self.now_index >= self.episode_length
        
        return out_unit, done

# %%
start_datetime = jst_timezone.localize(datetime.datetime(2020,11,10,9,0,0))
stock_list = ["4755","9984","6701","7203","7267"]
episode_length = 50

price_supplier = StockDBPriceSupplier(stock_db=stock_db,
                                     ticker_names=stock_list,
                                     episode_length=episode_length,
                                     freq_str="5T",
                                     interpolate=False
                                    )
data_unit, _ = price_supplier.reset(start_datetime, window=[-3,-2,-1,0,1,2,3])
print(data_unit)
# Out:
# DataSupplyUnit(
# names=['yen', '4755', '9984', '6701', '7203', '7267']
# key_currency_index=0
# datetime=2020-11-10 09:00:00+09:00
# window=[-3 -2 -1  0  1  2  3]
# open_array=[[1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00
#   1.0000e+00]
#  [1.1200e+03 1.1190e+03 1.1190e+03 1.1250e+03 1.1270e+03 1.1080e+03
#   1.1050e+03]
#  [7.0770e+03 7.0680e+03 7.0730e+03 7.0040e+03 7.0720e+03 7.0190e+03
#   7.0040e+03]
#  [5.7600e+03 5.7600e+03 5.7600e+03 5.7300e+03 5.7000e+03 5.7300e+03
#   5.7100e+03]
#  [7.1810e+03 7.1750e+03 7.1770e+03 7.3200e+03 7.3430e+03 7.3380e+03
#   7.3550e+03]
#  [2.8435e+03 2.8400e+03 2.8395e+03 2.9200e+03 2.9595e+03 2.9420e+03
#   2.9710e+03]]
# close_array=[[1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00
#   1.0000e+00]
#  [1.1200e+03 1.1190e+03 1.1170e+03 1.1280e+03 1.1070e+03 1.1050e+03
#   1.0620e+03]
#  [7.0690e+03 7.0740e+03 7.0960e+03 7.0720e+03 7.0190e+03 7.0040e+03
#   6.9880e+03]
#  [5.7600e+03 5.7600e+03 5.7600e+03 5.6800e+03 5.7200e+03 5.7100e+03
#   5.6900e+03]
#  [7.1750e+03 7.1770e+03 7.1770e+03 7.3420e+03 7.3360e+03 7.3530e+03
#   7.3280e+03]
#  [2.8400e+03 2.8395e+03 2.8340e+03 2.9595e+03 2.9415e+03 2.9705e+03
#   2.9310e+03]]
# high_array=[[1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00
#   1.0000e+00]
#  [1.1200e+03 1.1190e+03 1.1190e+03 1.1320e+03 1.1290e+03 1.1100e+03
#   1.1050e+03]
#  [7.0820e+03 7.0740e+03 7.0960e+03 7.0770e+03 7.0770e+03 7.0270e+03
#   7.0070e+03]
#  [5.7700e+03 5.7600e+03 5.7600e+03 5.7300e+03 5.7300e+03 5.7400e+03
#   5.7200e+03]
#  [7.1830e+03 7.1770e+03 7.1850e+03 7.3440e+03 7.3550e+03 7.3600e+03
#   7.3560e+03]
#  [2.8450e+03 2.8420e+03 2.8415e+03 2.9635e+03 2.9690e+03 2.9720e+03
#   2.9725e+03]]
# low_array=[[1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00
#   1.0000e+00]
#  [1.1190e+03 1.1180e+03 1.1170e+03 1.1240e+03 1.1050e+03 1.0990e+03
#   1.0550e+03]
#  [7.0660e+03 7.0530e+03 7.0730e+03 6.9350e+03 6.9900e+03 6.9640e+03
#   6.9770e+03]
#  [5.7600e+03 5.7500e+03 5.7500e+03 5.6700e+03 5.6800e+03 5.7000e+03
#   5.6800e+03]
#  [7.1680e+03 7.1720e+03 7.1720e+03 7.3020e+03 7.3150e+03 7.3210e+03
#   7.3230e+03]
#  [2.8395e+03 2.8350e+03 2.8340e+03 2.8840e+03 2.9340e+03 2.9235e+03
#   2.9255e+03]]
# volume_array=[[1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00
#   1.0000e+00]
#  [7.1600e+04 9.3300e+04 4.1190e+05 8.7840e+05 5.8380e+05 2.5710e+05
#   7.9410e+05]
#  [2.3750e+05 3.0980e+05 3.7840e+05 2.5031e+06 8.4220e+05 7.3700e+05
#   4.2530e+05]
#  [4.8200e+04 1.5600e+04 4.2800e+04 2.6540e+05 7.0900e+04 5.5200e+04
#   7.5200e+04]
#  [1.3520e+05 1.6710e+05 1.7530e+05 1.3002e+06 4.5750e+05 3.2870e+05
#   1.7930e+05]
#  [1.4200e+05 1.9780e+05 2.6770e+05 1.0599e+06 4.1260e+05 2.6840e+05
#   2.4110e+05]]
# )

# %%
def temp_func():
    price_supplier = StockDBPriceSupplier(stock_db=stock_db,
                                         ticker_names=stock_list,
                                         episode_length=episode_length,
                                         freq_str="5T",
                                         interpolate=True
                                        )
    data_unit, _ = price_supplier.reset(start_datetime, window=[-3,-2,-1,0,1,2,3])
    for i in range(30):
        data_unit, _ = price_supplier.step()
    
from line_profiler import LineProfiler
prf = LineProfiler()                                                                                         
prf.add_module(StockDBPriceSupplier)                                                                                          
#prf.add_function()                                                                                      
prf.runcall(temp_func)                         
prf.print_stats()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 3.17e-05 s
# File: <ipython-input-34-43659aa98df6>
# Function: __init__ at line 5
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      5                                               def __init__(self, stock_db, ticker_names, episode_length, freq_str, interpolate=True):
#      6                                                   """
#      7                                                   stock_db: get_stock_price.StockDatabase
#      8                                                       利用するStockDatabaseクラス
#      9                                                   ticker_names: list of str
#     10                                                       利用する銘柄名のリスト
#     11                                                   episode_length: int
#     12                                                       エピソードの長さ
#     13                                                   freq_str: str
#     14                                                       利用する周期を表す文字列
#     15                                                   interpolate: bool
#     16                                                       補間するかどうか
#     17                                                   """
#     18         1         99.0     99.0     31.2          self.stock_db = stock_db
#     19         1         63.0     63.0     19.9          self.ticker_names = ticker_names
#     20         1         53.0     53.0     16.7          self.episode_length = episode_length
#     21         1         52.0     52.0     16.4          self.freq_str = freq_str
#     22         1         50.0     50.0     15.8          self.interpolate = interpolate
#
# Total time: 0.89677 s
# File: <ipython-input-34-43659aa98df6>
# Function: reset at line 24
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     24                                               def reset(self, start_datetime, window=np.array([0])):
#     25                                                   """
#     26                                                   Parameters
#     27                                                   ----------
#     28                                                   start_datetime: datetime.datetime
#     29                                                       データ供給の開始時刻
#     30                                                   window: ndarray
#     31                                                       データ供給のウィンドウ
#     32
#     33                                                   Returns
#     34                                                   -------
#     35                                                   DatasupplyUnit
#     36                                                       提供する価格データ
#     37                                                   bool
#     38                                                       エピソードが終了したかどうか
#     39                                                   """
#     40                                                   # 終了時刻を求める
#     41                                                   # 全datetimeデータを保持
#     42         1        154.0    154.0      0.0          assert 0 in window
#     43         1        180.0    180.0      0.0          if not isinstance(window, np.ndarray):
#     44         1        605.0    605.0      0.0              self.window = np.array(window)
#     45                                                   else:
#     46                                                       self.window = window
#     47
#     48         1        522.0    522.0      0.0          min_window = min(self.window)
#     49         1        315.0    315.0      0.0          max_window = max(self.window)
#     50
#     51         1        198.0    198.0      0.0          if min_window <= 0:
#     52         1      39373.0  39373.0      0.4              episode_start_datetime = get_previous_workday_intraday_datetime(start_datetime, self.freq_str, abs(min_window))
#     53                                                   else:
#     54                                                       episode_start_datetime = get_next_workday_intraday_datetime(start_datetime, self.freq_str, min_window)
#     55
#     56         1        336.0    336.0      0.0          if self.episode_length+max_window <= 0:  # 基本的にあり得ない
#     57                                                       episode_end_datetime = get_previous_workday_intraday_datetime(start_datetime, self.freq_str, abs(self.episode_length+max_window))
#     58                                                   else:
#     59         1      25818.0  25818.0      0.3              episode_end_datetime = get_next_workday_intraday_datetime(start_datetime, self.freq_str, self.episode_length+max_window)
#     60
#     61         1        209.0    209.0      0.0          episode_df = self.stock_db.search_span(stock_names=self.ticker_names,
#     62         1        138.0    138.0      0.0                                                 start_datetime=episode_start_datetime,
#     63         1        134.0    134.0      0.0                                                 end_datetime=episode_end_datetime,
#     64         1        144.0    144.0      0.0                                                 freq_str=self.freq_str,
#     65         1        130.0    130.0      0.0                                                 is_end_include=True,  # 最後の値も含める
#     66         1    8160317.0 8160317.0     91.0                                                 to_tokyo=True,  #必ずTrueに
#     67                                                                                         )
#     68
#     69         1      90830.0  90830.0      1.0          self.episode_df = py_workdays.extract_workdays_intraday_jp(episode_df)
#     70
#     71                                                   # 各OHLCVに対応するboolを求めておく
#     72         1        577.0    577.0      0.0          column_names_array = self.episode_df.columns.values.astype(str)
#     73         1       1502.0   1502.0      0.0          self.open_bool_array = np.char.startswith(column_names_array, "Open")
#     74         1       1041.0   1041.0      0.0          self.high_bool_array = np.char.startswith(column_names_array, "High")
#     75         1       1013.0   1013.0      0.0          self.low_bool_array = np.char.startswith(column_names_array, "Low")
#     76         1       1052.0   1052.0      0.0          self.close_bool_array = np.char.startswith(column_names_array, "Close")
#     77         1       1027.0   1027.0      0.0          self.volume_bool_array = np.char.startswith(column_names_array, "Volume")
#     78
#     79
#     80         1         67.0     67.0      0.0          all_datetime_index = pd.date_range(start=episode_start_datetime,
#     81         1         54.0     54.0      0.0                                             end=episode_end_datetime,
#     82         1         62.0     62.0      0.0                                             freq=self.freq_str,
#     83         1      14493.0  14493.0      0.2                                             closed="left"
#     84                                                                                     )
#     85         1      83628.0  83628.0      0.9          self.all_datetime_index = py_workdays.extract_workdays_intraday_jp_index(all_datetime_index)
#     86
#     87                                                   # episode_dfの補間
#     88         1        150.0    150.0      0.0          if self.interpolate:
#     89         1      10079.0  10079.0      0.1              add_datetime_bool = ~self.all_datetime_index.isin(self.episode_df.index)
#     90         1      13632.0  13632.0      0.2              add_datetime_index = self.all_datetime_index[add_datetime_bool]
#     91                                                       # Noneのdfを作成
#     92         1     324480.0 324480.0      3.6              nan_df = pd.DataFrame(index=add_datetime_index, columns=self.episode_df.columns)
#     93
#     94                                                       # Noneのdfを追加
#     95         1      45508.0  45508.0      0.5              self.episode_df = self.episode_df.append(nan_df)
#     96         1       2795.0   2795.0      0.0              self.episode_df.sort_index(inplace=True)
#     97
#     98                                                       # np.nanの補間
#     99         1     131252.0 131252.0      1.5              self.episode_df.interpolate(limit_direction="both",inplace=True)
#    100                                                   else:
#    101                                                       share_index_bool = self.all_datetime_index.isin(self.episode_df.index)
#    102                                                       self.all_datetime_index = self.all_datetime_index[share_index_bool]
#    103
#    104                                                   # dfをndarrayに変更
#    105         1       2051.0   2051.0      0.0          self.episode_df_values = self.episode_df.values
#    106         1        302.0    302.0      0.0          del self.episode_df
#    107
#    108         1       4856.0   4856.0      0.1          self.all_datetime_index_values = self.all_datetime_index.to_pydatetime()
#    109         1        184.0    184.0      0.0          del self.all_datetime_index
#    110
#    111                                                   # データの取得
#    112         1       1484.0   1484.0      0.0          self.now_index = np.argwhere(self.window==0).item()
#    113         1        169.0    169.0      0.0          now_datetime = self.all_datetime_index_values[self.now_index]
#    114
#    115         1        280.0    280.0      0.0          add_window = self.now_index + self.window
#    116         1        515.0    515.0      0.0          window_data_value = self.episode_df_values[add_window,:]
#    117
#    118         1        417.0    417.0      0.0          open_array = window_data_value[:,self.open_bool_array].T
#    119         1        343.0    343.0      0.0          high_array = window_data_value[:,self.high_bool_array].T
#    120         1        327.0    327.0      0.0          low_array = window_data_value[:,self.low_bool_array].T
#    121         1        315.0    315.0      0.0          close_array = window_data_value[:,self.close_bool_array].T
#    122         1        311.0    311.0      0.0          volume_array = window_data_value[:,self.volume_bool_array].T
#    123
#    124         1        680.0    680.0      0.0          open_array = np.concatenate([np.ones((1, open_array.shape[1])), open_array], axis=0)
#    125         1        479.0    479.0      0.0          high_array = np.concatenate([np.ones((1, high_array.shape[1])), high_array], axis=0)
#    126         1        451.0    451.0      0.0          low_array = np.concatenate([np.ones((1, low_array.shape[1])), low_array], axis=0)
#    127         1        465.0    465.0      0.0          close_array = np.concatenate([np.ones((1, close_array.shape[1])), close_array], axis=0)
#    128         1        456.0    456.0      0.0          volume_array = np.concatenate([np.ones((1, volume_array.shape[1])), volume_array], axis=0)
#    129
#    130
#    131         1        123.0    123.0      0.0          out_ticker_names = ["yen"]
#    132         1        158.0    158.0      0.0          out_ticker_names.extend(self.ticker_names)
#    133
#    134         1        129.0    129.0      0.0          out_unit = DataSupplyUnit(names=out_ticker_names,
#    135         1        116.0    116.0      0.0                                    key_currency_index=0,
#    136         1        118.0    118.0      0.0                                    datetime=now_datetime,
#    137         1        121.0    121.0      0.0                                    window=self.window,
#    138         1        117.0    117.0      0.0                                    open_array=open_array,
#    139         1        116.0    116.0      0.0                                    close_array=close_array,
#    140         1        116.0    116.0      0.0                                    high_array=high_array,
#    141         1        117.0    117.0      0.0                                    low_array=low_array,
#    142         1        325.0    325.0      0.0                                    volume_array=volume_array
#    143                                                                            )
#    144         1        120.0    120.0      0.0          done = False
#    145         1        121.0    121.0      0.0          return out_unit, done
#
# Total time: 0.0127729 s
# File: <ipython-input-34-43659aa98df6>
# Function: step at line 147
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    147                                               def step(self):
#    148                                                   """
#    149                                                   Returns
#    150                                                   -------
#    151                                                   DatasupplyUnit
#    152                                                       提供する価格データ
#    153                                                   bool
#    154                                                       エピソードが終了したかどうか
#    155                                                   """
#    156                                                   # indexの更新
#    157        30       2102.0     70.1      1.6          self.now_index += 1
#    158        30       2315.0     77.2      1.8          now_datetime = self.all_datetime_index_values[self.now_index]
#    159
#    160        30       5141.0    171.4      4.0          add_window = self.now_index + self.window
#    161        30       7605.0    253.5      6.0          window_data_value = self.episode_df_values[add_window,:]
#    162
#    163        30       7464.0    248.8      5.8          open_array = window_data_value[:,self.open_bool_array].T
#    164        30       6335.0    211.2      5.0          high_array = window_data_value[:,self.high_bool_array].T
#    165        30       6442.0    214.7      5.0          low_array = window_data_value[:,self.low_bool_array].T
#    166        30       6209.0    207.0      4.9          close_array = window_data_value[:,self.close_bool_array].T
#    167        30       6296.0    209.9      4.9          volume_array = window_data_value[:,self.volume_bool_array].T
#    168
#    169        30      12352.0    411.7      9.7          open_array = np.concatenate([np.ones((1, open_array.shape[1])), open_array], axis=0)
#    170        30      10630.0    354.3      8.3          high_array = np.concatenate([np.ones((1, high_array.shape[1])), high_array], axis=0)
#    171        30      10173.0    339.1      8.0          low_array = np.concatenate([np.ones((1, low_array.shape[1])), low_array], axis=0)
#    172        30      10904.0    363.5      8.5          close_array = np.concatenate([np.ones((1, close_array.shape[1])), close_array], axis=0)
#    173        30      11270.0    375.7      8.8          volume_array = np.concatenate([np.ones((1, volume_array.shape[1])), volume_array], axis=0)
#    174
#    175        30       1578.0     52.6      1.2          out_ticker_names = ["yen"]
#    176        30       2067.0     68.9      1.6          out_ticker_names.extend(self.ticker_names)
#    177
#    178        30       1456.0     48.5      1.1          out_unit = DataSupplyUnit(names=out_ticker_names,
#    179        30       1287.0     42.9      1.0                                    key_currency_index=0,
#    180        30       1292.0     43.1      1.0                                    datetime=now_datetime,
#    181        30       1487.0     49.6      1.2                                    window=self.window,
#    182        30       1377.0     45.9      1.1                                    open_array=open_array,
#    183        30       1337.0     44.6      1.0                                    close_array=close_array,
#    184        30       1261.0     42.0      1.0                                    high_array=high_array,
#    185        30       1261.0     42.0      1.0                                    low_array=low_array,
#    186        30       4823.0    160.8      3.8                                    volume_array=volume_array
#    187                                                                            )
#    188        30       1863.0     62.1      1.5          done = self.now_index >= self.episode_length
#    189
#    190        30       1402.0     46.7      1.1          return out_unit, done

# %% [markdown]
# ## ポートフォリオの制限

# %% [markdown]
# 学習時にはポートフォリオベクトルに制限はもうけない．バックテストや実際の運用時に単元数・基軸通貨換算資産によって制限を設ける．これは強化学習を資産の保有率を求める問題にするためである．

# %%
class PortfilioRestrictor(metaclass=ABCMeta):
    """
    ポートフォリオの制限を行う抽象基底クラス
    restrictメソッドをオーバーライドする必要がある
    """
    @abstractmethod
    def restrict(self, portfolio_state, supplied_data_unit, portfolio_vector):
        pass

# %%
class PortfolioRestrictorSingleKey(PortfilioRestrictor):
    """
    """
    def __init__(self, unit_number, key_name):
        pass
        
    def restrict(self, portfolio_state, supplied_data_unit, portfolio_vector):
        pass

# %%
class PortfolioRestrictorIdentity(PortfilioRestrictor):
    """
    portfolioの恒等写像を行うPortfolioRestrictor
    """
    def restrict(self, portfolio_state, supplied_data_unit, portfolio_vector):
        return portfolio_vector

# %% [markdown]
# ## 取引手数料の計算クラス

# %%
class FeeCalculator(metaclass=ABCMeta):
    """
    手数料を計算する抽象基底クラス
    """
    @abstractmethod
    def calculate(self, pre_portfolio_state, new_portfolio_state):
        pass

# %%
class FeeCalculatorPerNumber(FeeCalculator):
    """
    取引個数に応じて手数料を計算するFeeCalculator
    """
    def __init__(self, fee_per_number):
        self.fee_per_number = fee_per_number
    def calculate(self, pre_portfolio_state, new_portfolio_state):
        not_key_currency_indices_list = list(range(len(pre_portfolio_state.names)))
        not_key_currency_indices_list.remove(pre_portfolio_state.key_currency_index)
        
        not_key_currency_indices = np.array(not_key_currency_indices_list) 
        commition_fee = self.fee_per_number*np.abs((new_portfolio_state.numbers[not_key_currency_indices] - pre_portfolio_state.numbers[not_key_currency_indices])).sum()
        return commition_fee

# %% [markdown]
# ##  ポートフォリオの遷移クラス

# %% [markdown]
# 強化学習の環境だけでなく，バックテスト等でも利用できるように汎用的なもの

# %%
class PortfolioTransformer:
    """
    price_supplierの提供するデータに応じてPortfolioStateを遷移させるクラス
    バックテスト・強化学習のどちらでも使えるようにする．
    """
    def __init__(self, 
                 price_supplier, 
                 portfolio_restrictor=PortfolioRestrictorIdentity(), 
                 use_ohlc="Close", 
                 initial_portfolio_vector=None, 
                 initial_all_assets=1e6, 
                 fee_calculator=FeeCalculatorPerNumber(fee_per_number=1e-3)):
        """
        price_supplier: PriceSupplier
            価格データを供給するクラス
        portfolio_restrictor: PortfolioRestrictor
            エージェントが渡すportfolio_vectorを制限するクラス
        use_ohlc: str, defalt:'Close'
            利用する価格データの指定
        initial_portfolio_vector: any, defalt:None
            初期ポートフォリオベクトル
        fee_calculator: FeeCalculator
            手数料を計算するクラス
        """
        self.price_supplier = price_supplier
        self.portfolio_restrictor = portfolio_restrictor
        self.initial_portfolio_vector = initial_portfolio_vector
        self.initial_all_assets = initial_all_assets
        self.fee_calculator = fee_calculator
    
        # 利用するohlcのいずれか
        if use_ohlc not in {"Open","High","Low","Close"}:
            raise Exception("use_ohlc must be in {'Open','High','Low','Close'}")
        
        field_name_dict = {"Open":"open_array",
                           "Close":"close_array",
                           "Low":"low_array",
                           "High":"high_array"
                          }
            
        self.use_ohlc_filed = field_name_dict[use_ohlc]
        
    def reset(self, start_datetime, window=[0]):
        """
        Parameters
        ----------
        start_datetime: datetime.datetime 
            データ供給の開始時刻
        window: ndarray
            データ供給のウィンドウ
            
        Returns
        -------
        PortfolioStat
             ポートフォリオ状態
        bool
            エピソードが終了したかどうか
        """
        initial_data_unit, done = self.price_supplier.reset(start_datetime, window)
    
        now_price_bool = initial_data_unit.window==0 
    
        if self.initial_portfolio_vector is None:
            self.initial_portfolio_vector = np.zeros(len(initial_data_unit.names))
            self.initial_portfolio_vector[initial_data_unit.key_currency_index] = 1.0
            
        else:
            assert len(initial_data_unit.names) == len(self.initial_portfolio_vector)
            assert self.initial_portfolio_vector.sum() == 1.0
            
        
        now_price_array = getattr(initial_data_unit, self.use_ohlc_filed)[:,now_price_bool].squeeze()
    
        self.portfolio_state = PortfolioState(names=initial_data_unit.names,
                                              key_currency_index=initial_data_unit.key_currency_index,
                                              window=initial_data_unit.window,
                                              datetime=initial_data_unit.datetime,
                                              price_array=getattr(initial_data_unit, self.use_ohlc_filed),
                                              volume_array=initial_data_unit.volume_array,
                                              now_price_array=now_price_array,
                                              portfolio_vector=self.initial_portfolio_vector,
                                              mean_cost_price_array=now_price_array,
                                              all_assets=self.initial_all_assets
                                             )
        
        
        return self.portfolio_state.copy(), done
    
    def step(self, action):
        """
        Parameters
        ----------
        action: ndarray
            エージェントが渡すポートフォリオベクトル
            
        Returns
        -------
        PortfolioStat
             ポートフォリオ状態
        bool
            エピソードが終了したかどうか
        """
        
        if not isinstance(action, np.ndarray):
            action = np.array(action)
        assert (action<0).sum() == 0 and (action>1).sum() == 0
        assert abs(action.sum() - 1.0) < 1.e-5  # 大体1ならOK
        
        #from IPython.core.debugger import Pdb; Pdb().set_trace()
        
        previous_portfolio_state = self.portfolio_state
        supplied_data_unit, done = self.price_supplier.step()
        
        assert len(action)==len(supplied_data_unit.names)
        
        restricted_portfolio_vector = self.portfolio_restrictor.restrict(previous_portfolio_state, supplied_data_unit, action)
        
        # 全資産の変化率を求める
        now_price_bool = supplied_data_unit.window==0
        now_price_array = getattr(supplied_data_unit, self.use_ohlc_filed)[:,now_price_bool].squeeze()
        
        price_change_ratio = now_price_array / previous_portfolio_state.now_price_array
        
        all_assets_change_ratio = np.dot(restricted_portfolio_vector, price_change_ratio)
        all_assets = previous_portfolio_state.all_assets * all_assets_change_ratio
        
        # 平均取得価格を設ける
        new_numbers = all_assets*restricted_portfolio_vector/now_price_array
        pre_numbers = previous_portfolio_state.numbers
        mean_num = pre_numbers*previous_portfolio_state.now_price_array + (new_numbers - pre_numbers) * now_price_array
        mean_den = new_numbers
        
        new_numbers_near_zero_bool = new_numbers < 1  # 取り合えず1以下の場合
        mean_num[new_numbers_near_zero_bool] = 1  # 適当に1にしておく
        mean_den[new_numbers_near_zero_bool] = 1  # 適当に1にしておく
        
        mean_cost_price_array = mean_num / mean_den
        mean_cost_price_array[new_numbers_near_zero_bool] = now_price_array[new_numbers_near_zero_bool]
        
        self.portfolio_state = PortfolioState(names=supplied_data_unit.names,
                                              key_currency_index=supplied_data_unit.key_currency_index,
                                              window=supplied_data_unit.window,
                                              datetime=supplied_data_unit.datetime,
                                              price_array=getattr(supplied_data_unit, self.use_ohlc_filed),
                                              volume_array=supplied_data_unit.volume_array,
                                              now_price_array=now_price_array,
                                              portfolio_vector=restricted_portfolio_vector,
                                              mean_cost_price_array=mean_cost_price_array,
                                              all_assets=all_assets
                                             )
                 
        # 手数料の計算と更新
        all_fee = self.fee_calculator.calculate(previous_portfolio_state, self.portfolio_state)
        self.portfolio_state = self.portfolio_state._replace(all_assets=all_assets-all_fee)   
        
        return self.portfolio_state.copy(), done

# %%
transformer = PortfolioTransformer(price_supplier=price_supplier,
                                   portfolio_restrictor=PortfolioRestrictorIdentity(),
                                   use_ohlc="Close",
                                   initial_portfolio_vector=None,
                                   initial_all_assets=1e6,
                                   fee_calculator=FeeCalculatorPerNumber(0.01)
                                  )

portfolio_state, _ = transformer.reset(start_datetime, window=[-3,-2,-1,0,1,2,3])
print(portfolio_state)
# Out:
# PortfolioState(
# names=['yen', '4755', '9984', '6701', '7203', '7267']
# key_currency_index=0
# window=[-3 -2 -1  0  1  2  3]
# datetime=2020-11-10 09:00:00+09:00
# price_array=[[1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00
#   1.0000e+00]
#  [1.
# mean_cost_price_array=[1.0000e+00 1.1070e+03 7.0190e+03 5.7200e+03 7.3360e+03 2.9415e+03]
# all_assets=981374.1134751774
# )

# %%
def temp_func():
    price_supplier = StockDBPriceSupplier(stock_db=stock_db,
                                     ticker_names=stock_list,
                                     episode_length=episode_length,
                                     freq_str="5T",
                                     interpolate=True
                                    )
    transformer = PortfolioTransformer(price_supplier=price_supplier,
                                       portfolio_restrictor=PortfolioRestrictorIdentity(),
                                       use_ohlc="Close",
                                       initial_portfolio_vector=None,
                                       initial_all_assets=1e6,
                                       fee_calculator=FeeCalculatorPerNumber(0.01)
                                      )
    portfolio_state, _ = transformer.reset(start_datetime, window=[-3,-2,-1,0,1,2,3])
    for _ in range(30):
        new_portfolio_vector = [0,1,0,0,0,0]
        portfolio_state, _ = transformer.step(new_portfolio_vector)
    
from line_profiler import LineProfiler
prf = LineProfiler()                                                                                         
prf.add_module(PortfolioTransformer)                                                                                          
#prf.add_function()                                                                                      
prf.runcall(temp_func)                                                                                          
prf.print_stats()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 6.2e-05 s
# File: <ipython-input-42-db242ee61848>
# Function: __init__ at line 6
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      6                                               def __init__(self,
#      7                                                            price_supplier,
#      8                                                            portfolio_restrictor=PortfolioRestrictorIdentity(),
#      9                                                            use_ohlc="Close",
#     10                                                            initial_portfolio_vector=None,
#     11                                                            initial_all_assets=1e6,
#     12                                                            fee_calculator=FeeCalculatorPerNumber(fee_per_number=1e-3)):
#     13                                                   """
#     14                                                   price_supplier: PriceSupplier
#     15                                                       価格データを供給するクラス
#     16                                                   portfolio_restrictor: PortfolioRestrictor
#     17                                                       エージェントが渡すportfolio_vectorを制限するクラス
#     18                                                   use_ohlc: str, defalt:'Close'
#     19                                                       利用する価格データの指定
#     20                                                   initial_portfolio_vector: any, defalt:None
#     21                                                       初期ポートフォリオベクトル
#     22                                                   fee_calculator: FeeCalculator
#     23                                                       手数料を計算するクラス
#     24                                                   """
#     25         1         92.0     92.0     14.8          self.price_supplier = price_supplier
#     26         1         61.0     61.0      9.8          self.portfolio_restrictor = portfolio_restrictor
#     27         1         54.0     54.0      8.7          self.initial_portfolio_vector = initial_portfolio_vector
#     28         1         55.0     55.0      8.9          self.initial_all_assets = initial_all_assets
#     29         1         50.0     50.0      8.1          self.fee_calculator = fee_calculator
#     30
#     31                                                   # 利用するohlcのいずれか
#     32         1         58.0     58.0      9.4          if use_ohlc not in {"Open","High","Low","Close"}:
#     33                                                       raise Exception("use_ohlc must be in {'Open','High','Low','Close'}")
#     34
#     35         1         46.0     46.0      7.4          field_name_dict = {"Open":"open_array",
#     36         1         44.0     44.0      7.1                             "Close":"close_array",
#     37         1         41.0     41.0      6.6                             "Low":"low_array",
#     38         1         62.0     62.0     10.0                             "High":"high_array"
#     39                                                                     }
#     40
#     41         1         57.0     57.0      9.2          self.use_ohlc_filed = field_name_dict[use_ohlc]
#
# Total time: 0.915443 s
# File: <ipython-input-42-db242ee61848>
# Function: reset at line 43
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     43                                               def reset(self, start_datetime, window=[0]):
#     44                                                   """
#     45                                                   Parameters
#     46                                                   ----------
#     47                                                   start_datetime: datetime.datetime
#     48                                                       データ供給の開始時刻
#     49                                                   window: ndarray
#     50                                                       データ供給のウィンドウ
#     51
#     52                                                   Returns
#     53                                                   -------
#     54                                                   PortfolioStat
#     55                                                        ポートフォリオ状態
#     56                                                   bool
#     57                                                       エピソードが終了したかどうか
#     58                                                   """
#     59         1    9149963.0 9149963.0    100.0          initial_data_unit, done = self.price_supplier.reset(start_datetime, window)
#     60
#     61         1        360.0    360.0      0.0          now_price_bool = initial_data_unit.window==0
#     62
#     63         1         91.0     91.0      0.0          if self.initial_portfolio_vector is None:
#     64         1        278.0    278.0      0.0              self.initial_portfolio_vector = np.zeros(len(initial_data_unit.names))
#     65         1        136.0    136.0      0.0              self.initial_portfolio_vector[initial_data_unit.key_currency_index] = 1.0
#     66
#     67                                                   else:
#     68                                                       assert len(initial_data_unit.names) == len(self.initial_portfolio_vector)
#     69                                                       assert self.initial_portfolio_vector.sum() == 1.0
#     70
#     71
#     72         1        492.0    492.0      0.0          now_price_array = getattr(initial_data_unit, self.use_ohlc_filed)[:,now_price_bool].squeeze()
#     73
#     74         1         87.0     87.0      0.0          self.portfolio_state = PortfolioState(names=initial_data_unit.names,
#     75         1         66.0     66.0      0.0                                                key_currency_index=initial_data_unit.key_currency_index,
#     76         1         64.0     64.0      0.0                                                window=initial_data_unit.window,
#     77         1        125.0    125.0      0.0                                                datetime=initial_data_unit.datetime,
#     78         1        144.0    144.0      0.0                                                price_array=getattr(initial_data_unit, self.use_ohlc_filed),
#     79         1        127.0    127.0      0.0                                                volume_array=initial_data_unit.volume_array,
#     80         1         83.0     83.0      0.0                                                now_price_array=now_price_array,
#     81         1         92.0     92.0      0.0                                                portfolio_vector=self.initial_portfolio_vector,
#     82         1         84.0     84.0      0.0                                                mean_cost_price_array=now_price_array,
#     83         1        385.0    385.0      0.0                                                all_assets=self.initial_all_assets
#     84                                                                                        )
#     85
#     86
#     87         1       1853.0   1853.0      0.0          return self.portfolio_state.copy(), done
#
# Total time: 0.0863778 s
# File: <ipython-input-42-db242ee61848>
# Function: step at line 89
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     89                                               def step(self, action):
#     90                                                   """
#     91                                                   Parameters
#     92                                                   ----------
#     93                                                   action: ndarray
#     94                                                       エージェントが渡すポートフォリオベクトル
#     95
#     96                                                   Returns
#     97                                                   -------
#     98                                                   PortfolioStat
#     99                                                        ポートフォリオ状態
#    100                                                   bool
#    101                                                       エピソードが終了したかどうか
#    102                                                   """
#    103
#    104        30       4089.0    136.3      0.5          if not isinstance(action, np.ndarray):
#    105        30      10080.0    336.0      1.2              action = np.array(action)
#    106        30      58615.0   1953.8      6.8          assert (action<0).sum() == 0 and (action>1).sum() == 0
#    107        30      32214.0   1073.8      3.7          assert abs(action.sum() - 1.0) < 1.e-5  # 大体1ならOK
#    108
#    109                                                   #from IPython.core.debugger import Pdb; Pdb().set_trace()
#    110
#    111        30       3376.0    112.5      0.4          previous_portfolio_state = self.portfolio_state
#    112        30     291124.0   9704.1     33.7          supplied_data_unit, done = self.price_supplier.step()
#    113
#    114        30       4942.0    164.7      0.6          assert len(action)==len(supplied_data_unit.names)
#    115
#    116        30       4865.0    162.2      0.6          restricted_portfolio_vector = self.portfolio_restrictor.restrict(previous_portfolio_state, supplied_data_unit, action)
#    117
#    118                                                   # 全資産の変化率を求める
#    119        30       9563.0    318.8      1.1          now_price_bool = supplied_data_unit.window==0
#    120        30      23237.0    774.6      2.7          now_price_array = getattr(supplied_data_unit, self.use_ohlc_filed)[:,now_price_bool].squeeze()
#    121
#    122        30       7910.0    263.7      0.9          price_change_ratio = now_price_array / previous_portfolio_state.now_price_array
#    123
#    124        30      12144.0    404.8      1.4          all_assets_change_ratio = np.dot(restricted_portfolio_vector, price_change_ratio)
#    125        30       6141.0    204.7      0.7          all_assets = previous_portfolio_state.all_assets * all_assets_change_ratio
#    126
#    127                                                   # 平均取得価格を設ける
#    128        30      56134.0   1871.1      6.5          new_numbers = all_assets*restricted_portfolio_vector/now_price_array
#    129        30      17267.0    575.6      2.0          pre_numbers = previous_portfolio_state.numbers
#    130        30      13977.0    465.9      1.6          mean_num = pre_numbers*previous_portfolio_state.now_price_array + (new_numbers - pre_numbers) * now_price_array
#    131        30       3204.0    106.8      0.4          mean_den = new_numbers
#    132
#    133        30      14981.0    499.4      1.7          new_numbers_near_zero_bool = new_numbers < 1  # 取り合えず1以下の場合
#    134        30      10050.0    335.0      1.2          mean_num[new_numbers_near_zero_bool] = 1  # 適当に1にしておく
#    135        30      36513.0   1217.1      4.2          mean_den[new_numbers_near_zero_bool] = 1  # 適当に1にしておく
#    136
#    137        30       6831.0    227.7      0.8          mean_cost_price_array = mean_num / mean_den
#    138        30       8164.0    272.1      0.9          mean_cost_price_array[new_numbers_near_zero_bool] = now_price_array[new_numbers_near_zero_bool]
#    139
#    140        30       5022.0    167.4      0.6          self.portfolio_state = PortfolioState(names=supplied_data_unit.names,
#    141        30       2877.0     95.9      0.3                                                key_currency_index=supplied_data_unit.key_currency_index,
#    142        30       2803.0     93.4      0.3                                                window=supplied_data_unit.window,
#    143        30       3401.0    113.4      0.4                                                datetime=supplied_data_unit.datetime,
#    144        30       5494.0    183.1      0.6                                                price_array=getattr(supplied_data_unit, self.use_ohlc_filed),
#    145        30       2984.0     99.5      0.3                                                volume_array=supplied_data_unit.volume_array,
#    146        30       2600.0     86.7      0.3                                                now_price_array=now_price_array,
#    147        30       2597.0     86.6      0.3                                                portfolio_vector=restricted_portfolio_vector,
#    148        30       2566.0     85.5      0.3                                                mean_cost_price_array=mean_cost_price_array,
#    149        30       9749.0    325.0      1.1                                                all_assets=all_assets
#    150                                                                                        )
#    151
#    152                                                   # 手数料の計算と更新
#    153        30     109258.0   3641.9     12.6          all_fee = self.fee_calculator.calculate(previous_portfolio_state, self.portfolio_state)
#    154        30      18227.0    607.6      2.1          self.portfolio_state = self.portfolio_state._replace(all_assets=all_assets-all_fee)
#    155
#    156        30      60779.0   2026.0      7.0          return self.portfolio_state.copy(), done

# %% [markdown]
# 高速化できる部分は無い

# %% [markdown]
# ## ポートフォリオの遷移を可視化

# %%
start_datetime = jst_timezone.localize(datetime.datetime(2020,11,10,9,0,0))
stock_list = ["4755","9984","6701","7203","7267", "6502"]
episode_length = 100

price_supplier = StockDBPriceSupplier(stock_db=stock_db,
                                     ticker_names=stock_list,
                                     episode_length=episode_length,
                                     freq_str="5T",
                                     interpolate=False
                                    )

transformer = PortfolioTransformer(price_supplier=price_supplier,
                                   portfolio_restrictor=PortfolioRestrictorIdentity(),
                                   use_ohlc="Close",
                                   initial_portfolio_vector=None,
                                   initial_all_assets=1e6,
                                   fee_calculator=FeeCalculatorPerNumber(0)
                                  )


portfolio_state_list = []
initial_state, _ = transformer.reset(start_datetime, window=[-1,0,1])
portfolio_state_list.append(initial_state.partial("names", "now_price_array", "mean_cost_price_array", "portfolio_vector", "all_assets", "datetime"))

while True:
    action = softmax(np.abs(np.random.randn(1+len(stock_list))))
    portfolio_state, done = transformer.step(action)
    portfolio_state_list.append(portfolio_state.partial("names", "now_price_array", "mean_cost_price_array", "portfolio_vector", "all_assets", "datetime"))
    if done:
        break

# %%
portfolio_state_list
# Out:
# [PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 0, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1280e+03, 7.0720e+03, 5.6800e+03, 7.3420e+03,
#         2.9595e+03, 2.7800e+03]), portfolio_vector=array([1., 0., 0., 0., 0., 0., 0.]), mean_cost_price_array=array([1.0000e+00, 1.1280e+03, 7.0720e+03, 5.6800e+03, 7.3420e+03,
#         2.9595e+03, 2.7800e+03]), all_assets=1000000.0),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 5, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1070e+03, 7.0190e+03, 5.7200e+03, 7.3360e+03,
#         2.9415e+03, 2.8040e+03]), portfolio_vector=array([0.24120279, 0.14954645, 0.15028568, 0.11824862, 0.16084736,
#         0.05689819, 0.1229709 ]), mean_cost_price_array=array([1.0000e+00, 1.1070e+03, 7.0190e+03, 5.7200e+03, 7.3360e+03,
#         2.9415e+03, 2.8040e+03]), all_assets=997506.4459530229),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 10, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.0000e+00, 1.1050e+03, 7.0040e+03, 5.7100e+03, 7.3530e+03,
#         2.9705e+03, 2.7950e+03]), portfolio_vector=array([0.07847444, 0.11181576, 0.08217972, 0.32273645, 0.13375526,
#         0.16916681, 0.10187157]), mean_cost_price_array=array([1.00000000e+00, 1.10766815e+03, 7.03135315e+03, 5.71365494e+03,
#         7.33252379e+03, 2.96065685e+03, 2.80582151e+03]), all_assets=998213.5955152052),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 15, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.062e+03, 6.988e+03, 5.690e+03, 7.328e+03, 2.931e+03,
#         2.777e+03]), portfolio_vector=array([0.16515202, 0.20119377, 0.10350873, 0.20596115, 0.16085739,
#         0.06163945, 0.10168749]), mean_cost_price_array=array([1.00000000e+00, 1.08521875e+03, 7.00081251e+03, 5.72157101e+03,
#         7.34894355e+03, 3.03913329e+03, 2.79511222e+03]), all_assets=987424.3512758174),
#  PortfolioState(names=['yen', '4755', '9984', '6701', '7203', '7267', '6502'], key_currency_index=None, window=None, datetime=datetime.datetime(2020, 11, 10, 9, 20, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1
tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), price_array=None, volume_array=None, now_price_array=array([1.000e+00, 1.106e+03, 6.615e+03, 5.680e+03, 7.443e+03, 2.974e+03,
#         2.775e+03]), portfolio_vector=array([0.1910704 , 0.11431049, 0.17512726, 0.1936561 , 0.06455254,
#         0.18824929, 0.07303391]), mean_cost_price_array=array([1.00000000e+00, 1.10600000e+03, 6.61559671e+03, 5.68000000e+03,
#         7.44395401e+03, 2.97426284e+03, 2.79164362e+03]), all_assets=998418.7287337184)]

# %%
def make_y_limit(y_array, upper_ratio=0.1, lowwer_ratio=0.1):
    min_value = np.amin(y_array)
    max_value = np.amax(y_array)
    diff = max_value - min_value
    return min_value-lowwer_ratio*diff, max_value+upper_ratio*diff

# %%
def make_y_limit_multi(y_arrays, upper_ratio=0.1, lowwer_ratio=0.1):
    min_values = []
    max_values = []
    for y_array in y_arrays:
        min_values.append(np.amin(y_array))
        max_values.append(np.amax(y_array))
        
    min_value = min(min_values)
    max_value = max(max_values)
    diff = max_value - min_value
    
    return min_value-lowwer_ratio*diff, max_value+upper_ratio*diff

# %%
def make_ticker_text(ticker_value_array, ticker_names):
    div_text = ""
    text_sum_line = 150
    text_sum_count = 0

    for i, ticker_name in enumerate(ticker_names):
        div_text += ticker_name + "="
        text_sum_count += len(ticker_name)
        ticke_value_str = str(ticker_value_array[i])
        div_text += ticke_value_str
        text_sum_count += len(ticke_value_str)

        div_text += ", "
        text_sum_count += 2

        if text_sum_count > text_sum_line:
            div_text += "\n"
            text_sum_count = 0
            
    return div_text

# %% [markdown]
# ここはメインの開発場所ではない，プロトタイプ版

# %%
def visualize_portfolio_transform_bokeh(portfolio_state_list, save_path=None, is_save=False, is_show=True, is_jupyter=True):
    # テータの取り出し
    ticker_names = portfolio_state_list[0].names
    colors = d3["Category20"][len(ticker_names)]

    all_price_array = np.stack([one_state.now_price_array for one_state in portfolio_state_list], axis=1)
    all_portfolio_vector = np.stack([one_state.portfolio_vector for one_state in portfolio_state_list], axis=1)
    all_mean_cost_price_array = np.stack([one_state.mean_cost_price_array for one_state in portfolio_state_list], axis=1)
    all_assets_array = np.array([one_state.all_assets for one_state in portfolio_state_list])
    all_datetime_array = np.array([get_naive_datetime_from_datetime(one_state.datetime) for one_state in portfolio_state_list])
    x = np.arange(0, len(portfolio_state_list))


    # sorceの作成
    portfolio_vector_source = {"x":x, "datetime":all_datetime_array}
    price_source_x = []
    price_source_y = []

    mean_cost_price_source_x = []
    mean_cost_price_source_y = []

    for i, ticker_name in enumerate(ticker_names):
        portfolio_vector_source[ticker_name] = all_portfolio_vector[i,:]

        price_source_x.append(x)
        price_source_y.append(all_price_array[i,:]/all_price_array[i,0])

        mean_cost_price_source_x.append(x)
        mean_cost_price_source_y.append(all_mean_cost_price_array[i,:]/all_mean_cost_price_array[i,0])

    # ホバーツールの設定
    #tool_tips = [("x", "@x")]
    tool_tips = [("datetime", "@datetime{%F %H:%M:%S}")]
    tool_tips.extend([(ticker_name, "@"+ticker_name+"{0.000}") for ticker_name in ticker_names])

    hover_tool = HoverTool(
        tooltips=tool_tips,
        formatters={'@datetime' : 'datetime'}
    )

    # 描画

    p1_text = Div(text=make_ticker_text(all_price_array[:,0], ticker_names))

    p1 = bokeh.plotting.figure(plot_width=1200,plot_height=500,title="正規化価格・ポートフォリオ")
    p1.add_tools(hover_tool)

    p1.extra_y_ranges = {"portfolio_vector": Range1d(start=0, end=3)}
    p1.add_layout(LinearAxis(y_range_name="portfolio_vector"), 'right')
    p1.vbar_stack(ticker_names, x='x', width=1, color=colors,y_range_name="portfolio_vector", source=portfolio_vector_source, legend_label=ticker_names, alpha=0.8)

    p1.multi_line(xs=price_source_x, ys=price_source_y, line_color=colors, line_width=2)
    y_min, y_max = make_y_limit_multi(price_source_y, lowwer_ratio=0.1, upper_ratio=0.1)
    y_min -= (y_max - y_min) * 0.66  #  ポートフォリオ割合のためのオフセット
    p1.y_range = Range1d(start=y_min, end=y_max)

    p1.yaxis[0].axis_label = "正規化価格"
    p1.yaxis[1].axis_label = "保有割合"

    p1.xaxis.major_label_overrides = {str(one_x) : str(all_datetime_array[i]) for i, one_x in enumerate(x)}

    p2_text = Div(text=make_ticker_text(all_mean_cost_price_array[:,0], ticker_names))

    p2 = bokeh.plotting.figure(plot_width=1200,plot_height=300,title="正規化平均取得価格・全資産")
    p2.multi_line(xs=mean_cost_price_source_x, ys=mean_cost_price_source_y, line_color=colors, line_width=2)
    y_min, y_max = make_y_limit_multi(mean_cost_price_source_y, lowwer_ratio=0.1, upper_ratio=0.1)
    p2.y_range = Range1d(start=y_min, end=y_max)

    y_max, y_min = make_y_limit(all_assets_array, upper_ratio=0.1, lowwer_ratio=0.1)
    p2.extra_y_ranges = {"all_assets": Range1d(start=y_max, end=y_min)}
    p2.add_layout(LinearAxis(y_range_name="all_assets"), 'right')
    p2.line(x, all_assets_array, color="red", legend_label="all_assets", line_width=4, y_range_name="all_assets")

    # 疑似的なレジェンドをつける
    for ticker_name, color in zip(ticker_names, colors):
        p2.line([], [], legend_label=ticker_name, color=color, line_width=2)

    p2.yaxis[0].axis_label = "正規化平均取得価格"
    p2.yaxis[1].axis_label = "全資産 [円]"

    p2.xaxis.major_label_overrides = {str(one_x) : str(all_datetime_array[i]) for i, one_x in enumerate(x)}

    created_figure = bokeh.layouts.column(p1_text, p1, p2_text, p2)

    if is_save:
            if save_path.suffix == ".png":
                bokeh.io.export_png(created_figure, filename=save_path)
            elif save_path.suffix == ".html":
                output_file(save_path)
                bokeh.io.save(created_figure, filename=save_path, title="trading process")    
            else:
                raise Exception("The suffix of save_path is must be '.png' or '.html'.")
    if is_show:
        try:
            reset_output()
            if is_jupyter:
                output_notebook()
            show(created_figure)
        except:
            if is_jupyter:
                output_notebook()
            show(created_figure)
        
    if not is_save and not is_show:
        raise Exception("is_save and is_show is False. This function do nothing")

# %%
visualize_portfolio_transform_bokeh(portfolio_state_list, save_path=Path("visualization/trade_transform.png"), is_save=True, is_show=True)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1967">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a4ca5725-28e0-453f-8421-f0f94ee6759c" data-root-id="1465"></div>
