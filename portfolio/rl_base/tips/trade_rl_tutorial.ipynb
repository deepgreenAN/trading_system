# %% [markdown]
# rootディレクトリに移動

# %%
# %cd ../..
# Out:
# E:\システムトレード入門\trade_system_git_workspace

# %% [markdown]
# # 強化学習で株取引　その１

# %% [markdown]
# 今回は環境の作成もかねて，一つの銘柄の取引を強化学習で行う．予測とはアルゴリズムを分離するため，未来の株価も含めるように調整する．

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from numpy.random import RandomState
import pandas as pd
from tqdm.notebook import tqdm
import collections

# %%
import gym
from gym import spaces, logger
from gym.utils import seeding

# %%
import datetime
from pytz import timezone

# %%
from pathlib import Path

# %%
import pfrl

# %%
from get_stock_price import StockDatabase

# %%
from utils import middle_sample_type_with_check, get_sec_from_freq, get_workdays_jp, get_previous_datetime, get_next_workday_jp
from utils import extract_workdays_intraday_jp_index, extract_workdays_intraday_jp

# %% [markdown]
# ### データベース

# %%
db_path = Path("E:/システムトレード入門/trade_system_git_workspace/db/stock_db") / Path("stock.db")
stock_db = StockDatabase(db_path)

# %%
stock_list = ["4755","9984","6701","7203","7267"]
stock_db.stock_in(stock_list)
# Out:
# array([ True,  True,  True,  True,  True])

# %%
stock_db.stock_timestamp(stock_list)
# Out:
#                 min_datetime               max_datetime column_name
# 0  2020-11-02 00:00:00+00:00  2021-03-16 05:59:00+00:00        4755
# 1  2020-11-02 00:00:00+00:00  2021-03-16 05:59:00+00:00        9984
# 2  2020-11-02 00:00:00+00:00  2021-03-16 05:59:00+00:00        6701
# 3  2020-11-02 00:00:00+00:00  2021-03-16 05:59:00+00:00        7203
# 4  2020-11-02 00:00:00+00:00  2021-03-16 05:59:00+00:00        7267

# %%
jst_timezone = timezone("Asia/Tokyo")
start_datetime = jst_timezone.localize(datetime.datetime(2020,11,1,0,0,0))
end_datetime = jst_timezone.localize(datetime.datetime(2020,12,1,0,0,0))

stock_df = stock_db.search_span(stock_names=["6502"], 
                                start_datetime=start_datetime,
                                end_datetime=end_datetime,
                                freq_str="T",
                                to_tokyo=True
                               )
stock_df
# Out:
#                            Open_6502  High_6502  Low_6502  Close_6502  \
# timestamp
# 2020-11-02 09:00:00+09:00     2607.0     2620.0    2606.0      2617.0
# 2020-11-02 09:01:00+09:00     2619.0     2627.0    2619.0      2627.0
# 2020-11-02 09:02:00+09:00     2634.0     2636.0    2634.0      2634.0
# 2020-11-02 09:03:00+09:00     2636.0     2642.0    2633.0      2636.0
# 2020-11-02 09:04:00+09:00     2638.0     2640.0    2633.0      2638.0
# ...                              ...        ...       ...         ...
# 2020-11-30 23:55:00+09:00        NaN        NaN       NaN         NaN
# 2020-11-30 23:56:00+09:00        NaN        NaN       NaN         NaN
# 2020-11-30 23:57:00+09:00        NaN        NaN       NaN         NaN
# 2020-11-30 23:58:00+09:00        NaN        NaN       NaN         NaN
# 2020-11-30 23:59:00+09:00        NaN        NaN       NaN         NaN
#
#                            Volume_6502
# timestamp
# 2020-11-02 09:00:00+09:00          0.0
# 2020-11-02 09:01:00+09:00       4900.0
# 2020-11-02 09:02:00+09:00      30000.0
# 2020-11-02 09:03:00+09:00      35000.0
# 2020-11-02 09:04:00+09:00      10100.0
# ...                                ...
# 2020-11-30 23:55:00+09:00          NaN
# 2020-11-30 23:56:00+09:00          NaN
# 2020-11-30 23:57:00+09:00          NaN
# 2020-11-30 23:58:00+09:00          NaN
# 2020-11-30 23:59:00+09:00          NaN
#
# [31860 rows x 5 columns]

# %% [markdown]
# ### 環境クラス

# %% [markdown]
# #### 前処理用のクラス

# %%
class NormalizeState():
    def __init__(self, init_cash, init_cash_times=1, unit_const=1, price_const=1, replace=False):
        self.cash_devide_const = init_cash * init_cash_times
        self.unit_devide_const = unit_const
        self.price_devide_const = price_const
        
        self.replace = replace
        
    def __call__(self, state):
        if not self.replace:
            state = state.copy()

        # cash
        state[0] = state[0]/self.cash_devide_const
        # unit
        state[1] = state[1]/self.unit_devide_const
        # price
        state[2:] = state[2:]/self.price_devide_const

        return state

class NormalizeReward():
    def __init__(self, init_cash, init_cash_times=1):
        self.reward_devide_const = init_cash * init_cash_times
        
    def __call__(self, reward):
        reward = reward / self.reward_devide_const
        
        return reward

# %% [markdown]
# #### サンプリングのためのクラス

# %%
class WindowSampler():
    def __init__(self, stock_names, start_datetime, end_datetime, freq_str, end_include=False):
        """
        指定した範囲から，エピソード分利用可能なdatetimeをサンプリングするためのクラス
        """
        if isinstance(stock_names, str):  # 銘柄コードが一つの場合
            stock_names = [stock_names]
        self.stock_names = stock_names
        
        self.start_datetime = start_datetime
        self.end_datetime = end_datetime
        # タイムゾーンが同じかチェック
        if self.start_datetime.tzinfo != self.end_datetime.tzinfo:
            raise Exception("The timezone of start_datetime and end_datetime must be same")
        
        self.freq_str = middle_sample_type_with_check(freq_str)
                
        stock_name_datetime_array_list = []
        
        for stock_name in stock_names:
            # 指定した範囲内，周期のdatetimeのndarrayを取得
            if end_include:
                datetime_index = pd.date_range(start=self.start_datetime,
                                               end=self.end_datetime,
                                               freq=self.freq_str
                                              )
                
            else:
                datetime_index = pd.date_range(start=self.start_datetime,
                                               end=get_previous_datetime(self.end_datetime, freq_str=self.freq_str),
                                               freq=self.freq_str
                                              )

            datetime_index = extract_workdays_intraday_jp_index(datetime_index, return_as="index")
            
            stock_name_array = np.full(len(datetime_index), stock_name).astype(object)  # object同士でstackするため
            datetime_array = datetime_index.to_pydatetime()
            stock_name_datetime_array = np.stack([stock_name_array, datetime_array], axis=1)  # [銘柄コード, datetime]のndarray
            stock_name_datetime_array_list.append(stock_name_datetime_array)
            
    
        self.all_stockname_datetime_array = np.concatenate(stock_name_datetime_array_list, axis=0)
        
    def sample(self, seed=None, remove=False):
        if seed is not None and remove:
            raise Exception("If use seed, cannot remove")
            
        random_index = RandomState(seed).randint(0, len(self.all_stockname_datetime_array))
        #ランダムに取り出す
        stock_datetime = self.all_stockname_datetime_array[random_index]
        # 取り出したものを削除
        if remove:
            self.all_stockname_datetime_array = np.delete(self.all_stockname_datetime_array,random_index,axis=0)
        return stock_datetime

# %%
#jst_timezone = timezone("Asia/Tokyo")
#start_datetime = jst_timezone.localize(datetime.datetime(2020,11,1,0,0,0))
#end_datetime = jst_timezone.localize(datetime.datetime(2020,12,1,0,0,0))

start_datetime = datetime.datetime(2020,11,1,0,0,0)
end_datetime = datetime.datetime(2020,12,1,0,0,0)
#stock_names = "6502"
stock_names = ["6502","4755"]

window_sampler = WindowSampler(stock_names, start_datetime, end_datetime, freq_str="T", end_include=False)

# %%
window_sampler.sample(seed=133, remove=False)
# Out:
# array(['4755', datetime.datetime(2020, 11, 27, 10, 53)], dtype=object)

# %% [markdown]
# #### 環境クラス本体

# %%
class OneStockEnv(gym.Env):
    """
    一つの銘柄の株式に関する環境
    """
    def __init__(self, 
                 stock_db,
                 stock_names,
                 start_datetime,
                 end_datetime,
                 freq_str,
                 episode_length,
                 state_time_list=[0],
                 use_ohlc="Close",
                 initial_cash=1.e6,  # 100万円
                 initial_unit=50,  # 初期単元数
                 use_view=False,
                 one_unit_stocks=100,
                 max_units_number=10,
                 low_limmit=1.e3,  # 1000円
                 interpolate=True,
                 sample_remove=False,
                 penalty_ratio=1.e-4,
                 penalty_init_cash_bound=0.1,
                 action_restriction = False
                ):
        """
        stock_db: StockDataBase
            値を読み込むデータベース．1エピソード分のデータをreset事に読み込む
        stock_names: str list
            利用するデータの銘柄，複数指定した場合はreset時にランダムで決定される
        start_datetime: datetime
            利用するデータの始端
        ed_datetime: datetime
            利用するデータの終端
        freq_str: str
            サンプリング周期
        episode_length: int
            1エピソードの状態の個数
        start_time_list: int list
            状態として利用する株価の現在からのインデックスのリスト．最初の値は現在(0)でなければならない
        use_ohlc: str, defalt: "Close"
            サンプリング周期における利用するデータの指定(Open, High, Low, Close)
        initial_cash: int, defalt: 1.e6
            種銭
        use_view: bool
            reset時にviewを使うかどうか．使う場合，若干高速になるがcloseをしなければならない
        one_unit_stocks: int
            単元数．通常は100だが，独自に定義できる
        max_units_number: int, default: 10
            売買時の単元のセット数の上限・下限．
        low_limmmit: int, defalt:1.e3
            資産額の下限値．この値を下回った場合，エピソードを終了する．
        interpolate: bool
            指定した期間内のデータ中にnanがあった場合，あるいはデータが取得できなかった場合に補間をするかどうか
        sample_remove: bool
            reset時に取得するデータで一度利用したデータを取り除くかどうか
        """
        
        # データベース
        self.stock_db = stock_db
        # ビューの作成
        self.use_view = use_view
        if self.use_view:
            self.stock_view = self.stock_db.create_view(stock_names, start_datetime=start_datetime, end_datetime=end_datetime)
        
        # 利用するohlcのいずれか
        if use_ohlc not in {"Open","High","Low","Close"}:
            raise Exception("use_ohlc must be in {'Open','High','Low','Close'}")
        self.use_ohlc = use_ohlc
        
        self.freq_str = middle_sample_type_with_check(freq_str)
        # 全datetimeデータを保持
        all_datetime_index = pd.date_range(start=start_datetime,
                                           end=get_previous_datetime(end_datetime, freq_str=self.freq_str),
                                           freq=self.freq_str,
                                          )
        
        self.all_datetime_index = extract_workdays_intraday_jp_index(all_datetime_index, return_as="index")
            
        self.episode_length = episode_length
        self.initial_cash = initial_cash
        self.initial_unit = initial_unit
        self.low_limmit = low_limmit
        self.interpolate = interpolate
        self.sample_remove = sample_remove
        self.seed_number = None
        self.penalty_ratio = penalty_ratio
        self.penalty_init_cash_bound = penalty_init_cash_bound
        self.action_restriction = action_restriction
        
        if state_time_list[0] != 0:
            raise Exception("The first value of state_time_list must be 0")
        
        self.state_time_list = state_time_list
        
        self.max_state_time = max(state_time_list)  # 利用する未来の状態の現在からのタイムステップ数
        last_start_datetime = self.all_datetime_index[-(self.max_state_time + self.episode_length)]  # エピソードの開始時刻の最後

        self.sampler = WindowSampler(stock_names,
                                     start_datetime=start_datetime,
                                     end_datetime=last_start_datetime,
                                     freq_str=self.freq_str,
                                     end_include=True,  # 最後も含む
                                    )
        # 状態空間と行動空間の定義
        
        min_stock_price = 0
        max_stock_price = np.finfo(np.float32).max
        
        min_cash = 0
        max_cash = np.finfo(np.float32).max
        
        min_unit = 0
        max_unit = 1.e6  # # 100万＊単元まで売買できる 
        
        state_max_list = [max_cash, max_unit, max_stock_price]  # 現金，保有単元数，平均取得価格
        state_max_list.extend([max_stock_price]*len(self.state_time_list))  # [現在価格，指定した未来の価格]
        
        state_min_list = [min_cash, min_unit, min_stock_price]  # 現金，保有単元数，平均取得価格
        state_min_list.extend([min_stock_price]*len(self.state_time_list))  # [現在価格，指定した未来の価格]
                
        state_max_array = np.array(state_max_list, dtype=np.float32)
        state_min_array = np.array(state_min_list, dtype=np.float32)
        
        self.one_unit_stocks = one_unit_stocks  # 独自単元．
        self.max_units_number = max_units_number  # 売買する独自単元の最大数 
        self.action_class_number = 2 * self.max_units_number + 1 # 行動数は 2 * self.max_unit_number + 1(ステイ)
        
        self.action_space = spaces.Discrete(self.action_class_number)
        self.observation_space = spaces.Box(state_min_array, state_max_array, dtype=np.float32)
        
        # 行動クラスの定義
        sell_action_array = np.arange(-self.max_units_number, 0, 1)  # 売りクラス マイナス
        stay_action_arrray = np.array([0])  # ステイクラス
        buy_action_array = np.arange(1, self.max_units_number+1, 1)  # 買いクラス　プラス
        
        self.stay_index = len(sell_action_array)  # ステイのインデックス
        self.action_class_array = np.concatenate([sell_action_array, stay_action_arrray, buy_action_array], axis=0)  # 売りクラス，ステイクラス，買いクラスの順番
        
        self.state = None
        self.steps_beyond_done = None  # エラー処理に利用
        

    def reset(self, select_datetime=None, select_stock_name=None):
        """
        環境をリセットする．エピソード開始日時と銘柄名を指定することで，特定の
        select_datetime: datetime.datetime
            エピソードの開始日時
        select_stock_name: str
            銘柄名
        """
        iter_counter = 0
        while True:  # 条件をクリアしたらreturn,それまで繰り返し
            stock_and_datetime = self.sampler.sample(remove=self.sample_remove, seed=self.seed_number)
            
            if select_stock_name is None:  # 銘柄名が与えられなかった場合
                stock_name = stock_and_datetime[0]
            else:
                if select_stock_name in self.sampler.stock_names:  # 銘柄名の列
                    stock_name = select_stock_name
                else:
                    raise Exception("select_stock must be in stock_names of constructor args")
            
            if select_datetime is None:  # 日時が与えられなかった場合
                episode_start_datetime = stock_and_datetime[1]
            else:
                select_datetime_array = np.array([select_datetime])
                if np.in1d(select_datetime_array, self.sampler.all_stockname_datetime_array[:,1]).item():  # datetimeの列
                    episode_start_datetime = select_datetime
                else:
                    raise Exception("select_datetime must be in sample range of datetime")
                
            episode_start_datetime_index = np.where(self.all_datetime_index==episode_start_datetime)[0].item()  # エピソードで利用する開始時刻

            episode_end_datetime_index = episode_start_datetime_index + (self.episode_length-1) + self.max_state_time  # 状態が利用する未来のデータも含める
            episode_end_datetime = self.all_datetime_index[episode_end_datetime_index]  # エピソードで利用する終端時刻(エピソードの終了時刻ではない)

            # 利用するカラム名
            use_column_name = self.use_ohlc+"_"+stock_name
            
            # エピソード分+状態利用分のデータの取得
        
            if self.use_view:
                episode_series = self.stock_db.search_span(stock_names=stock_name, 
                                                           start_datetime=episode_start_datetime,
                                                           end_datetime=episode_end_datetime,
                                                           freq_str=self.freq_str,
                                                           is_end_include=True,  # 最後の値も含める
                                                           to_tokyo=True,  #必ずTrueに
                                                           view=self.stock_view
                                                           ).loc[:,use_column_name]
                
            else:
                episode_series = self.stock_db.search_span(stock_names=stock_name, 
                                                           start_datetime=episode_start_datetime,
                                                           end_datetime=episode_end_datetime,
                                                           freq_str=self.freq_str,
                                                           is_end_include=True,  # 最後の値も含める
                                                           to_tokyo=True,  #必ずTrueに
                                                           ).loc[:,use_column_name]
            
            # 領域を営業日日中に変更
            
            
            self.episode_series = extract_workdays_intraday_jp(episode_series, return_as="df")
            
            
            
            # 領域にnanが入っているか判定
            if self.episode_series.isnull().sum() > 0:
                IsNan = True
            else:
                IsNan = False
            
            
            # すべて取得できたか判定(データが存在しないか判定)
            part_datetime_bool = (episode_start_datetime <= self.all_datetime_index) & (self.all_datetime_index <= episode_end_datetime)  # 最後も含める
            part_datetime_index = self.all_datetime_index[part_datetime_bool].copy()
                       
            if not self.episode_series.index.equals(part_datetime_index):  # 同一判定
                IsCannotGet = True
            else:
                IsCannotGet = False
            
            iter_counter += 1
            
            # nanが入っておらず，全て取得できた場合．あるいは補間する場合，あるいは日時・もしくはstock_nameが与えられた場合
            if ((not IsNan) and (not IsCannotGet)) or self.interpolate or (select_datetime is not None or stock_name is not None):
                break

        # 線形補間
        if (self.interpolate or (select_datetime is not None or select_stock_name is not None)) and (IsNan or IsCannotGet):  # 補間の必要性がある場合

            if IsCannotGet:  # データが存在しない場合
                # part_datetime_indexに含まれて，self.episode_series.indexに含まれないdatetime
                add_datetime_indice = np.setdiff1d(part_datetime_index.to_pydatetime(), self.episode_series.index.to_pydatetime())
                add_series = pd.Series(index=add_datetime_indice,dtype=np.float64)  # nameは指定しなくてもOK, 値はnan
                new_episode_series = pd.concat([self.episode_series, add_series]).sort_index()  # 存在しないデータがnanで補間
                self.episode_series = new_episode_series
            
            # 線形補間
            self.episode_series.interpolate(limit_direction="both",inplace=True)

                
        cash = self.initial_cash
        unit_number = self.initial_unit
        #cash_and_unit_array = np.array([cash, unit_number])

        # 状態で利用する部分を取得
        #state_datetimes = [self.all_datetime_index[episode_start_datetime_index+add_index].to_pydatetime() for add_index in self.state_time_list]  # datetime.datetimeに変更
        state_datetimes = [self.all_datetime_index[episode_start_datetime_index+add_index] for add_index in self.state_time_list]  # pd.Timestampのまま
        
        state_prices_bool_array = self.episode_series.index.isin(state_datetimes)

        state_prices_series = self.episode_series.loc[state_prices_bool_array].copy()
        state_prices_array = state_prices_series.values
        
        now_price = state_prices_array[0]

        # 現状態をアトリビュートとして保持
        self.state = np.concatenate([cash_and_unit_array, state_prices_array], axis=0)
        self.all_property = cash + now_price * unit_number * self.one_unit_stocks  # 最初は現在の価格
        self.now_datetime = episode_start_datetime  # 現時間
        self.info = {"datetime":self.now_datetime,
                     "stock_name":stock_name,
                     "done_actine":None,
                     "iter_counter":iter_counter,
                     "all_property":self.all_property,
                     "penalty":None,
                    }
        
        self.now_index = episode_start_datetime_index  # 現時間のインデックス
        self.stock_name = stock_name  # 現銘柄コード
        self.step_counter = 1  # ステップ数のカウンタ
        done = False  # ここではもちろんFalse
        
        # エラー処理で利用
        self.steps_beyond_done = None
        
        return self.state.copy(), None, done, self.info  # なぜかagentがinplaceに変更してしまうので，stateをコピー
    
    def step(self, action):
        #assert self.action_space.contains(action), "action {} ({}) invalid".format(action, type(action))
        
        state = self.state
        
        cash = state[0]
        unit_number = state[1]
        
        prices = state[2:]  # 使わない？
        
        now_index = self.now_index + 1
        now_datetime = self.all_datetime_index[now_index].to_pydatetime()  # infoで利用
        
        #state_datetimes = [self.all_datetime_index[now_index+add_index].to_pydatetime() for add_index in self.state_time_list]
        state_datetimes = [self.all_datetime_index[now_index+add_index] for add_index in self.state_time_list]  # pd.Timestampのまま
        
        state_prices_bool_array = self.episode_series.index.isin(state_datetimes)

        state_prices_series = self.episode_series.loc[state_prices_bool_array].copy()
        state_prices_array = state_prices_series.values
        
        # 行動の制約（現金より多く変えない，保持数より多くは売れない)
        now_price = state_prices_array[0]  # state_priceの最初は必ずnowでなければならない
        criped_cash = max(0, cash)  # 条件判定はマイナスを除く
        buy_condition_bool = (criped_cash - now_price * self.action_class_array * self.one_unit_stocks) >= 0  # 買い条件を満たしたブール, キャッシュがマイナスの時，0にする
        # print("buy_condition_bool:",buy_condition_bool)
        buy_condition_true_max_index = buy_condition_bool.sum() - 1  # 条件を満たした最大値のインデックス
        if buy_condition_true_max_index < 0:  # -1になってしまった場合
            buy_condition_true_max_index = 0

        criped_unit_number = max(0, unit_number)
        sell_condition_bool = (criped_unit_number + self.action_class_array) > 0  # 売り条件を満たしたブール．unit_numberがマイナスの時，0にする
        # print("sell_conditiion_bool:",sell_condition_bool)
        sell_condition_true_min_index = (~sell_condition_bool).sum() - 1  # 条件を満たした最小値のインデックス
        if sell_condition_true_min_index < 0:  # -1になってしまった場合
            sell_condition_true_min_index = 0
                
        if self.action_restriction:
            if action < self.stay_index:  # 売りの場合
                if action < sell_condition_true_min_index:  # 行動が最小条件より下になった場合
                    action = sell_condition_true_min_index

            elif action > self.stay_index:  # 買いの場合
                if action > buy_condition_true_max_index:  # 行動が最大条件より上になった場合
                    action = buy_condition_true_max_index
                
        # それ以外(ステイ)はそのまま
        
        
        # rewardの計算とunit・cashの更新
        row_reward = now_price * self.one_unit_stocks * (- self.action_class_array[action]) # 買いがプラスであるため，マイナスをかける．cashの計算に利用する．
        #print("row_reward:",row_reward)
        # ペナルティ条件
        penalty_condition1 = action==self.stay_index  # ステイしている
        penalty_condition2 = abs((cash + row_reward)-self.initial_cash)<(self.initial_cash*self.penalty_init_cash_bound)  # 種銭付近
        penalty_condition3 = unit_number==0 # unit数が0
        penalty_condition4 = unit_number<10 # unit数が少ない
        
        penalty = 0
        
        
        # ペナルティの計算
        #if penalty_condition1:  # ステイの場合
        #    prepenalty = - self.initial_cash * 0.1
        #    #print("stay penalty",prepenalty)
        #    penalty += prepenalty
        #if penalty_condition1 and penalty_condition4:  # unit数が少ない状態でステイ
        #    prepenalty = - self.initial_cash * 0.1
        #    penalty += prepenalty
        
        unit_penalty = np.abs(self.action_class_array)*1.5*1.e4  # 売買の単位が多い方が良い
        #print("unit penalty:",unit_penalty[action])
        #print("unit_penalty:",unit_penalty)
        penalty += unit_penalty[action]  # unitに対するペナルティ
        
        # 売買条件ペナルティ
        #print("action:",action)
        if action < self.stay_index:  # 売りの場合
            #print("sell_condition_true_min_index:",sell_condition_true_min_index)
            if action < sell_condition_true_min_index:  # 行動が最小条件より下になった場合
                prepenalty = - (sell_condition_true_min_index - action) * self.initial_cash * 0.5
                assert prepenalty <= 0,"this penalty must be minus {}".format(prepenalty)
                #print("sell penalty:",prepenalty)
                penalty += prepenalty
            
        elif action > self.stay_index:  # 買いの場合
            #print("buy_condition_true_max_index:",buy_condition_true_max_index)
            if action > buy_condition_true_max_index:  # 行動が最大条件より上になった場合
                prepenalty = - (action - buy_condition_true_max_index) * self.initial_cash * 0.5
                assert prepenalty <= 0,"this penalty must be minus {}".format(prepenalty)
                #print("buy penalty:",prepenalty)
                penalty += prepenalty
        
        reward = row_reward + penalty  # ペナルティの追加．強化学習に利用する．
        

        unit_number += self.action_class_array[action]  # actionはint?
        #print("add_unit:",self.action_class_array[action])
        #print("unit_number:",unit_number)
        cash += row_reward  # 手数料はない

        self.all_property = cash + now_price * unit_number * self.one_unit_stocks  # 全資産
        
        cash_and_unit_array = np.array([cash, unit_number])
        self.state = np.concatenate([cash_and_unit_array, state_prices_array],axis=0)
        self.now_datetime = now_datetime
        
        self.info = {"datetime":self.now_datetime, 
                     "stock_name":self.stock_name,
                     "done_action":action,
                     "all_property":self.all_property,
                     "penalty":penalty
                    }  # stock_nameを入れる意味ある？
        
        self.now_index = now_index
        self.step_counter += 1
        
        # doneの更新
        done = (self.step_counter >= self.episode_length) or (self.all_property < self.low_limmit)
        
        # エピソードが終了して，resetが呼ばれる前にstepが呼ばれた時のエラー判定
        if done:
            if self.steps_beyond_done is None:
                self.steps_beyond_done = 0  # 0 に初期化
                
            elif self.steps_beyond_done == 0:  # 0の時のみロギング
                logger.warn(
                    "You are calling 'step()' even though this "
                    "environment has already returned done = True. You"
                    "should always call 'reset()' once you receive 'done ="
                    "True' -- any further steps are undefined behavior"
                )
                self.steps_beyond_done += 1
        
        return self.state.copy(), reward, done, self.info  # なぜかagentがinplaceに変更してしまうので，stateをコピー

    def get_gein_reward(now_price, action):
        """
        株式の売却による利益を意味する報酬
        """
        gein_reward = now_price * self.one_unit_stocks * (- self.action_class_array[action]) # 買いがプラスであるため，マイナスをかける．cashの計算に利用する．
        return gein_reward
    
    
    def close(self):
        """
        ビューのクローズとseedのリセット
        """
        if self.use_view:
            self.stock_view.close()
        self.seed(None)  # シードの初期化
    
    def seed(self, seed=None):
        """
        reset時のサンプリングのseedを設定する．リセットの場合，何も指定しないかNoneを指定
        """
        self.seed_number = seed

# %%
jst_timezone = timezone("Asia/Tokyo")
start_datetime = jst_timezone.localize(datetime.datetime(2020,11,1,0,0,0))
end_datetime = jst_timezone.localize(datetime.datetime(2020,12,1,0,0,0))
#end_datetime = get_next_workday_jp(start_datetime, days=11)  # 営業日で一週間(5日間)

initial_cash = 1.e6
initial_unit = 50

stock_names = "4755"
#stock_namess = "9984"
#stock_names = ["6502","4755"]
#stock_list = ["4755","9984","6701","7203","7267"]

freq_str = "5T"
episode_length = 12*5*7  # 2週間

#state_time_list = [0,1,12,12*3,12*5,12*5*3],  # [現在，次時刻，一時間後，3時間後，5時間後(1日後), 15時間後(3日後)]
state_time_list = [0,
                   1,
                   2,
                   6,
                   12,
                   12*2,
                   12*3,
                   12*4,
                   12*5*1,
                   12*5*2,
                   12*5*3,
                   12*5*4,
                   12*5*5,
                   ]  # 現在，5分後, 10分後, 30分後, 1時間後, 2時間後, 3時間後, 4時間後, 1日後, 2日後, 3日後, 4日後, 5日後, 6日後, 7日後

penalty_ratio=1.e-3
#penalty_ratio = 0
penalty_init_cash_bound = 0.1
one_unit_stocks = 20


env = OneStockEnv(stock_db,
                  stock_names=stock_names,
                  start_datetime=start_datetime,
                  end_datetime=end_datetime,
                  freq_str="5T",
                  episode_length=episode_length,  # 一週間
                  state_time_list=state_time_list,
                  use_ohlc="Close",  # 終値を使う
                  initial_cash=initial_cash,  # 種銭：100万円,
                  initial_unit=initial_unit,
                  use_view=False,
                  one_unit_stocks=one_unit_stocks,  # 独自単元数
                  max_units_number=10,  # 一度に売買できる独自単元数
                  low_limmit=1.e4,  # 全財産がこの値以下になれば終了
                  interpolate=True,
                  penalty_ratio=penalty_ratio,
                  penalty_init_cash_bound=penalty_init_cash_bound
                 )

# %%
#env.reset(select_datetime=jst_timezone.localize(datetime.datetime(2020, 11, 4, 14, 0)), select_stock_name="4755")
env.reset()
# Out:
# (array([1.000e+06, 5.000e+01, 1.049e+03, 1.049e+03, 1.050e+03, 1.050e+03,
#         1.083e+03, 1.081e+03, 1.088e+03, 1.079e+03, 1.079e+03, 1.125e+03,
#         1.086e+03, 1.108e+03, 1.130e+03]),
#  None,
#  False,
#  {'datetime': datetime.datetime(2020, 11, 5, 14, 5, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>),
#   'stock_name': '4755',
#   'done_actine': None,
#   'iter_counter': 1,
#   'all_property': 2049000.0,
#   'penalty': None})

# %%
state_transform = NormalizeState(init_cash=1.e6, 
                                 init_cash_times=1,
                                 unit_const=100,
                                 price_const=1.e4,
                                 replace=False
                                )

reward_transform = NormalizeReward(init_cash=1.e6,
                                   init_cash_times=1,
                                  )

# %% [markdown]
# ### 環境の動きをデバッグ

# %%
for i in range(100):
    action = env.action_space.sample()
    #action = 15
    observe, reward, done, info = env.step(action)

    cash = observe[0]
    unit_number = observe[1]
    now_price = observe[2]

    done_action = info["done_action"]
    print("action selected:{}, done:{}".format(action, done_action))
    print("done_buy_sell stocks:{}, deal:{}:".format(env.action_class_array[done_action]*env.one_unit_stocks, -now_price*env.action_class_array[done_action]))
    print("observe:",observe)
    print("cash:",cash)
    print("stocks:",unit_number*env.one_unit_stocks)
    print("all property:",env.all_property)
    print("penalty:",info["penalty"])
    print("#################################")
# Out:
# action selected:8, done:8
# done_buy_sell stocks:-40, deal:2098.0:
# observe: [1.04196e+06 4.80000e+01 1.04900e+03 1.05000e+03 1.05200e+03 1.05200e+03
#  1.08300e+03 1.07700e+03 1.08600e+03 1.07900e+03 1.07900e+03 1.12400e+03
#  1.08800e+03 1.10900e+03 1.13100e+03]
# cash: 1041960.0
# stocks: 960.0
# all property: 2049000.0
# penalty: 30000.0
# #################################
# action selected:16, done:16
# done_buy_sell stocks:120, deal:-6300.0:
# observe: [9.1596e+05 5.4000e+01 1.0500e+03 1.0520e+03 1.0510e+03 1.0500e+03
#  1.0820e+03 1.0800e+03 1.0850e+03 1.0820e+03 1.0810e+03 1.1230e+03
#  1.0890e+03 1.1130e+03 1.1290e+03]
# cash: 915960.0
# stocks: 1080.0
# all property: 2049960.0
# penalty: 90000.0
# #################################
# action selected:11, done:11
# done_buy_sell stocks:20, deal:-1052.0:
# observe: [8.9492e+05 5.5000e+01 1.0520e+03 1.0510e+03 1.0500e+03 1.0510e+03
#  1.0780e+03 1.0840e+03 1.0860e+03 1.0800e+03 1.0810e+03 1.1240e+03
#  1.0900e+03 1.1140e+03 1.1310e+03]
# cash: 894920.0
# stocks: 1100.0
# all property: 2052120.0
# penalty: 15000.0
# #################################
# action selected:18, done:18
# done_buy_sell stocks:160, deal:-8408.0:
# observe: [7.2676e+05 6.3000e+01 1.0510e+03 1.0500e+03 1.0500e+03 1.0510e+03
#  1.0820e+03 1.0840e+03 1.0860e+03 1.0800e+03 1.0800e+03 1.1220e+03
#  1.0890e+03 1.1130e+03 1.1310e+03]
# cash: 726760.0
# stocks: 1260.0
# all property: 2051020.0
# penalty: 120000.0
# #################################
# action selected:0, done:0
# done_buy_sell stocks:-200, deal:10500.0:
# observe: [9.3676e+05 5.3000e+01 1.0500e+03 1.0500e+03 1.0520e+03 1.0810e+03
#  1.0880e+03 1.0830e+03 1.0820e+03 1.0820e+03 1.0800e+03 1.1200e+03
#  1.0900e+03 1.1110e+03 1.1310e+03]
# cash: 936760.0
# stocks: 1060.0
# all property: 2049760.0
# penalty: 150000.0
# #################################
# action selected:4, done:4
# done_buy_sell stocks:-120, deal:6300.0:
# observe: [1.06276e+06 4.70000e+01 1.05000e+03 1.05200e+03 1.05000e+03 1.08300e+03
#  1.08700e+03 1.08600e+03 1.08400e+03 1.08100e+03 1.07800e+03 1.12000e+03
#  1.09100e+03 1.11000e+03 1.13200e+03]
# cash: 1062760.0
# stocks: 940.0
# all property: 2049760.0
# penalty: 90000.0
# #################################
# action selected:20, done:20
# done_buy_sell stocks:200, deal:-10520.0:
# observe: [8.5236e+05 5.7000e+01 1.0520e+03 1.0500e+03 1.0510e+03 1.0830e+03
#  1.0840e+03 1.0880e+03 1.0830e+03 1.0800e+03 1.0790e+03 1.1200e+03
#  1.0890e+03 1.1100e+03 1.1280e+03]
# cash: 852360.0
# stocks: 1140.0
# all property: 2051640.0
# penalty: 150000.0
# #################################
# action selected:17, done:17
# done_buy_sell stocks:140, deal:-7350.0:
# observe: [7.0536e+05 6.4000e+01 1.0500e+03 1.0510e+03 1.0510e+03 1.0820e+03
#  1.0880e+03 1.0850e+03 1.0840e+03 1.0800e+03 1.0780e+03 1.1200e+03
#  1.0910e+03 1.1110e+03 1.1290e+03]
# cash: 705360.0
# stocks: 1280.0
# all property: 2049360.0
# penalty: 105000.0
# #################################
# action selected:16, done:16
# done_buy_sell stocks:120, deal:-6306.0:
# observe: [5.7924e+05 7.0000e+01 1.0510e+03 1.0510e+03 1.0810e+03 1.0780e+03
#  1.0840e+03 1.0870e+03 1.0820e+03 1.0790e+03 1.0790e+03 1.1190e+03
#  1.0890e+03 1.1090e+03 1.1280e+03]
# cash: 579240.0
# stocks: 1400.0
# all property: 2050640.0
# penalty: 90000.0
# #################################
# action selected:8, done:8
# done_buy_sell stocks:-40, deal:2102.0:
# observe: [6.2128e+05 6.8000e+01 1.0510e+03 1.0810e+03 1.0830e+03 1.0820e+03
#  1.0790e+03 1.0900e+03 1.0820e+03 1.0780e+03 1.0790e+03 1.1170e+03
#  1.0890e+03 1.1120e+03 1.1300e+03]
# cash: 621280.0
# stocks: 1360.0
# all property: 2050640.0
# penalty: 30000.0
# #################################
# action selected:6, done:6
# done_buy_sell stocks:-80, deal:4324.0:
# observe: [7.0776e+05 6.4000e+01 1.0810e+03 1.0830e+03 1.0830e+03 1.0880e+03
#  1.0810e+03 1.0890e+03 1.0800e+03 1.0780e+03 1.1040e+03 1.1280e+03
#  1.0910e+03 1.1250e+03 1.0970e+03]
# cash: 707760.0
# stocks: 1280.0
# all property: 2091440.0
# penalty: 60000.0
# #################################
# action selected:13, done:13
# done_buy_sell stocks:60, deal:-3249.0:
# observe: [6.4278e+05 6.7000e+01 1.0830e+03 1.0830e+03 1.0820e+03 1.0870e+03
#  1.0810e+03 1.0880e+03 1.0790e+03 1.0790e+03 1.1030e+03 1.1070e+03
#  1.0910e+03 1.1230e+03 1.0710e+03]
# cash: 642780.0
# stocks: 1340.0
# all property: 2094000.0
# penalty: 45000.0
# #################################
# action selected:8, done:8
# done_buy_sell stocks:-40, deal:2166.0:
# observe: [6.861e+05 6.500e+01 1.083e+03 1.082e+03 1.078e+03 1.084e+03 1.077e+03
#  1.086e+03 1.079e+03 1.079e+03 1.102e+03 1.105e+03 1.093e+03 1.125e+03
#  1.086e+03]
# cash: 686100.0
# stocks: 1300.0
# all property: 2094000.0
# penalty: 30000.0
# #################################
# action selected:10, done:10
# done_buy_sell stocks:0, deal:-0.0:
# observe: [6.861e+05 6.500e+01 1.082e+03 1.078e+03 1.082e+03 1.088e+03 1.080e+03
#  1.085e+03 1.082e+03 1.081e+03 1.100e+03 1.062e+03 1.099e+03 1.122e+03
#  1.083e+03]
# cash: 686100.0
# stocks: 1300.0
# all property: 2092700.0
# penalty: 0.0
# #################################
# action selected:9, done:9
# done_buy_sell stocks:-20, deal:1078.0:
# observe: [7.0766e+05 6.4000e+01 1.0780e+03 1.0820e+03 1.0880e+03 1.0840e+03
#  1.0840e+03 1.0860e+03 1.0800e+03 1.0810e+03 1.1000e+03 1.0760e+03
#  1.0970e+03 1.1230e+03 1.0800e+03]
# cash: 707660.0
# stocks: 1280.0
# all property: 2087500.0
# penalty: 15000.0
# #################################
# action selected:12, done:12
# done_buy_sell stocks:40, deal:-2164.0:
# observe: [6.6438e+05 6.6000e+01 1.0820e+03 1.0880e+03 1.0870e+03 1.0790e+03
#  1.0840e+03 1.0860e+03 1.0800e+03 1.0800e+03 1.1010e+03 1.0850e+03
#  1.0940e+03 1.1280e+03 1.0820e+03]
# cash: 664380.0
# stocks: 1320.0
# all property: 2092620.0
# penalty: 30000.0
# #################################
# action selected:8, done:8
# done_buy_sell stocks:-40, deal:2176.0:
# observe: [7.079e+05 6.400e+01 1.088e+03 1.087e+03 1.084e+03 1.081e+03 1.083e+03
#  1.082e+03 1.082e+03 1.080e+03 1.101e+03 1.081e+03 1.094e+03 1.129e+03
#  1.094e+03]
# cash: 707900.0
# stocks: 1280.0
# all property: 2100540.0
# penalty: 30000.0
# #################################
# action selected:9, done:9
# done_buy_sell stocks:-20, deal:1087.0:
# observe: [7.2964e+05 6.3000e+01 1.0870e+03 1.0840e+03 1.0880e+03 1.0810e+03
#  1.0860e+03 1.0840e+03 1.0810e+03 1.0780e+03 1.1060e+03 1.0890e+03
#  1.0950e+03 1.1300e+03 1.0920e+03]
# cash: 729640.0
# stocks: 1260.0
# all property: 2099260.0
# penalty: 15000.0
# #################################
# action selected:6, done:6
# done_buy_sell stocks:-80, deal:4336.0:
# observe: [8.1636e+05 5.9000e+01 1.0840e+03 1.0880e+03 1.0840e+03 1.0770e+03
#  1.0880e+03 1.0830e+03 1.0800e+03 1.0790e+03 1.1080e+03 1.0890e+03
#  1.0980e+03 1.1280e+03 1.0920e+03]
# cash: 816360.0
# stocks: 1180.0
# all property: 2095480.0
# penalty: 60000.0
# #################################
# action selected:11, done:11
# done_buy_sell stocks:20, deal:-1088.0:
# observe: [7.946e+05 6.000e+01 1.088e+03 1.084e+03 1.079e+03 1.080e+03 1.085e+03
#  1.084e+03 1.080e+03 1.078e+03 1.111e+03 1.097e+03 1.098e+03 1.132e+03
#  1.093e+03]
# cash: 794600.0
# stocks: 1200.0
# all property: 2100200.0
# penalty: 15000.0
# #################################
# action selected:11, done:11
# done_buy_sell stocks:20, deal:-1084.0:
# observe: [7.7292e+05 6.1000e+01 1.0840e+03 1.0790e+03 1.0810e+03 1.0840e+03
#  1.0870e+03 1.0820e+03 1.0790e+03 1.0790e+03 1.1090e+03 1.0980e+03
#  1.0970e+03 1.1300e+03 1.0920e+03]
# cash: 772920.0
# stocks: 1220.0
# all property: 2095400.0
# penalty: 15000.0
# #################################
# action selected:10, done:10
# done_buy_sell stocks:0, deal:-0.0:
# observe: [7.7292e+05 6.1000e+01 1.0790e+03 1.0810e+03 1.0810e+03 1.0840e+03
#  1.0900e+03 1.0820e+03 1.0780e+03 1.0790e+03 1.1090e+03 1.1040e+03
#  1.0980e+03 1.1310e+03 1.0970e+03]
# cash: 772920.0
# stocks: 1220.0
# all property: 2089300.0
# penalty: 0.0
# #################################
# action selected:18, done:18
# done_buy_sell stocks:160, deal:-8648.0:
# observe: [5.9996e+05 6.9000e+01 1.0810e+03 1.0810e+03 1.0770e+03 1.0830e+03
#  1.0890e+03 1.0800e+03 1.0780e+03 1.1040e+03 1.1120e+03 1.1110e+03
#  1.0970e+03 1.1310e+03 1.0990e+03]
# cash: 599960.0
# stocks: 1380.0
# all property: 2091740.0
# penalty: 120000.0
# #################################
# action selected:17, done:17
# done_buy_sell stocks:140, deal:-7567.0:
# observe: [4.4862e+05 7.6000e+01 1.0810e+03 1.0770e+03 1.0800e+03 1.0860e+03
#  1.0880e+03 1.0790e+03 1.0790e+03 1.1030e+03 1.1160e+03 1.1140e+03
#  1.0980e+03 1.1360e+03 1.0980e+03]
# cash: 448620.0
# stocks: 1520.0
# all property: 2091740.0
# penalty: 105000.0
# #################################
# action selected:8, done:8
# done_buy_sell stocks:-40, deal:2154.0:
# observe: [4.917e+05 7.400e+01 1.077e+03 1.080e+03 1.084e+03 1.088e+03 1.086e+03
#  1.079e+03 1.079e+03 1.102e+03 1.116e+03 1.112e+03 1.100e+03 1.134e+03
#  1.096e+03]
# cash: 491700.0
# stocks: 1480.0
# all property: 2085660.0
# penalty: 30000.0
# #################################
# action selected:17, done:17
# done_buy_sell stocks:140, deal:-7560.0:
# observe: [3.405e+05 8.100e+01 1.080e+03 1.084e+03 1.084e+03 1.085e+03 1.085e+03
#  1.082e+03 1.081e+03 1.100e+03 1.114e+03 1.108e+03 1.103e+03 1.131e+03
#  1.099e+03]
# cash: 340500.0
# stocks: 1620.0
# all property: 2090100.0
# penalty: 105000.0
# #################################
# action selected:8, done:8
# done_buy_sell stocks:-40, deal:2168.0:
# observe: [3.8386e+05 7.9000e+01 1.0840e+03 1.0840e+03 1.0830e+03 1.0870e+03
#  1.0860e+03 1.0800e+03 1.0810e+03 1.1000e+03 1.1170e+03 1.1080e+03
#  1.1000e+03 1.1310e+03 1.1000e+03]
# cash: 383860.0
# stocks: 1580.0
# all property: 2096580.0
# penalty: 30000.0
# #################################
# action selected:5, done:5
# done_buy_sell stocks:-100, deal:5420.0:
# observe: [4.9226e+05 7.4000e+01 1.0840e+03 1.0830e+03 1.0860e+03 1.0900e+03
#  1.0860e+03 1.0800e+03 1.0800e+03 1.1010e+03 1.1180e+03 1.1110e+03
#  1.1000e+03 1.1320e+03 1.1010e+03]
# cash: 492260.0
# stocks: 1480.0
# all property: 2096580.0
# penalty: 75000.0
# #################################
# action selected:10, done:10
# done_buy_sell stocks:0, deal:-0.0:
# observe: [4.9226e+05 7.4000e+01 1.0830e+03 1.0860e+03 1.0880e+03 1.0890e+03
#  1.0820e+03 1.0820e+03 1.0800e+03 1.1010e+03 1.1190e+03 1.1030e+03
#  1.0990e+03 1.1310e+03 1.1000e+03]
# cash: 492260.0
# stocks: 1480.0
# all property: 2095100.0
# penalty: 0.0
# #################################
# action selected:3, done:3
# done_buy_sell stocks:-140, deal:7602.0:
# observe: [6.443e+05 6.700e+01 1.086e+03 1.088e+03 1.085e+03 1.088e+03 1.084e+03
#  1.081e+03 1.078e+03 1.106e+03 1.120e+03 1.098e+03 1.101e+03 1.131e+03
#  1.103e+03]
# cash: 644300.0
# stocks: 1340.0
# all property: 2099540.0
# penalty: 105000.0
# #################################
# action selected:14, done:14
# done_buy_sell stocks:80, deal:-4352.0:
# observe: [5.5726e+05 7.1000e+01 1.0880e+03 1.0850e+03 1.0870e+03 1.0860e+03
#  1.0830e+03 1.0800e+03 1.0790e+03 1.1080e+03 1.1220e+03 1.0950e+03
#  1.1040e+03 1.1320e+03 1.1050e+03]
# cash: 557260.0
# stocks: 1420.0
# all property: 2102220.0
# penalty: 60000.0
# #################################
# action selected:5, done:5
# done_buy_sell stocks:-100, deal:5425.0:
# observe: [6.6576e+05 6.6000e+01 1.0850e+03 1.0870e+03 1.0900e+03 1.0850e+03
#  1.0840e+03 1.0800e+03 1.0780e+03 1.1110e+03 1.1230e+03 1.0950e+03
#  1.1020e+03 1.1300e+03 1.1010e+03]
# cash: 665760.0
# stocks: 1320.0
# all property: 2097960.0
# penalty: 75000.0
# #################################
# action selected:14, done:14
# done_buy_sell stocks:80, deal:-4348.0:
# observe: [5.788e+05 7.000e+01 1.087e+03 1.090e+03 1.089e+03 1.086e+03 1.082e+03
#  1.079e+03 1.079e+03 1.109e+03 1.123e+03 1.092e+03 1.101e+03 1.129e+03
#  1.101e+03]
# cash: 578800.0
# stocks: 1400.0
# all property: 2100600.0
# penalty: 60000.0
# #################################
# action selected:1, done:1
# done_buy_sell stocks:-180, deal:9810.0:
# observe: [7.750e+05 6.100e+01 1.090e+03 1.089e+03 1.088e+03 1.086e+03 1.082e+03
#  1.078e+03 1.079e+03 1.109e+03 1.124e+03 1.090e+03 1.102e+03 1.129e+03
#  1.095e+03]
# cash: 775000.0
# stocks: 1220.0
# all property: 2104800.0
# penalty: 135000.0
# #################################
# action selected:0, done:0
# done_buy_sell stocks:-200, deal:10890.0:
# observe: [9.928e+05 5.100e+01 1.089e+03 1.088e+03 1.086e+03 1.082e+03 1.080e+03
#  1.078e+03 1.104e+03 1.112e+03 1.124e+03 1.094e+03 1.101e+03 1.128e+03
#  1.092e+03]
# cash: 992800.0
# stocks: 1020.0
# all property: 2103580.0
# penalty: 150000.0
# #################################
# action selected:3, done:3
# done_buy_sell stocks:-140, deal:7616.0:
# observe: [1.14512e+06 4.40000e+01 1.08800e+03 1.08600e+03 1.08500e+03 1.08400e+03
#  1.07900e+03 1.07900e+03 1.10300e+03 1.11600e+03 1.12200e+03 1.09900e+03
#  1.10200e+03 1.12800e+03 1.08800e+03]
# cash: 1145120.0
# stocks: 880.0
# all property: 2102560.0
# penalty: 105000.0
# #################################
# action selected:15, done:15
# done_buy_sell stocks:100, deal:-5430.0:
# observe: [1.03652e+06 4.90000e+01 1.08600e+03 1.08500e+03 1.08600e+03 1.08300e+03
#  1.07900e+03 1.07900e+03 1.10200e+03 1.11600e+03 1.12400e+03 1.09600e+03
#  1.10200e+03 1.12900e+03 1.09000e+03]
# cash: 1036520.0
# stocks: 980.0
# all property: 2100800.0
# penalty: 75000.0
# #################################
# action selected:2, done:2
# done_buy_sell stocks:-160, deal:8680.0:
# observe: [1.21012e+06 4.10000e+01 1.08500e+03 1.08600e+03 1.08600e+03 1.08400e+03
#  1.08200e+03 1.08100e+03 1.10000e+03 1.11400e+03 1.12300e+03 1.09700e+03
#  1.10100e+03 1.12700e+03 1.09100e+03]
# cash: 1210120.0
# stocks: 820.0
# all property: 2099820.0
# penalty: 120000.0
# #################################
# action selected:3, done:3
# done_buy_sell stocks:-140, deal:7602.0:
# observe: [1.36216e+06 3.40000e+01 1.08600e+03 1.08600e+03 1.08200e+03 1.08200e+03
#  1.08000e+03 1.08100e+03 1.10000e+03 1.11700e+03 1.12200e+03 1.09600e+03
#  1.10100e+03 1.12400e+03 1.09000e+03]
# cash: 1362160.0
# stocks: 680.0
# all property: 2100640.0
# penalty: 105000.0
# #################################
# action selected:5, done:5
# done_buy_sell stocks:-100, deal:5430.0:
# observe: [1.47076e+06 2.90000e+01 1.08600e+03 1.08200e+03 1.08400e+03 1.08200e+03
#  1.08000e+03 1.08000e+03 1.10100e+03 1.11800e+03 1.12500e+03 1.09500e+03
#  1.10000e+03 1.12600e+03 1.09200e+03]
# cash: 1470760.0
# stocks: 580.0
# all property: 2100640.0
# penalty: 75000.0
# #################################
# action selected:4, done:4
# done_buy_sell stocks:-120, deal:6492.0:
# observe: [1.6006e+06 2.3000e+01 1.0820e+03 1.0840e+03 1.0830e+03 1.0800e+03
#  1.0820e+03 1.0800e+03 1.1010e+03 1.1190e+03 1.1220e+03 1.0940e+03
#  1.1040e+03 1.1300e+03 1.0890e+03]
# cash: 1600600.0
# stocks: 460.0
# all property: 2098320.0
# penalty: 90000.0
# #################################
# action selected:11, done:11
# done_buy_sell stocks:20, deal:-1084.0:
# observe: [1.57892e+06 2.40000e+01 1.08400e+03 1.08300e+03 1.08400e+03 1.07900e+03
#  1.08100e+03 1.07800e+03 1.10600e+03 1.12000e+03 1.11900e+03 1.08800e+03
#  1.10400e+03 1.12600e+03 1.09000e+03]
# cash: 1578920.0
# stocks: 480.0
# all property: 2099240.0
# penalty: 15000.0
# #################################
# action selected:16, done:16
# done_buy_sell stocks:120, deal:-6498.0:
# observe: [1.44896e+06 3.00000e+01 1.08300e+03 1.08400e+03 1.08200e+03 1.07900e+03
#  1.08000e+03 1.07900e+03 1.10800e+03 1.12200e+03 1.11800e+03 1.08700e+03
#  1.10400e+03 1.12500e+03 1.09000e+03]
# cash: 1448960.0
# stocks: 600.0
# all property: 2098760.0
# penalty: 90000.0
# #################################
# action selected:16, done:16
# done_buy_sell stocks:120, deal:-6504.0:
# observe: [1.31888e+06 3.60000e+01 1.08400e+03 1.08200e+03 1.08200e+03 1.08200e+03
#  1.08000e+03 1.07800e+03 1.11100e+03 1.12300e+03 1.11800e+03 1.08700e+03
#  1.10000e+03 1.12600e+03 1.09100e+03]
# cash: 1318880.0
# stocks: 720.0
# all property: 2099360.0
# penalty: 90000.0
# #################################
# action selected:2, done:2
# done_buy_sell stocks:-160, deal:8656.0:
# observe: [1.492e+06 2.800e+01 1.082e+03 1.082e+03 1.080e+03 1.080e+03 1.079e+03
#  1.079e+03 1.109e+03 1.123e+03 1.119e+03 1.087e+03 1.102e+03 1.130e+03
#  1.091e+03]
# cash: 1492000.0
# stocks: 560.0
# all property: 2097920.0
# penalty: 120000.0
# #################################
# action selected:4, done:4
# done_buy_sell stocks:-120, deal:6492.0:
# observe: [1.62184e+06 2.20000e+01 1.08200e+03 1.08000e+03 1.07900e+03 1.08000e+03
#  1.07800e+03 1.07900e+03 1.10900e+03 1.12400e+03 1.11600e+03 1.08900e+03
#  1.10400e+03 1.12700e+03 1.08900e+03]
# cash: 1621840.0
# stocks: 440.0
# all property: 2097920.0
# penalty: 90000.0
# #################################
# action selected:4, done:4
# done_buy_sell stocks:-120, deal:6480.0:
# observe: [1.75144e+06 1.60000e+01 1.08000e+03 1.07900e+03 1.07900e+03 1.08200e+03
#  1.07800e+03 1.10400e+03 1.11200e+03 1.12400e+03 1.11600e+03 1.08900e+03
#  1.10400e+03 1.12700e+03 1.08800e+03]
# cash: 1751440.0
# stocks: 320.0
# all property: 2097040.0
# penalty: 90000.0
# #################################
# action selected:11, done:11
# done_buy_sell stocks:20, deal:-1079.0:
# observe: [1.72986e+06 1.70000e+01 1.07900e+03 1.07900e+03 1.08200e+03 1.08100e+03
#  1.07900e+03 1.10300e+03 1.11600e+03 1.12200e+03 1.11900e+03 1.08600e+03
#  1.10500e+03 1.12900e+03 1.08700e+03]
# cash: 1729860.0
# stocks: 340.0
# all property: 2096720.0
# penalty: 15000.0
# #################################
# action selected:4, done:4
# done_buy_sell stocks:-120, deal:6474.0:
# observe: [1.85934e+06 1.10000e+01 1.07900e+03 1.08200e+03 1.08000e+03 1.08000e+03
#  1.07900e+03 1.10200e+03 1.11600e+03 1.12400e+03 1.11800e+03 1.08600e+03
#  1.10600e+03 1.12800e+03 1.09000e+03]
# cash: 1859340.0
# stocks: 220.0
# all property: 2096720.0
# penalty: 90000.0
# #################################
# action selected:3, done:3
# done_buy_sell stocks:-140, deal:7574.0:
# observe: [2.01082e+06 4.00000e+00 1.08200e+03 1.08000e+03 1.08000e+03 1.08000e+03
#  1.08100e+03 1.10000e+03 1.11400e+03 1.12300e+03 1.12100e+03 1.08400e+03
#  1.10600e+03 1.12800e+03 1.09200e+03]
# cash: 2010820.0
# stocks: 80.0
# all property: 2097380.0
# penalty: 105000.0
# #################################
# action selected:19, done:19
# done_buy_sell stocks:180, deal:-9720.0:
# observe: [1.81642e+06 1.30000e+01 1.08000e+03 1.08000e+03 1.08200e+03 1.07900e+03
#  1.08100e+03 1.10000e+03 1.11700e+03 1.12200e+03 1.12000e+03 1.08300e+03
#  1.10700e+03 1.12800e+03 1.09000e+03]
# cash: 1816420.0
# stocks: 260.0
# all property: 2097220.0
# penalty: 135000.0
# #################################
# action selected:14, done:14
# done_buy_sell stocks:80, deal:-4320.0:
# observe: [1.73002e+06 1.70000e+01 1.08000e+03 1.08200e+03 1.08100e+03 1.07800e+03
#  1.08000e+03 1.10100e+03 1.11800e+03 1.12500e+03 1.11900e+03 1.08300e+03
#  1.10800e+03 1.12900e+03 1.09100e+03]
# cash: 1730020.0
# stocks: 340.0
# all property: 2097220.0
# penalty: 60000.0
# #################################
# action selected:0, done:0
# done_buy_sell stocks:-200, deal:10820.0:
# observe: [1.94642e+06 7.00000e+00 1.08200e+03 1.08100e+03 1.08000e+03 1.07800e+03
#  1.08000e+03 1.10100e+03 1.11900e+03 1.12200e+03 1.11900e+03 1.08300e+03
#  1.10700e+03 1.13000e+03 1.09100e+03]
# cash: 1946420.0
# stocks: 140.0
# all property: 2097900.0
# penalty: 150000.0
# #################################
# action selected:10, done:10
# done_buy_sell stocks:0, deal:-0.0:
# observe: [1.94642e+06 7.00000e+00 1.08100e+03 1.08000e+03 1.08000e+03 1.07900e+03
#  1.07800e+03 1.10600e+03 1.12000e+03 1.11900e+03 1.12100e+03 1.08500e+03
#  1.10800e+03 1.13000e+03 1.09100e+03]
# cash: 1946420.0
# stocks: 140.0
# all property: 2097760.0
# penalty: 0.0
# #################################
# action selected:13, done:13
# done_buy_sell stocks:60, deal:-3240.0:
# observe: [1.88162e+06 1.00000e+01 1.08000e+03 1.08000e+03 1.07900e+03 1.07900e+03
#  1.07900e+03 1.10800e+03 1.12200e+03 1.11800e+03 1.12100e+03 1.08200e+03
#  1.10700e+03 1.13000e+03 1.09100e+03]
# cash: 1881620.0
# stocks: 200.0
# all property: 2097620.0
# penalty: 45000.0
# #################################
# action selected:17, done:17
# done_buy_sell stocks:140, deal:-7560.0:
# observe: [1.73042e+06 1.70000e+01 1.08000e+03 1.07900e+03 1.07800e+03 1.08100e+03
#  1.07800e+03 1.11100e+03 1.12300e+03 1.11800e+03 1.12300e+03 1.08200e+03
#  1.10900e+03 1.13100e+03 1.09000e+03]
# cash: 1730420.0
# stocks: 340.0
# all property: 2097620.0
# penalty: 105000.0
# #################################
# action selected:8, done:8
# done_buy_sell stocks:-40, deal:2158.0:
# observe: [1.77358e+06 1.50000e+01 1.07900e+03 1.07800e+03 1.07800e+03 1.08100e+03
#  1.07900e+03 1.10900e+03 1.12300e+03 1.11900e+03 1.12300e+03 1.08100e+03
#  1.10800e+03 1.13000e+03 1.09100e+03]
# cash: 1773580.0
# stocks: 300.0
# all property: 2097280.0
# penalty: 30000.0
# #################################
# action selected:16, done:16
# done_buy_sell stocks:120, deal:-6468.0:
# observe: [1.64422e+06 2.10000e+01 1.07800e+03 1.07800e+03 1.07900e+03 1.08000e+03
#  1.07900e+03 1.10900e+03 1.12400e+03 1.11600e+03 1.12700e+03 1.08100e+03
#  1.10700e+03 1.13000e+03 1.09000e+03]
# cash: 1644220.0
# stocks: 420.0
# all property: 2096980.0
# penalty: 90000.0
# #################################
# action selected:5, done:5
# done_buy_sell stocks:-100, deal:5390.0:
# observe: [1.75202e+06 1.60000e+01 1.07800e+03 1.07900e+03 1.07900e+03 1.08000e+03
#  1.10400e+03 1.11200e+03 1.12400e+03 1.11600e+03 1.12400e+03 1.08600e+03
#  1.10800e+03 1.12800e+03 1.08700e+03]
# cash: 1752020.0
# stocks: 320.0
# all property: 2096980.0
# penalty: 75000.0
# #################################
# action selected:14, done:14
# done_buy_sell stocks:80, deal:-4316.0:
# observe: [1.6657e+06 2.0000e+01 1.0790e+03 1.0790e+03 1.0810e+03 1.0780e+03
#  1.1030e+03 1.1160e+03 1.1220e+03 1.1190e+03 1.1250e+03 1.0860e+03
#  1.1080e+03 1.1300e+03 1.0870e+03]
# cash: 1665700.0
# stocks: 400.0
# all property: 2097300.0
# penalty: 60000.0
# #################################
# action selected:18, done:18
# done_buy_sell stocks:160, deal:-8632.0:
# observe: [1.49306e+06 2.80000e+01 1.07900e+03 1.08100e+03 1.08100e+03 1.07900e+03
#  1.10200e+03 1.11600e+03 1.12400e+03 1.11800e+03 1.12400e+03 1.08800e+03
#  1.10900e+03 1.13100e+03 1.08800e+03]
# cash: 1493060.0
# stocks: 560.0
# all property: 2097300.0
# penalty: 120000.0
# #################################
# action selected:18, done:18
# done_buy_sell stocks:160, deal:-8648.0:
# observe: [1.3201e+06 3.6000e+01 1.0810e+03 1.0810e+03 1.0800e+03 1.0780e+03
#  1.1000e+03 1.1140e+03 1.1230e+03 1.1210e+03 1.1230e+03 1.0890e+03
#  1.1130e+03 1.1290e+03 1.0910e+03]
# cash: 1320100.0
# stocks: 720.0
# all property: 2098420.0
# penalty: 120000.0
# #################################
# action selected:1, done:1
# done_buy_sell stocks:-180, deal:9729.0:
# observe: [1.51468e+06 2.70000e+01 1.08100e+03 1.08000e+03 1.08000e+03 1.07900e+03
#  1.10000e+03 1.11700e+03 1.12200e+03 1.12000e+03 1.12400e+03 1.09000e+03
#  1.11400e+03 1.13100e+03 1.09000e+03]
# cash: 1514680.0
# stocks: 540.0
# all property: 2098420.0
# penalty: 135000.0
# #################################
# action selected:17, done:17
# done_buy_sell stocks:140, deal:-7560.0:
# observe: [1.36348e+06 3.40000e+01 1.08000e+03 1.08000e+03 1.07800e+03 1.07900e+03
#  1.10100e+03 1.11800e+03 1.12500e+03 1.11900e+03 1.12200e+03 1.08900e+03
#  1.11300e+03 1.13100e+03 1.09100e+03]
# cash: 1363480.0
# stocks: 680.0
# all property: 2097880.0
# penalty: 105000.0
# #################################
# action selected:16, done:16
# done_buy_sell stocks:120, deal:-6480.0:
# observe: [1.23388e+06 4.00000e+01 1.08000e+03 1.07800e+03 1.07900e+03 1.10400e+03
#  1.10100e+03 1.11900e+03 1.12200e+03 1.11900e+03 1.12000e+03 1.09000e+03
#  1.11100e+03 1.13100e+03 1.09000e+03]
# cash: 1233880.0
# stocks: 800.0
# all property: 2097880.0
# penalty: 90000.0
# #################################
# action selected:20, done:20
# done_buy_sell stocks:200, deal:-10780.0:
# observe: [1.01828e+06 5.00000e+01 1.07800e+03 1.07900e+03 1.07800e+03 1.10300e+03
#  1.10600e+03 1.12000e+03 1.11900e+03 1.12100e+03 1.12000e+03 1.09100e+03
#  1.11000e+03 1.13200e+03 1.09000e+03]
# cash: 1018280.0
# stocks: 1000.0
# all property: 2096280.0
# penalty: 150000.0
# #################################
# action selected:1, done:1
# done_buy_sell stocks:-180, deal:9711.0:
# observe: [1.2125e+06 4.1000e+01 1.0790e+03 1.0780e+03 1.0790e+03 1.1020e+03
#  1.1080e+03 1.1220e+03 1.1180e+03 1.1210e+03 1.1200e+03 1.0890e+03
#  1.1100e+03 1.1280e+03 1.0920e+03]
# cash: 1212500.0
# stocks: 820.0
# all property: 2097280.0
# penalty: 135000.0
# #################################
# action selected:6, done:6
# done_buy_sell stocks:-80, deal:4312.0:
# observe: [1.29874e+06 3.70000e+01 1.07800e+03 1.07900e+03 1.07900e+03 1.10000e+03
#  1.11100e+03 1.12300e+03 1.11800e+03 1.12300e+03 1.12000e+03 1.09100e+03
#  1.11100e+03 1.12900e+03 1.09000e+03]
# cash: 1298740.0
# stocks: 740.0
# all property: 2096460.0
# penalty: 60000.0
# #################################
# action selected:1, done:1
# done_buy_sell stocks:-180, deal:9711.0:
# observe: [1.49296e+06 2.80000e+01 1.07900e+03 1.07900e+03 1.10400e+03 1.10000e+03
#  1.10900e+03 1.12300e+03 1.11900e+03 1.12300e+03 1.11900e+03 1.08900e+03
#  1.10900e+03 1.12800e+03 1.09200e+03]
# cash: 1492960.0
# stocks: 560.0
# all property: 2097200.0
# penalty: 135000.0
# #################################
# action selected:19, done:19
# done_buy_sell stocks:180, deal:-9711.0:
# observe: [1.29874e+06 3.70000e+01 1.07900e+03 1.10400e+03 1.10300e+03 1.10100e+03
#  1.10900e+03 1.12400e+03 1.11600e+03 1.12700e+03 1.11700e+03 1.08900e+03
#  1.11200e+03 1.13000e+03 1.09300e+03]
# cash: 1298740.0
# stocks: 740.0
# all property: 2097200.0
# penalty: 135000.0
# #################################
# action selected:5, done:5
# done_buy_sell stocks:-100, deal:5520.0:
# observe: [1.40914e+06 3.20000e+01 1.10400e+03 1.10300e+03 1.10200e+03 1.10100e+03
#  1.11200e+03 1.12400e+03 1.11600e+03 1.12400e+03 1.12800e+03 1.09100e+03
#  1.12500e+03 1.09700e+03 1.10200e+03]
# cash: 1409140.0
# stocks: 640.0
# all property: 2115700.0
# penalty: 75000.0
# #################################
# action selected:10, done:10
# done_buy_sell stocks:0, deal:-0.0:
# observe: [1.40914e+06 3.20000e+01 1.10300e+03 1.10200e+03 1.10000e+03 1.10600e+03
#  1.11600e+03 1.12200e+03 1.11900e+03 1.12500e+03 1.10700e+03 1.09100e+03
#  1.12300e+03 1.07100e+03 1.10200e+03]
# cash: 1409140.0
# stocks: 640.0
# all property: 2115060.0
# penalty: 0.0
# #################################
# action selected:13, done:13
# done_buy_sell stocks:60, deal:-3306.0:
# observe: [1.34302e+06 3.50000e+01 1.10200e+03 1.10000e+03 1.10000e+03 1.10800e+03
#  1.11600e+03 1.12400e+03 1.11800e+03 1.12400e+03 1.10500e+03 1.09300e+03
#  1.12500e+03 1.08600e+03 1.10500e+03]
# cash: 1343020.0
# stocks: 700.0
# all property: 2114420.0
# penalty: 45000.0
# #################################
# action selected:18, done:18
# done_buy_sell stocks:160, deal:-8800.0:
# observe: [1.16702e+06 4.30000e+01 1.10000e+03 1.10000e+03 1.10100e+03 1.11100e+03
#  1.11400e+03 1.12300e+03 1.12100e+03 1.12300e+03 1.06200e+03 1.09900e+03
#  1.12200e+03 1.08300e+03 1.11000e+03]
# cash: 1167020.0
# stocks: 860.0
# all property: 2113020.0
# penalty: 120000.0
# #################################
# action selected:5, done:5
# done_buy_sell stocks:-100, deal:5500.0:
# observe: [1.27702e+06 3.80000e+01 1.10000e+03 1.10100e+03 1.10100e+03 1.10900e+03
#  1.11700e+03 1.12200e+03 1.12000e+03 1.12400e+03 1.07600e+03 1.09700e+03
#  1.12300e+03 1.08000e+03 1.11800e+03]
# cash: 1277020.0
# stocks: 760.0
# all property: 2113020.0
# penalty: 75000.0
# #################################
# action selected:16, done:16
# done_buy_sell stocks:120, deal:-6606.0:
# observe: [1.1449e+06 4.4000e+01 1.1010e+03 1.1010e+03 1.1060e+03 1.1090e+03
#  1.1180e+03 1.1250e+03 1.1190e+03 1.1220e+03 1.0850e+03 1.0940e+03
#  1.1280e+03 1.0820e+03 1.1230e+03]
# cash: 1144900.0
# stocks: 880.0
# all property: 2113780.0
# penalty: 90000.0
# #################################
# action selected:6, done:6
# done_buy_sell stocks:-80, deal:4404.0:
# observe: [1.23298e+06 4.00000e+01 1.10100e+03 1.10600e+03 1.10800e+03 1.11200e+03
#  1.11900e+03 1.12200e+03 1.11900e+03 1.12000e+03 1.08100e+03 1.09400e+03
#  1.12900e+03 1.09400e+03 1.13100e+03]
# cash: 1232980.0
# stocks: 800.0
# all property: 2113780.0
# penalty: 60000.0
# #################################
# action selected:12, done:12
# done_buy_sell stocks:40, deal:-2212.0:
# observe: [1.18874e+06 4.20000e+01 1.10600e+03 1.10800e+03 1.11100e+03 1.11600e+03
#  1.12000e+03 1.11900e+03 1.12100e+03 1.12000e+03 1.08900e+03 1.09500e+03
#  1.13000e+03 1.09200e+03 1.13100e+03]
# cash: 1188740.0
# stocks: 840.0
# all property: 2117780.0
# penalty: 30000.0
# #################################
# action selected:17, done:17
# done_buy_sell stocks:140, deal:-7756.0:
# observe: [1.03362e+06 4.90000e+01 1.10800e+03 1.11100e+03 1.10900e+03 1.11600e+03
#  1.12200e+03 1.11800e+03 1.12100e+03 1.12000e+03 1.08900e+03 1.09800e+03
#  1.12800e+03 1.09200e+03 1.13000e+03]
# cash: 1033620.0
# stocks: 980.0
# all property: 2119460.0
# penalty: 105000.0
# #################################
# action selected:20, done:20
# done_buy_sell stocks:200, deal:-11110.0:
# observe: [8.1142e+05 5.9000e+01 1.1110e+03 1.1090e+03 1.1090e+03 1.1140e+03
#  1.1230e+03 1.1180e+03 1.1230e+03 1.1200e+03 1.0970e+03 1.0980e+03
#  1.1320e+03 1.0930e+03 1.1320e+03]
# cash: 811420.0
# stocks: 1180.0
# all property: 2122400.0
# penalty: 150000.0
# #################################
# action selected:14, done:14
# done_buy_sell stocks:80, deal:-4436.0:
# observe: [7.227e+05 6.300e+01 1.109e+03 1.109e+03 1.112e+03 1.117e+03 1.123e+03
#  1.119e+03 1.123e+03 1.119e+03 1.098e+03 1.097e+03 1.130e+03 1.092e+03
#  1.129e+03]
# cash: 722700.0
# stocks: 1260.0
# all property: 2120040.0
# penalty: 60000.0
# #################################
# action selected:12, done:12
# done_buy_sell stocks:40, deal:-2218.0:
# observe: [6.7834e+05 6.5000e+01 1.1090e+03 1.1120e+03 1.1160e+03 1.1180e+03
#  1.1240e+03 1.1160e+03 1.1270e+03 1.1170e+03 1.1040e+03 1.0980e+03
#  1.1310e+03 1.0970e+03 1.1290e+03]
# cash: 678340.0
# stocks: 1300.0
# all property: 2120040.0
# penalty: 30000.0
# #################################
# action selected:20, done:20
# done_buy_sell stocks:200, deal:-11120.0:
# observe: [4.5594e+05 7.5000e+01 1.1120e+03 1.1160e+03 1.1160e+03 1.1190e+03
#  1.1240e+03 1.1160e+03 1.1240e+03 1.1280e+03 1.1110e+03 1.0970e+03
#  1.1310e+03 1.0990e+03 1.1310e+03]
# cash: 455940.0
# stocks: 1500.0
# all property: 2123940.0
# penalty: 150000.0
# #################################
# action selected:13, done:13
# done_buy_sell stocks:60, deal:-3348.0:
# observe: [3.8898e+05 7.8000e+01 1.1160e+03 1.1160e+03 1.1140e+03 1.1200e+03
#  1.1220e+03 1.1190e+03 1.1250e+03 1.1070e+03 1.1140e+03 1.0980e+03
#  1.1360e+03 1.0980e+03 1.1310e+03]
# cash: 388980.0
# stocks: 1560.0
# all property: 2129940.0
# penalty: 45000.0
# #################################
# action selected:10, done:10
# done_buy_sell stocks:0, deal:-0.0:
# observe: [3.8898e+05 7.8000e+01 1.1160e+03 1.1140e+03 1.1170e+03 1.1220e+03
#  1.1240e+03 1.1180e+03 1.1240e+03 1.1050e+03 1.1120e+03 1.1000e+03
#  1.1340e+03 1.0960e+03 1.1280e+03]
# cash: 388980.0
# stocks: 1560.0
# all property: 2129940.0
# penalty: 0.0
# #################################
# action selected:20, done:20
# done_buy_sell stocks:200, deal:-11140.0:
# observe: [1.6618e+05 8.8000e+01 1.1140e+03 1.1170e+03 1.1180e+03 1.1230e+03
#  1.1230e+03 1.1210e+03 1.1230e+03 1.0620e+03 1.1080e+03 1.1030e+03
#  1.1310e+03 1.0990e+03 1.1270e+03]
# cash: 166180.0
# stocks: 1760.0
# all property: 2126820.0
# penalty: 150000.0
# #################################
# action selected:6, done:6
# done_buy_sell stocks:-80, deal:4468.0:
# observe: [2.5554e+05 8.4000e+01 1.1170e+03 1.1180e+03 1.1190e+03 1.1230e+03
#  1.1220e+03 1.1200e+03 1.1240e+03 1.0760e+03 1.1080e+03 1.1000e+03
#  1.1310e+03 1.1000e+03 1.1260e+03]
# cash: 255540.0
# stocks: 1680.0
# all property: 2132100.0
# penalty: 60000.0
# #################################
# action selected:18, done:18
# done_buy_sell stocks:160, deal:-8944.0:
# observe: [76660.    92.  1118.  1119.  1120.  1124.  1125.  1119.  1122.  1085.
#   1111.  1100.  1132.  1101.  1130.]
# cash: 76660.0
# stocks: 1840.0
# all property: 2133780.0
# penalty: 120000.0
# #################################
# action selected:13, done:13
# done_buy_sell stocks:60, deal:-3357.0:
# observe: [9520.   95. 1119. 1120. 1122. 1124. 1122. 1119. 1120. 1081. 1103. 1099.
#  1131. 1100. 1130.]
# cash: 9520.0
# stocks: 1900.0
# all property: 2135620.0
# penalty: 45000.0
# #################################
# action selected:11, done:11
# done_buy_sell stocks:20, deal:-1120.0:
# observe: [-12880.     96.   1120.   1122.   1123.   1122.   1119.   1121.   1120.
#    1089.   1098.   1101.   1131.   1103.   1131.]
# cash: -12880.0
# stocks: 1920.0
# all property: 2137520.0
# penalty: -485000.0
# #################################
# action selected:4, done:4
# done_buy_sell stocks:-120, deal:6732.0:
# observe: [1.2176e+05 9.0000e+01 1.1220e+03 1.1230e+03 1.1230e+03 1.1240e+03
#  1.1180e+03 1.1210e+03 1.1200e+03 1.0890e+03 1.0950e+03 1.1040e+03
#  1.1320e+03 1.1050e+03 1.1300e+03]
# cash: 121760.0
# stocks: 1800.0
# all property: 2141360.0
# penalty: 90000.0
# #################################
# action selected:16, done:16
# done_buy_sell stocks:120, deal:-6738.0:
# observe: [-13000.     96.   1123.   1123.   1124.   1123.   1118.   1123.   1120.
#    1097.   1095.   1102.   1130.   1101.   1125.]
# cash: -13000.0
# stocks: 1920.0
# all property: 2143160.0
# penalty: -410000.0
# #################################
# action selected:2, done:2
# done_buy_sell stocks:-160, deal:8984.0:
# observe: [1.6668e+05 8.8000e+01 1.1230e+03 1.1240e+03 1.1240e+03 1.1220e+03
#  1.1190e+03 1.1230e+03 1.1190e+03 1.0980e+03 1.0920e+03 1.1010e+03
#  1.1290e+03 1.1010e+03 1.1230e+03]
# cash: 166680.0
# stocks: 1760.0
# all property: 2143160.0
# penalty: 120000.0
# #################################
# action selected:0, done:0
# done_buy_sell stocks:-200, deal:11240.0:
# observe: [3.9148e+05 7.8000e+01 1.1240e+03 1.1240e+03 1.1220e+03 1.1250e+03
#  1.1160e+03 1.1270e+03 1.1170e+03 1.1040e+03 1.0900e+03 1.1020e+03
#  1.1290e+03 1.0950e+03 1.1250e+03]
# cash: 391480.0
# stocks: 1560.0
# all property: 2144920.0
# penalty: 150000.0
# #################################
# action selected:16, done:16
# done_buy_sell stocks:120, deal:-6744.0:
# observe: [2.566e+05 8.400e+01 1.124e+03 1.122e+03 1.124e+03 1.122e+03 1.116e+03
#  1.124e+03 1.128e+03 1.111e+03 1.094e+03 1.101e+03 1.128e+03 1.092e+03
#  1.123e+03]
# cash: 256600.0
# stocks: 1680.0
# all property: 2144920.0
# penalty: 90000.0
# #################################
# action selected:19, done:19
# done_buy_sell stocks:180, deal:-10098.0:
# observe: [54640.    93.  1122.  1124.  1123.  1119.  1119.  1125.  1107.  1114.
#   1099.  1102.  1128.  1088.  1120.]
# cash: 54640.0
# stocks: 1860.0
# all property: 2141560.0
# penalty: 135000.0
# #################################
# action selected:9, done:9
# done_buy_sell stocks:-20, deal:1124.0:
# observe: [77120.    92.  1124.  1123.  1122.  1118.  1118.  1124.  1105.  1112.
#   1096.  1102.  1129.  1090.  1117.]
# cash: 77120.0
# stocks: 1840.0
# all property: 2145280.0
# penalty: 15000.0
# #################################
# action selected:11, done:11
# done_buy_sell stocks:20, deal:-1123.0:
# observe: [54660.    93.  1123.  1122.  1125.  1118.  1121.  1123.  1062.  1108.
#   1097.  1101.  1127.  1091.  1115.]
# cash: 54660.0
# stocks: 1860.0
# all property: 2143440.0
# penalty: 15000.0
# #################################
# action selected:3, done:3
# done_buy_sell stocks:-140, deal:7854.0:
# observe: [2.1174e+05 8.6000e+01 1.1220e+03 1.1250e+03 1.1220e+03 1.1190e+03
#  1.1200e+03 1.1240e+03 1.0760e+03 1.1080e+03 1.0960e+03 1.1010e+03
#  1.1240e+03 1.0900e+03 1.1140e+03]
# cash: 211740.0
# stocks: 1720.0
# all property: 2141580.0
# penalty: 105000.0
# #################################
# action selected:9, done:9
# done_buy_sell stocks:-20, deal:1125.0:
# observe: [2.3424e+05 8.5000e+01 1.1250e+03 1.1220e+03 1.1190e+03 1.1160e+03
#  1.1190e+03 1.1220e+03 1.0850e+03 1.1110e+03 1.0950e+03 1.1000e+03
#  1.1260e+03 1.0920e+03 1.1150e+03]
# cash: 234240.0
# stocks: 1700.0
# all property: 2146740.0
# penalty: 15000.0
# #################################

# %% [markdown]
# ### Q関数の定義

# %%
class QFunction(nn.Module):
    def __init__(self, obs_size, n_actions):
        super().__init__()
        self.fc1 = nn.Linear(obs_size, 32)
        self.bn1 = nn.BatchNorm1d(32)
        
        self.fc2 = nn.Linear(32, 128)
        self.bn2 = nn.BatchNorm1d(128)
        
        self.fc3 = nn.Linear(128, 256)
        self.bn3 = nn.BatchNorm1d(256)
        
        #self.fc4 = nn.Linear(256, 528)
        #self.bn4 = nn.BatchNorm1d(528)
        
        #self.fc5 = nn.Linear(528, 256)
        #self.bn5 = nn.BatchNorm1d(256)
        
        #self.fc6 = nn.Linear(256, 128)
        #self.bn6 = nn.BatchNorm1d(128)
        
        #self.fc7 = nn.Linear(128, 64)
        #self.bn7 = nn.BatchNorm1d(64)
        
        self.fc4 = nn.Linear(256, n_actions)
    def forward(self, x):
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = F.relu(self.bn3(self.fc3(x)))
        #x = F.relu(self.bn4(self.fc4(x)))
        #x = F.relu(self.bn5(self.fc5(x)))
        #x = F.relu(self.bn6(self.fc6(x)))
        #x = F.relu(self.bn7(self.fc7(x)))
        
        x = self.fc4(x)
        out = pfrl.action_value.DiscreteActionValue(x)
        return out

# %% [markdown]
# ### Q関数の初期化

# %%
obs_size = env.observation_space.low.size
print("observation size:", obs_size)
n_actions = env.action_space.n
print("action size:",n_actions)
q_func = QFunction(obs_size, n_actions)
# Out:
# observation size: 15
# action size: 21

# %% [markdown]
# ### エージェントの定義

# %% [markdown]
# 今回はDobuleQ

# %%
optimizer = torch.optim.Adam(q_func.parameters(), eps=1e-4)

gamma = 0.95

init_episilon = 0.9
init_explorer = pfrl.explorers.ConstantEpsilonGreedy(epsilon=init_episilon,
                                                random_action_func=env.action_space.sample
                                               )

replay_buffer = pfrl.replay_buffers.ReplayBuffer(capacity=10**6)

phi = lambda x: x.astype(np.float32, copy=False)

gpu = -1 # -1 is cpu

agent = pfrl.agents.DoubleDQN(
    q_function=q_func,
    optimizer=optimizer,
    replay_buffer=replay_buffer,
    gamma=gamma,
    explorer=init_explorer,
    replay_start_size=500,
    update_interval=1,
    target_update_interval=100,
    phi=phi,
    gpu=gpu
)

# %% [markdown]
# ###  イプシロンの減衰

# %%
def extinction_epsilon(episode_number):
    if episode_number < 200:
        return 0.9
    elif episode_number < 400:
        return 0.8
    elif episode_number < 600:
        return 0.7
    elif episode_number < 800:
        return 0.6
    elif episode_number < 1000:
        return 0.5
    elif episode_number < 1200:
        return 0.4
    elif episode_number < 1400:
        return 0.3
    elif episode_number < 1600:
        return 0.2
    else:
        return 0.1

# %% [markdown]
# ### 学習

# %%
# n_episodes = 300
n_episodes = 3000

# seedのセッティング
#env.seed(0)
env.seed()

# 学習


for i in tqdm(range(1, n_episodes + 1)):
    # epsilonの減衰
    epsilon = extinction_epsilon(i)
    explorer = pfrl.explorers.ConstantEpsilonGreedy(epsilon=epsilon,
                                                random_action_func=env.action_space.sample
                                               )
    
    agent.explorer = explorer
    
    obs,_,_,_ = env.reset()
    
    normalized_obs = state_transform(obs)
    #normalized_obs = obs
    
    R = 0
    t = 0
    train_action_list = []
    
    while True:
        action = agent.act(normalized_obs)
        train_action_list.append(action)
        obs, reward, done, info = env.step(action)

        R += reward
        t += 1
        reset = False  # リセットタイミングはdoneに依存
        # state, rewardの前処理
        normalized_obs = state_transform(obs)
        normalized_reward = reward_transform(reward)
        #normalized_obs = obs
        #normalized_reward = reward
        
        agent.observe(normalized_obs, normalized_reward, done, reset)
        if done:
            break

    if i%10 == 0:
        print("episode:{}, return:{}, episode_length:{}".format(i, R, t))
        print("action_counter:",collections.Counter(train_action_list))
    if i%50 == 0:
        print("statistics:", agent.get_statistics())
        
    # テスト(イプシロンを無視)
    if i%10 == 0:
        with agent.eval_mode():
            env.seed()
            #env.seed(0)
            obs,_,_,info = env.reset()
            
            test_action_list = []
            
            normalized_obs = state_transform(obs)
            #normalized_obs = obs
            
            R = 0
            t = 0
            
            print("\tt:{},all_property:{}, unit_number:{}, price:{}, penalty:{}, cash:{}".format(t,
                                                                                                 info["all_property"],
                                                                                                 obs[1],
                                                                                                 obs[2],
                                                                                                 info["penalty"],
                                                                                                 obs[0]
                                                                                                ))
            while True:
                action = agent.act(normalized_obs)
                test_action_list.append(action)
                obs, reward, done, info = env.step(action)
                R += reward
                t += 1
                reset = False

                # state, rewardの前処理
                normalized_obs = state_transform(obs)
                normalized_reward = reward_transform(reward)
                #normalized_obs = obs
                #normalized_reward = reward


                #agent.observe(normalized_obs, normalized_reward, done, reset)
                if done or reset:
                    break
                if t%100==0:
                    print("\tt:{},all_property:{}, unit_number:{}, price:{}, penalty:{}, cash:{}".format(t,
                                                                                                         info["all_property"],
                                                                                                         obs[1],
                                                                                                         obs[2],
                                                                                                         info["penalty"],
                                                                                                         obs[0]
                                                                                                        ))
                    print("\taction_counter:",collections.Counter(test_action_list))

            print("\tevaluation episode: {}, return:{}, episode_length:{}".format(i, R, t))
            print("\tall_property:", info["all_property"])
            print("\n")

env.close()
print("Finshed")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# episode:10, return:-329970260.0, episode_length:419
# action_counter: Counter({2: 31, 19: 28, 11: 27, 18: 23, 0: 23, 3: 22, 1: 22, 9: 22, 17: 21, 16: 21, 12: 19, 8: 19, 6: 18, 4: 18, 13: 16, 7: 16, 10: 15, 20: 15, 5: 15, 14: 14, 15: 14})
# 	t:0,all_property:2088000.0, unit_number:50.0, price:1088.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2096200.0, unit_number:10.0, price:1128.0, penalty:150000.0, cash:1870600.0
# 	action_counter: Counter({16: 60, 0: 40})
# 	t:200,all_property:2085920.0, unit_number:18.0, price:1107.0, penalty:90000.0, cash:1687400.0
# 	action_counter: Counter({16: 123, 0: 77})
# 	t:300,all_property:2089800.0, unit_number:10.0, price:1105.0, penalty:150000.0, cash:1868800.0
# 	action_counter: Counter({16: 185, 0: 115})
# 	t:400,all_property:2090880.0, unit_number:18.0, price:1118.0, penalty:90000.0, cash:1688400.0
# 	action_counter: Counter({16: 248, 0: 152})
# 	evaluation episode: 10, return:47894440.0, episode_length:419
# 	all_property: 2092840.0
#
#
# episode:20, return:-86920555.0, episode_length:419
# action_counter: Counter({1: 38, 2: 33, 20: 29, 19: 25, 11: 23, 13: 22, 16: 22, 17: 21, 15: 21, 10: 19, 5: 19, 6: 18, 0: 18, 9: 18, 3: 16, 12: 16, 7: 15, 14: 15, 8: 12, 4: 11, 18: 8})
# 	t:0,all_property:2103000.0, unit_number:50.0, price:1103.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2098160.0, unit_number:24.0, price:1083.0, penalty:150000.0, cash:1578320.0
# 	action_counter: Counter({0: 47, 20: 45, 2: 4, 14: 2, 19: 2})
# 	t:200,all_property:2115720.0, unit_number:24.0, price:1130.0, penalty:150000.0, cash:1573320.0
# 	action_counter: Counter({0: 97, 20: 95, 2: 4, 14: 2, 19: 2})
# 	t:300,all_property:2106880.0, unit_number:24.0, price:1102.0, penalty:150000.0, cash:1577920.0
# 	action_counter: Counter({0: 147, 20: 145, 2: 4, 14: 2, 19: 2})
# 	t:400,all_property:2111140.0, unit_number:13.0, price:1109.0, penalty:150000.0, cash:1822800.0
# 	action_counter: Counter({0: 194, 20: 162, 19: 31, 14: 9, 2: 4})
# 	evaluation episode: 20, return:62055000.0, episode_length:419
# 	all_property: 2111520.0
#
#
# episode:30, return:-26670240.0, episode_length:419
# action_counter: Counter({8: 27, 10: 25, 16: 24, 19: 24, 12: 24, 5: 24, 4: 22, 1: 22, 20: 22, 2: 21, 17: 21, 0: 20, 3: 20, 13: 19, 6: 17, 11: 17, 18: 17, 15: 15, 9: 14, 7: 14, 14: 10})
# 	t:0,all_property:2089000.0, unit_number:50.0, price:1089.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2104180.0, unit_number:14.0, price:1131.0, penalty:135000.0, cash:1787500.0
# 	action_counter: Counter({1: 52, 19: 48})
# 	t:200,all_property:2084780.0, unit_number:17.0, price:1090.0, penalty:135000.0, cash:1714180.0
# 	action_counter: Counter({1: 101, 19: 98, 4: 1})
# 	t:300,all_property:2096060.0, unit_number:7.0, price:1111.0, penalty:135000.0, cash:1940520.0
# 	action_counter: Counter({1: 149, 19: 146, 4: 2, 6: 2, 14: 1})
# 	t:400,all_property:2086940.0, unit_number:7.0, price:1087.0, penalty:135000.0, cash:1934760.0
# 	action_counter: Counter({1: 199, 19: 196, 4: 2, 6: 2, 14: 1})
# 	evaluation episode: 30, return:56989280.0, episode_length:419
# 	all_property: 2086160.0
#
#
# episode:40, return:-67300320.0, episode_length:419
# action_counter: Counter({17: 29, 1: 26, 3: 26, 5: 25, 18: 24, 13: 24, 14: 23, 16: 23, 6: 21, 2: 20, 8: 19, 10: 18, 11: 18, 0: 18, 7: 16, 9: 16, 20: 16, 12: 16, 19: 14, 15: 14, 4: 13})
# 	t:0,all_property:2080000.0, unit_number:50.0, price:1080.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2085420.0, unit_number:9.0, price:1095.0, penalty:105000.0, cash:1888320.0
# 	action_counter: Counter({18: 40, 5: 35, 3: 21, 0: 3, 1: 1})
# 	t:200,all_property:2093880.0, unit_number:9.0, price:1125.0, penalty:150000.0, cash:1891380.0
# 	action_counter: Counter({18: 62, 5: 59, 3: 29, 0: 26, 20: 23, 1: 1})
# 	t:300,all_property:2083820.0, unit_number:15.0, price:1090.0, penalty:120000.0, cash:1756820.0
# 	action_counter: Counter({18: 92, 5: 82, 3: 46, 0: 41, 20: 38, 1: 1})
# 	t:400,all_property:2090600.0, unit_number:8.0, price:1119.0, penalty:75000.0, cash:1911560.0
# 	action_counter: Counter({18: 139, 5: 94, 3: 75, 0: 53, 20: 38, 1: 1})
# 	evaluation episode: 40, return:48291740.0, episode_length:419
# 	all_property: 2088160.0
#
#
# episode:50, return:-91314340.0, episode_length:419
# action_counter: Counter({1: 34, 20: 28, 0: 28, 10: 26, 9: 24, 19: 22, 12: 20, 4: 20, 17: 19, 14: 19, 18: 18, 16: 18, 15: 18, 5: 17, 3: 17, 11: 17, 8: 17, 13: 16, 2: 15, 6: 15, 7: 11})
# statistics: [('average_q', 1.5831159), ('average_loss', 0.07042051819618791), ('cumulative_steps', 20950), ('n_updates', 20451), ('rlen', 20950)]
# 	t:0,all_property:2037000.0, unit_number:50.0, price:1037.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2038060.0, unit_number:15.0, price:1081.0, penalty:135000.0, cash:1713760.0
# 	action_counter: Counter({1: 32, 12: 32, 19: 22, 4: 9, 20: 4, 15: 1})
# 	t:200,all_property:2036900.0, unit_number:14.0, price:1088.0, penalty:135000.0, cash:1732260.0
# 	action_counter: Counter({12: 92, 1: 42, 4: 29, 19: 27, 20: 7, 17: 2, 15: 1})
# 	t:300,all_property:2039820.0, unit_number:2.0, price:1131.0, penalty:90000.0, cash:1994580.0
# 	action_counter: Counter({12: 137, 1: 61, 4: 45, 19: 35, 17: 11, 20: 10, 15: 1})
# 	t:400,all_property:2033100.0, unit_number:2.0, price:1091.0, penalty:90000.0, cash:1989460.0
# 	action_counter: Counter({12: 196, 1: 73, 4: 62, 19: 36, 17: 20, 20: 12, 15: 1})
# 	evaluation episode: 50, return:32215160.0, episode_length:419
# 	all_property: 2037900.0
#
#
# episode:60, return:-68819220.0, episode_length:419
# action_counter: Counter({1: 29, 15: 27, 16: 25, 2: 25, 13: 24, 10: 23, 9: 22, 19: 22, 3: 21, 12: 20, 4: 20, 17: 20, 5: 20, 20: 20, 11: 17, 8: 16, 0: 16, 6: 15, 18: 14, 14: 12, 7: 11})
# 	t:0,all_property:2123000.0, unit_number:50.0, price:1123.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2105560.0, unit_number:16.0, price:1095.0, penalty:90000.0, cash:1755160.0
# 	action_counter: Counter({0: 43, 16: 30, 18: 27})
# 	t:200,all_property:2115520.0, unit_number:17.0, price:1130.0, penalty:135000.0, cash:1731320.0
# 	action_counter: Counter({0: 87, 16: 46, 18: 42, 19: 25})
# 	t:300,all_property:2109700.0, unit_number:6.0, price:1115.0, penalty:150000.0, cash:1975900.0
# 	action_counter: Counter({0: 130, 18: 79, 16: 65, 19: 26})
# 	t:400,all_property:2106820.0, unit_number:6.0, price:1096.0, penalty:150000.0, cash:1975300.0
# 	action_counter: Counter({0: 172, 18: 115, 16: 87, 19: 26})
# 	evaluation episode: 60, return:53915580.0, episode_length:419
# 	all_property: 2105180.0
#
#
# episode:70, return:-238130120.0, episode_length:419
# action_counter: Counter({13: 29, 5: 27, 0: 26, 12: 26, 19: 26, 20: 25, 7: 24, 11: 24, 4: 23, 1: 22, 14: 19, 6: 17, 16: 17, 8: 17, 17: 16, 2: 15, 18: 14, 3: 14, 10: 14, 9: 13, 15: 11})
# 	t:0,all_property:2083000.0, unit_number:50.0, price:1083.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2089880.0, unit_number:9.0, price:1119.0, penalty:75000.0, cash:1888460.0
# 	action_counter: Counter({5: 67, 20: 31, 2: 2})
# 	t:200,all_property:2086320.0, unit_number:19.0, price:1102.0, penalty:150000.0, cash:1667560.0
# 	action_counter: Counter({5: 133, 20: 65, 2: 2})
# 	t:300,all_property:2077640.0, unit_number:14.0, price:1071.0, penalty:75000.0, cash:1777760.0
# 	action_counter: Counter({5: 200, 20: 98, 2: 2})
# 	t:400,all_property:2088480.0, unit_number:19.0, price:1114.0, penalty:150000.0, cash:1665160.0
# 	action_counter: Counter({5: 253, 20: 135, 0: 10, 2: 2})
# 	evaluation episode: 70, return:43617660.0, episode_length:419
# 	all_property: 2090700.0
#
#
# episode:80, return:-123043720.0, episode_length:419
# action_counter: Counter({11: 29, 20: 25, 3: 24, 16: 24, 12: 23, 9: 23, 0: 22, 2: 22, 10: 22, 17: 21, 19: 20, 8: 20, 18: 20, 6: 19, 1: 19, 13: 18, 5: 17, 7: 15, 14: 13, 15: 13, 4: 10})
# 	t:0,all_property:2082000.0, unit_number:50.0, price:1082.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2088360.0, unit_number:3.0, price:1128.0, penalty:120000.0, cash:2020680.0
# 	action_counter: Counter({2: 36, 16: 30, 12: 23, 20: 6, 0: 4, 5: 1})
# 	t:200,all_property:2086900.0, unit_number:3.0, price:1123.0, penalty:30000.0, cash:2019520.0
# 	action_counter: Counter({2: 70, 16: 63, 12: 55, 20: 7, 0: 4, 5: 1})
# 	t:300,all_property:2082300.0, unit_number:3.0, price:1109.0, penalty:30000.0, cash:2015760.0
# 	action_counter: Counter({2: 102, 16: 90, 12: 90, 20: 7, 14: 6, 0: 4, 5: 1})
# 	t:400,all_property:2079900.0, unit_number:0.0, price:1080.0, penalty:120000.0, cash:2079900.0
# 	action_counter: Counter({2: 136, 16: 124, 12: 120, 20: 8, 14: 6, 0: 4, 5: 2})
# 	evaluation episode: 80, return:35897540.0, episode_length:419
# 	all_property: 2080940.0
#
#
# episode:90, return:-45208740.0, episode_length:419
# action_counter: Counter({0: 39, 1: 27, 20: 25, 17: 24, 14: 24, 9: 24, 7: 23, 19: 21, 15: 20, 18: 20, 10: 20, 4: 19, 12: 18, 3: 18, 16: 17, 13: 17, 2: 16, 11: 16, 6: 15, 5: 9, 8: 7})
# 	t:0,all_property:2044000.0, unit_number:50.0, price:1044.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2051500.0, unit_number:10.0, price:1101.0, penalty:135000.0, cash:1831300.0
# 	action_counter: Counter({1: 48, 19: 48, 0: 4})
# 	t:200,all_property:2051840.0, unit_number:10.0, price:1082.0, penalty:135000.0, cash:1835440.0
# 	action_counter: Counter({1: 98, 19: 98, 0: 4})
# 	t:300,all_property:2056180.0, unit_number:10.0, price:1128.0, penalty:135000.0, cash:1830580.0
# 	action_counter: Counter({1: 148, 19: 148, 0: 4})
# 	t:400,all_property:2057520.0, unit_number:10.0, price:1123.0, penalty:135000.0, cash:1832920.0
# 	action_counter: Counter({1: 198, 19: 198, 0: 4})
# 	evaluation episode: 90, return:57557040.0, episode_length:419
# 	all_property: 2059100.0
#
#
# episode:100, return:-75943220.0, episode_length:419
# action_counter: Counter({13: 28, 18: 25, 6: 25, 20: 24, 0: 24, 2: 24, 1: 24, 3: 23, 19: 22, 14: 19, 16: 19, 5: 19, 12: 18, 10: 17, 11: 17, 4: 17, 17: 16, 7: 15, 15: 15, 9: 14, 8: 14})
# statistics: [('average_q', 2.2281923), ('average_loss', 0.0785337095009163), ('cumulative_steps', 41900), ('n_updates', 41401), ('rlen', 41900)]
# 	t:0,all_property:2123000.0, unit_number:50.0, price:1123.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2106500.0, unit_number:16.0, price:1095.0, penalty:90000.0, cash:1756100.0
# 	action_counter: Counter({1: 41, 16: 33, 17: 23, 2: 3})
# 	t:200,all_property:2122920.0, unit_number:18.0, price:1130.0, penalty:90000.0, cash:1716120.0
# 	action_counter: Counter({1: 82, 16: 76, 17: 38, 2: 3, 18: 1})
# 	t:300,all_property:2120540.0, unit_number:22.0, price:1115.0, penalty:90000.0, cash:1629940.0
# 	action_counter: Counter({1: 124, 16: 112, 17: 56, 20: 4, 2: 3, 18: 1})
# 	t:400,all_property:2114660.0, unit_number:19.0, price:1096.0, penalty:90000.0, cash:1698180.0
# 	action_counter: Counter({1: 165, 16: 161, 17: 64, 20: 4, 2: 3, 18: 3})
# 	evaluation episode: 100, return:47678720.0, episode_length:419
# 	all_property: 2117380.0
#
#
# episode:110, return:-85173620.0, episode_length:419
# action_counter: Counter({0: 29, 15: 27, 11: 26, 14: 24, 1: 24, 6: 22, 20: 22, 2: 22, 9: 21, 12: 20, 19: 20, 18: 20, 5: 18, 3: 17, 16: 17, 13: 17, 7: 15, 8: 15, 17: 15, 4: 15, 10: 13})
# 	t:0,all_property:2116000.0, unit_number:50.0, price:1116.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2118880.0, unit_number:10.0, price:1090.0, penalty:120000.0, cash:1900880.0
# 	action_counter: Counter({3: 48, 18: 28, 13: 24})
# 	t:200,all_property:2125400.0, unit_number:0.0, price:1130.0, penalty:105000.0, cash:2125400.0
# 	action_counter: Counter({3: 93, 18: 56, 13: 51})
# 	t:300,all_property:2126700.0, unit_number:10.0, price:1128.0, penalty:45000.0, cash:1901100.0
# 	action_counter: Counter({3: 137, 18: 86, 13: 77})
# 	t:400,all_property:2127220.0, unit_number:0.0, price:1117.0, penalty:105000.0, cash:2127220.0
# 	action_counter: Counter({3: 182, 18: 114, 13: 104})
# 	evaluation episode: 110, return:39938100.0, episode_length:419
# 	all_property: 2127520.0
#
#
# episode:120, return:-56290860.0, episode_length:419
# action_counter: Counter({20: 32, 0: 32, 18: 27, 4: 25, 16: 23, 8: 22, 3: 21, 5: 21, 14: 21, 10: 20, 12: 19, 1: 19, 15: 19, 2: 18, 7: 17, 17: 17, 19: 16, 9: 14, 6: 12, 11: 12, 13: 12})
# 	t:0,all_property:2122000.0, unit_number:50.0, price:1122.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2113240.0, unit_number:16.0, price:1097.0, penalty:150000.0, cash:1762200.0
# 	action_counter: Counter({20: 47, 0: 38, 2: 11, 1: 4})
# 	t:200,all_property:2121320.0, unit_number:-2.0, price:1131.0, penalty:-880000.0, cash:2166560.0
# 	action_counter: Counter({20: 96, 0: 88, 2: 12, 1: 4})
# 	t:300,all_property:2122840.0, unit_number:6.0, price:1121.0, penalty:150000.0, cash:1988320.0
# 	action_counter: Counter({20: 146, 0: 134, 2: 16, 1: 4})
# 	t:400,all_property:2114400.0, unit_number:14.0, price:1100.0, penalty:150000.0, cash:1806400.0
# 	action_counter: Counter({20: 196, 0: 180, 2: 20, 1: 4})
# 	evaluation episode: 120, return:61216800.0, episode_length:419
# 	all_property: 2114720.0
#
#
# episode:130, return:-274630840.0, episode_length:419
# action_counter: Counter({4: 27, 11: 25, 18: 25, 20: 24, 2: 23, 5: 23, 15: 22, 1: 22, 7: 22, 9: 20, 14: 20, 12: 20, 0: 19, 10: 19, 3: 18, 16: 16, 13: 16, 19: 16, 17: 16, 8: 14, 6: 12})
# 	t:0,all_property:2025000.0, unit_number:50.0, price:1025.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2025100.0, unit_number:8.0, price:1039.0, penalty:75000.0, cash:1858860.0
# 	action_counter: Counter({5: 45, 15: 27, 1: 12, 20: 12, 19: 4})
# 	t:200,all_property:2036680.0, unit_number:11.0, price:1084.0, penalty:75000.0, cash:1798200.0
# 	action_counter: Counter({5: 85, 19: 38, 15: 36, 1: 24, 20: 12, 2: 5})
# 	t:300,all_property:2048220.0, unit_number:10.0, price:1114.0, penalty:75000.0, cash:1825420.0
# 	action_counter: Counter({5: 95, 19: 75, 1: 53, 15: 49, 2: 16, 20: 12})
# 	t:400,all_property:2046240.0, unit_number:15.0, price:1113.0, penalty:135000.0, cash:1712340.0
# 	action_counter: Counter({19: 112, 5: 104, 15: 61, 1: 60, 2: 51, 20: 12})
# 	evaluation episode: 130, return:46994300.0, episode_length:419
# 	all_property: 2050020.0
#
#
# episode:140, return:-169795900.0, episode_length:419
# action_counter: Counter({0: 29, 17: 29, 2: 27, 20: 26, 12: 25, 8: 25, 9: 21, 5: 21, 10: 21, 16: 20, 1: 19, 6: 18, 13: 18, 11: 18, 3: 17, 19: 17, 15: 16, 7: 14, 14: 14, 18: 12, 4: 12})
# 	t:0,all_property:2123000.0, unit_number:50.0, price:1123.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2119000.0, unit_number:14.0, price:1095.0, penalty:105000.0, cash:1812400.0
# 	action_counter: Counter({3: 53, 17: 41, 18: 6})
# 	t:200,all_property:2131320.0, unit_number:14.0, price:1130.0, penalty:105000.0, cash:1814920.0
# 	action_counter: Counter({3: 103, 17: 91, 18: 6})
# 	t:300,all_property:2125300.0, unit_number:14.0, price:1115.0, penalty:105000.0, cash:1813100.0
# 	action_counter: Counter({3: 153, 17: 141, 18: 6})
# 	t:400,all_property:2119560.0, unit_number:14.0, price:1096.0, penalty:105000.0, cash:1812680.0
# 	action_counter: Counter({3: 203, 17: 191, 18: 6})
# 	evaluation episode: 140, return:44743680.0, episode_length:419
# 	all_property: 2120260.0
#
#
# episode:150, return:-79265160.0, episode_length:419
# action_counter: Counter({0: 33, 17: 31, 12: 29, 18: 26, 2: 25, 16: 23, 1: 23, 8: 20, 20: 19, 4: 19, 10: 19, 6: 18, 15: 18, 19: 16, 11: 16, 7: 16, 13: 16, 3: 15, 14: 15, 9: 13, 5: 9})
# statistics: [('average_q', 1.8113048), ('average_loss', 0.07508433742215857), ('cumulative_steps', 62850), ('n_updates', 62351), ('rlen', 62850)]
# 	t:0,all_property:2046000.0, unit_number:50.0, price:1046.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2056040.0, unit_number:19.0, price:1083.0, penalty:150000.0, cash:1644500.0
# 	action_counter: Counter({0: 49, 20: 48, 3: 3})
# 	t:200,all_property:2061780.0, unit_number:16.0, price:1119.0, penalty:150000.0, cash:1703700.0
# 	action_counter: Counter({20: 93, 0: 79, 3: 18, 4: 8, 5: 1, 15: 1})
# 	t:300,all_property:2049820.0, unit_number:13.0, price:1102.0, penalty:150000.0, cash:1763300.0
# 	action_counter: Counter({20: 116, 0: 87, 3: 33, 5: 24, 15: 24, 4: 16})
# 	t:400,all_property:2042760.0, unit_number:1.0, price:1071.0, penalty:75000.0, cash:2021340.0
# 	action_counter: Counter({20: 156, 0: 91, 3: 70, 4: 34, 5: 25, 15: 24})
# 	evaluation episode: 150, return:53512000.0, episode_length:419
# 	all_property: 2044300.0
#
#
# episode:160, return:-70456060.0, episode_length:419
# action_counter: Counter({0: 36, 18: 29, 2: 29, 20: 23, 4: 22, 17: 22, 13: 21, 3: 20, 10: 20, 19: 19, 15: 19, 6: 19, 16: 19, 5: 18, 8: 17, 9: 16, 7: 15, 11: 15, 14: 14, 12: 14, 1: 12})
# 	t:0,all_property:2037000.0, unit_number:50.0, price:1037.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2057660.0, unit_number:30.0, price:1081.0, penalty:150000.0, cash:1409060.0
# 	action_counter: Counter({0: 49, 20: 47, 1: 2, 19: 2})
# 	t:200,all_property:2067860.0, unit_number:30.0, price:1088.0, penalty:150000.0, cash:1415060.0
# 	action_counter: Counter({0: 99, 20: 97, 1: 2, 19: 2})
# 	t:300,all_property:2084260.0, unit_number:10.0, price:1131.0, penalty:150000.0, cash:1858060.0
# 	action_counter: Counter({0: 150, 20: 146, 1: 2, 19: 2})
# 	t:400,all_property:2065860.0, unit_number:30.0, price:1091.0, penalty:150000.0, cash:1411260.0
# 	action_counter: Counter({0: 199, 20: 197, 1: 2, 19: 2})
# 	evaluation episode: 160, return:63418660.0, episode_length:419
# 	all_property: 2080260.0
#
#
# episode:170, return:-129760020.0, episode_length:419
# action_counter: Counter({1: 28, 0: 26, 19: 25, 7: 23, 20: 23, 17: 22, 12: 22, 16: 21, 10: 21, 9: 19, 13: 19, 6: 19, 18: 18, 2: 18, 8: 18, 15: 17, 4: 17, 3: 16, 14: 16, 11: 16, 5: 15})
# 	t:0,all_property:2042000.0, unit_number:50.0, price:1042.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2054600.0, unit_number:12.0, price:1084.0, penalty:150000.0, cash:1794440.0
# 	action_counter: Counter({17: 47, 0: 43, 18: 9, 1: 1})
# 	t:200,all_property:2060200.0, unit_number:15.0, price:1120.0, penalty:105000.0, cash:1724200.0
# 	action_counter: Counter({17: 106, 0: 84, 18: 9, 1: 1})
# 	t:300,all_property:2068320.0, unit_number:6.0, price:1104.0, penalty:150000.0, cash:1935840.0
# 	action_counter: Counter({17: 164, 0: 121, 18: 9, 1: 6})
# 	t:400,all_property:2069300.0, unit_number:9.0, price:1100.0, penalty:150000.0, cash:1871300.0
# 	action_counter: Counter({17: 223, 0: 162, 18: 9, 1: 6})
# 	evaluation episode: 170, return:52893460.0, episode_length:419
# 	all_property: 2064140.0
#
#
# episode:180, return:-165982540.0, episode_length:419
# action_counter: Counter({0: 46, 12: 24, 10: 24, 19: 24, 20: 24, 9: 23, 5: 22, 16: 21, 17: 21, 11: 21, 3: 21, 18: 20, 13: 17, 14: 16, 7: 16, 2: 15, 4: 15, 6: 14, 15: 13, 1: 11, 8: 11})
# 	t:0,all_property:2047000.0, unit_number:50.0, price:1047.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2051620.0, unit_number:15.0, price:1081.0, penalty:150000.0, cash:1727320.0
# 	action_counter: Counter({0: 51, 20: 44, 17: 5})
# 	t:200,all_property:2069320.0, unit_number:15.0, price:1122.0, penalty:150000.0, cash:1732720.0
# 	action_counter: Counter({0: 101, 20: 94, 17: 5})
# 	t:300,all_property:2055920.0, unit_number:15.0, price:1100.0, penalty:150000.0, cash:1725920.0
# 	action_counter: Counter({0: 151, 20: 144, 17: 5})
# 	t:400,all_property:2058320.0, unit_number:15.0, price:1098.0, penalty:150000.0, cash:1728920.0
# 	action_counter: Counter({0: 201, 20: 194, 17: 5})
# 	evaluation episode: 180, return:63135320.0, episode_length:419
# 	all_property: 2055320.0
#
#
# episode:190, return:-162693380.0, episode_length:419
# action_counter: Counter({0: 30, 10: 28, 18: 26, 15: 25, 13: 24, 1: 24, 16: 22, 17: 20, 20: 20, 9: 19, 6: 19, 3: 18, 8: 18, 7: 18, 4: 17, 2: 17, 19: 16, 12: 15, 14: 15, 5: 15, 11: 13})
# 	t:0,all_property:2089000.0, unit_number:50.0, price:1089.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2089960.0, unit_number:8.0, price:1076.0, penalty:105000.0, cash:1917800.0
# 	action_counter: Counter({3: 52, 17: 46, 0: 1, 20: 1})
# 	t:200,all_property:2094080.0, unit_number:8.0, price:1107.0, penalty:105000.0, cash:1916960.0
# 	action_counter: Counter({3: 102, 17: 96, 0: 1, 20: 1})
# 	t:300,all_property:2091120.0, unit_number:8.0, price:1092.0, penalty:105000.0, cash:1916400.0
# 	action_counter: Counter({3: 152, 17: 146, 0: 1, 20: 1})
# 	t:400,all_property:2096880.0, unit_number:8.0, price:1121.0, penalty:105000.0, cash:1917520.0
# 	action_counter: Counter({3: 202, 17: 196, 0: 1, 20: 1})
# 	evaluation episode: 190, return:44845440.0, episode_length:419
# 	all_property: 2095840.0
#
#
# episode:200, return:-144875500.0, episode_length:419
# action_counter: Counter({20: 43, 0: 35, 19: 30, 2: 28, 1: 26, 5: 23, 17: 22, 15: 22, 6: 21, 3: 20, 4: 19, 11: 19, 16: 16, 7: 15, 14: 14, 12: 14, 18: 13, 13: 12, 10: 11, 8: 10, 9: 6})
# statistics: [('average_q', 1.7057124), ('average_loss', 0.07070910424925386), ('cumulative_steps', 83800), ('n_updates', 83301), ('rlen', 83800)]
# 	t:0,all_property:2037000.0, unit_number:50.0, price:1037.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2049880.0, unit_number:30.0, price:1078.0, penalty:135000.0, cash:1403080.0
# 	action_counter: Counter({20: 36, 2: 35, 0: 19, 19: 10})
# 	t:200,all_property:2041160.0, unit_number:30.0, price:1086.0, penalty:135000.0, cash:1389560.0
# 	action_counter: Counter({2: 89, 20: 54, 19: 38, 0: 19})
# 	t:300,all_property:2068280.0, unit_number:26.0, price:1132.0, penalty:120000.0, cash:1479640.0
# 	action_counter: Counter({2: 143, 19: 70, 20: 68, 0: 19})
# 	t:400,all_property:2038060.0, unit_number:21.0, price:1090.0, penalty:120000.0, cash:1580260.0
# 	action_counter: Counter({2: 197, 19: 103, 20: 81, 0: 19})
# 	evaluation episode: 200, return:55521360.0, episode_length:419
# 	all_property: 2056800.0
#
#
# episode:210, return:-112393260.0, episode_length:419
# action_counter: Counter({0: 32, 19: 28, 10: 26, 20: 25, 1: 25, 14: 21, 17: 21, 3: 20, 8: 20, 13: 19, 2: 19, 4: 19, 18: 18, 15: 18, 11: 18, 9: 18, 7: 17, 6: 16, 5: 16, 16: 13, 12: 10})
# 	t:0,all_property:2047000.0, unit_number:50.0, price:1047.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2057440.0, unit_number:11.0, price:1047.0, penalty:135000.0, cash:1827100.0
# 	action_counter: Counter({19: 47, 0: 36, 4: 17})
# 	t:200,all_property:2071800.0, unit_number:4.0, price:1124.0, penalty:150000.0, cash:1981880.0
# 	action_counter: Counter({19: 96, 0: 75, 4: 28, 18: 1})
# 	t:300,all_property:2061020.0, unit_number:2.0, price:1099.0, penalty:150000.0, cash:2017060.0
# 	action_counter: Counter({19: 144, 0: 116, 4: 36, 18: 4})
# 	t:400,all_property:2065720.0, unit_number:1.0, price:1130.0, penalty:150000.0, cash:2043120.0
# 	action_counter: Counter({19: 185, 0: 162, 4: 37, 18: 16})
# 	evaluation episode: 210, return:58122240.0, episode_length:419
# 	all_property: 2059120.0
#
#
# episode:220, return:-114391560.0, episode_length:419
# action_counter: Counter({0: 39, 20: 38, 14: 28, 3: 28, 18: 26, 10: 23, 1: 23, 5: 23, 6: 18, 15: 17, 13: 17, 17: 16, 12: 16, 19: 16, 11: 15, 7: 15, 2: 13, 4: 13, 8: 13, 9: 11, 16: 11})
# 	t:0,all_property:2036000.0, unit_number:50.0, price:1036.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2046620.0, unit_number:1.0, price:1079.0, penalty:105000.0, cash:2025040.0
# 	action_counter: Counter({0: 45, 19: 40, 17: 10, 3: 3, 6: 2})
# 	t:200,all_property:2034700.0, unit_number:1.0, price:1094.0, penalty:105000.0, cash:2012820.0
# 	action_counter: Counter({0: 75, 19: 57, 17: 47, 3: 19, 6: 2})
# 	t:300,all_property:2039640.0, unit_number:4.0, price:1130.0, penalty:150000.0, cash:1949240.0
# 	action_counter: Counter({0: 110, 17: 91, 19: 69, 3: 28, 6: 2})
# 	t:400,all_property:2031760.0, unit_number:19.0, price:1088.0, penalty:135000.0, cash:1618320.0
# 	action_counter: Counter({0: 151, 17: 128, 19: 89, 3: 30, 6: 2})
# 	evaluation episode: 220, return:54469640.0, episode_length:419
# 	all_property: 2041320.0
#
#
# episode:230, return:-64435960.0, episode_length:419
# action_counter: Counter({0: 39, 20: 34, 17: 25, 3: 22, 2: 22, 4: 22, 16: 22, 6: 21, 12: 21, 11: 20, 19: 20, 18: 18, 5: 18, 1: 16, 8: 15, 15: 15, 7: 15, 14: 14, 10: 14, 13: 14, 9: 12})
# 	t:0,all_property:2026000.0, unit_number:50.0, price:1026.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2026840.0, unit_number:8.0, price:1035.0, penalty:60000.0, cash:1861240.0
# 	action_counter: Counter({14: 45, 7: 21, 4: 20, 0: 8, 20: 5, 1: 1})
# 	t:200,all_property:2032520.0, unit_number:6.0, price:1082.0, penalty:105000.0, cash:1902680.0
# 	action_counter: Counter({14: 69, 3: 31, 18: 31, 7: 22, 4: 21, 0: 20, 20: 5, 1: 1})
# 	t:300,all_property:2019660.0, unit_number:2.0, price:1098.0, penalty:105000.0, cash:1975740.0
# 	action_counter: Counter({3: 81, 18: 78, 14: 69, 0: 23, 7: 22, 4: 21, 20: 5, 1: 1})
# 	t:400,all_property:2022760.0, unit_number:4.0, price:1112.0, penalty:105000.0, cash:1933800.0
# 	action_counter: Counter({3: 133, 18: 125, 14: 69, 0: 24, 7: 22, 4: 21, 20: 5, 1: 1})
# 	evaluation episode: 230, return:43487880.0, episode_length:419
# 	all_property: 2023600.0
#
#
# episode:240, return:-8974600.0, episode_length:419
# action_counter: Counter({0: 37, 20: 34, 1: 32, 6: 25, 16: 25, 7: 24, 18: 21, 17: 21, 10: 20, 4: 20, 14: 18, 12: 18, 15: 17, 19: 17, 5: 15, 9: 14, 2: 14, 8: 13, 11: 12, 3: 11, 13: 11})
# 	t:0,all_property:2020000.0, unit_number:50.0, price:1020.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2031000.0, unit_number:5.0, price:1035.0, penalty:60000.0, cash:1927500.0
# 	action_counter: Counter({20: 28, 6: 19, 2: 18, 4: 14, 5: 8, 17: 7, 10: 3, 0: 3})
# 	t:200,all_property:2041560.0, unit_number:2.0, price:1081.0, penalty:60000.0, cash:1998320.0
# 	action_counter: Counter({20: 65, 2: 39, 6: 39, 4: 35, 5: 8, 17: 7, 10: 3, 0: 3, 11: 1})
# 	t:300,all_property:2039720.0, unit_number:14.0, price:1087.0, penalty:150000.0, cash:1735360.0
# 	action_counter: Counter({20: 84, 2: 81, 6: 45, 4: 42, 19: 21, 17: 12, 5: 8, 10: 3, 0: 3, 11: 1})
# 	t:400,all_property:2049700.0, unit_number:13.0, price:1131.0, penalty:135000.0, cash:1755640.0
# 	action_counter: Counter({2: 124, 20: 104, 6: 57, 4: 44, 19: 42, 17: 14, 5: 8, 10: 3, 0: 3, 11: 1})
# 	evaluation episode: 240, return:49295860.0, episode_length:419
# 	all_property: 2048420.0
#
#
# episode:250, return:-183272320.0, episode_length:419
# action_counter: Counter({0: 49, 20: 33, 1: 27, 16: 26, 19: 25, 17: 25, 3: 22, 18: 19, 10: 17, 5: 17, 13: 17, 11: 17, 15: 16, 14: 16, 2: 15, 7: 15, 8: 14, 9: 14, 6: 12, 4: 12, 12: 11})
# statistics: [('average_q', 1.7095915), ('average_loss', 0.04970758317038417), ('cumulative_steps', 104750), ('n_updates', 104251), ('rlen', 104750)]
# 	t:0,all_property:2114000.0, unit_number:50.0, price:1114.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2114300.0, unit_number:9.0, price:1091.0, penalty:150000.0, cash:1917920.0
# 	action_counter: Counter({20: 41, 0: 36, 3: 17, 19: 4, 6: 2})
# 	t:200,all_property:2124780.0, unit_number:9.0, price:1127.0, penalty:150000.0, cash:1921920.0
# 	action_counter: Counter({20: 91, 0: 86, 3: 17, 19: 4, 6: 2})
# 	t:300,all_property:2125740.0, unit_number:9.0, price:1127.0, penalty:150000.0, cash:1922880.0
# 	action_counter: Counter({20: 139, 0: 131, 3: 22, 19: 5, 6: 3})
# 	t:400,all_property:2125180.0, unit_number:9.0, price:1115.0, penalty:150000.0, cash:1924480.0
# 	action_counter: Counter({20: 189, 0: 181, 3: 22, 19: 5, 6: 3})
# 	evaluation episode: 250, return:62216080.0, episode_length:419
# 	all_property: 2119840.0
#
#
# episode:260, return:-52301160.0, episode_length:419
# action_counter: Counter({0: 43, 20: 42, 2: 25, 17: 25, 18: 25, 4: 23, 5: 22, 9: 20, 13: 19, 12: 19, 6: 18, 10: 16, 14: 16, 7: 16, 19: 15, 1: 15, 15: 14, 3: 13, 11: 11, 16: 11, 8: 11})
# 	t:0,all_property:2018000.0, unit_number:50.0, price:1018.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2019060.0, unit_number:11.0, price:1039.0, penalty:150000.0, cash:1790480.0
# 	action_counter: Counter({0: 49, 20: 46, 1: 3, 19: 2})
# 	t:200,all_property:2027260.0, unit_number:15.0, price:1102.0, penalty:135000.0, cash:1696660.0
# 	action_counter: Counter({0: 81, 19: 52, 20: 47, 2: 17, 1: 3})
# 	t:300,all_property:2020540.0, unit_number:13.0, price:1083.0, penalty:135000.0, cash:1738960.0
# 	action_counter: Counter({0: 107, 19: 102, 20: 47, 2: 41, 1: 3})
# 	t:400,all_property:2031460.0, unit_number:17.0, price:1129.0, penalty:135000.0, cash:1647600.0
# 	action_counter: Counter({19: 152, 0: 130, 2: 68, 20: 47, 1: 3})
# 	evaluation episode: 260, return:59050220.0, episode_length:419
# 	all_property: 2030860.0
#
#
# episode:270, return:-49864240.0, episode_length:419
# action_counter: Counter({1: 37, 20: 31, 0: 29, 16: 25, 19: 25, 2: 24, 11: 23, 9: 22, 18: 21, 7: 19, 12: 17, 17: 17, 14: 17, 3: 15, 5: 15, 10: 15, 15: 14, 8: 14, 6: 13, 4: 13, 13: 13})
# 	t:0,all_property:2090000.0, unit_number:50.0, price:1090.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2085220.0, unit_number:19.0, price:1062.0, penalty:135000.0, cash:1681660.0
# 	action_counter: Counter({19: 51, 0: 49})
# 	t:200,all_property:2101940.0, unit_number:26.0, price:1108.0, penalty:135000.0, cash:1525780.0
# 	action_counter: Counter({19: 104, 0: 96})
# 	t:300,all_property:2096240.0, unit_number:14.0, price:1095.0, penalty:150000.0, cash:1789640.0
# 	action_counter: Counter({19: 156, 0: 144})
# 	t:400,all_property:2105460.0, unit_number:21.0, price:1123.0, penalty:135000.0, cash:1633800.0
# 	action_counter: Counter({19: 209, 0: 191})
# 	evaluation episode: 270, return:60197720.0, episode_length:419
# 	all_property: 2102700.0
#
#
# episode:280, return:-186344940.0, episode_length:419
# action_counter: Counter({20: 35, 1: 31, 2: 25, 12: 25, 7: 23, 6: 23, 4: 22, 16: 22, 0: 21, 10: 21, 15: 20, 13: 19, 5: 18, 9: 18, 18: 17, 19: 15, 17: 14, 8: 14, 3: 14, 14: 12, 11: 10})
# 	t:0,all_property:2119000.0, unit_number:50.0, price:1119.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2105820.0, unit_number:11.0, price:1098.0, penalty:150000.0, cash:1864260.0
# 	action_counter: Counter({20: 42, 1: 31, 2: 15, 5: 12})
# 	t:200,all_property:2108740.0, unit_number:6.0, price:1129.0, penalty:135000.0, cash:1973260.0
# 	action_counter: Counter({20: 87, 1: 73, 5: 21, 2: 19})
# 	t:300,all_property:2095140.0, unit_number:13.0, price:1122.0, penalty:150000.0, cash:1803420.0
# 	action_counter: Counter({20: 132, 1: 109, 5: 32, 2: 27})
# 	t:400,all_property:2094420.0, unit_number:13.0, price:1098.0, penalty:150000.0, cash:1808940.0
# 	action_counter: Counter({20: 177, 1: 149, 5: 42, 2: 32})
# 	evaluation episode: 280, return:57196480.0, episode_length:419
# 	all_property: 2094480.0
#
#
# episode:290, return:-71409100.0, episode_length:419
# action_counter: Counter({19: 34, 0: 29, 2: 26, 10: 26, 9: 24, 6: 23, 17: 23, 5: 21, 12: 21, 15: 20, 20: 20, 18: 19, 1: 19, 3: 18, 4: 15, 13: 15, 11: 15, 8: 15, 7: 14, 14: 11, 16: 11})
# 	t:0,all_property:2087000.0, unit_number:50.0, price:1087.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2088440.0, unit_number:13.0, price:1105.0, penalty:135000.0, cash:1801140.0
# 	action_counter: Counter({19: 39, 0: 34, 2: 16, 20: 9, 5: 2})
# 	t:200,all_property:2088820.0, unit_number:12.0, price:1107.0, penalty:135000.0, cash:1823140.0
# 	action_counter: Counter({19: 89, 0: 67, 2: 28, 20: 9, 5: 7})
# 	t:300,all_property:2089520.0, unit_number:12.0, price:1101.0, penalty:135000.0, cash:1825280.0
# 	action_counter: Counter({19: 136, 0: 95, 2: 49, 20: 12, 5: 8})
# 	t:400,all_property:2094280.0, unit_number:12.0, price:1124.0, penalty:135000.0, cash:1824520.0
# 	action_counter: Counter({19: 182, 0: 122, 2: 72, 20: 16, 5: 8})
# 	evaluation episode: 290, return:58101820.0, episode_length:419
# 	all_property: 2093900.0
#
#
# episode:300, return:-38530440.0, episode_length:419
# action_counter: Counter({0: 46, 20: 36, 2: 27, 19: 26, 16: 23, 6: 20, 11: 20, 5: 19, 8: 19, 18: 19, 1: 18, 15: 18, 13: 18, 17: 18, 4: 16, 9: 15, 12: 15, 14: 13, 3: 12, 7: 11, 10: 10})
# statistics: [('average_q', 1.7525005), ('average_loss', 0.059032234225887804), ('cumulative_steps', 125700), ('n_updates', 125201), ('rlen', 125700)]
# 	t:0,all_property:2106000.0, unit_number:50.0, price:1106.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2090200.0, unit_number:18.0, price:1081.0, penalty:150000.0, cash:1701040.0
# 	action_counter: Counter({2: 54, 20: 43, 0: 3})
# 	t:200,all_property:2097480.0, unit_number:4.0, price:1127.0, penalty:120000.0, cash:2007320.0
# 	action_counter: Counter({2: 107, 20: 85, 8: 5, 0: 3})
# 	t:300,all_property:2086040.0, unit_number:8.0, price:1131.0, penalty:120000.0, cash:1905080.0
# 	action_counter: Counter({2: 161, 20: 129, 8: 7, 0: 3})
# 	t:400,all_property:2081800.0, unit_number:6.0, price:1110.0, penalty:120000.0, cash:1948600.0
# 	action_counter: Counter({2: 198, 20: 164, 8: 35, 0: 3})
# 	evaluation episode: 300, return:53137560.0, episode_length:419
# 	all_property: 2078600.0
#
#
# episode:310, return:-121574280.0, episode_length:419
# action_counter: Counter({0: 38, 2: 30, 1: 29, 20: 29, 16: 29, 17: 28, 18: 25, 6: 21, 4: 21, 19: 21, 9: 19, 5: 18, 11: 16, 15: 16, 13: 13, 12: 13, 10: 12, 8: 12, 14: 12, 7: 10, 3: 7})
# 	t:0,all_property:2048000.0, unit_number:50.0, price:1048.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2058600.0, unit_number:11.0, price:1116.0, penalty:120000.0, cash:1813080.0
# 	action_counter: Counter({18: 43, 2: 41, 0: 6, 5: 5, 16: 5})
# 	t:200,all_property:2051440.0, unit_number:11.0, price:1090.0, penalty:120000.0, cash:1811640.0
# 	action_counter: Counter({18: 93, 2: 91, 0: 6, 5: 5, 16: 5})
# 	t:300,all_property:2057680.0, unit_number:11.0, price:1130.0, penalty:120000.0, cash:1809080.0
# 	action_counter: Counter({18: 143, 2: 141, 0: 6, 5: 5, 16: 5})
# 	t:400,all_property:2056280.0, unit_number:11.0, price:1128.0, penalty:120000.0, cash:1808120.0
# 	action_counter: Counter({18: 193, 2: 191, 0: 6, 5: 5, 16: 5})
# 	evaluation episode: 310, return:51073440.0, episode_length:419
# 	all_property: 2055580.0
#
#
# episode:320, return:-113643160.0, episode_length:419
# action_counter: Counter({1: 36, 20: 34, 10: 28, 0: 27, 19: 27, 5: 25, 18: 24, 15: 21, 4: 20, 7: 19, 2: 18, 8: 18, 12: 18, 14: 17, 17: 17, 3: 15, 11: 14, 13: 12, 6: 11, 9: 10, 16: 8})
# 	t:0,all_property:2109000.0, unit_number:50.0, price:1109.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2102620.0, unit_number:7.0, price:1088.0, penalty:135000.0, cash:1950300.0
# 	action_counter: Counter({19: 48, 0: 39, 5: 8, 1: 5})
# 	t:200,all_property:2104660.0, unit_number:11.0, price:1120.0, penalty:150000.0, cash:1858260.0
# 	action_counter: Counter({19: 98, 0: 63, 1: 24, 5: 15})
# 	t:300,all_property:2097120.0, unit_number:7.0, price:1099.0, penalty:135000.0, cash:1943260.0
# 	action_counter: Counter({19: 148, 0: 87, 1: 45, 5: 20})
# 	t:400,all_property:2101970.0, unit_number:12.0, price:1124.0, penalty:150000.0, cash:1832210.0
# 	action_counter: Counter({19: 198, 0: 94, 1: 85, 5: 23})
# 	evaluation episode: 320, return:56876530.0, episode_length:419
# 	all_property: 2104090.0
#
#
# episode:330, return:-158596120.0, episode_length:419
# action_counter: Counter({0: 44, 18: 30, 20: 22, 4: 22, 12: 22, 13: 21, 17: 21, 7: 21, 6: 21, 19: 21, 14: 20, 3: 18, 16: 18, 5: 17, 1: 17, 15: 17, 11: 16, 9: 16, 2: 13, 10: 12, 8: 10})
# 	t:0,all_property:2102000.0, unit_number:50.0, price:1102.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2096640.0, unit_number:6.0, price:1083.0, penalty:150000.0, cash:1966680.0
# 	action_counter: Counter({0: 52, 20: 47, 16: 1})
# 	t:200,all_property:2103960.0, unit_number:6.0, price:1114.0, penalty:150000.0, cash:1970280.0
# 	action_counter: Counter({0: 102, 20: 97, 16: 1})
# 	t:300,all_property:2100000.0, unit_number:6.0, price:1101.0, penalty:150000.0, cash:1967880.0
# 	action_counter: Counter({0: 152, 20: 147, 16: 1})
# 	t:400,all_property:2099540.0, unit_number:6.0, price:1103.0, penalty:150000.0, cash:1967180.0
# 	action_counter: Counter({0: 202, 20: 197, 16: 1})
# 	evaluation episode: 330, return:63534780.0, episode_length:419
# 	all_property: 2102540.0
#
#
# episode:340, return:-90332580.0, episode_length:419
# action_counter: Counter({0: 41, 20: 31, 12: 27, 16: 25, 2: 25, 17: 22, 11: 21, 4: 21, 19: 20, 6: 20, 18: 20, 5: 17, 8: 17, 14: 16, 1: 16, 7: 16, 3: 15, 10: 14, 9: 12, 15: 12, 13: 11})
# 	t:0,all_property:2078000.0, unit_number:50.0, price:1078.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2091300.0, unit_number:13.0, price:1086.0, penalty:150000.0, cash:1808940.0
# 	action_counter: Counter({5: 65, 20: 30, 0: 3, 19: 2})
# 	t:200,all_property:2099760.0, unit_number:8.0, price:1132.0, penalty:75000.0, cash:1918640.0
# 	action_counter: Counter({5: 132, 20: 63, 0: 3, 19: 2})
# 	t:300,all_property:2099040.0, unit_number:3.0, price:1090.0, penalty:75000.0, cash:2033640.0
# 	action_counter: Counter({5: 199, 20: 96, 0: 3, 19: 2})
# 	t:400,all_property:2100100.0, unit_number:13.0, price:1111.0, penalty:150000.0, cash:1811240.0
# 	action_counter: Counter({5: 265, 20: 130, 0: 3, 19: 2})
# 	evaluation episode: 340, return:42892840.0, episode_length:419
# 	all_property: 2101400.0
#
#
# episode:350, return:-47344620.0, episode_length:419
# action_counter: Counter({0: 38, 12: 27, 2: 25, 10: 24, 16: 24, 13: 24, 19: 22, 20: 22, 17: 21, 6: 20, 9: 20, 14: 20, 3: 19, 15: 18, 1: 17, 7: 15, 18: 15, 8: 14, 5: 12, 11: 11, 4: 11})
# statistics: [('average_q', 1.9373648), ('average_loss', 0.05536497039953247), ('cumulative_steps', 146650), ('n_updates', 146151), ('rlen', 146650)]
# 	t:0,all_property:2103000.0, unit_number:50.0, price:1103.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2098600.0, unit_number:10.0, price:1109.0, penalty:150000.0, cash:1876800.0
# 	action_counter: Counter({0: 52, 20: 48})
# 	t:200,all_property:2094400.0, unit_number:10.0, price:1090.0, penalty:150000.0, cash:1876400.0
# 	action_counter: Counter({0: 102, 20: 98})
# 	t:300,all_property:2101400.0, unit_number:10.0, price:1120.0, penalty:150000.0, cash:1877400.0
# 	action_counter: Counter({0: 152, 20: 148})
# 	t:400,all_property:2096800.0, unit_number:10.0, price:1098.0, penalty:150000.0, cash:1877200.0
# 	action_counter: Counter({0: 202, 20: 198})
# 	evaluation episode: 350, return:63509800.0, episode_length:419
# 	all_property: 2094600.0
#
#
# episode:360, return:-99254305.0, episode_length:419
# action_counter: Counter({0: 43, 20: 31, 1: 25, 12: 24, 5: 23, 16: 22, 18: 22, 11: 21, 17: 20, 7: 20, 3: 19, 15: 18, 10: 18, 9: 17, 6: 17, 19: 17, 14: 16, 4: 16, 13: 15, 8: 8, 2: 7})
# 	t:0,all_property:2018000.0, unit_number:50.0, price:1018.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2027800.0, unit_number:12.0, price:1038.0, penalty:135000.0, cash:1778680.0
# 	action_counter: Counter({4: 37, 20: 19, 18: 19, 7: 12, 1: 8, 0: 5})
# 	t:200,all_property:2034180.0, unit_number:1.0, price:1078.0, penalty:150000.0, cash:2012620.0
# 	action_counter: Counter({20: 60, 4: 52, 0: 38, 18: 19, 7: 15, 1: 11, 17: 5})
# 	t:300,all_property:2030660.0, unit_number:2.0, price:1097.0, penalty:150000.0, cash:1986780.0
# 	action_counter: Counter({20: 81, 4: 74, 0: 66, 17: 34, 18: 19, 7: 15, 1: 11})
# 	t:400,all_property:2033900.0, unit_number:3.0, price:1130.0, penalty:90000.0, cash:1966100.0
# 	action_counter: Counter({4: 99, 20: 98, 0: 91, 17: 67, 18: 19, 7: 15, 1: 11})
# 	evaluation episode: 360, return:51501160.0, episode_length:419
# 	all_property: 2034540.0
#
#
# episode:370, return:-98935680.0, episode_length:419
# action_counter: Counter({0: 33, 1: 33, 20: 29, 18: 28, 15: 26, 4: 25, 19: 23, 7: 20, 17: 20, 13: 19, 5: 19, 10: 18, 6: 17, 9: 16, 11: 15, 3: 15, 14: 14, 16: 13, 2: 13, 12: 12, 8: 11})
# 	t:0,all_property:2080000.0, unit_number:50.0, price:1080.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2075820.0, unit_number:14.0, price:1094.0, penalty:135000.0, cash:1769500.0
# 	action_counter: Counter({1: 52, 19: 48})
# 	t:200,all_property:2081060.0, unit_number:14.0, price:1123.0, penalty:135000.0, cash:1766620.0
# 	action_counter: Counter({1: 102, 19: 98})
# 	t:300,all_property:2075700.0, unit_number:14.0, price:1091.0, penalty:135000.0, cash:1770220.0
# 	action_counter: Counter({1: 152, 19: 148})
# 	t:400,all_property:2081980.0, unit_number:14.0, price:1116.0, penalty:135000.0, cash:1769500.0
# 	action_counter: Counter({1: 202, 19: 198})
# 	evaluation episode: 370, return:57535380.0, episode_length:419
# 	all_property: 2081280.0
#
#
# episode:380, return:-25946220.0, episode_length:419
# action_counter: Counter({1: 40, 19: 32, 20: 31, 18: 25, 5: 25, 0: 23, 2: 21, 7: 20, 10: 19, 3: 18, 17: 17, 11: 17, 8: 17, 6: 16, 15: 16, 16: 14, 12: 14, 13: 14, 9: 14, 14: 13, 4: 13})
# 	t:0,all_property:2080000.0, unit_number:50.0, price:1080.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2080200.0, unit_number:11.0, price:1095.0, penalty:150000.0, cash:1839300.0
# 	action_counter: Counter({5: 64, 20: 32, 0: 3, 1: 1})
# 	t:200,all_property:2086800.0, unit_number:6.0, price:1125.0, penalty:75000.0, cash:1951800.0
# 	action_counter: Counter({5: 131, 20: 65, 0: 3, 1: 1})
# 	t:300,all_property:2077100.0, unit_number:1.0, price:1090.0, penalty:75000.0, cash:2055300.0
# 	action_counter: Counter({5: 198, 20: 98, 0: 3, 1: 1})
# 	t:400,all_property:2084580.0, unit_number:11.0, price:1119.0, penalty:150000.0, cash:1838400.0
# 	action_counter: Counter({5: 264, 20: 132, 0: 3, 1: 1})
# 	evaluation episode: 380, return:43010700.0, episode_length:419
# 	all_property: 2083780.0
#
#
# episode:390, return:-90399560.0, episode_length:419
# action_counter: Counter({20: 38, 2: 31, 0: 29, 19: 28, 7: 22, 16: 22, 5: 22, 1: 20, 18: 20, 3: 20, 4: 19, 8: 19, 10: 18, 9: 17, 17: 17, 6: 15, 12: 14, 15: 13, 14: 12, 11: 12, 13: 11})
# 	t:0,all_property:2107000.0, unit_number:50.0, price:1107.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2105100.0, unit_number:16.0, price:1105.0, penalty:135000.0, cash:1751500.0
# 	action_counter: Counter({20: 31, 1: 23, 3: 19, 19: 14, 0: 13})
# 	t:200,all_property:2106540.0, unit_number:4.0, price:1118.0, penalty:135000.0, cash:2017100.0
# 	action_counter: Counter({20: 56, 1: 54, 19: 37, 0: 27, 3: 25, 2: 1})
# 	t:300,all_property:2101920.0, unit_number:7.0, price:1099.0, penalty:135000.0, cash:1948060.0
# 	action_counter: Counter({1: 93, 20: 72, 19: 70, 0: 33, 3: 30, 2: 2})
# 	t:400,all_property:2104895.0, unit_number:7.0, price:1117.0, penalty:135000.0, cash:1948515.0
# 	action_counter: Counter({19: 115, 1: 109, 20: 78, 0: 63, 3: 33, 2: 2})
# 	evaluation episode: 390, return:58406915.0, episode_length:419
# 	all_property: 2109795.0
#
#
# episode:400, return:-43983000.0, episode_length:419
# action_counter: Counter({0: 34, 19: 33, 20: 30, 17: 29, 2: 28, 1: 26, 5: 25, 6: 23, 18: 22, 3: 20, 14: 19, 15: 18, 4: 17, 9: 13, 11: 13, 10: 12, 16: 12, 7: 12, 13: 12, 12: 11, 8: 10})
# statistics: [('average_q', 1.7621511), ('average_loss', 0.08084637289168313), ('cumulative_steps', 167600), ('n_updates', 167101), ('rlen', 167600)]
# 	t:0,all_property:2021000.0, unit_number:50.0, price:1021.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2021760.0, unit_number:9.0, price:1040.0, penalty:60000.0, cash:1834560.0
# 	action_counter: Counter({10: 81, 17: 6, 0: 4, 5: 3, 4: 3, 7: 2, 6: 1})
# 	t:200,all_property:2026680.0, unit_number:4.0, price:1080.0, penalty:0.0, cash:1940280.0
# 	action_counter: Counter({10: 161, 17: 14, 5: 11, 0: 5, 7: 3, 4: 3, 6: 3})
# 	t:300,all_property:2029600.0, unit_number:4.0, price:1099.0, penalty:0.0, cash:1941680.0
# 	action_counter: Counter({10: 205, 0: 33, 20: 28, 17: 14, 5: 11, 7: 3, 4: 3, 6: 3})
# 	t:400,all_property:2034520.0, unit_number:14.0, price:1128.0, penalty:150000.0, cash:1718680.0
# 	action_counter: Counter({10: 294, 0: 38, 20: 34, 17: 14, 5: 11, 7: 3, 4: 3, 6: 3})
# 	evaluation episode: 400, return:17472880.0, episode_length:419
# 	all_property: 2033120.0
#
#
# episode:410, return:-83520140.0, episode_length:419
# action_counter: Counter({2: 39, 4: 32, 18: 31, 20: 31, 19: 25, 0: 24, 17: 24, 1: 24, 11: 23, 3: 20, 16: 17, 15: 16, 9: 16, 12: 15, 8: 14, 7: 13, 5: 12, 6: 12, 10: 11, 13: 11, 14: 9})
# 	t:0,all_property:2044000.0, unit_number:50.0, price:1044.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2052240.0, unit_number:10.0, price:1082.0, penalty:120000.0, cash:1835840.0
# 	action_counter: Counter({4: 52, 19: 36, 2: 6, 18: 3, 1: 2, 0: 1})
# 	t:200,all_property:2050400.0, unit_number:2.0, price:1123.0, penalty:105000.0, cash:2005480.0
# 	action_counter: Counter({4: 52, 2: 43, 18: 37, 19: 36, 5: 16, 20: 11, 1: 2, 3: 2, 0: 1})
# 	t:300,all_property:2050840.0, unit_number:13.0, price:1102.0, penalty:150000.0, cash:1764320.0
# 	action_counter: Counter({2: 81, 18: 75, 4: 52, 19: 36, 5: 30, 20: 20, 1: 3, 3: 2, 0: 1})
# 	t:400,all_property:2045680.0, unit_number:10.0, price:1082.0, penalty:120000.0, cash:1829280.0
# 	action_counter: Counter({2: 101, 18: 96, 5: 69, 4: 53, 20: 39, 19: 36, 1: 3, 3: 2, 0: 1})
# 	evaluation episode: 410, return:42844000.0, episode_length:419
# 	all_property: 2047680.0
#
#
# episode:420, return:-57076940.0, episode_length:419
# action_counter: Counter({0: 40, 19: 36, 20: 33, 1: 30, 12: 23, 14: 21, 4: 20, 6: 19, 7: 19, 2: 19, 18: 18, 13: 18, 16: 18, 15: 17, 11: 17, 5: 15, 10: 14, 8: 13, 3: 12, 9: 12, 17: 5})
# 	t:0,all_property:2020000.0, unit_number:50.0, price:1020.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2025040.0, unit_number:15.0, price:1051.0, penalty:120000.0, cash:1709740.0
# 	action_counter: Counter({10: 85, 5: 8, 18: 4, 1: 3})
# 	t:200,all_property:2032100.0, unit_number:14.0, price:1112.0, penalty:135000.0, cash:1720740.0
# 	action_counter: Counter({10: 99, 1: 40, 19: 33, 5: 12, 18: 10, 20: 3, 0: 2, 7: 1})
# 	t:300,all_property:2024500.0, unit_number:14.0, price:1090.0, penalty:135000.0, cash:1719300.0
# 	action_counter: Counter({10: 99, 1: 90, 19: 83, 5: 12, 18: 10, 20: 3, 0: 2, 7: 1})
# 	t:400,all_property:2031960.0, unit_number:14.0, price:1125.0, penalty:135000.0, cash:1716960.0
# 	action_counter: Counter({1: 140, 19: 133, 10: 99, 5: 12, 18: 10, 20: 3, 0: 2, 7: 1})
# 	evaluation episode: 420, return:43234820.0, episode_length:419
# 	all_property: 2032720.0
#
#
# episode:430, return:-19981355.0, episode_length:419
# action_counter: Counter({0: 57, 20: 43, 2: 25, 19: 24, 17: 23, 15: 21, 8: 20, 18: 20, 5: 19, 1: 19, 3: 19, 14: 18, 16: 17, 13: 15, 9: 15, 4: 13, 11: 12, 6: 10, 7: 10, 12: 10, 10: 9})
# 	t:0,all_property:2080000.0, unit_number:50.0, price:1080.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2085940.0, unit_number:10.0, price:1087.0, penalty:105000.0, cash:1868540.0
# 	action_counter: Counter({3: 47, 17: 47, 0: 5, 20: 1})
# 	t:200,all_property:2093420.0, unit_number:8.0, price:1136.0, penalty:105000.0, cash:1911660.0
# 	action_counter: Counter({17: 91, 3: 86, 0: 15, 19: 7, 20: 1})
# 	t:300,all_property:2089860.0, unit_number:8.0, price:1091.0, penalty:105000.0, cash:1915300.0
# 	action_counter: Counter({17: 141, 3: 136, 0: 15, 19: 7, 20: 1})
# 	t:400,all_property:2090420.0, unit_number:8.0, price:1112.0, penalty:105000.0, cash:1912500.0
# 	action_counter: Counter({17: 191, 3: 186, 0: 15, 19: 7, 20: 1})
# 	evaluation episode: 430, return:45993460.0, episode_length:419
# 	all_property: 2090720.0
#
#
# episode:440, return:-110939860.0, episode_length:419
# action_counter: Counter({0: 60, 20: 51, 3: 25, 19: 23, 17: 22, 1: 20, 2: 20, 10: 20, 15: 19, 13: 18, 12: 18, 18: 16, 6: 15, 16: 14, 8: 13, 5: 13, 14: 12, 4: 12, 11: 12, 7: 11, 9: 5})
# 	t:0,all_property:2101000.0, unit_number:50.0, price:1101.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2113880.0, unit_number:14.0, price:1081.0, penalty:150000.0, cash:1811200.0
# 	action_counter: Counter({0: 49, 20: 47, 7: 3, 3: 1})
# 	t:200,all_property:2121860.0, unit_number:4.0, price:1129.0, penalty:150000.0, cash:2031540.0
# 	action_counter: Counter({0: 93, 20: 93, 7: 13, 3: 1})
# 	t:300,all_property:2121360.0, unit_number:14.0, price:1131.0, penalty:150000.0, cash:1804680.0
# 	action_counter: Counter({20: 140, 0: 136, 7: 23, 3: 1})
# 	t:400,all_property:2121600.0, unit_number:14.0, price:1109.0, penalty:150000.0, cash:1811080.0
# 	action_counter: Counter({20: 190, 0: 186, 7: 23, 3: 1})
# 	evaluation episode: 440, return:61420080.0, episode_length:419
# 	all_property: 2117680.0
#
#
# episode:450, return:-66237300.0, episode_length:419
# action_counter: Counter({1: 52, 20: 42, 19: 29, 0: 28, 18: 23, 8: 20, 2: 20, 9: 20, 10: 19, 15: 19, 4: 16, 17: 16, 6: 15, 16: 15, 5: 15, 14: 13, 12: 12, 3: 12, 13: 12, 7: 11, 11: 10})
# statistics: [('average_q', 1.7330428), ('average_loss', 0.05793626573868096), ('cumulative_steps', 188550), ('n_updates', 188051), ('rlen', 188550)]
# 	t:0,all_property:2096000.0, unit_number:50.0, price:1096.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2099920.0, unit_number:13.0, price:1128.0, penalty:150000.0, cash:1806640.0
# 	action_counter: Counter({20: 45, 1: 41, 2: 11, 0: 3})
# 	t:200,all_property:2091660.0, unit_number:5.0, price:1087.0, penalty:135000.0, cash:1982960.0
# 	action_counter: Counter({20: 90, 1: 85, 2: 16, 7: 4, 0: 3, 5: 2})
# 	t:300,all_property:2093740.0, unit_number:12.0, price:1115.0, penalty:150000.0, cash:1826140.0
# ...
#
#
# episode:2290, return:43378740.0, episode_length:419
# action_counter: Counter({20: 105, 0: 96, 2: 47, 19: 36, 1: 33, 18: 23, 17: 19, 5: 10, 3: 10, 15: 7, 6: 6, 11: 5, 10: 5, 7: 5, 13: 3, 16: 3, 4: 2, 12: 2, 9: 1, 14: 1})
# 	t:0,all_property:2017000.0, unit_number:50.0, price:1017.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2017660.0, unit_number:10.0, price:1043.0, penalty:150000.0, cash:1809060.0
# 	action_counter: Counter({0: 51, 20: 45, 19: 3, 3: 1})
# 	t:200,all_property:2018060.0, unit_number:10.0, price:1100.0, penalty:150000.0, cash:1798060.0
# 	action_counter: Counter({0: 101, 20: 95, 19: 3, 3: 1})
# 	t:300,all_property:2013660.0, unit_number:10.0, price:1082.0, penalty:150000.0, cash:1797260.0
# 	action_counter: Counter({0: 151, 20: 145, 19: 3, 3: 1})
# 	t:400,all_property:2019060.0, unit_number:10.0, price:1128.0, penalty:150000.0, cash:1793460.0
# 	action_counter: Counter({0: 201, 20: 195, 19: 3, 3: 1})
# 	evaluation episode: 2290, return:45778460.0, episode_length:419
# 	all_property: 2018460.0
#
#
# episode:2300, return:22553020.0, episode_length:419
# action_counter: Counter({0: 139, 20: 128, 3: 28, 18: 24, 19: 21, 2: 15, 17: 15, 6: 13, 7: 6, 1: 5, 15: 4, 9: 4, 14: 3, 5: 3, 12: 3, 8: 3, 4: 2, 11: 2, 16: 1})
# statistics: [('average_q', 2.2551656), ('average_loss', 0.01904648249328602), ('cumulative_steps', 963700), ('n_updates', 963201), ('rlen', 963700)]
# 	t:0,all_property:2098000.0, unit_number:50.0, price:1098.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2104200.0, unit_number:10.0, price:1131.0, penalty:150000.0, cash:1878000.0
# 	action_counter: Counter({0: 52, 20: 48})
# 	t:200,all_property:2103800.0, unit_number:10.0, price:1119.0, penalty:150000.0, cash:1880000.0
# 	action_counter: Counter({0: 102, 20: 98})
# 	t:300,all_property:2102000.0, unit_number:10.0, price:1103.0, penalty:150000.0, cash:1881400.0
# 	action_counter: Counter({0: 152, 20: 148})
# 	t:400,all_property:2102200.0, unit_number:10.0, price:1090.0, penalty:150000.0, cash:1884200.0
# 	action_counter: Counter({0: 202, 20: 198})
# 	evaluation episode: 2300, return:63953500.0, episode_length:419
# 	all_property: 2103500.0
#
#
# episode:2310, return:18170660.0, episode_length:419
# action_counter: Counter({0: 108, 20: 105, 2: 69, 19: 35, 18: 27, 17: 15, 16: 11, 7: 10, 3: 9, 1: 6, 13: 4, 6: 3, 9: 3, 4: 3, 8: 3, 12: 2, 5: 2, 14: 2, 15: 1, 10: 1})
# 	t:0,all_property:2087000.0, unit_number:50.0, price:1087.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2086720.0, unit_number:10.0, price:1105.0, penalty:135000.0, cash:1865720.0
# 	action_counter: Counter({19: 48, 0: 28, 2: 24})
# 	t:200,all_property:2085560.0, unit_number:10.0, price:1107.0, penalty:135000.0, cash:1864160.0
# 	action_counter: Counter({19: 98, 0: 53, 2: 49})
# 	t:300,all_property:2086200.0, unit_number:10.0, price:1101.0, penalty:135000.0, cash:1866000.0
# 	action_counter: Counter({19: 148, 0: 78, 2: 74})
# 	t:400,all_property:2088820.0, unit_number:10.0, price:1124.0, penalty:135000.0, cash:1864020.0
# 	action_counter: Counter({19: 198, 0: 103, 2: 99})
# 	evaluation episode: 2310, return:57691280.0, episode_length:419
# 	all_property: 2088640.0
#
#
# episode:2320, return:39772460.0, episode_length:419
# action_counter: Counter({0: 138, 20: 130, 2: 46, 18: 33, 19: 27, 6: 6, 3: 6, 5: 5, 7: 4, 4: 4, 9: 3, 12: 3, 10: 2, 11: 2, 14: 2, 17: 2, 13: 2, 1: 2, 15: 1, 8: 1})
# 	t:0,all_property:2122000.0, unit_number:50.0, price:1122.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2123800.0, unit_number:10.0, price:1094.0, penalty:150000.0, cash:1905000.0
# 	action_counter: Counter({0: 52, 20: 48})
# 	t:200,all_property:2127400.0, unit_number:10.0, price:1131.0, penalty:150000.0, cash:1901200.0
# 	action_counter: Counter({0: 102, 20: 98})
# 	t:300,all_property:2127400.0, unit_number:10.0, price:1120.0, penalty:150000.0, cash:1903400.0
# 	action_counter: Counter({0: 152, 20: 148})
# 	t:400,all_property:2123200.0, unit_number:10.0, price:1095.0, penalty:150000.0, cash:1904200.0
# 	action_counter: Counter({0: 202, 20: 198})
# 	evaluation episode: 2320, return:63974800.0, episode_length:419
# 	all_property: 2124800.0
#
#
# episode:2330, return:35668980.0, episode_length:419
# action_counter: Counter({0: 147, 20: 112, 19: 40, 2: 38, 18: 36, 7: 8, 15: 7, 8: 4, 1: 4, 4: 4, 13: 3, 3: 3, 11: 2, 10: 2, 12: 2, 17: 2, 16: 2, 5: 1, 14: 1, 6: 1})
# 	t:0,all_property:2102000.0, unit_number:50.0, price:1102.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2106080.0, unit_number:12.0, price:1096.0, penalty:135000.0, cash:1843040.0
# 	action_counter: Counter({2: 44, 19: 34, 18: 9, 7: 8, 0: 3, 5: 2})
# 	t:200,all_property:2107520.0, unit_number:3.0, price:1110.0, penalty:120000.0, cash:2040920.0
# 	action_counter: Counter({2: 90, 19: 78, 5: 11, 18: 10, 7: 8, 0: 3})
# 	t:300,all_property:2110600.0, unit_number:6.0, price:1100.0, penalty:120000.0, cash:1978600.0
# 	action_counter: Counter({2: 135, 19: 123, 5: 17, 7: 12, 18: 10, 0: 3})
# 	t:400,all_property:2109900.0, unit_number:1.0, price:1112.0, penalty:75000.0, cash:2087660.0
# 	action_counter: Counter({2: 180, 19: 168, 5: 27, 7: 12, 18: 10, 0: 3})
# 	evaluation episode: 2330, return:51774420.0, episode_length:419
# 	all_property: 2112960.0
#
#
# episode:2340, return:25576820.0, episode_length:419
# action_counter: Counter({20: 129, 0: 125, 2: 37, 17: 28, 19: 16, 6: 15, 5: 14, 18: 9, 1: 8, 4: 8, 16: 7, 12: 6, 8: 4, 11: 3, 13: 2, 14: 2, 7: 2, 3: 2, 10: 2})
# 	t:0,all_property:2023000.0, unit_number:50.0, price:1023.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2024200.0, unit_number:8.0, price:1037.0, penalty:120000.0, cash:1858280.0
# 	action_counter: Counter({18: 48, 2: 47, 0: 5})
# 	t:200,all_property:2031500.0, unit_number:0.0, price:1083.0, penalty:150000.0, cash:2031500.0
# 	action_counter: Counter({18: 83, 2: 63, 0: 31, 19: 14, 6: 8, 16: 1})
# 	t:300,all_property:2038760.0, unit_number:-1.0, price:1111.0, penalty:-350000.0, cash:2060980.0
# 	action_counter: Counter({2: 83, 18: 83, 19: 64, 0: 58, 6: 8, 3: 3, 16: 1})
# 	t:400,all_property:2037120.0, unit_number:-1.0, price:1114.0, penalty:-350000.0, cash:2059400.0
# 	action_counter: Counter({19: 114, 2: 108, 0: 83, 18: 83, 6: 8, 3: 3, 16: 1})
# 	evaluation episode: 2340, return:37090180.0, episode_length:419
# 	all_property: 2038760.0
#
#
# episode:2350, return:33546135.0, episode_length:419
# action_counter: Counter({0: 100, 20: 87, 19: 60, 2: 54, 17: 20, 1: 19, 18: 19, 3: 16, 4: 11, 16: 7, 8: 5, 7: 5, 12: 3, 6: 3, 15: 3, 14: 2, 13: 2, 9: 1, 5: 1, 10: 1})
# statistics: [('average_q', 2.2285438), ('average_loss', 0.02215544675826095), ('cumulative_steps', 984650), ('n_updates', 984151), ('rlen', 984650)]
# 	t:0,all_property:2081000.0, unit_number:50.0, price:1081.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2091080.0, unit_number:11.0, price:1127.0, penalty:150000.0, cash:1843140.0
# 	action_counter: Counter({0: 51, 20: 48, 1: 1})
# 	t:200,all_property:2092980.0, unit_number:11.0, price:1131.0, penalty:150000.0, cash:1844160.0
# 	action_counter: Counter({20: 85, 0: 84, 2: 13, 18: 9, 1: 5, 17: 4})
# 	t:300,all_property:2086160.0, unit_number:11.0, price:1110.0, penalty:150000.0, cash:1841960.0
# 	action_counter: Counter({20: 135, 0: 134, 2: 13, 18: 9, 1: 5, 17: 4})
# 	t:400,all_property:2087080.0, unit_number:8.0, price:1079.0, penalty:105000.0, cash:1914440.0
# 	action_counter: Counter({20: 161, 0: 153, 2: 34, 17: 20, 18: 17, 1: 12, 4: 3})
# 	evaluation episode: 2350, return:60451400.0, episode_length:419
# 	all_property: 2088120.0
#
#
# episode:2360, return:19421840.0, episode_length:419
# action_counter: Counter({20: 123, 0: 115, 1: 33, 19: 30, 17: 22, 2: 21, 3: 19, 18: 10, 6: 7, 4: 7, 16: 5, 14: 5, 13: 4, 5: 4, 11: 3, 8: 3, 9: 3, 10: 2, 7: 2, 15: 1})
# 	t:0,all_property:2050000.0, unit_number:50.0, price:1050.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2073800.0, unit_number:10.0, price:1119.0, penalty:150000.0, cash:1850000.0
# 	action_counter: Counter({0: 52, 20: 48})
# 	t:200,all_property:2074400.0, unit_number:10.0, price:1100.0, penalty:150000.0, cash:1854400.0
# 	action_counter: Counter({0: 102, 20: 98})
# 	t:300,all_property:2077200.0, unit_number:10.0, price:1129.0, penalty:150000.0, cash:1851400.0
# 	action_counter: Counter({0: 152, 20: 148})
# 	t:400,all_property:2077000.0, unit_number:10.0, price:1113.0, penalty:150000.0, cash:1854400.0
# 	action_counter: Counter({0: 202, 20: 198})
# 	evaluation episode: 2360, return:63925600.0, episode_length:419
# 	all_property: 2075600.0
#
#
# episode:2370, return:54007760.0, episode_length:419
# action_counter: Counter({20: 135, 0: 134, 19: 38, 1: 29, 2: 23, 18: 12, 7: 9, 6: 6, 15: 5, 3: 5, 4: 4, 12: 4, 13: 3, 17: 3, 8: 3, 11: 2, 10: 2, 5: 1, 14: 1})
# 	t:0,all_property:2045000.0, unit_number:50.0, price:1045.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2040040.0, unit_number:12.0, price:1052.0, penalty:150000.0, cash:1787560.0
# 	action_counter: Counter({0: 51, 20: 48, 2: 1})
# 	t:200,all_property:2045200.0, unit_number:12.0, price:1116.0, penalty:150000.0, cash:1777360.0
# 	action_counter: Counter({0: 101, 20: 98, 2: 1})
# 	t:300,all_property:2040760.0, unit_number:12.0, price:1100.0, penalty:150000.0, cash:1776760.0
# 	action_counter: Counter({0: 151, 20: 148, 2: 1})
# 	t:400,all_property:2044680.0, unit_number:12.0, price:1128.0, penalty:150000.0, cash:1773960.0
# 	action_counter: Counter({0: 201, 20: 198, 2: 1})
# 	evaluation episode: 2370, return:63815960.0, episode_length:419
# 	all_property: 2039920.0
#
#
# episode:2380, return:39592640.0, episode_length:419
# action_counter: Counter({0: 147, 20: 133, 19: 36, 2: 32, 18: 13, 7: 12, 3: 10, 17: 5, 11: 5, 6: 4, 4: 4, 12: 3, 16: 3, 10: 3, 15: 3, 5: 2, 9: 1, 14: 1, 13: 1, 1: 1})
# 	t:0,all_property:2087000.0, unit_number:50.0, price:1087.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2090120.0, unit_number:3.0, price:1134.0, penalty:135000.0, cash:2022080.0
# 	action_counter: Counter({2: 28, 20: 27, 1: 21, 17: 18, 6: 5, 0: 1})
# 	t:200,all_property:2086780.0, unit_number:0.0, price:1090.0, penalty:60000.0, cash:2086780.0
# 	action_counter: Counter({2: 62, 20: 60, 1: 31, 17: 29, 6: 17, 0: 1})
# 	t:300,all_property:2091460.0, unit_number:12.0, price:1111.0, penalty:150000.0, cash:1824820.0
# 	action_counter: Counter({2: 89, 20: 87, 1: 53, 17: 51, 6: 18, 0: 1, 16: 1})
# 	t:400,all_property:2086900.0, unit_number:3.0, price:1085.0, penalty:135000.0, cash:2021800.0
# 	action_counter: Counter({2: 125, 20: 121, 1: 61, 17: 60, 6: 31, 0: 1, 16: 1})
# 	evaluation episode: 2380, return:52936460.0, episode_length:419
# 	all_property: 2086620.0
#
#
# episode:2390, return:43557140.0, episode_length:419
# action_counter: Counter({0: 112, 20: 100, 19: 67, 2: 47, 1: 24, 17: 13, 6: 10, 13: 6, 4: 6, 18: 5, 7: 5, 15: 4, 3: 4, 10: 4, 12: 3, 8: 2, 11: 2, 16: 2, 14: 1, 5: 1, 9: 1})
# 	t:0,all_property:2104000.0, unit_number:50.0, price:1104.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2101720.0, unit_number:11.0, price:1097.0, penalty:135000.0, cash:1860380.0
# 	action_counter: Counter({1: 48, 19: 27, 20: 14, 18: 4, 0: 3, 7: 2, 17: 2})
# 	t:200,all_property:2102980.0, unit_number:10.0, price:1111.0, penalty:105000.0, cash:1880780.0
# 	action_counter: Counter({1: 98, 19: 48, 20: 33, 17: 12, 18: 4, 0: 3, 7: 2})
# 	t:300,all_property:2097640.0, unit_number:13.0, price:1099.0, penalty:150000.0, cash:1811900.0
# 	action_counter: Counter({1: 146, 20: 66, 19: 57, 17: 17, 18: 5, 0: 3, 5: 3, 7: 2, 6: 1})
# 	t:400,all_property:2098370.0, unit_number:3.0, price:1108.0, penalty:135000.0, cash:2031890.0
# 	action_counter: Counter({1: 191, 20: 109, 19: 59, 17: 17, 5: 12, 18: 5, 0: 3, 7: 2, 6: 1, 2: 1})
# 	evaluation episode: 2390, return:57499750.0, episode_length:419
# 	all_property: 2100950.0
#
#
# episode:2400, return:42637615.0, episode_length:419
# action_counter: Counter({20: 166, 0: 157, 2: 18, 19: 13, 1: 11, 3: 8, 17: 7, 7: 6, 18: 6, 6: 6, 5: 5, 8: 3, 9: 3, 16: 2, 13: 2, 12: 2, 11: 1, 10: 1, 15: 1, 14: 1})
# statistics: [('average_q', 2.2760262), ('average_loss', 0.014401893991744146), ('cumulative_steps', 1005600), ('n_updates', 1005101), ('rlen', 1000000)]
# 	t:0,all_property:2019000.0, unit_number:50.0, price:1019.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2033560.0, unit_number:13.0, price:1050.0, penalty:150000.0, cash:1760560.0
# 	action_counter: Counter({0: 49, 20: 48, 1: 3})
# 	t:200,all_property:2039040.0, unit_number:0.0, price:1117.0, penalty:150000.0, cash:2039040.0
# 	action_counter: Counter({0: 99, 20: 97, 1: 3, 7: 1})
# 	t:300,all_property:2039840.0, unit_number:0.0, price:1089.0, penalty:150000.0, cash:2039840.0
# 	action_counter: Counter({0: 149, 20: 147, 1: 3, 7: 1})
# 	t:400,all_property:2043440.0, unit_number:0.0, price:1127.0, penalty:150000.0, cash:2043440.0
# 	action_counter: Counter({0: 199, 20: 197, 1: 3, 7: 1})
# 	evaluation episode: 2400, return:63517040.0, episode_length:419
# 	all_property: 2043440.0
#
#
# episode:2410, return:30663640.0, episode_length:419
# action_counter: Counter({0: 152, 20: 137, 19: 36, 2: 25, 7: 12, 18: 11, 3: 8, 5: 6, 17: 4, 15: 4, 13: 4, 1: 4, 14: 3, 4: 3, 6: 3, 9: 2, 16: 1, 8: 1, 10: 1, 12: 1, 11: 1})
# 	t:0,all_property:2081000.0, unit_number:50.0, price:1081.0, penalty:None, cash:1000000.0
# 	t:100,all_property:2084800.0, unit_number:10.0, price:1120.0, penalty:150000.0, cash:1860800.0
# 	action_counter: Counter({0: 52, 20: 48})
# 	t:200,all_property:2080200.0, unit_number:10.0, price:1104.0, penalty:150000.0, cash:1859400.0
# 	action_counter: Counter({0: 102, 20: 98})
# 	t:300,all_property:2083200.0, unit_number:10.0, price:1097.0, penalty:150000.0, cash:1863800.0
# 	action_counter: Counter({0: 152, 20: 148})
# 	t:400,all_property:2080200.0, unit_number:10.0, price:1115.0, penalty:150000.0, cash:1857200.0
# 	action_counter: Counter({0: 202, 20: 198})
# 	evaluation episode: 2410, return:63930400.0, episode_length:419
# 	all_property: 2080400.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-273-23b7f2c85ab2> in <module>
#      30         action = agent.act(normalized_obs)
#      31         train_action_list.append(action)
# ---> 32         obs, reward, done, info = env.step(action)
#      33
#      34         R += reward
#
# <ipython-input-210-1babf907440d> in step(self, action)
#     296         state_prices_bool_array = self.episode_series.index.isin(state_datetimes)
#     297
# --> 298         state_prices_series = self.episode_series.loc[state_prices_bool_array].copy()
#     299         state_prices_array = state_prices_series.values
#     300
#
# ~\Anaconda3\envs\torch_py37\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\envs\torch_py37\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1088             return self._get_slice_axis(key, axis=axis)
#    1089         elif com.is_bool_indexer(key):
# -> 1090             return self._getbool_axis(key, axis=axis)
#    1091         elif is_list_like_indexer(key):
#    1092
#
# ~\Anaconda3\envs\torch_py37\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
#     896         key = check_bool_indexer(labels, key)
#     897         inds = key.nonzero()[0]
# --> 898         return self.obj._take_with_is_copy(inds, axis=axis)
#     899
#     900
#
# ~\Anaconda3\envs\torch_py37\lib\site-packages\pandas\core\series.py in _take_with_is_copy(self, indices, axis)
#     845         See the docstring of `take` for full explanation of the parameters.
#     846         """
# --> 847         return self.take(indices=indices, axis=axis)
#     848
#     849     def _ixs(self, i: int, axis: int = 0):
#
# ~\Anaconda3\envs\torch_py37\lib\site-packages\pandas\core\series.py in take(self, indices, axis, is_copy, **kwargs)
#     831         indices = ensure_platform_int(indices)
#     832         new_index = self.index.take(indices)
# --> 833         new_values = self._values.take(indices)
#     834
#     835         result = self._constructor(new_values, index=new_index, fastpath=True)
#
# KeyboardInterrupt:

# %% [markdown]
# ###  モデルの評価

# %%
with agent.eval_mode():
    env.seed()
    #env.seed(0)
    for i in range(10):
        obs,_,_,_ = env.reset()
        R = 0
        t = 1
        while True:
            action = agent.act(obs)
            obs, reward, done, info = env.step(action)
            R += reward
            t += 1
            reset = False

            # state, rewardの前処理
            normalized_obs = state_transform(obs)
            #normalized_reward = reward_transform(reward)
            #normalized_obs = obs
            normalized_reward = reward


            #agent.observe(normalized_obs, normalized_reward, done, reset)
            if done or reset:
                break
        
        print("evaluation episode: {}, return:{}, episode_length:{}".format(i, R, t))
        print("all_property:", env.all_property)
# Out:
# evaluation episode: 0, return:-945578600.0, episode_length:420
# all_property: 238500.0
# evaluation episode: 1, return:-945513800.0, episode_length:420
# all_property: 426000.0
# evaluation episode: 2, return:-944627900.0, episode_length:420
# all_property: 2089000.0
# evaluation episode: 3, return:-944718500.0, episode_length:420
# all_property: 3225400.0
# evaluation episode: 4, return:-944574100.0, episode_length:420
# all_property: 2101900.0
# evaluation episode: 5, return:-944704950.0, episode_length:420
# all_property: 2052850.0
# evaluation episode: 6, return:-945600500.0, episode_length:420
# all_property: 216600.0
# evaluation episode: 7, return:-945057700.0, episode_length:420
# all_property: 800300.0
# evaluation episode: 8, return:-944660800.0, episode_length:420
# all_property: 2342400.0
# evaluation episode: 9, return:-944588800.0, episode_length:420
# all_property: 1882700.0

# %% [markdown]
# ###  売買過程の描画

# %% [markdown]
# #### 一度に描画

# %%
price_list = []
stocks_list = []
all_property_list = []
datetime_list = []


with agent.eval_mode():
    #env.seed()
    env.seed()
    obs,_,_,info = env.reset()

    price_list.append(obs[2])
    stocks_list.append(obs[1]*env.one_unit_stocks)
    all_property_list.append(info["all_property"])
    datetime_list.append(info["datetime"])

    R = 0
    t = 1
    while True:
        action = agent.act(obs)
        obs, reward, done, info = env.step(action)
        R += reward
        t += 1
        reset = False

        price_list.append(obs[2])
        stocks_list.append(obs[1]*env.one_unit_stocks)
        all_property_list.append(info["all_property"])
        datetime_list.append(info["datetime"])

        # state, rewardの前処理
        normalized_obs = state_transform(obs)
        #normalized_reward = reward_transform(reward)
        #normalized_obs = obs
        normalized_reward = reward

        agent.observe(normalized_obs, normalized_reward, done, reset)
        if done or reset:
            break

print("finishet. episode length: {}".format(t))

price_array = np.array(price_list)
stocks_array = np.array(stocks_list)
all_property_array = np.array(all_property_list)
datetime_array = np.array(datetime_list)
# Out:
# finishet. episode length: 420

# %% [markdown]
# matplotlibで描画

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(50,30))
ax1 = fig.add_subplot(211)

# 価格の描画
x = np.arange(0,len(datetime_array))
ax1.plot(x, price_array, zorder=1)

# 保有量の描画
ax2 = ax1.twinx()
ax2.bar(x, stocks_array, color="C1", zorder=2)
ax2.set_ylim(0, max(stocks_array)*5)

ax2 = fig.add_subplot(212, sharex=ax1)

# 全財産の推移
ax3 = fig.add_subplot(212)
ax3.plot(x, all_property_array, color="C2")
ax3.axhline(y=initial_cash, xmin=0, xmax=420)

# %% [markdown]
# ### 環境のクローズ

# %%
env.close()

# %% [markdown]
# ### モデルの保存

# %%
now_datetime = datetime.datetime.now()
now_str = now_datetime.strftime("%Y_%m_%d__%H_%M_%S")
agent.save(Path("agents")/Path(now_str))
