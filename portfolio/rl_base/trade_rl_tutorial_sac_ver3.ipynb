# %% [markdown]
# # 強化学習で株取引　その１

# %% [markdown]
# 今回は環境の作成もかねて，一つの銘柄の取引を強化学習で行う．予測とはアルゴリズムを分離するため，未来の株価も含めるように調整する．

# %%
import sys
sys.path.append(r"E:\システムトレード入門\tutorials\rl\pfrl")
sys.path.append(r"E:\システムトレード入門\trade_system_git_workspace")

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from numpy.random import RandomState
import pandas as pd
from tqdm.notebook import tqdm
from collections import namedtuple
import collections
from copy import deepcopy
import matplotlib.pyplot as plt

# %%
import gym
from gym import spaces, logger
from gym.utils import seeding

# %%
import datetime
from pytz import timezone

# %%
from pathlib import Path

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
import pfrl

# %%
from get_stock_price import StockDatabase

# %%
from utils import middle_sample_type_with_check, get_previous_datetime, get_next_workday_jp
from utils import extract_workdays_intraday_jp_index, extract_workdays_intraday_jp

# %%
from utils import py_restart

# %%
from visualize_trading_process_ver2 import plot_trading_process_matplotlib, plot_trading_process_bokeh

# %%
from envs_ver4 import OneStockEnv, make_env

# %% [markdown]
# ### データベース

# %%
db_path = Path("E:/システムトレード入門/trade_system_git_workspace/db/sub_stock_db") / Path("sub_stock.db")
stock_db = StockDatabase(db_path)

# %% [markdown]
# ### 利用するデータ

# %%
jst_timezone = timezone("Asia/Tokyo")
start_datetime = jst_timezone.localize(datetime.datetime(2020,11,1,0,0,0))
end_datetime = jst_timezone.localize(datetime.datetime(2020,12,1,0,0,0))
#end_datetime = get_next_workday_jp(start_datetime, days=11)  # 営業日で一週間(5日間)

#stock_names = "4755"
#stock_names = "9984"
stock_names = "6502"
#stock_names = ["6502","4755"]
#stock_list = ["4755","9984","6701","7203","7267"]

use_ohlc="Close"

# %% [markdown]
# ### 環境クラス

# %%
initial_cash = 10.e6  # 種銭：100万円
initial_unit = 100  # 初期単元数

freq_str = "5T"
episode_length = 12*5*7  # 1週間

#state_time_list = [0,1,12,12*3,12*5,12*5*3],  # [現在，次時刻，一時間後，3時間後，5時間後(1日後), 15時間後(3日後)]
state_time_list = [0,
                   1,
                   2,
                   6,
                   12,
                   12*2,
                   12*3,
                   12*4,
                   12*5*1,
                   12*5*2,
                   12*5*3,
                   12*5*4,
                   12*5*5,
                   ]  # 現在，5分後, 10分後, 30分後, 1時間後, 2時間後, 3時間後, 4時間後, 1日後, 2日後, 3日後, 4日後, 5日後, 6日後, 7日後

one_unit_stocks = 20
max_units_number = 5
stay_penalty_unit_bound=30
stay_penalty_cash_bound = 1.e5
penalty_mcp_np_diff_bound = 3


env = OneStockEnv(stock_db,
                  stock_names=stock_names,
                  start_datetime=start_datetime,
                  end_datetime=end_datetime,
                  freq_str="5T",
                  episode_length=episode_length,  # 一週間
                  state_time_list=state_time_list,
                  use_ohlc=use_ohlc,  # 終値を使う
                  initial_cash=initial_cash,  # 種銭
                  initial_unit=initial_unit,
                  use_view=False,
                  one_unit_stocks=one_unit_stocks,  # 独自単元株数
                  max_units_number=max_units_number,  # 一度に売買できる独自単元数
                  low_limmit=1.e4,  # 全財産がこの値以下になれば終了
                  interpolate=True,
                  stay_penalty_unit_bound=stay_penalty_unit_bound,  # このunit数以下の場合のstayはペナルティ
                  stay_penalty_cash_bound=stay_penalty_cash_bound,  # このcash以下の場合のstayはペナルティ
                  penalty_mcp_np_diff_bound=penalty_mcp_np_diff_bound
                 )

# %%
#env.reset(select_datetime=jst_timezone.localize(datetime.datetime(2020, 11, 4, 14, 0)), select_stock_name="4755")
env.reset()
# Out:
# (StockState(cash=10000000.0, unit_number=100, mean_cost_price=2804.9044568037407, all_property=15594000.0, price_array=array([2797., 2792., 2790., 2765., 2748., 2802., 2770., 2803., 2748.,
#         2722., 2706., 2823., 2837.])),
#  0,
#  False,
#  {'datetime': datetime.datetime(2020, 11, 11, 13, 0, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>),
#   'stock_name': '6502',
#   'done_active': None,
#   'iter_counter': 1,
#   'penalty': 0,
#   'gein_reward': 0,
#   'price_reward': 0,
#   'all_property_reward': 0,
#   'reward': 0})

# %% [markdown]
# ### 環境の並列化

# %%
env_number = 4
batch_env = pfrl.envs.MultiprocessVectorEnv([make_env for _ in range(env_number)])

# %% [markdown]
# ### 前処理用のクラス

# %%
state_transform = NormalizeState(cash_const=initial_cash,
                                 unit_const=100,
                                 price_const=1.e4,
                                 all_property_const=5*initial_cash
                                )

reward_transform = NormalizeReward(reward_const=1.e5,
                                  )

# %% [markdown]
# ### モデルの定義

# %%
class PolicyValueModel(nn.Module):
    def __init__(self, obs_size, n_actions):
        super().__init__()
        self.fc1 = nn.Linear(obs_size, 32)
        self.bn1 = nn.BatchNorm1d(32)
        
        self.fc2 = nn.Linear(32, 128)
        self.bn2 = nn.BatchNorm1d(128)
        
        self.fc3 = nn.Linear(128, 256)
        self.bn3 = nn.BatchNorm1d(256)
        
        self.br1_fc1 = nn.Linear(256, 50)
        self.br1_bn1 = nn.BatchNorm1d(50)
        
        self.br1_fc2 = nn.Linear(50, n_actions)
        self.br1_bn2 = nn.BatchNorm1d(n_actions)
        self.policy_head = pfrl.policies.SoftmaxCategoricalHead()
        
        self.br2_fc1 = nn.Linear(256, 50)
        self.br2_bn1 = nn.BatchNorm1d(50)
        self.value_head = nn.Linear(50, 1)
        
    def forward(self, x):
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        branch = F.relu(self.bn3(self.fc3(x)))
        
        policy_x = F.relu(self.br1_bn1(self.br1_fc1(branch)))
        policy_x = F.relu(self.br1_bn2(self.br1_fc2(policy_x))
        out_policy = self.policy_head(policy_x)
        
        
        value_x = F.relu(self.br2_bn1(self.br2_fc1(branch))) 
        out_value = self.value_head(value_x)  # exampleの実装では最終層の活性化関数は無い
        
        return out_policy, out_value

# %%
obs_size = env.observation_space.low.size
action_dim = env.action_space.n

policy_value_model = PolicyValueModel(obs_size, n_action)
# Out:
# observation size: 17
# action size: 11

# %% [markdown]
# ### 学習係数の減衰

# %%
def extinction_lr(episode_number):
    if episode_number < 200:
        return 1.0
    elif episode_number < 400:
        return 0.8
    elif episode_number < 600:
        return 0.6
    elif episode_number < 800:
        return 0.4
    elif episode_number < 1000:
        return 0.2
    elif episode_number < 1200:
        return 0.1
    elif episode_number < 1400:
        return 0.08
    elif episode_number < 1600:
        return 0.04
    elif episode_number < 1800:
        return 0.02
    else:
        return 0.01

# %% [markdown]
# ### エージェントの定義

# %% [markdown]
# 今回はDobuleQ

# %%
a2c_opt = pfrl.optimizers.RMSpropEpsInsideSqrt(
        policy_value_model.parameters(),
        lr=7e-4,
        eps=1e-5,
        alpha=0.99,
    )

gamma = 0.99

update_steps = 10

phi = lambda x: x.astype(np.float32, copy=False)

use_gae = False

tau = 0.95

max_grad_norm = 40

gpu = -1

num_processes = process_number


a2c_agent = pfrl.agents.A2C(
    policy_value_model,
    a2c_opt,
    gamma=gamma,
    gpu=gpu,
    num_processes=process_number,
    update_steps=update_steps,
    phi=phi,
    use_gae=use_gae,
    tau=tau,
    max_grad_norm=max_grad_norm,
)

# %%
gamma = 0.95

init_episilon = 0.3
init_explorer = pfrl.explorers.ConstantEpsilonGreedy(epsilon=init_episilon,
                                                random_action_func=env.action_space.sample
                                               )

#replay_buffer = pfrl.replay_buffers.ReplayBuffer(capacity=10**6)

def phi_func(observe):
    observe_array = observe.to_numpy()
    return observe_array.astype(np.float32, copy=False)


phi = phi_func

#gpu = 0 # -1 is cpu
gpu = -1

def initialize_agent():  # agentのアトリビュートの直接的な変更を防ぐため
    q_func = QFunction(obs_size, n_actions)  # Q関数の初期化
    optimizer = torch.optim.Adam(q_func.parameters(), eps=1e-4) # optimizerの初期化
    scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=extinction_lr)  # schedulerの初期化
    replay_buffer = pfrl.replay_buffers.ReplayBuffer(capacity=10**6)  # バッファの初期化

    agent = pfrl.agents.DoubleDQN(
        q_function=q_func,
        optimizer=optimizer,
        replay_buffer=replay_buffer,
        gamma=gamma,
        explorer=init_explorer,
        replay_start_size=500,
        update_interval=1,
        target_update_interval=100,
        phi=phi,
        gpu=gpu
    )
    return agent, scheduler

agent, scheduler = initialize_agent()

# %% [markdown]
# ### モデルのロード

# %%
UseLoad=False
if UseLoad:
    folder_name = "2020_12_26__22_59_52"
    load_path = Path("agents") / Path(folder_name)
    agent.load(load_path)

# %% [markdown]
# ###  イプシロンの減衰

# %%
def extinction_epsilon(episode_number):
    if episode_number < 200:
        return 0.9
    elif episode_number < 400:
        return 0.8
    elif episode_number < 600:
        return 0.7
    elif episode_number < 800:
        return 0.6
    elif episode_number < 1000:
        return 0.5
    elif episode_number < 1200:
        return 0.4
    elif episode_number < 1400:
        return 0.3
    elif episode_number < 1600:
        return 0.2
    else:
        return 0.1

# %% [markdown]
# ### ランダムシードの設定

# %%
class SeedSetter():
    def __init__(self, env):
        self.env = env
        self.initial_seed = np.random.randint(0,1000)
        self.mcp_seed = np.random.randint(0,1000)
    
    def initialize(self, initial_seed=None, mcp_seed=None):
        if initial_seed is None:
            self.initial_seed = np.random.randint(0,1000)
        else:
            self.initial_seed = initial_seed
        
        if mcp_seed is None:
            self.mcp_seed = np.random.randint(0,1000)
        else:
            self.mcp_seed = mcp_seed

    def set_seed(self, episode_number):
        if episode_number  < 1000:
            self.env.seed(self.initial_seed, self.mcp_seed)
        elif episode_number < 3000:
            self.env.seed(self.initial_seed, None)
        #else:
        #    self.env.seed(None, None)
    
    def get_seed(self):
        return self.initial_seed, self.mcp_seed

# %%
seed_setter = SeedSetter(env)

# %% [markdown]
# ### 初期探索の終了判定クラス

# %%
def visualize_unit_number_matplotlib(title_text,
                                     x, 
                                     unit_number_array,
                                     ransac_solution,
                                     sampled_x_tensor,
                                     b_beta_hat, 
                                     sampled_x_tensor_flatten, 
                                     sampled_unit_number_tensor_flatten,
                                     ransac_solution_voted_points_bool,
                                     save_path=None,
                                    ):
    
        
    fig, ax = plt.subplots(figsize=(20,4))
    ax.set_title(title_text)
                                     
    ax.bar(x, unit_number_array, color="blue",zorder=1)
    # ransac結果の直線の描画
    x_min = 0
    x_max = len(x)
    X_start_end = np.array([[x_min, 1],[x_max,1]])
    y_hat_start_end = np.dot(X_start_end, ransac_solution)
    ax.plot([x_min, x_max],y_hat_start_end, color="limegreen")
    
    # サンプリングしたデータの直線の描画
    # 同時に描画できるけど面倒だからfor文
    for i in range(len(b_beta_hat)):
        one_beta_hat = b_beta_hat[i]
        one_beta_hat_squeezed = torch.squeeze(one_beta_hat,dim=1).numpy()


        # 描画領域のxを取得
        sampled_points_x = sampled_x_tensor[i]
        sampled_points_x_min = torch.min(sampled_points_x).item()
        sampled_points_x_max = torch.max(sampled_points_x).item()
        one_X_start_end = np.array([[sampled_points_x_min, 1],[sampled_points_x_max, 1]])
        one_y_hat_start_end = np.dot(one_X_start_end, one_beta_hat_squeezed)

        ax.plot([sampled_points_x_min, sampled_points_x_max], one_y_hat_start_end, color="black",zorder=2)
        
    ax.scatter(sampled_x_tensor_flatten.numpy().astype(int)[~ransac_solution_voted_points_bool],
               sampled_unit_number_tensor_flatten.numpy()[~ransac_solution_voted_points_bool], color="pink",zorder=3)
    ax.scatter(sampled_x_tensor_flatten.numpy().astype(int)[ransac_solution_voted_points_bool],
               sampled_unit_number_tensor_flatten.numpy()[ransac_solution_voted_points_bool],color="red",zorder=3)
    
    if save_path is not None:
        fig.savefig(save_path,bbox_inches='tight', pad_inches=0)
        plt.close()


class RansacGradLearningDecider():
    def __init__(self, line_number=10, point_number=2, distance_th=0.2, decision_rate=0.7, grad_abs_limit=20):
        self.line_number = line_number
        self.point_number = point_number
        self.distance_th = distance_th
        self.decision_rate = decision_rate
        self.grad_abs_limit = grad_abs_limit
        self.save_path = None
        
    def set_save_path(self, save_path):
        self.save_path = save_path
        
    def decide(self, state_list, info_list, env):
        """
        うまく学習できているかどうか判定
        """
        # unit_number の arrayを取得
        unit_number_array = np.array(list(map(lambda state: state.unit_number, state_list)))
        unit_number_tensor = torch.from_numpy(unit_number_array)


        x = np.arange(0, len(unit_number_array))
        x_tensor = torch.from_numpy(x).float()

        # line_number の数だけサンプリング(重複なし)
        random_index = np.array([np.random.permutation(len(unit_number_array))[:self.point_number] for i in range(self.line_number)])  # 重複なく(.line_number, point_number)のインデックスを取得

        sampled_unit_number_tensor = torch.from_numpy(unit_number_array[random_index]).float()  # (line_number(m), point_number(s))
        sampled_x_tensor = torch.from_numpy(x[random_index]).float()  # (line_number(m), point_number(s))

        sampled_unit_number_tensor_flatten = sampled_unit_number_tensor.flatten()  # (m*n)ベクトルとして利用する場合
        sampled_x_tensor_flatten  = sampled_x_tensor.flatten()  # (m*n)ベクトルとして利用する場合


        # バッチの最小二乗解
        b_X = torch.stack([sampled_x_tensor, torch.ones_like(sampled_x_tensor).float()],dim=2)
        b_XtX = torch.bmm(b_X.transpose(1,2),b_X)
        b_inv_XtX = torch.inverse(b_XtX)
        b_Xty = torch.bmm(b_X.transpose(1,2), sampled_unit_number_tensor[:,:,None])

        b_beta_hat = torch.bmm(b_inv_XtX, b_Xty)  # (line_number(m),2,1) であることに注意

        b_beta_hat_squeeze = b_beta_hat.squeeze()  # (line_number(m),2)

        # 距離の計算
        a = b_beta_hat_squeeze[:,0]  # (line_number(m))
        c = b_beta_hat_squeeze[:,1]  # (line_number(m))
        d_num = a[:,None] * sampled_x_tensor_flatten[None,:]  - sampled_unit_number_tensor_flatten[None,:] + c[:,None]  # (line_number(m), all_point_number(n))
        d_den = torch.sqrt(a**2+(-1)**2)  # (line_number(m))
        d = torch.abs(d_num) / d_den[:,None]

        distance_boolean = d < self.distance_th  # (line_number(m), all_point_number(n))

        b_vote_number = distance_boolean.sum(dim=1)  # (line_number(m))
        vote_max = np.amax(b_vote_number.numpy(), axis=0)  # 必要なのは最大投票数

        ransac_solution_index = np.argmax(b_vote_number.numpy(),axis=0)  # 正確な比較のためにnumpyで計算
        ransac_solution_voted_points_bool = distance_boolean[ransac_solution_index].numpy()  # 距離の閾値を満たす点のブール 

        ransac_solution = b_beta_hat_squeeze[ransac_solution_index].numpy()
        # 最大投票数の割合によって判定
        if vote_max / (self.line_number * self.point_number) < self.decision_rate:  # 近い割合がdecision_rateより低い場合
            if abs(ransac_solution[0]) < self.grad_abs_limit:  # 傾きが大きすぎない
                return_bool = True
            else:
                return_bool = False
        else:
            return_bool = False
            
        if self.save_path is not None:
            visualize_unit_number_matplotlib("voted_ratio:{}".format(vote_max/(self.line_number*self.point_number)),
                                             x,
                                             unit_number_array,
                                             ransac_solution,
                                             sampled_x_tensor,
                                             b_beta_hat,
                                             sampled_x_tensor_flatten,
                                             sampled_unit_number_tensor_flatten,
                                             ransac_solution_voted_points_bool,
                                             save_path=self.save_path
                                            )
        
        return return_bool
    

class UnitMinusDecider():
    def __init__(self, minus_ratio=0.2):
        self.minus_ratio = minus_ratio
    def decide(self, state_list, info_list, env):
        # stock_number の arrayを取得
        stock_number_array = np.array(list(map(lambda state: state.unit_number*env.one_unit_stocks, state_list)))
        minus_bool_array = stock_number_array < 0
        if minus_bool_array.sum()/len(stock_number_array) < self.minus_ratio:
            return True
        else:
            return False
        
class DeciderComposer():
    def __init__(self, decider_list):
        self.decider_list = decider_list
        
    def decide(self, state_list, info_list, env):
        bool_list = [decider.decide(state_list, info_list, env) for decider in self.decider_list]
        if all(bool_list):
            return True
        else:
            return False

# %% [markdown]
# ### プロファイリング

# %% [markdown]
# #### 学習のための関数

# %%
def episode(env, agent, state_transform=None, reward_transform=None, print_span=None, is_observe=True):
    state_list = []
    info_list = []
    action_list = []
    
    obs,_,_,info = env.reset()

    state_list.append(obs)
    info_list.append(info)
    R = 0
    t = 1
    if print_span is not None:
        print("\tt:{},all_property:{}, unit_number:{}, price:{}, penalty:{}, cash:{}".format(t,
                                                                                             obs.all_property,
                                                                                             obs.unit_number,
                                                                                             obs.now_price,
                                                                                             info["penalty"],
                                                                                             obs.cash
                                                                                            ))
    
    if state_transform is not None:
        normalized_obs = state_transform(obs)
    else:
        normalized_obs = obs

    while True:
        action = agent.act(normalized_obs)
        action_list.append(action)
        obs, reward, done, info = env.step(action)
        R += reward
        t += 1
        reset = False

        # state, rewardの前処理
        if state_transform is not None:
            normalized_obs = state_transform(obs)
        else:
            normalized_obs = obs
        if reward_transform is not None:
            normalized_reward = reward_transform(reward)
        else:
            normalized_reward = reward

        if is_observe:  # 観測(学習)する場合
            agent.observe(normalized_obs, normalized_reward, done, reset)

        state_list.append(obs)
        info_list.append(info)

        if done or reset:
            break
        if print_span is not None:
            if t%print_span==0:
                print("\tt:{},all_property:{}, unit_number:{}, price:{}, penalty:{}, cash:{}".format(t,
                                                                                                     obs.all_property,
                                                                                                     obs.unit_number,
                                                                                                     obs.now_price,
                                                                                                     info["penalty"],
                                                                                                     obs.cash
                                                                                                    ))
                print("\taction_counter:",collections.Counter(action_list))
    
    if print_span is not None:
        print("\tt:{},all_property:{}, unit_number:{}, price:{}, penalty:{}, cash:{}".format(t,
                                                                                             obs.all_property,
                                                                                             obs.unit_number,
                                                                                             obs.now_price,
                                                                                             info["penalty"],
                                                                                             obs.cash
                                                                                            ))
        print("\taction_counter:",collections.Counter(action_list))
        print("finished. episode length: {}".format(t))
    return state_list, info_list, action_list

# %%
def profile_episode():
    #episode(env, agent, state_transform=state_transform, reward_transform=None, print_span=100, is_observe=True)
    pass

# %% [markdown]
# #### 速度のプロファイリング

# %%
from line_profiler import LineProfiler
prf = LineProfiler()                                                                                         
prf.add_module(StockState)
prf.add_module(OneStockEnv)
prf.add_function(episode)                                                                                      
prf.runcall(profile_episode)                                                                                          
prf.print_stats()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0 s
# File: <ipython-input-17-33450f4d8cfd>
# Function: to_numpy at line 5
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      5                                               def to_numpy(self):
#      6                                                   """
#      7                                                   ndarrayに変更する．最後に利用するのがいい？
#      8                                                   """
#      9                                                   cash_unit_mean_all_array = np.array([self.cash, self.unit_number, self.mean_cost_price, self.all_property])
#     10                                                   return np.concatenate([cash_unit_mean_all_array, self.price_array.copy()], axis=0)  # コピーすることに注意
#
# Total time: 0 s
# File: <ipython-input-17-33450f4d8cfd>
# Function: copy at line 25
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     25                                               def copy(self):
#     26                                                   """
#     27                                                   deepcopyでもいいが，一応明示しておく
#     28                                                   """
#     29                                                   new_state = StockState(cash=self.cash,
#     30                                                                          unit_number=self.unit_number,
#     31                                                                          mean_cost_price=self.mean_cost_price,
#     32                                                                          all_property=self.all_property,
#     33                                                                          price_array=self.price_array.copy())
#     34                                                   return new_state
#
# Total time: 0 s
# File: <ipython-input-22-ab1a00779c1a>
# Function: __init__ at line 5
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      5                                               def __init__(self,
#      6                                                            stock_db,
#      7                                                            stock_names,
#      8                                                            start_datetime,
#      9                                                            end_datetime,
#     10                                                            freq_str,
#     11                                                            episode_length,
#     12                                                            state_time_list=[0],
#     13                                                            use_ohlc="Close",
#     14                                                            initial_cash=1.e6,  # 100万円
#     15                                                            initial_unit=50,  # 初期単元数
#     16                                                            use_view=False,
#     17                                                            one_unit_stocks=100,
#     18                                                            max_units_number=10,
#     19                                                            low_limmit=1.e3,  # 1000円
#     20                                                            interpolate=True,
#     21                                                            sample_remove=False,
#     22                                                            action_restriction = False,
#     23                                                            stay_penalty_unit_bound=20,
#     24                                                            stay_penalty_cash_bound=1.e5,
#     25                                                            penalty_mcp_np_diff_bound=3
#     26                                                           ):
#     27                                                   """
#     28                                                   stock_db: StockDataBase
#     29                                                       値を読み込むデータベース．1エピソード分のデータをreset事に読み込む
#     30                                                   stock_names: str list
#     31                                                       利用するデータの銘柄，複数指定した場合はreset時にランダムで決定される
#     32                                                   start_datetime: datetime
#     33                                                       利用するデータの始端
#     34                                                   ed_datetime: datetime
#     35                                                       利用するデータの終端
#     36                                                   freq_str: str
#     37                                                       サンプリング周期
#     38                                                   episode_length: int
#     39                                                       1エピソードの状態の個数
#     40                                                   start_time_list: int list
#     41                                                       状態として利用する株価の現在からのインデックスのリスト．最初の値は現在(0)でなければならない
#     42                                                   use_ohlc: str, defalt: "Close"
#     43                                                       サンプリング周期における利用するデータの指定(Open, High, Low, Close)
#     44                                                   initial_cash: int, defalt: 1.e6
#     45                                                       種銭
#     46                                                   use_view: bool
#     47                                                       reset時にviewを使うかどうか．使う場合，若干高速になるがcloseをしなければならない
#     48                                                   one_unit_stocks: int
#     49                                                       単元数．通常は100だが，独自に定義できる
#     50                                                   max_units_number: int, default: 10
#     51                                                       売買時の単元のセット数の上限・下限．
#     52                                                   low_limmmit: int, defalt:1.e3
#     53                                                       資産額の下限値．この値を下回った場合，エピソードを終了する．
#     54                                                   interpolate: bool
#     55                                                       指定した期間内のデータ中にnanがあった場合，あるいはデータが取得できなかった場合に補間をするかどうか
#     56                                                   sample_remove: bool
#     57                                                       reset時に取得するデータで一度利用したデータを取り除くかどうか
#     58                                                   """
#     59
#     60                                                   # データベース
#     61                                                   self.stock_db = stock_db
#     62                                                   # ビューの作成
#     63                                                   self.use_view = use_view
#     64                                                   if self.use_view:
#     65                                                       self.stock_view = self.stock_db.create_view(stock_names, start_datetime=start_datetime, end_datetime=end_datetime)
#     66
#     67                                                   # 利用するohlcのいずれか
#     68                                                   if use_ohlc not in {"Open","High","Low","Close"}:
#     69                                                       raise Exception("use_ohlc must be in {'Open','High','Low','Close'}")
#     70                                                   self.use_ohlc = use_ohlc
#     71
#     72                                                   self.freq_str = middle_sample_type_with_check(freq_str)
#     73                                                   # 全datetimeデータを保持
#     74                                                   all_datetime_index = pd.date_range(start=start_datetime,
#     75                                                                                      end=get_previous_datetime(end_datetime, freq_str=self.freq_str),
#     76                                                                                      freq=self.freq_str,
#     77                                                                                     )
#     78
#     79                                                   self.all_datetime_index = extract_workdays_intraday_jp_index(all_datetime_index, return_as="index")
#     80
#     81                                                   self.episode_length = episode_length
#     82                                                   self.initial_cash = initial_cash
#     83                                                   self.initial_unit = initial_unit
#     84                                                   self.low_limmit = low_limmit
#     85                                                   self.interpolate = interpolate
#     86                                                   self.sample_remove = sample_remove
#     87                                                   self.action_restriction = action_restriction
#     88                                                   self.stay_penalty_unit_bound = stay_penalty_unit_bound
#     89                                                   self.stay_penalty_cash_bound = stay_penalty_cash_bound
#     90                                                   self.penalty_mcp_np_diff_bound = penalty_mcp_np_diff_bound
#     91                                                   self.penalty_const = 1.e5
#     92
#     93                                                   # 乱数シード
#     94                                                   self.initial_seed_number = None
#     95                                                   self.mcp_seed_number = None
#     96
#     97                                                   # 報酬の重み
#     98                                                   self.gein_reward_weight = 0
#     99                                                   self.price_reward_weight = 1
#    100                                                   self.penalty_weight = 1
#    101                                                   self.all_property_reward_weight = 1
#    102
#    103                                                   if state_time_list[0] != 0:
#    104                                                       raise Exception("The first value of state_time_list must be 0")
#    105
#    106                                                   if state_time_list[1] != 1:
#    107                                                       raise Exception("The second value of state_time_list must be 1")
#    108
#    109                                                   self.state_time_list = state_time_list
#    110
#    111                                                   self.max_state_time = max(state_time_list)  # 利用する未来の状態の現在からのタイムステップ数
#    112                                                   last_start_datetime = self.all_datetime_index[-(self.max_state_time + self.episode_length)]  # エピソードの開始時刻の最後
#    113
#    114                                                   self.sampler = WindowSampler(stock_names,
#    115                                                                                start_datetime=start_datetime,
#    116                                                                                end_datetime=last_start_datetime,
#    117                                                                                freq_str=self.freq_str,
#    118                                                                                end_include=True,  # 最後も含む
#    119                                                                               )
#    120                                                   # 状態空間と行動空間の定義
#    121
#    122                                                   min_stock_price = 0
#    123                                                   max_stock_price = np.finfo(np.float32).max
#    124
#    125                                                   min_cash = 0
#    126                                                   max_cash = np.finfo(np.float32).max
#    127
#    128                                                   min_unit = 0
#    129                                                   max_unit = 1.e6  # # 100万＊単元まで売買できる
#    130
#    131                                                   state_max_list = [max_cash, max_unit, max_stock_price, max_cash]  # 現金，保有単元数，平均取得価格，全資産
#    132                                                   state_max_list.extend([max_stock_price]*len(self.state_time_list))  # [現在価格，指定した未来の価格]
#    133
#    134                                                   state_min_list = [min_cash, min_unit, min_stock_price, min_cash]  # 現金，保有単元数，平均取得価格，全資産
#    135                                                   state_min_list.extend([min_stock_price]*len(self.state_time_list))  # [現在価格，指定した未来の価格]
#    136
#    137                                                   state_max_array = np.array(state_max_list, dtype=np.float32)
#    138                                                   state_min_array = np.array(state_min_list, dtype=np.float32)
#    139
#    140                                                   self.one_unit_stocks = one_unit_stocks  # 独自単元．
#    141                                                   self.max_units_number = max_units_number  # 売買する独自単元の最大数
#    142                                                   self.action_class_number = 2 * self.max_units_number + 1 # 行動数は 2 * self.max_unit_number + 1(ステイ)
#    143
#    144                                                   self.action_space = spaces.Discrete(self.action_class_number)
#    145                                                   self.observation_space = spaces.Box(state_min_array, state_max_array, dtype=np.float32)
#    146
#    147                                                   # 行動クラスの定義
#    148                                                   sell_action_array = np.arange(-self.max_units_number, 0, 1)  # 売りクラス マイナス
#    149                                                   stay_action_arrray = np.array([0])  # ステイクラス
#    150                                                   buy_action_array = np.arange(1, self.max_units_number+1, 1)  # 買いクラス　プラス
#    151
#    152                                                   self.stay_index = len(sell_action_array)  # ステイのインデックス
#    153                                                   self.action_class_array = np.concatenate([sell_action_array, stay_action_arrray, buy_action_array], axis=0)  # 売りクラス，ステイクラス，買いクラスの順番
#    154
#    155                                                   self.state = None
#    156                                                   self.steps_beyond_done = None  # エラー処理に利用
#
# Total time: 0 s
# File: <ipython-input-22-ab1a00779c1a>
# Function: reset at line 159
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    159                                               def reset(self, select_datetime=None, select_stock_name=None):
#    160                                                   """
#    161                                                   環境をリセットする．エピソード開始日時と銘柄名を指定することで，特定の
#    162                                                   select_datetime: datetime.datetime
#    163                                                       エピソードの開始日時
#    164                                                   select_stock_name: str
#    165                                                       銘柄名
#    166                                                   """
#    167                                                   iter_counter = 0
#    168                                                   while True:  # 条件をクリアしたらreturn,それまで繰り返し
#    169                                                       stock_and_datetime = self.sampler.sample(remove=self.sample_remove, seed=self.initial_seed_number)
#    170
#    171                                                       if select_stock_name is None:  # 銘柄名が与えられなかった場合
#    172                                                           stock_name = stock_and_datetime[0]
#    173                                                       else:
#    174                                                           if select_stock_name in self.sampler.stock_names:  # 銘柄名の列
#    175                                                               stock_name = select_stock_name
#    176                                                           else:
#    177                                                               raise Exception("select_stock must be in stock_names of constructor args")
#    178
#    179                                                       if select_datetime is None:  # 日時が与えられなかった場合
#    180                                                           episode_start_datetime = stock_and_datetime[1]
#    181                                                       else:
#    182                                                           select_datetime_array = np.array([select_datetime])
#    183                                                           if np.in1d(select_datetime_array, self.sampler.all_stockname_datetime_array[:,1]).item():  # datetimeの列
#    184                                                               episode_start_datetime = select_datetime
#    185                                                           else:
#    186                                                               raise Exception("select_datetime must be in sample range of datetime")
#    187
#    188                                                       episode_start_datetime_index = np.where(self.all_datetime_index==episode_start_datetime)[0].item()  # エピソードで利用する開始時刻
#    189
#    190                                                       episode_end_datetime_index = episode_start_datetime_index + (self.episode_length-1) + self.max_state_time  # 状態が利用する未来のデータも含める
#    191                                                       episode_end_datetime = self.all_datetime_index[episode_end_datetime_index]  # エピソードで利用する終端時刻(エピソードの終了時刻ではない)
#    192
#    193                                                       # 利用するカラム名
#    194                                                       use_column_name = self.use_ohlc+"_"+stock_name
#    195
#    196                                                       # エピソード分+状態利用分のデータの取得
#    197
#    198                                                       if self.use_view:
#    199                                                           episode_series = self.stock_db.search_span(stock_names=stock_name,
#    200                                                                                                      start_datetime=episode_start_datetime,
#    201                                                                                                      end_datetime=episode_end_datetime,
#    202                                                                                                      freq_str=self.freq_str,
#    203                                                                                                      is_end_include=True,  # 最後の値も含める
#    204                                                                                                      to_tokyo=True,  #必ずTrueに
#    205                                                                                                      view=self.stock_view
#    206                                                                                                      ).loc[:,use_column_name]
#    207
#    208                                                       else:
#    209                                                           episode_series = self.stock_db.search_span(stock_names=stock_name,
#    210                                                                                                      start_datetime=episode_start_datetime,
#    211                                                                                                      end_datetime=episode_end_datetime,
#    212                                                                                                      freq_str=self.freq_str,
#    213                                                                                                      is_end_include=True,  # 最後の値も含める
#    214                                                                                                      to_tokyo=True,  #必ずTrueに
#    215                                                                                                      ).loc[:,use_column_name]
#    216
#    217                                                       # 領域を営業日日中に変更
#    218
#    219
#    220                                                       self.episode_series = extract_workdays_intraday_jp(episode_series, return_as="df")
#    221
#    222
#    223
#    224                                                       # 領域にnanが入っているか判定
#    225                                                       if self.episode_series.isnull().sum() > 0:
#    226                                                           IsNan = True
#    227                                                       else:
#    228                                                           IsNan = False
#    229
#    230
#    231                                                       # すべて取得できたか判定(データが存在しないか判定)
#    232                                                       part_datetime_bool = (episode_start_datetime <= self.all_datetime_index) & (self.all_datetime_index <= episode_end_datetime)  # 最後も含める
#    233                                                       part_datetime_index = self.all_datetime_index[part_datetime_bool].copy()
#    234
#    235                                                       if not self.episode_series.index.equals(part_datetime_index):  # 同一判定
#    236                                                           IsCannotGet = True
#    237                                                       else:
#    238                                                           IsCannotGet = False
#    239
#    240                                                       iter_counter += 1
#    241
#    242                                                       # nanが入っておらず，全て取得できた場合．あるいは補間する場合，あるいは日時・もしくはstock_nameが与えられた場合
#    243                                                       if ((not IsNan) and (not IsCannotGet)) or self.interpolate or (select_datetime is not None or stock_name is not None):
#    244                                                           break
#    245
#    246                                                   # 線形補間
#    247                                                   if (self.interpolate or (select_datetime is not None or select_stock_name is not None)) and (IsNan or IsCannotGet):  # 補間の必要性がある場合
#    248
#    249                                                       if IsCannotGet:  # データが存在しない場合
#    250                                                           # part_datetime_indexに含まれて，self.episode_series.indexに含まれないdatetime
#    251                                                           add_datetime_indice = np.setdiff1d(part_datetime_index.to_pydatetime(), self.episode_series.index.to_pydatetime())
#    252                                                           add_series = pd.Series(index=add_datetime_indice,dtype=np.float64)  # nameは指定しなくてもOK, 値はnan
#    253                                                           new_episode_series = pd.concat([self.episode_series, add_series]).sort_index()  # 存在しないデータがnanで補間
#    254                                                           self.episode_series = new_episode_series
#    255
#    256                                                       # 線形補間
#    257                                                       self.episode_series.interpolate(limit_direction="both",inplace=True)
#    258
#    259
#    260                                                   cash = self.initial_cash  # 現金
#    261                                                   unit_number = self.initial_unit  # 保有単元数
#    262
#    263                                                   # 状態で利用する部分を取得
#    264                                                   #state_datetimes = [self.all_datetime_index[episode_start_datetime_index+add_index].to_pydatetime() for add_index in self.state_time_list]  # datetime.datetimeに変更
#    265                                                   state_datetimes = [self.all_datetime_index[episode_start_datetime_index+add_index] for add_index in self.state_time_list]  # pd.Timestampのリスト
#    266
#    267                                                   state_prices_bool_array = self.episode_series.index.isin(state_datetimes)
#    268
#    269                                                   state_prices_series = self.episode_series.loc[state_prices_bool_array].copy()
#    270                                                   state_prices_array = state_prices_series.values
#    271
#    272                                                   now_price = state_prices_array[0]  # 最初は現在の価格
#    273
#    274                                                   #mean_cost_price = now_price  # unit数にかかわらず，最初の平均取得価格は現在価格(unit数が0のときも含める)
#    275                                                   #random_index = RandomState(self.mcp_seed_number).randint(0, len(self.episode_series.index))  # 既存のseedと区別するため，+1
#    276                                                   #mean_cost_price = self.episode_series.loc[self.episode_series.index[random_index]]  # 平均取得価格はランダムに決める
#    277                                                   mean_cost_price = now_price + 5 * RandomState(self.mcp_seed_number).randn(1).item()  # intにするため
#    278
#    279                                                   all_property = cash + now_price * unit_number * self.one_unit_stocks
#    280
#    281                                                   # 現状態をアトリビュートとして保持
#    282                                                   self.state = StockState(cash=cash,
#    283                                                                           unit_number=unit_number,
#    284                                                                           mean_cost_price=mean_cost_price,
#    285                                                                           all_property=all_property,
#    286                                                                           price_array=state_prices_array
#    287                                                                          )
#    288
#    289                                                   self.now_datetime = episode_start_datetime  # 現時間
#    290                                                   self.info = {"datetime":self.now_datetime,
#    291                                                                "stock_name":stock_name,
#    292                                                                "done_active":None,
#    293                                                                "iter_counter":iter_counter,
#    294                                                                "penalty":0,
#    295                                                                "gein_reward":0,
#    296                                                                "price_reward":0,
#    297                                                                "all_property_reward":0,
#    298                                                                "reward":0,
#    299                                                               }
#    300
#    301                                                   self.now_index = episode_start_datetime_index  # 現時間のインデックス
#    302                                                   self.stock_name = stock_name  # 現銘柄コード
#    303                                                   self.step_counter = 1  # ステップ数のカウンタ
#    304                                                   done = False  # ここではもちろんFalse
#    305
#    306                                                   # エラー処理で利用
#    307                                                   self.steps_beyond_done = None
#    308
#    309                                                   return self.state.copy(), 0, done, self.info  # 一応stateをコピー
#
# Total time: 0 s
# File: <ipython-input-22-ab1a00779c1a>
# Function: step at line 311
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    311                                               def step(self, action):
#    312                                                   #assert self.action_space.contains(action), "action {} ({}) invalid".format(action, type(action))
#    313
#    314                                                   state = self.state
#    315
#    316                                                   cash = state.cash
#    317                                                   unit_number = state.unit_number
#    318                                                   mean_cost_price = state.mean_cost_price
#    319                                                   all_property = state.all_property
#    320                                                   prices = state.price_array  # 使わない？
#    321
#    322                                                   # インデックスを更新
#    323                                                   now_index = self.now_index + 1
#    324                                                   now_datetime = self.all_datetime_index[now_index].to_pydatetime()  # infoで利用
#    325
#    326                                                   state_datetimes = [self.all_datetime_index[now_index+add_index] for add_index in self.state_time_list]  # pd.Timestampのまま
#    327
#    328                                                   state_prices_bool_array = self.episode_series.index.isin(state_datetimes)
#    329
#    330                                                   state_prices_series = self.episode_series.loc[state_prices_bool_array].copy()
#    331                                                   state_prices_array = state_prices_series.values
#    332
#    333                                                   # 行動の制約条件（現金より多くかえない，保持数より多くは売れない)
#    334                                                   now_price = state_prices_array[0]  # state_priceの最初は必ずnowでなければならない
#    335                                                   cliped_cash = max(0, cash)  # 条件判定はマイナスを除く
#    336                                                   buy_condition_bool = (cliped_cash - now_price * self.action_class_array * self.one_unit_stocks) >= 0  # 買い条件を満たしたブール, キャッシュがマイナスの時，0にする
#    337                                                   buy_condition_true_max_index = buy_condition_bool.sum() - 1  # 条件を満たした最大値のインデックス
#    338                                                   if buy_condition_true_max_index < 0:  # -1になってしまった場合
#    339                                                       buy_condition_true_max_index = 0
#    340
#    341                                                   cliped_unit_number = max(0, unit_number)
#    342                                                   sell_condition_bool = (cliped_unit_number + self.action_class_array) > 0  # 売り条件を満たしたブール．unit_numberがマイナスの時，0にする
#    343                                                   sell_condition_true_min_index = (~sell_condition_bool).sum() - 1  # 条件を満たした最小値のインデックス
#    344                                                   if sell_condition_true_min_index < 0:  # -1になってしまった場合
#    345                                                       sell_condition_true_min_index = 0
#    346
#    347                                                   # 行動の制約を厳密化
#    348                                                   if self.action_restriction:
#    349                                                       if action < self.stay_index:  # 売りの場合
#    350                                                           if action < sell_condition_true_min_index:  # 行動が最小条件より下になった場合
#    351                                                               action = sell_condition_true_min_index
#    352
#    353                                                       elif action > self.stay_index:  # 買いの場合
#    354                                                           if action > buy_condition_true_max_index:  # 行動が最大条件より上になった場合
#    355                                                               action = buy_condition_true_max_index
#    356
#    357                                                       # それ以外(ステイ)はそのまま
#    358
#    359                                                   penalty = 0
#    360
#    361                                                   # 行動ペナルティ
#    362                                                   # 売買条件ペナルティ
#    363                                                   trading_penalty = self.get_trading_penalty(sell_condition_true_min_index, buy_condition_true_max_index, action)
#    364                                                   penalty += trading_penalty
#    365
#    366                                                   # ステイペナルティ
#    367                                                   stay_penalty = self.get_stay_penalty(cash, action, unit_number)
#    368                                                   penalty += stay_penalty
#    369
#    370                                                   # 平均取得価格と現在価格が近いときのペナルティ
#    371                                                   #mca_np_diff_penalty = self.get_mcp_np_diff_penalty(mean_cost_price, now_price)
#    372                                                   #penalty += mca_np_diff_penalty
#    373
#    374                                                   # マイナスペナルティ
#    375                                                   minus_penalty = self.get_minus_penalty(unit_number, cash, now_price)
#    376                                                   penalty += minus_penalty
#    377
#    378                                                   # ペナルティのチェック
#    379                                                   if penalty > 0:
#    380                                                       raise Exception("penalty must be minus")
#    381
#    382                                                   # 追加単元数
#    383                                                   add_unit_number = self.action_class_array[action]  # actionはint?
#    384
#    385                                                   # 状態の計算に必要な報酬
#    386                                                   gein_reward = self.get_gein_reward(now_price, add_unit_number)  # 株式売買による報酬
#    387                                                   price_reward = self.get_price_reward(now_price, mean_cost_price, add_unit_number)  # 平均取得価格による報酬
#    388
#    389                                                   # 状態の更新
#    390                                                   new_unit_number = unit_number + add_unit_number
#    391                                                   new_cash = cash + gein_reward  # 手数料はない
#    392
#    393                                                   # 平均取得価格の計算
#    394                                                   if add_unit_number > 0:  # 買いの場合
#    395                                                       num = cliped_unit_number * mean_cost_price + add_unit_number * now_price
#    396                                                       den = (cliped_unit_number + add_unit_number)
#    397                                                       new_mean_cost_price = num / den
#    398                                                   elif add_unit_number <= 0:  # ステイ・売りの場合
#    399                                                       if unit_number <= 0:  # ユニット数が0以下である場合
#    400                                                           new_mean_cost_price = now_price  # 現在価格とする．
#    401                                                       else:
#    402                                                           new_mean_cost_price = mean_cost_price  # 元のまま
#    403
#    404
#    405                                                   new_all_property = new_cash + now_price * new_unit_number * self.one_unit_stocks  # 全資産
#    406
#    407                                                   self.state = StockState(cash=new_cash,
#    408                                                                           unit_number=new_unit_number,
#    409                                                                           mean_cost_price=new_mean_cost_price,
#    410                                                                           all_property=new_all_property,
#    411                                                                           price_array=state_prices_array
#    412                                                                          )
#    413
#    414                                                   # 学習に利用する報酬
#    415                                                   all_property_reward = self.get_all_property_reward(all_property, new_all_property)  # 全資産による報酬
#    416                                                   reward = self.gein_reward_weight * gein_reward + self.price_reward_weight * price_reward +  self.penalty_weight * penalty
#    417                                                   reward += self.all_property_reward_weight * all_property_reward # 重み
#    418
#    419
#    420                                                   self.now_datetime = now_datetime
#    421
#    422                                                   self.info = {"datetime":self.now_datetime,
#    423                                                                "stock_name":self.stock_name,
#    424                                                                "done_action":action,
#    425                                                                "penalty":penalty,
#    426                                                                "gein_reward":gein_reward,
#    427                                                                "price_reward":price_reward,
#    428                                                                "all_property_reward":all_property_reward,
#    429                                                                "reward":reward,
#    430                                                               }  # stock_nameを入れる意味ある？
#    431
#    432                                                   self.now_index = now_index
#    433                                                   self.step_counter += 1
#    434
#    435                                                   # doneの更新
#    436                                                   done = (self.step_counter >= self.episode_length) or (new_all_property < self.low_limmit)
#    437
#    438                                                   # エピソードが終了して，resetが呼ばれる前にstepが呼ばれた時のエラー判定
#    439                                                   if done:
#    440                                                       if self.steps_beyond_done is None:
#    441                                                           self.steps_beyond_done = 0  # 0 に初期化
#    442
#    443                                                       elif self.steps_beyond_done == 0:  # 0の時のみロギング
#    444                                                           logger.warn(
#    445                                                               "You are calling 'step()' even though this "
#    446                                                               "environment has already returned done = True. You"
#    447                                                               "should always call 'reset()' once you receive 'done ="
#    448                                                               "True' -- any further steps are undefined behavior"
#    449                                                           )
#    450                                                           self.steps_beyond_done += 1
#    451
#    452                                                   return self.state.copy(), reward, done, self.info  # 一応stateをコピー
#
# Total time: 0 s
# File: <ipython-input-22-ab1a00779c1a>
# Function: get_gein_reward at line 454
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    454                                               def get_gein_reward(self, now_price, add_unit_number):
#    455                                                   """
#    456                                                   株式の売却による利益を意味する報酬
#    457                                                   """
#    458                                                   gein_reward = now_price * self.one_unit_stocks * (- add_unit_number) # 買いがプラスであるため，マイナスをかける．cashの計算に利用する．
#    459                                                   return gein_reward
#
# Total time: 0 s
# File: <ipython-input-22-ab1a00779c1a>
# Function: get_price_reward at line 461
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    461                                               def get_price_reward(self, now_price, mean_cost_price, add_unit_number):
#    462                                                   """
#    463                                                   平均取得価格と現在価格とその売買に関係する報酬
#    464                                                   """
#    465                                                   price_reward = (now_price - mean_cost_price) * self.one_unit_stocks * (- add_unit_number)
#    466                                                   return price_reward
#
# Total time: 0 s
# File: <ipython-input-22-ab1a00779c1a>
# Function: get_all_property_reward at line 468
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    468                                               def get_all_property_reward(self, pre_all_property, new_all_property):
#    469                                                   """
#    470                                                   全資産による報酬
#    471                                                   """
#    472                                                   all_property_reward = new_all_property - pre_all_property
#    473                                                   return all_property_reward
#
# Total time: 0 s
# File: <ipython-input-22-ab1a00779c1a>
# Function: get_trading_penalty at line 475
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    475                                               def get_trading_penalty(self, sell_condition_index, buy_condition_index, action):
#    476                                                   """
#    477                                                   売買条件を制限するペナルティ．
#    478                                                   """
#    479                                                   penalty = 0
#    480                                                   # 売買条件ペナルティ
#    481                                                   if action < self.stay_index:  # 売りの場合
#    482                                                       if action < sell_condition_index:  # 行動が最小条件より下になった場合
#    483                                                           prepenalty = - (sell_condition_index - action) * self.initial_cash * 0
#    484                                                           assert prepenalty <= 0,"this penalty must be minus {}".format(prepenalty)
#    485                                                           penalty += prepenalty
#    486
#    487                                                   elif action > self.stay_index:  # 買いの場合
#    488                                                       if action > buy_condition_index:  # 行動が最大条件より上になった場合
#    489                                                           prepenalty = - (action - buy_condition_index) * self.initial_cash * 0
#    490                                                           assert prepenalty <= 0,"this penalty must be minus {}".format(prepenalty)
#    491                                                           penalty += prepenalty
#    492                                                   return penalty
#
# Total time: 0 s
# File: <ipython-input-22-ab1a00779c1a>
# Function: get_stay_penalty at line 494
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    494                                               def get_stay_penalty(self, cash, action, unit_number):
#    495                                                   penalty = 0
#    496                                                   condition_list = []
#    497                                                   low_unit_stay_condition = action == self.stay_index and unit_number < self.stay_penalty_unit_bound  # 行動がステイかつユニット数が閾値以下の場合
#    498                                                   condition_list.append(low_unit_stay_condition)
#    499                                                   low_cash_stay_condition = action == self.stay_index and cash < self.stay_penalty_cash_bound  # 行動がステイかつ現金が閾値以下の場合
#    500                                                   condition_list.append(low_cash_stay_condition)
#    501
#    502                                                   if any(condition_list):  # 条件のどれかが当てはまる場合
#    503                                                       #prepenalty = cash * (-0.10)  # 現金のx%のペナルティ
#    504                                                       #prepenalty = - self.initial_cash * 0
#    505                                                       prepenalty = -self.penalty_const
#    506                                                       penalty += prepenalty
#    507
#    508                                                   prepenalty = - cash * 0.0  # 条件に関わらないペナルティ
#    509                                                   penalty += prepenalty
#    510
#    511                                                   return penalty
#
# Total time: 0 s
# File: <ipython-input-22-ab1a00779c1a>
# Function: get_mcp_np_diff_penalty at line 513
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    513                                               def get_mcp_np_diff_penalty(self, mean_cost_price, now_price):
#    514                                                   penalty = 0
#    515                                                   mcp_np_diff = abs(now_price-mean_cost_price)
#    516                                                   if mcp_np_diff < self.penalty_mcp_np_diff_bound:
#    517                                                       prepenalty = - self.initial_cash * 0.1
#    518                                                       penalty += prepenalty
#    519                                                   return penalty
#
# Total time: 0 s
# File: <ipython-input-22-ab1a00779c1a>
# Function: get_minus_penalty at line 521
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    521                                               def get_minus_penalty(self, unit_number, cash, now_price):
#    522                                                   penalty = 0
#    523                                                   if unit_number < 0:
#    524                                                       minus_abs_unit = abs(unit_number)
#    525                                                       #prepenalty = - self.initial_cash * 10 * minus_abs_unit
#    526                                                       prepenalty = - self.penalty_const
#    527                                                       penalty += prepenalty
#    528
#    529                                                   if cash < 0:
#    530                                                       minus_abs_cash = abs(cash)
#    531                                                       minus_abs_cash_as_unit = minus_abs_cash / (self.one_unit_stocks * now_price)
#    532                                                       #prepenalty = - self.initial_cash * 10 * minus_abs_cash_as_unit
#    533                                                       prepenalty = -self.penalty_const
#    534                                                       penalty += prepenalty
#    535
#    536                                                   return penalty
#
# Total time: 0 s
# File: <ipython-input-22-ab1a00779c1a>
# Function: close at line 538
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    538                                               def close(self):
#    539                                                   """
#    540                                                   ビューのクローズとseedのリセット
#    541                                                   """
#    542                                                   if self.use_view:
#    543                                                       self.stock_view.close()
#    544                                                   self.seed()  # シードの初期化
#
# Total time: 0 s
# File: <ipython-input-22-ab1a00779c1a>
# Function: seed at line 546
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    546                                               def seed(self, initial_seed=None, mcp_seed=None):
#    547                                                   """
#    548                                                   reset時のサンプリングのseedを設定する．リセットの場合，何も指定しないかNoneを指定
#    549                                                   """
#    550                                                   self.initial_seed_number = initial_seed
#    551                                                   self.mcp_seed_number = mcp_seed
#
# Total time: 0 s
# File: <ipython-input-22-ab1a00779c1a>
# Function: set_weight at line 554
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    554                                               def set_weight(self, gein_reward_weight=0, price_reward_weight=1, penalty_weight=1, all_property_reward_weight=1):
#    555                                                   self.gein_reward_weight = gein_reward_weight
#    556                                                   self.price_reward_weight = price_reward_weight
#    557                                                   self.all_property_reward_weight = all_property_reward_weight
#    558                                                   self.penalty_weight = penalty_weight
#
# Total time: 0 s
# File: <ipython-input-40-e4b20cf6b554>
# Function: episode at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def episode(env, agent, state_transform=None, reward_transform=None, print_span=None, is_observe=True):
#      2                                               state_list = []
#      3                                               info_list = []
#      4                                               action_list = []
#      5
#      6                                               obs,_,_,info = env.reset()
#      7
#      8                                               state_list.append(obs)
#      9                                               info_list.append(info)
#     10                                               R = 0
#     11                                               t = 1
#     12                                               if print_span is not None:
#     13                                                   print("\tt:{},all_property:{}, unit_number:{}, price:{}, penalty:{}, cash:{}".format(t,
#     14                                                                                                                                        obs.all_property,
#     15                                                                                                                                        obs.unit_number,
#     16                                                                                                                                        obs.now_price,
#     17                                                                                                                                        info["penalty"],
#     18                                                                                                                                        obs.cash
#     19                                                                                                                                       ))
#     20
#     21                                               if state_transform is not None:
#     22                                                   normalized_obs = state_transform(obs)
#     23                                               else:
#     24                                                   normalized_obs = obs
#     25
#     26                                               while True:
#     27                                                   action = agent.act(normalized_obs)
#     28                                                   action_list.append(action)
#     29                                                   obs, reward, done, info = env.step(action)
#     30                                                   R += reward
#     31                                                   t += 1
#     32                                                   reset = False
#     33
#     34                                                   # state, rewardの前処理
#     35                                                   if state_transform is not None:
#     36                                                       normalized_obs = state_transform(obs)
#     37                                                   else:
#     38                                                       normalized_obs = obs
#     39                                                   if reward_transform is not None:
#     40                                                       normalized_reward = reward_transform(reward)
#     41                                                   else:
#     42                                                       normalized_reward = reward
#     43
#     44                                                   if is_observe:  # 観測(学習)する場合
#     45                                                       agent.observe(normalized_obs, normalized_reward, done, reset)
#     46
#     47                                                   state_list.append(obs)
#     48                                                   info_list.append(info)
#     49
#     50                                                   if done or reset:
#     51                                                       break
#     52                                                   if print_span is not None:
#     53                                                       if t%print_span==0:
#     54                                                           print("\tt:{},all_property:{}, unit_number:{}, price:{}, penalty:{}, cash:{}".format(t,
#     55                                                                                                                                                obs.all_property,
#     56                                                                                                                                                obs.unit_number,
#     57                                                                                                                                                obs.now_price,
#     58                                                                                                                                                info["penalty"],
#     59                                                                                                                                                obs.cash
#     60                                                                                                                                               ))
#     61                                                           print("\taction_counter:",collections.Counter(action_list))
#     62
#     63                                               if print_span is not None:
#     64                                                   print("\tt:{},all_property:{}, unit_number:{}, price:{}, penalty:{}, cash:{}".format(t,
#     65                                                                                                                                        obs.all_property,
#     66                                                                                                                                        obs.unit_number,
#     67                                                                                                                                        obs.now_price,
#     68                                                                                                                                        info["penalty"],
#     69                                                                                                                                        obs.cash
#     70                                                                                                                                       ))
#     71                                                   print("\taction_counter:",collections.Counter(action_list))
#     72                                                   print("finished. episode length: {}".format(t))
#     73                                               return state_list, info_list, action_list

# %% [markdown]
# #### メモリのプロファイリング

# %% [markdown]
# ### 学習

# %% [markdown]
# #### 学習がうまく進んでいるか判定

# %%
lr_eval_ransac = RansacGradLearningDecider(line_number=20, point_number=4, distance_th=2, decision_rate=0.25)
lr_eval_decider = DeciderComposer([lr_eval_ransac,
                                   UnitMinusDecider(minus_ratio=0.1),
                                  ])

# %% [markdown]
# #### エージェント名

# %%
now_datetime = datetime.datetime.now()
now_str = now_datetime.strftime("%Y_%m_%d__%H_%M_%S")
agent_name = now_str

# %% [markdown]
# ####  一次保存用のオブジェクト

# %%
temp_save_dict = {"agent_name":agent_name}
temp_save_dict["initial_seed"], temp_save_dict["mcp_seed"] = seed_setter.get_seed()

# %% [markdown]
# #### 一時保存用の設定

# %%
temp_filepath = Path("training_temp.tmp")

save_funcs = [agent.save]
load_funcs = [agent.load]
func_paths = [Path("temp_agent")]

object_temp_filepath = Path("temp_save_dict")

# %% [markdown]
# #### 一時保存のロード

# %%
counter = py_restart.enable_counter(temp_filepath, each_save=True, save_span=100)

temp_save_dict = counter.save_load_object(temp_save_dict, object_temp_filepath)
counter.save_load_funcs(save_funcs=save_funcs,
                        load_funcs=load_funcs,
                        func_paths=func_paths
                        )

# %%
agent_name = temp_save_dict["agent_name"]
print(agent_name)
seed_setter.initialize(initial_seed=temp_save_dict["initial_seed"],
                       mcp_seed=temp_save_dict["mcp_seed"]
                       )
# Out:
# 2021_01_16__12_22_59

# %% [markdown]
# #### 画像を保存するディレクトリ

# %%
save_fig_dir_path = Path("tradng_process_figures") / Path(agent_name)
if not save_fig_dir_path.exists():
    save_fig_dir_path.mkdir()

# %% [markdown]
# #### 画像を保存するディレクトリ2

# %%
save_fig_dir_path2 = Path("search_result_figures") / Path(agent_name)
if not save_fig_dir_path2.exists():
    save_fig_dir_path2.mkdir()

# %% [markdown]
# #### 学習

# %%
# n_episodes = 300
n_episodes = 5000
n_search_episodes = 50

# うまく学習のできる乱数シードを探索
search_learning = True
search_counter = 0

# 一時保存がされていない場合初期探索を行う
if not temp_filepath.exists():
    while search_learning:
        seed_setter.initialize()
        seed_setter.set_seed(0)  # seedのセッティング
        agent, scheduler = initialize_agent()  # エージェントの初期化
        for i in range(1, n_search_episodes+1):
            print("\rsearch counter{}, i:{}".format(search_counter, i), end="")
            _,_,_ = episode(env, agent, state_transform=state_transform, reward_transform=None, print_span=None, is_observe=True)
        
        with agent.eval_mode():
            search_state_list, search_info_list, search_action_list = episode(env, agent, state_transform=state_transform, reward_transform=None, print_span=None, is_observe=False) 
        
        print("\nsearch_counter:{}".format(search_counter))
        print("action_counter:",collections.Counter(search_action_list))
        
        # 判定の描画
        save_image_path = save_fig_dir_path2 / Path("trading_process_initial_search_count_{}.png".format(search_counter))
        lr_eval_ransac.set_save_path(save_image_path)
        search_learning = not lr_eval_decider.decide(search_state_list, search_info_list, env)
        # 取引過程の描画
        save_image_path = save_fig_dir_path / Path("trading_process_initial_search_count_{}.png".format(search_counter))
        plot_trading_process_matplotlib(search_state_list,
                                search_info_list,
                                env,
                                title="stock_name:{},initial_seed:{},mcp_seed:{}".format(env.stock_name, env.initial_seed_number, env.mcp_seed_number),
                                save_path=save_image_path,
                                is_save=True,
                                )

        search_counter += 1

    # search結果のモデルを保存
    agent.save(Path("/content/gdrive/MyDrive/trading_rl/searched_agents")/Path(agent_name))

# 学習の初期化
#agent, scheduler = initialize_agent()  # エージェントの初期化

# 実際の学習
for i in counter(tqdm(range(1, n_episodes + 1))):
    # seedのセッティング
    seed_setter.set_seed(i)
    # temp_save_dictの更新
    temp_save_dict["initial_seed"], temp_save_dict["mcp_seed"] = seed_setter.get_seed()
    counter.object = temp_save_dict
    
    # epsilonの減衰
    #epsilon = extinction_epsilon(i)
    #explorer = pfrl.explorers.ConstantEpsilonGreedy(epsilon=epsilon, random_action_func=env.action_space.sample)
    
    #agent.explorer = explorer
    
    _,_,train_action_list = episode(env, agent, state_transform=state_transform, reward_transform=None, print_span=None, is_observe=True)
    scheduler.step()
    
    if i%100 == 0:
        print("episode:{}".format(i))
        print("action_counter:",collections.Counter(train_action_list))
    if i%500 == 0:
        print("statistics:", agent.get_statistics())
        
    # テスト(イプシロンを無視)
    if i%100 == 0:
        with agent.eval_mode():
            state_list, info_list, _ = episode(env, agent, state_transform=state_transform, reward_transform=None, print_span=1000, is_observe=False) 
        
        # 取引過程の描画
        save_image_path = save_fig_dir_path / Path("trading_process_i_{}.png".format(i))
        plot_trading_process_matplotlib(state_list,
                                info_list,
                                env,
                                title="stock_name:{},initial_seed:{},mcp_seed:{}".format(env.stock_name, env.initial_seed_number, env.mcp_seed_number),
                                save_path=save_image_path,
                                is_save=True,
                                )
        # モデルの保存
        agent.save(Path("/content/gdrive/MyDrive/trading_rl/agents")/Path(agent_name))


print("Finshed")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5000.0), HTML(value='')))
# episode:700
# action_counter: Counter({0: 146, 10: 116, 9: 40, 4: 24, 5: 22, 7: 18, 8: 11, 2: 11, 6: 11, 1: 10, 3: 10})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12348280.0, unit_number:168, price:1115.0, penalty:0.0, cash:8601880.0
# 	action_counter: Counter({0: 172, 10: 119, 9: 70, 7: 17, 8: 13, 5: 13, 4: 9, 3: 4, 6: 1, 1: 1})
# finished. episode length: 420
# episode:800
# action_counter: Counter({0: 141, 10: 93, 8: 45, 9: 37, 3: 18, 6: 18, 5: 16, 7: 13, 1: 13, 4: 13, 2: 12})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12419820.0, unit_number:180, price:1115.0, penalty:0.0, cash:8405820.0
# 	action_counter: Counter({0: 166, 10: 134, 9: 48, 5: 40, 8: 20, 7: 3, 4: 3, 1: 2, 3: 2, 2: 1})
# finished. episode length: 420
# episode:900
# action_counter: Counter({0: 152, 10: 118, 9: 39, 5: 22, 8: 21, 4: 13, 2: 13, 7: 13, 3: 12, 1: 10, 6: 6})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12385340.0, unit_number:106, price:1115.0, penalty:0.0, cash:10021540.0
# 	action_counter: Counter({0: 165, 10: 114, 9: 54, 8: 46, 1: 22, 5: 11, 3: 4, 7: 2, 4: 1})
# finished. episode length: 420
# episode:1000
# action_counter: Counter({0: 147, 10: 93, 9: 62, 8: 27, 4: 15, 2: 14, 6: 14, 7: 13, 3: 13, 5: 11, 1: 10})
# statistics: [('average_q', -58.73), ('average_loss', 10755.017002563476), ('cumulative_steps', 465167), ('n_updates', 464667), ('rlen', 465167)]
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12480040.0, unit_number:150, price:1115.0, penalty:0.0, cash:9135040.0
# 	action_counter: Counter({0: 169, 10: 146, 5: 38, 9: 36, 8: 11, 4: 7, 6: 5, 1: 4, 7: 3})
# finished. episode length: 420
# episode:1100
# action_counter: Counter({0: 141, 10: 112, 9: 42, 8: 27, 1: 25, 7: 22, 3: 14, 4: 11, 6: 10, 5: 10, 2: 5})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12375940.0, unit_number:206, price:1115.0, penalty:0.0, cash:7782140.0
# 	action_counter: Counter({0: 158, 10: 133, 5: 50, 9: 49, 8: 19, 1: 7, 7: 3})
# finished. episode length: 420
# episode:1200
# action_counter: Counter({0: 125, 10: 114, 5: 41, 9: 35, 8: 25, 1: 20, 4: 20, 7: 15, 6: 10, 3: 7, 2: 7})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12440800.0, unit_number:1849, price:1115.0, penalty:-100000.0, cash:-28791900.0
# 	action_counter: Counter({10: 370, 0: 30, 9: 13, 7: 2, 1: 2, 5: 1, 6: 1})
# finished. episode length: 420
# episode:1300
# action_counter: Counter({0: 111, 10: 99, 1: 50, 9: 42, 8: 31, 5: 26, 6: 20, 7: 18, 2: 10, 3: 9, 4: 3})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12365820.0, unit_number:183, price:1115.0, penalty:0.0, cash:8284920.0
# 	action_counter: Counter({0: 137, 10: 133, 5: 73, 9: 43, 1: 22, 8: 7, 7: 2, 2: 2})
# finished. episode length: 420
# episode:1400
# action_counter: Counter({10: 111, 0: 98, 1: 54, 9: 41, 5: 37, 6: 15, 4: 15, 3: 14, 2: 14, 8: 12, 7: 8})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12429820.0, unit_number:1825, price:1115.0, penalty:-100000.0, cash:-28267680.0
# 	action_counter: Counter({10: 363, 1: 21, 5: 16, 0: 9, 9: 9, 8: 1})
# finished. episode length: 420
# episode:1500
# action_counter: Counter({10: 104, 0: 82, 1: 78, 9: 32, 8: 29, 5: 25, 6: 19, 2: 13, 7: 13, 4: 13, 3: 11})
# statistics: [('average_q', -2607.3157), ('average_loss', 27629.95280517578), ('cumulative_steps', 674667), ('n_updates', 674167), ('rlen', 674667)]
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12360600.0, unit_number:98, price:1115.0, penalty:0.0, cash:10175200.0
# 	action_counter: Counter({10: 149, 0: 99, 1: 96, 5: 37, 9: 27, 8: 6, 7: 4, 3: 1})
# finished. episode length: 420
# episode:1600
# action_counter: Counter({10: 124, 0: 90, 1: 73, 9: 38, 5: 19, 8: 18, 7: 16, 3: 16, 2: 10, 6: 9, 4: 6})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12460920.0, unit_number:215, price:1115.0, penalty:0.0, cash:7666420.0
# 	action_counter: Counter({10: 126, 1: 102, 5: 68, 0: 61, 9: 35, 8: 18, 4: 4, 7: 3, 6: 2})
# finished. episode length: 420
# episode:1700
# action_counter: Counter({10: 108, 0: 107, 1: 54, 9: 40, 5: 36, 8: 18, 7: 17, 3: 12, 2: 11, 6: 9, 4: 7})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12445720.0, unit_number:1807, price:1115.0, penalty:-100000.0, cash:-27850380.0
# 	action_counter: Counter({10: 364, 1: 21, 0: 15, 9: 10, 5: 6, 7: 3})
# finished. episode length: 420
# episode:1800
# action_counter: Counter({10: 102, 0: 83, 1: 63, 9: 41, 5: 40, 8: 28, 4: 14, 6: 14, 7: 13, 2: 12, 3: 9})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12327520.0, unit_number:983, price:1115.0, penalty:-100000.0, cash:-9593380.0
# 	action_counter: Counter({10: 237, 0: 100, 9: 49, 5: 12, 8: 9, 1: 8, 7: 3, 6: 1})
# finished. episode length: 420
# episode:1900
# action_counter: Counter({10: 109, 0: 77, 1: 74, 9: 43, 8: 30, 5: 24, 7: 18, 3: 14, 2: 13, 4: 10, 6: 7})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12445020.0, unit_number:1803, price:1115.0, penalty:-100000.0, cash:-27761880.0
# 	action_counter: Counter({10: 359, 1: 25, 0: 13, 9: 13, 7: 4, 8: 4, 6: 1})
# finished. episode length: 420
# episode:2000
# action_counter: Counter({10: 107, 1: 83, 0: 81, 9: 44, 8: 26, 5: 19, 4: 15, 2: 13, 7: 11, 3: 10, 6: 10})
# statistics: [('average_q', 1729.974), ('average_loss', 10529.49023010254), ('cumulative_steps', 884167), ('n_updates', 883667), ('rlen', 884167)]
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12443040.0, unit_number:1823, price:1115.0, penalty:-100000.0, cash:-28209860.0
# 	action_counter: Counter({10: 361, 1: 24, 9: 14, 0: 12, 8: 4, 7: 3, 5: 1})
# finished. episode length: 420
# episode:2100
# action_counter: Counter({10: 114, 0: 92, 1: 80, 9: 36, 4: 18, 5: 18, 7: 16, 8: 16, 3: 11, 6: 10, 2: 8})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12438920.0, unit_number:1794, price:1115.0, penalty:-100000.0, cash:-27567280.0
# 	action_counter: Counter({10: 358, 1: 20, 0: 16, 9: 12, 5: 6, 7: 3, 8: 3, 6: 1})
# finished. episode length: 420
# episode:2200
# action_counter: Counter({10: 109, 1: 87, 0: 84, 9: 35, 8: 19, 5: 19, 4: 18, 7: 17, 6: 12, 3: 10, 2: 9})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12433880.0, unit_number:1794, price:1115.0, penalty:-100000.0, cash:-27572320.0
# 	action_counter: Counter({10: 355, 1: 24, 0: 14, 9: 13, 8: 8, 7: 4, 6: 1})
# finished. episode length: 420
# episode:2300
# action_counter: Counter({0: 113, 10: 111, 1: 49, 8: 41, 9: 36, 3: 14, 2: 14, 4: 14, 6: 11, 7: 9, 5: 7})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12436660.0, unit_number:1784, price:1115.0, penalty:-100000.0, cash:-27346540.0
# 	action_counter: Counter({10: 343, 0: 27, 9: 26, 8: 10, 1: 9, 7: 3, 5: 1})
# finished. episode length: 420
# episode:2400
# action_counter: Counter({0: 91, 10: 72, 8: 55, 9: 55, 1: 54, 7: 22, 3: 19, 4: 18, 2: 16, 5: 9, 6: 8})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12365960.0, unit_number:120, price:1115.0, penalty:0.0, cash:9689960.0
# 	action_counter: Counter({0: 145, 10: 101, 9: 65, 1: 38, 8: 38, 7: 15, 4: 6, 5: 5, 3: 4, 6: 2})
# finished. episode length: 420
# episode:2500
# action_counter: Counter({0: 109, 10: 76, 8: 60, 1: 47, 9: 33, 5: 22, 7: 17, 3: 17, 6: 16, 2: 11, 4: 11})
# statistics: [('average_q', 7773.978), ('average_loss', 6093.644841308594), ('cumulative_steps', 1093667), ('n_updates', 1093167), ('rlen', 1000000)]
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12418360.0, unit_number:1821, price:1115.0, penalty:-100000.0, cash:-28189940.0
# 	action_counter: Counter({10: 318, 9: 53, 0: 22, 8: 14, 5: 6, 1: 4, 6: 1, 7: 1})
# finished. episode length: 420
# episode:2600
# action_counter: Counter({0: 114, 10: 91, 8: 49, 1: 46, 9: 41, 4: 17, 7: 15, 3: 14, 5: 12, 2: 12, 6: 8})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12425140.0, unit_number:125, price:1115.0, penalty:0.0, cash:9637640.0
# 	action_counter: Counter({0: 149, 10: 97, 9: 60, 8: 45, 5: 30, 1: 20, 4: 8, 7: 5, 3: 3, 2: 2})
# finished. episode length: 420
# episode:2700
# action_counter: Counter({0: 100, 10: 95, 1: 57, 9: 43, 8: 36, 3: 23, 6: 17, 5: 16, 2: 12, 4: 11, 7: 9})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12355200.0, unit_number:134, price:1115.0, penalty:0.0, cash:9367000.0
# 	action_counter: Counter({1: 96, 10: 94, 0: 77, 8: 62, 9: 52, 3: 32, 4: 3, 7: 3})
# finished. episode length: 420
# episode:2800
# action_counter: Counter({0: 113, 10: 92, 9: 39, 8: 37, 1: 35, 5: 20, 3: 19, 4: 19, 6: 17, 2: 15, 7: 13})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12444660.0, unit_number:148, price:1115.0, penalty:0.0, cash:9144260.0
# 	action_counter: Counter({0: 128, 10: 103, 5: 60, 9: 48, 8: 35, 1: 32, 7: 4, 6: 4, 4: 3, 2: 1, 3: 1})
# finished. episode length: 420
# episode:2900
# action_counter: Counter({0: 103, 10: 99, 1: 41, 8: 33, 9: 31, 4: 27, 7: 23, 3: 17, 5: 17, 2: 15, 6: 13})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12292900.0, unit_number:112, price:1115.0, penalty:0.0, cash:9795300.0
# 	action_counter: Counter({10: 84, 0: 77, 9: 66, 4: 62, 1: 52, 3: 21, 8: 18, 2: 14, 5: 14, 6: 9, 7: 2})
# finished. episode length: 420
# episode:3000
# action_counter: Counter({10: 102, 0: 76, 1: 52, 3: 35, 5: 28, 6: 26, 9: 26, 8: 22, 4: 21, 7: 16, 2: 15})
# statistics: [('average_q', 9702.806), ('average_loss', 5757.081360473633), ('cumulative_steps', 1303167), ('n_updates', 1302667), ('rlen', 1000000)]
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12383180.0, unit_number:176, price:1115.0, penalty:0.0, cash:8458380.0
# 	action_counter: Counter({10: 129, 0: 122, 9: 40, 1: 40, 8: 24, 5: 22, 4: 21, 3: 8, 6: 5, 7: 5, 2: 3})
# finished. episode length: 420
# episode:3100
# action_counter: Counter({10: 109, 0: 83, 1: 46, 4: 44, 9: 28, 5: 24, 7: 22, 8: 22, 2: 15, 6: 13, 3: 13})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12342940.0, unit_number:201, price:1115.0, penalty:0.0, cash:7860640.0
# 	action_counter: Counter({10: 134, 0: 92, 1: 73, 8: 35, 9: 30, 4: 29, 2: 7, 7: 6, 5: 5, 3: 4, 6: 4})
# finished. episode length: 420
# episode:3200
# action_counter: Counter({10: 97, 0: 75, 4: 52, 1: 45, 7: 32, 9: 28, 5: 27, 3: 23, 8: 16, 6: 12, 2: 12})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12334200.0, unit_number:214, price:1115.0, penalty:0.0, cash:7562000.0
# 	action_counter: Counter({10: 142, 0: 113, 4: 58, 1: 32, 9: 30, 8: 13, 7: 12, 5: 8, 2: 6, 3: 5})
# finished. episode length: 420
# episode:3300
# action_counter: Counter({10: 105, 0: 99, 4: 49, 9: 31, 1: 29, 8: 25, 7: 23, 5: 17, 3: 15, 2: 14, 6: 12})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12340800.0, unit_number:170, price:1115.0, penalty:0.0, cash:8549800.0
# 	action_counter: Counter({10: 141, 0: 121, 4: 79, 9: 28, 1: 22, 5: 16, 8: 6, 7: 5, 2: 1})
# finished. episode length: 420
# episode:3400
# action_counter: Counter({0: 121, 10: 96, 4: 45, 9: 39, 1: 29, 8: 24, 2: 15, 7: 13, 3: 13, 5: 13, 6: 11})
# 	t:1,all_property:12158000.0, unit_number:100, price:1079.0, penalty:0, cash:10000000.0
# 	t:420,all_property:12343380.0, unit_number:216, price:1115.0, penalty:0.0, cash:7526580.0
# 	action_counter: Counter({10: 139, 0: 115, 4: 74, 9: 28, 1: 23, 7: 13, 8: 12, 5: 11, 2: 4})
# finished. episode length: 420

# %% [markdown]
# ###  モデルの評価

# %%
with agent.eval_mode():
    seed_setter.set_seed(i)
    #env.seed()
    #env.seed(0,0)
    #env.seed(0)
    #seed_setter.set_seed(0)
    state_list, info_list, _ = episode(env, agent, state_transform=state_transform, reward_transform=reward_transform, print_span=100, is_observe=False)

# %% [markdown]
# matplotlibで描画

# %%
plot_trading_process_bokeh(state_list, 
                           info_list,
                           env,
                           title="stock_name:{},initial_seed:{},mcp_seed:{}".format(env.stock_name, env.initial_seed_number, env.mcp_seed_number),
                           is_save=False)

# %% [markdown]
# ### 環境のクローズ

# %%
env.close()

# %% [markdown]
# ### モデルの保存

# %%
agent.save(Path("agents")/Path(agent_name))
print(agent_name)
